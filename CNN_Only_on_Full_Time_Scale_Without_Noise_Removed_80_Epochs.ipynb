# %%
# this mounts your Google Drive to the Colab VM.
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# enter the foldername in your Drive where you have saved the unzipped
# assignment folder, e.g. 'cs231n/assignments/assignment3/'
FOLDERNAME = 'PROJECT/'
assert FOLDERNAME is not None, "[!] Enter the foldername."

# now that we've mounted your Drive, this ensures that
# the Python interpreter of the Colab VM can load
# python files from within it.
import sys
sys.path.append('/content/drive/My Drive/{}'.format(FOLDERNAME))

# this downloads the CIFAR-10 dataset to your Drive
# if it doesn't already exist.
#%cd /content/drive/My\ Drive/$FOLDERNAME/
#!bash get_datasets.sh
# Out:
# Mounted at /content/drive

# %%
import os 
os.chdir("/content/drive/My Drive/")
os.chdir(FOLDERNAME)
#!bash get_datasets.sh

# %%
#"neu_3.0_2.0_2.3333_Whole_Length.png".split('_')

# %%
#import sys
#!{sys.executable} -m pip install torchsummary


from torch.utils.data import Dataset,DataLoader
from torchvision import transforms
import os
import numpy as np
import time
from PIL import Image
#from PIL import ImageFile
#ImageFile.LOAD_TRUNCATED_IMAGES = True
from collections import defaultdict
import cv2
import pdb
IMG_SIZE = (200,300)

from torchvision import models
from torchsummary import summary
import copy

# %%
#dataset_train.__len__
#dataset_test.shape
#dataset_val.shape

#'''test corrupted images'''
#data_path = "/home/mandeep_stanford/cs231n_project/code/pre-processed_data/images_denoised/session1/"
#dataset_train, dataset_test, dataset_val = get_imagenet_datasets(data_path, "cpc")
#
#print(f"Number of train samplest {dataset_train.__len__()}")
#print(f"Number of samples in test split {dataset_test.__len__()}")
#
#BATCH_SIZE = 200
#
#data_loader_train = DataLoader(dataset_train, BATCH_SIZE, shuffle = True)
#data_loader_test = DataLoader(dataset_test, BATCH_SIZE, shuffle = True)
#
#
#import matplotlib.pyplot as plt
#
#fig, axes = plt.subplots(BATCH_SIZE//20,20, figsize=(6,10))
#
#for batch in data_loader_train:
#
#    print(f"Shape of batch['image'] {batch['image'].shape}")
#    print(f"Shape of batch['cls'] {batch['cls'].shape}")
#
#    for i in range(BATCH_SIZE):
#
#        col = i % 20
#        row = i // 20
#
#        img = batch['image'][i].numpy()
#
#        axes[row,col].set_axis_off()
#        #axes[row,col].set_title(batch['class_name'][i])
#        axes[row,col].imshow(np.transpose(img,(1,2,0)))
#
#    plt.show()
#
#    break

# %%
#data_path = "/home/mandeep_stanford/cs231n_project/code/pre-processed_data/images/session1/"
#data_path = "/home/mandeep_stanford/cs231n_project/code/pre-processed_data/combined_session1_2/"
data_path1 = "without_noise_cleanup/session1/"
data_path2 = "without_noise_cleanup/session2/"
data_path3 = "without_noise_cleanup/session3/"
data_path4 = "without_noise_cleanup/session4/"

#img_files = os.listdir("/home/mandeep_stanford/cs231n_project/code/pre-processed_data/images/session1/")
#img_files = os.listdir("/home/mandeep_stanford/cs231n_project/code/pre-processed_data/combined_session1_2/")
#img_files = os.listdir("/home/mandeep_stanford/cs231n_project/code/pre-processed_data/4_EMOTIONS/cb_removed/with_noise_cleanup/session1/")

pkl_file = "without_noise_cleanup_denoised_WHOLE.pkl"

# %%
import pickle
X = []
Y = []
i = 0
#extract_emotion = ['hap','sad','ang','neu','fea', 'exc', 'fru']
extract_emotion = ['hap','sad','ang','neu']
if 0:
    path = [data_path1, data_path2, data_path3, data_path4]
    for p_files in path:
        for file_name in os.listdir(p_files):
                    
            print("Working on ", i)
            i = i+1
            #if i >= 7000:
            #    break
            if "Whole" in file_name.split('_'):
              print("")
            else:
              print("Skipping ", file_name)
              continue
            cat = file_name.split('_')[0]
            if cat in extract_emotion:
                #print("")
                if cat == "hap":
                    cat = 0
                if cat == "sad":
                    cat = 1
                if cat == "ang":
                    cat = 2
                if cat == "neu":
                    cat = 3
            else:
                continue
            
            Y.append(cat)
            img = Image.open(p_files+file_name)
            img = img.convert('RGB')
            tr = transforms.Resize((200,300))
            img=tr(img)
            tr = transforms.ToTensor()
            img1 = tr(img)
            img1 = np.array(img1)
            #X=np.vstack((X,img1))
            X.append(img1)
    
            del img1
            del img
            del tr

    Y = np.asarray(Y)
    X = np.asarray(X)
    data = {}
    data["X"] = X
    data["Y"] = Y
    with open(pkl_file, 'wb') as f:
        pickle.dump(data, f)
        f.close()

# %%
import pickle
import torch
assert '.'.join(torch.__version__.split('.')[:2]) == '1.5'
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torch.utils.data import sampler
import torch.utils.data as data_utils
import torchvision.datasets as dset
import torchvision.transforms as T
import torch.nn.functional as F 
import numpy as np
#pkl_file = "/home/mandeep_stanford/cs231n_project/code/pre-processed_data/images_denoised/session1_pkl_tensor1.pkl"
data = pickle.load(open(pkl_file, 'rb'))
X = data["X"]
Y = data["Y"]

# %%
X.shape
# Out:
# (1530, 3, 200, 300)

# %%
np.unique(Y)
# Out:
# array([0, 1, 2, 3])

# %%
import numpy as np
total_images = X.shape[0]
test_data_images = np.int(total_images*0.2)
train_data_images = total_images - test_data_images
#X_train = X[0:train_data_images,-1]
#y_train = Y[0:train_data_images]
#X_test = X[train_data_images:train_data_images+test_data_images, -1]
#y_test= Y[train_data_images:train_data_images+test_data_images]

#X_train = np.asarray(X_train)
#X_test = np.asarray(X_test)
#y_train = np.asarray(y_train)
#y_test = np.asarray(y_test)

#y_train = y_train.reshape((y_train[0]))
#y_test = y_test.reshape((y_test[0]))
#print(X_train.shape)
#print(y_train.shape)
#print(X_test.shape)
#print(y_test.shape)

# %%
USE_GPU = True

dtype = torch.float32 # we will be using float throughout this tutorial

if USE_GPU and torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')

# Constant to control how frequently we print train loss
print_every = 100

print('using device:', device)
# Out:
# using device: cuda

# %%
train_data = []
keys_array = np.unique(Y)
for i in range(len(X)):
   ind = np.where(keys_array==Y[i]) 
   train_data.append([X[i], Y[i]])
print("DONE")
#dataset = data_utils.TensorDataset(train_data, batch_size=100)
print(train_data_images)
print(train_data_images+test_data_images)
loader_train = DataLoader(train_data, batch_size=64, 
                          sampler=sampler.SubsetRandomSampler(range(0,train_data_images)))

loader_val = DataLoader(train_data, batch_size=64, 
                        sampler=sampler.SubsetRandomSampler(range(train_data_images, train_data_images+test_data_images)))


#for t, (x,y) in enumerate(loader_train):
#  print(t, x, y)
# Out:
# DONE
# 1224
# 1530

# %%
print_every = 1

# %%
def check_train_accuracy(loader, model):
    #if loader.dataset.train:
    #    print('Checking accuracy on validation set')
    #else:
    #    print('Checking accuracy on test set')
    print('Checking accuracy on TRAIN set')
    num_correct = 0
    num_samples = 0
    model.eval()  # set model to evaluation mode
    with torch.no_grad():
        for x, y in loader:
            x = x.to(device=device, dtype=dtype)  # move to device, e.g. GPU
            y = y.to(device=device, dtype=torch.long)
            #pdb.set_trace()
            #y = torch.stack(y) #.to(device=device)
            #y = y.reshape((x.shape[0]))
            scores = model(x)
            _, preds = scores.max(1)
            
            num_correct += (preds == y).sum()
            num_samples += preds.size(0)
        acc = float(num_correct) / num_samples
        print('Got %d / %d correct (%.2f)' % (num_correct, num_samples, 100 * acc))
        return acc

# %%
def check_accuracy_part34(loader, model):
    #if loader.dataset.train:
    #    print('Checking accuracy on validation set')
    #else:
    #    print('Checking accuracy on test set')
    print('Checking accuracy on VAL set')
    num_correct = 0
    num_samples = 0
    model.eval()  # set model to evaluation mode
    with torch.no_grad():
        for x, y in loader:
            x = x.to(device=device, dtype=dtype)  # move to device, e.g. GPU
            y = y.to(device=device, dtype=torch.long)
            #pdb.set_trace()
            #y = torch.stack(y) #.to(device=device)
            #y = y.reshape((x.shape[0]))
            scores = model(x)
            _, preds = scores.max(1)
            
            num_correct += (preds == y).sum()
            num_samples += preds.size(0)
        acc = float(num_correct) / num_samples
        print('Got %d / %d correct (%.2f)' % (num_correct, num_samples, 100 * acc))
        return acc

# %%
def train_part34(model, optimizer, epochs=1):
    """
    Train a model on CIFAR-10 using the PyTorch Module API.
    
    Inputs:
    - model: A PyTorch Module giving the model to train.
    - optimizer: An Optimizer object we will use to train the model
    - epochs: (Optional) A Python integer giving the number of epochs to train for
    
    Returns: Nothing, but prints model accuracies during training.
    """
    acc = 0
    per_epoch_train_accuracy_list = []
    per_epoch_test_accuracy_list = []
    train_accuracy_list = []
    test_accuracy_list = []
    loss_list = []
    best_model = model = model.to(device=device)  # move the model parameters to CPU/GPU
    for e in range(epochs):
        for t, (x, y) in enumerate(loader_train):
            import pdb
            #pdb.set_trace()
            model.train()  # put model to training mode
            x = x.to(device=device, dtype=dtype)  # move to device, e.g. GPU
            y = y.to(device=device, dtype=torch.long)
            #y = torch.stack(y) #.to(device=device)
            #y = y.reshape((x.shape[0]))
            scores = model(x)
            
            loss = F.cross_entropy(scores, y)
            loss_list.append(loss.item())
            # Zero out all of the gradients for the variables which the optimizer
            # will update.
            optimizer.zero_grad()

            # This is the backwards pass: compute the gradient of the loss with
            # respect to each  parameter of the model.
            loss.backward()

            # Actually update the parameters of the model using the gradients
            # computed by the backwards pass.
            optimizer.step()
            #pdb.set_trace()
            #print("IN ITERATION", t)
            if t % print_every == 0:
                print('Epoch %d, Iteration %d, loss = %.4f' % (e, t, loss.item()))
                #pdb.set_trace()
                xx = x.cpu().data.numpy()
                yy = y.cpu().data.numpy()
                tt_data = []
                for i in range(len(xx)):
                  ind = np.where(keys_array==Y[i]) 
                  tt_data.append([xx[i], yy[i]])
                
                train_d = DataLoader(tt_data, batch_size = 1)
                
                train_acc = check_train_accuracy(train_d, model)
                train_accuracy_list.append(train_acc)
                test_acc = check_accuracy_part34(loader_val, model)
                test_accuracy_list.append(test_acc)
                if test_acc > acc:
                  acc = test_acc
                  best_model = copy.deepcopy(model)
                print()
        
        e_test_accuracy = check_accuracy_part34(loader_val, model)        
        per_epoch_test_accuracy_list.append(e_test_accuracy)     
        e_train_accuracy = check_train_accuracy(loader_train, model)        
        per_epoch_train_accuracy_list.append(e_train_accuracy)     
    return best_model, acc, train_accuracy_list, test_accuracy_list, per_epoch_train_accuracy_list, per_epoch_test_accuracy_list, loss_list

# %%
class Flatten(nn.Module):
    def flatten(x):
        N = x.shape[0] # read in N, C, H, W
        return x.view(N, -1)  # "flatten" the C * H * W values into a single vector per image

    def forward(self, x):
        N = x.shape[0]
        return x.view(N, -1)

class LSTM(nn.Module):
    def __init__(self):
        super().__init__()
        #self.model = nn.LSTM(input_size=(32*25*37),hidden_size=128,num_layers=2,batch_first=True,bidirectional =True, dropout=0.1)
        self.model = nn.RNN(input_size=(32*25*37),hidden_size=128,num_layers=2,batch_first=True,bidirectional =True, dropout=0.1)
    def forward(self, x):

        # From [batches, seqs, seq len, features]
        # to [seq len, batch data, features]
        x = x.unsqueeze(1)
       
        # Data is fed to the LSTM
        out, _ = self.model(x)

        # From [seq len, batch, num_directions * hidden_size]
        # to [batches, seqs, seq_len,prediction]
        out = out.squeeze(1)


        return out

#hidden_layer_size = 500
#learning_rate = 1e-2

#model = nn.Sequential(
#    Flatten(),
#    nn.Linear(3 * 200 * 300, hidden_layer_size),
#    nn.ReLU(),
#    nn.Linear(hidden_layer_size, keys_array.shape[0]),
#)


l1 = nn.Sequential(
            nn.Conv2d(3, 16, kernel_size=(12,16), padding=(6,8), stride=1),
            nn.ReLU(),
            #nn.Conv2d(channel_1, channel_1, kernel_size=5, padding=2, stride=1),
            nn.MaxPool2d(2, 2)
)

#for t, (x, y) in enumerate(loader_train):
#            # put model to training mode
#            x = x.to(device=device, dtype=dtype)
#            import pdb
#            pdb.set_trace()
#            break
    
#pdb.set_trace()
#h = l1(x)
#h.shape

l2 = nn.Sequential(
            nn.Conv2d(16, 24, kernel_size=(8,12), padding=(4,6), stride=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2)
)
#h = l2(h)

#l3 = nn.Sequential(
#            nn.Conv2d(24, 32, kernel_size=(5,7), padding=(2,3), stride=1),
#            nn.ReLU(),
#            nn.MaxPool2d(2, 2),
#            Flatten(),
#            LSTM()           
#)

l3 = nn.Sequential(
            nn.Conv2d(24, 32, kernel_size=(5,7), padding=(2,3), stride=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2)
            
)

#l4 = nn.Sequential(
#            nn.Conv2d(channel_3, channel_4, kernel_size=3, padding=1, stride=1),
#            nn.MaxPool2d(2, 1)
#)

#import pdb
#pdb.set_trace()
hidden_layer_size = keys_array.shape[0]
learning_rate = 1e-4 #1e-4   1e-3 looks gud
'''
model = nn.Sequential(
            l1,
            l2,
            l3,
            nn.Linear(256, 64),
            nn.ReLU(),
            nn.Dropout(p=0.2),
            nn.Linear(64, keys_array.shape[0])
)
'''
model = nn.Sequential(
            l1,
            l2,
            l3,
            Flatten(),
            nn.Linear(32*25*37, 64),
            nn.ReLU(),
            nn.Dropout(p=0.2),
            nn.Linear(64, keys_array.shape[0])
)


# you can use Nesterov momentum in optim.SGD
#optimizer = optim.Adam(model.parameters(), lr=learning_rate,momentum=0.9, nesterov=True)
optimizer = optim.Adam(model.parameters(), lr=learning_rate, 
                     betas=(0.9, 0.999), eps=1e-08, weight_decay=0, amsgrad=False) #weight_decay = 0 luks gud. Trying with 0.1


#best_model, best_test_acc, train_accuracy_list, test_accuracy_list, loss_list = train_part34(model, optimizer, 2)
best_model, best_test_acc, train_accuracy_list, test_accuracy_list, per_epoch_train_accuracy_list, per_epoch_test_accuracy_list, loss_list = train_part34(model, optimizer, 80)
print("DONE TRAINING")
# Out:
# Streaming output truncated to the last 5000 lines.
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 146 / 306 correct (47.71)
#
# Epoch 39, Iteration 15, loss = 1.0924
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 146 / 306 correct (47.71)
#
# Epoch 39, Iteration 16, loss = 1.0387
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 144 / 306 correct (47.06)
#
# Epoch 39, Iteration 17, loss = 1.3014
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 142 / 306 correct (46.41)
#
# Epoch 39, Iteration 18, loss = 1.1218
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 145 / 306 correct (47.39)
#
# Epoch 39, Iteration 19, loss = 1.3816
# Checking accuracy on TRAIN set
# Got 3 / 8 correct (37.50)
# Checking accuracy on VAL set
# Got 147 / 306 correct (48.04)
#
# Checking accuracy on VAL set
# Got 147 / 306 correct (48.04)
# Checking accuracy on TRAIN set
# Got 647 / 1224 correct (52.86)
# Epoch 40, Iteration 0, loss = 1.0243
# Checking accuracy on TRAIN set
# Got 36 / 64 correct (56.25)
# Checking accuracy on VAL set
# Got 142 / 306 correct (46.41)
#
# Epoch 40, Iteration 1, loss = 1.1140
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 137 / 306 correct (44.77)
#
# Epoch 40, Iteration 2, loss = 1.0126
# Checking accuracy on TRAIN set
# Got 39 / 64 correct (60.94)
# Checking accuracy on VAL set
# Got 134 / 306 correct (43.79)
#
# Epoch 40, Iteration 3, loss = 1.2204
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 136 / 306 correct (44.44)
#
# Epoch 40, Iteration 4, loss = 1.1203
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 134 / 306 correct (43.79)
#
# Epoch 40, Iteration 5, loss = 1.1157
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 132 / 306 correct (43.14)
#
# Epoch 40, Iteration 6, loss = 1.2022
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 132 / 306 correct (43.14)
#
# Epoch 40, Iteration 7, loss = 1.0165
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 136 / 306 correct (44.44)
#
# Epoch 40, Iteration 8, loss = 1.1724
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 140 / 306 correct (45.75)
#
# Epoch 40, Iteration 9, loss = 0.9331
# Checking accuracy on TRAIN set
# Got 36 / 64 correct (56.25)
# Checking accuracy on VAL set
# Got 137 / 306 correct (44.77)
#
# Epoch 40, Iteration 10, loss = 1.1119
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 140 / 306 correct (45.75)
#
# Epoch 40, Iteration 11, loss = 1.2253
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 140 / 306 correct (45.75)
#
# Epoch 40, Iteration 12, loss = 0.9890
# Checking accuracy on TRAIN set
# Got 45 / 64 correct (70.31)
# Checking accuracy on VAL set
# Got 142 / 306 correct (46.41)
#
# Epoch 40, Iteration 13, loss = 1.1452
# Checking accuracy on TRAIN set
# Got 36 / 64 correct (56.25)
# Checking accuracy on VAL set
# Got 141 / 306 correct (46.08)
#
# Epoch 40, Iteration 14, loss = 1.1194
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 136 / 306 correct (44.44)
#
# Epoch 40, Iteration 15, loss = 1.0546
# Checking accuracy on TRAIN set
# Got 35 / 64 correct (54.69)
# Checking accuracy on VAL set
# Got 137 / 306 correct (44.77)
#
# Epoch 40, Iteration 16, loss = 1.0740
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 140 / 306 correct (45.75)
#
# Epoch 40, Iteration 17, loss = 1.2761
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 136 / 306 correct (44.44)
#
# Epoch 40, Iteration 18, loss = 1.1181
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 135 / 306 correct (44.12)
#
# Epoch 40, Iteration 19, loss = 1.3743
# Checking accuracy on TRAIN set
# Got 4 / 8 correct (50.00)
# Checking accuracy on VAL set
# Got 143 / 306 correct (46.73)
#
# Checking accuracy on VAL set
# Got 143 / 306 correct (46.73)
# Checking accuracy on TRAIN set
# Got 672 / 1224 correct (54.90)
# Epoch 41, Iteration 0, loss = 1.1631
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 148 / 306 correct (48.37)
#
# Epoch 41, Iteration 1, loss = 1.0338
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 147 / 306 correct (48.04)
#
# Epoch 41, Iteration 2, loss = 1.0485
# Checking accuracy on TRAIN set
# Got 39 / 64 correct (60.94)
# Checking accuracy on VAL set
# Got 146 / 306 correct (47.71)
#
# Epoch 41, Iteration 3, loss = 1.0310
# Checking accuracy on TRAIN set
# Got 35 / 64 correct (54.69)
# Checking accuracy on VAL set
# Got 147 / 306 correct (48.04)
#
# Epoch 41, Iteration 4, loss = 1.1472
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 146 / 306 correct (47.71)
#
# Epoch 41, Iteration 5, loss = 0.9807
# Checking accuracy on TRAIN set
# Got 40 / 64 correct (62.50)
# Checking accuracy on VAL set
# Got 144 / 306 correct (47.06)
#
# Epoch 41, Iteration 6, loss = 1.1370
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 144 / 306 correct (47.06)
#
# Epoch 41, Iteration 7, loss = 1.1965
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 146 / 306 correct (47.71)
#
# Epoch 41, Iteration 8, loss = 1.0994
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 147 / 306 correct (48.04)
#
# Epoch 41, Iteration 9, loss = 1.0382
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 147 / 306 correct (48.04)
#
# Epoch 41, Iteration 10, loss = 1.0047
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 141 / 306 correct (46.08)
#
# Epoch 41, Iteration 11, loss = 1.1607
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 141 / 306 correct (46.08)
#
# Epoch 41, Iteration 12, loss = 1.1145
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 140 / 306 correct (45.75)
#
# Epoch 41, Iteration 13, loss = 1.0308
# Checking accuracy on TRAIN set
# Got 35 / 64 correct (54.69)
# Checking accuracy on VAL set
# Got 139 / 306 correct (45.42)
#
# Epoch 41, Iteration 14, loss = 1.1390
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 138 / 306 correct (45.10)
#
# Epoch 41, Iteration 15, loss = 1.1221
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 139 / 306 correct (45.42)
#
# Epoch 41, Iteration 16, loss = 1.0714
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 138 / 306 correct (45.10)
#
# Epoch 41, Iteration 17, loss = 1.1200
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 138 / 306 correct (45.10)
#
# Epoch 41, Iteration 18, loss = 1.0912
# Checking accuracy on TRAIN set
# Got 35 / 64 correct (54.69)
# Checking accuracy on VAL set
# Got 142 / 306 correct (46.41)
#
# Epoch 41, Iteration 19, loss = 1.4134
# Checking accuracy on TRAIN set
# Got 3 / 8 correct (37.50)
# Checking accuracy on VAL set
# Got 149 / 306 correct (48.69)
#
# Checking accuracy on VAL set
# Got 149 / 306 correct (48.69)
# Checking accuracy on TRAIN set
# Got 649 / 1224 correct (53.02)
# Epoch 42, Iteration 0, loss = 1.1591
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 154 / 306 correct (50.33)
#
# Epoch 42, Iteration 1, loss = 1.1283
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 159 / 306 correct (51.96)
#
# Epoch 42, Iteration 2, loss = 1.0939
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 160 / 306 correct (52.29)
#
# Epoch 42, Iteration 3, loss = 1.0756
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 164 / 306 correct (53.59)
#
# Epoch 42, Iteration 4, loss = 1.1965
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 164 / 306 correct (53.59)
#
# Epoch 42, Iteration 5, loss = 1.2603
# Checking accuracy on TRAIN set
# Got 25 / 64 correct (39.06)
# Checking accuracy on VAL set
# Got 166 / 306 correct (54.25)
#
# Epoch 42, Iteration 6, loss = 1.1665
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 155 / 306 correct (50.65)
#
# Epoch 42, Iteration 7, loss = 1.1083
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 149 / 306 correct (48.69)
#
# Epoch 42, Iteration 8, loss = 1.1504
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 146 / 306 correct (47.71)
#
# Epoch 42, Iteration 9, loss = 1.1088
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 147 / 306 correct (48.04)
#
# Epoch 42, Iteration 10, loss = 1.1086
# Checking accuracy on TRAIN set
# Got 39 / 64 correct (60.94)
# Checking accuracy on VAL set
# Got 135 / 306 correct (44.12)
#
# Epoch 42, Iteration 11, loss = 1.0343
# Checking accuracy on TRAIN set
# Got 41 / 64 correct (64.06)
# Checking accuracy on VAL set
# Got 134 / 306 correct (43.79)
#
# Epoch 42, Iteration 12, loss = 1.1457
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 134 / 306 correct (43.79)
#
# Epoch 42, Iteration 13, loss = 1.0617
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 134 / 306 correct (43.79)
#
# Epoch 42, Iteration 14, loss = 0.9579
# Checking accuracy on TRAIN set
# Got 43 / 64 correct (67.19)
# Checking accuracy on VAL set
# Got 135 / 306 correct (44.12)
#
# Epoch 42, Iteration 15, loss = 1.0443
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 134 / 306 correct (43.79)
#
# Epoch 42, Iteration 16, loss = 1.0488
# Checking accuracy on TRAIN set
# Got 40 / 64 correct (62.50)
# Checking accuracy on VAL set
# Got 138 / 306 correct (45.10)
#
# Epoch 42, Iteration 17, loss = 1.2256
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 147 / 306 correct (48.04)
#
# Epoch 42, Iteration 18, loss = 1.1000
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 155 / 306 correct (50.65)
#
# Epoch 42, Iteration 19, loss = 1.1993
# Checking accuracy on TRAIN set
# Got 3 / 8 correct (37.50)
# Checking accuracy on VAL set
# Got 143 / 306 correct (46.73)
#
# Checking accuracy on VAL set
# Got 143 / 306 correct (46.73)
# Checking accuracy on TRAIN set
# Got 627 / 1224 correct (51.23)
# Epoch 43, Iteration 0, loss = 1.1342
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 140 / 306 correct (45.75)
#
# Epoch 43, Iteration 1, loss = 1.0649
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 134 / 306 correct (43.79)
#
# Epoch 43, Iteration 2, loss = 1.2347
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 131 / 306 correct (42.81)
#
# Epoch 43, Iteration 3, loss = 1.0915
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 137 / 306 correct (44.77)
#
# Epoch 43, Iteration 4, loss = 1.1504
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 137 / 306 correct (44.77)
#
# Epoch 43, Iteration 5, loss = 1.1402
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 143 / 306 correct (46.73)
#
# Epoch 43, Iteration 6, loss = 1.0328
# Checking accuracy on TRAIN set
# Got 38 / 64 correct (59.38)
# Checking accuracy on VAL set
# Got 143 / 306 correct (46.73)
#
# Epoch 43, Iteration 7, loss = 1.2019
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 141 / 306 correct (46.08)
#
# Epoch 43, Iteration 8, loss = 1.0187
# Checking accuracy on TRAIN set
# Got 35 / 64 correct (54.69)
# Checking accuracy on VAL set
# Got 142 / 306 correct (46.41)
#
# Epoch 43, Iteration 9, loss = 0.9572
# Checking accuracy on TRAIN set
# Got 41 / 64 correct (64.06)
# Checking accuracy on VAL set
# Got 141 / 306 correct (46.08)
#
# Epoch 43, Iteration 10, loss = 1.1510
# Checking accuracy on TRAIN set
# Got 35 / 64 correct (54.69)
# Checking accuracy on VAL set
# Got 139 / 306 correct (45.42)
#
# Epoch 43, Iteration 11, loss = 0.9949
# Checking accuracy on TRAIN set
# Got 41 / 64 correct (64.06)
# Checking accuracy on VAL set
# Got 135 / 306 correct (44.12)
#
# Epoch 43, Iteration 12, loss = 1.0598
# Checking accuracy on TRAIN set
# Got 35 / 64 correct (54.69)
# Checking accuracy on VAL set
# Got 134 / 306 correct (43.79)
#
# Epoch 43, Iteration 13, loss = 1.1618
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 134 / 306 correct (43.79)
#
# Epoch 43, Iteration 14, loss = 0.9298
# Checking accuracy on TRAIN set
# Got 36 / 64 correct (56.25)
# Checking accuracy on VAL set
# Got 141 / 306 correct (46.08)
#
# Epoch 43, Iteration 15, loss = 0.9711
# Checking accuracy on TRAIN set
# Got 42 / 64 correct (65.62)
# Checking accuracy on VAL set
# Got 146 / 306 correct (47.71)
#
# Epoch 43, Iteration 16, loss = 1.1597
# Checking accuracy on TRAIN set
# Got 38 / 64 correct (59.38)
# Checking accuracy on VAL set
# Got 146 / 306 correct (47.71)
#
# Epoch 43, Iteration 17, loss = 1.1242
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 146 / 306 correct (47.71)
#
# Epoch 43, Iteration 18, loss = 1.1249
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 146 / 306 correct (47.71)
#
# Epoch 43, Iteration 19, loss = 1.1787
# Checking accuracy on TRAIN set
# Got 4 / 8 correct (50.00)
# Checking accuracy on VAL set
# Got 150 / 306 correct (49.02)
#
# Checking accuracy on VAL set
# Got 150 / 306 correct (49.02)
# Checking accuracy on TRAIN set
# Got 664 / 1224 correct (54.25)
# Epoch 44, Iteration 0, loss = 1.0615
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 148 / 306 correct (48.37)
#
# Epoch 44, Iteration 1, loss = 1.0714
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 153 / 306 correct (50.00)
#
# Epoch 44, Iteration 2, loss = 1.1054
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 151 / 306 correct (49.35)
#
# Epoch 44, Iteration 3, loss = 1.1079
# Checking accuracy on TRAIN set
# Got 43 / 64 correct (67.19)
# Checking accuracy on VAL set
# Got 150 / 306 correct (49.02)
#
# Epoch 44, Iteration 4, loss = 1.0331
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 142 / 306 correct (46.41)
#
# Epoch 44, Iteration 5, loss = 1.1429
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 141 / 306 correct (46.08)
#
# Epoch 44, Iteration 6, loss = 1.1445
# Checking accuracy on TRAIN set
# Got 35 / 64 correct (54.69)
# Checking accuracy on VAL set
# Got 145 / 306 correct (47.39)
#
# Epoch 44, Iteration 7, loss = 1.0400
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 139 / 306 correct (45.42)
#
# Epoch 44, Iteration 8, loss = 0.9687
# Checking accuracy on TRAIN set
# Got 40 / 64 correct (62.50)
# Checking accuracy on VAL set
# Got 139 / 306 correct (45.42)
#
# Epoch 44, Iteration 9, loss = 1.0456
# Checking accuracy on TRAIN set
# Got 39 / 64 correct (60.94)
# Checking accuracy on VAL set
# Got 141 / 306 correct (46.08)
#
# Epoch 44, Iteration 10, loss = 1.1734
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 142 / 306 correct (46.41)
#
# Epoch 44, Iteration 11, loss = 1.1323
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 140 / 306 correct (45.75)
#
# Epoch 44, Iteration 12, loss = 1.1023
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 143 / 306 correct (46.73)
#
# Epoch 44, Iteration 13, loss = 1.0097
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 145 / 306 correct (47.39)
#
# Epoch 44, Iteration 14, loss = 1.1090
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 145 / 306 correct (47.39)
#
# Epoch 44, Iteration 15, loss = 1.1338
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 145 / 306 correct (47.39)
#
# Epoch 44, Iteration 16, loss = 1.1573
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 146 / 306 correct (47.71)
#
# Epoch 44, Iteration 17, loss = 1.1405
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 146 / 306 correct (47.71)
#
# Epoch 44, Iteration 18, loss = 1.1543
# Checking accuracy on TRAIN set
# Got 26 / 64 correct (40.62)
# Checking accuracy on VAL set
# Got 144 / 306 correct (47.06)
#
# Epoch 44, Iteration 19, loss = 1.0512
# Checking accuracy on TRAIN set
# Got 5 / 8 correct (62.50)
# Checking accuracy on VAL set
# Got 145 / 306 correct (47.39)
#
# Checking accuracy on VAL set
# Got 145 / 306 correct (47.39)
# Checking accuracy on TRAIN set
# Got 651 / 1224 correct (53.19)
# Epoch 45, Iteration 0, loss = 1.2643
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 145 / 306 correct (47.39)
#
# Epoch 45, Iteration 1, loss = 1.1585
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 145 / 306 correct (47.39)
#
# Epoch 45, Iteration 2, loss = 1.0424
# Checking accuracy on TRAIN set
# Got 40 / 64 correct (62.50)
# Checking accuracy on VAL set
# Got 144 / 306 correct (47.06)
#
# Epoch 45, Iteration 3, loss = 1.0318
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 142 / 306 correct (46.41)
#
# Epoch 45, Iteration 4, loss = 1.0791
# Checking accuracy on TRAIN set
# Got 35 / 64 correct (54.69)
# Checking accuracy on VAL set
# Got 141 / 306 correct (46.08)
#
# Epoch 45, Iteration 5, loss = 1.0643
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 141 / 306 correct (46.08)
#
# Epoch 45, Iteration 6, loss = 1.1455
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 141 / 306 correct (46.08)
#
# Epoch 45, Iteration 7, loss = 1.1526
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 139 / 306 correct (45.42)
#
# Epoch 45, Iteration 8, loss = 0.9561
# Checking accuracy on TRAIN set
# Got 40 / 64 correct (62.50)
# Checking accuracy on VAL set
# Got 141 / 306 correct (46.08)
#
# Epoch 45, Iteration 9, loss = 1.0765
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 146 / 306 correct (47.71)
#
# Epoch 45, Iteration 10, loss = 1.0917
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 148 / 306 correct (48.37)
#
# Epoch 45, Iteration 11, loss = 1.0941
# Checking accuracy on TRAIN set
# Got 36 / 64 correct (56.25)
# Checking accuracy on VAL set
# Got 152 / 306 correct (49.67)
#
# Epoch 45, Iteration 12, loss = 1.0243
# Checking accuracy on TRAIN set
# Got 35 / 64 correct (54.69)
# Checking accuracy on VAL set
# Got 152 / 306 correct (49.67)
#
# Epoch 45, Iteration 13, loss = 1.0282
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 152 / 306 correct (49.67)
#
# Epoch 45, Iteration 14, loss = 1.0981
# Checking accuracy on TRAIN set
# Got 36 / 64 correct (56.25)
# Checking accuracy on VAL set
# Got 149 / 306 correct (48.69)
#
# Epoch 45, Iteration 15, loss = 1.0193
# Checking accuracy on TRAIN set
# Got 38 / 64 correct (59.38)
# Checking accuracy on VAL set
# Got 147 / 306 correct (48.04)
#
# Epoch 45, Iteration 16, loss = 1.0409
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 148 / 306 correct (48.37)
#
# Epoch 45, Iteration 17, loss = 1.0568
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 145 / 306 correct (47.39)
#
# Epoch 45, Iteration 18, loss = 1.1619
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 146 / 306 correct (47.71)
#
# Epoch 45, Iteration 19, loss = 0.7519
# Checking accuracy on TRAIN set
# Got 7 / 8 correct (87.50)
# Checking accuracy on VAL set
# Got 144 / 306 correct (47.06)
#
# Checking accuracy on VAL set
# Got 144 / 306 correct (47.06)
# Checking accuracy on TRAIN set
# Got 673 / 1224 correct (54.98)
# Epoch 46, Iteration 0, loss = 1.1054
# Checking accuracy on TRAIN set
# Got 38 / 64 correct (59.38)
# Checking accuracy on VAL set
# Got 143 / 306 correct (46.73)
#
# Epoch 46, Iteration 1, loss = 1.2017
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 141 / 306 correct (46.08)
#
# Epoch 46, Iteration 2, loss = 1.0826
# Checking accuracy on TRAIN set
# Got 26 / 64 correct (40.62)
# Checking accuracy on VAL set
# Got 137 / 306 correct (44.77)
#
# Epoch 46, Iteration 3, loss = 0.9159
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 137 / 306 correct (44.77)
#
# Epoch 46, Iteration 4, loss = 0.9636
# Checking accuracy on TRAIN set
# Got 39 / 64 correct (60.94)
# Checking accuracy on VAL set
# Got 140 / 306 correct (45.75)
#
# Epoch 46, Iteration 5, loss = 0.9792
# Checking accuracy on TRAIN set
# Got 39 / 64 correct (60.94)
# Checking accuracy on VAL set
# Got 142 / 306 correct (46.41)
#
# Epoch 46, Iteration 6, loss = 1.1661
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 147 / 306 correct (48.04)
#
# Epoch 46, Iteration 7, loss = 1.1742
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 148 / 306 correct (48.37)
#
# Epoch 46, Iteration 8, loss = 1.2168
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 146 / 306 correct (47.71)
#
# Epoch 46, Iteration 9, loss = 1.0873
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 148 / 306 correct (48.37)
#
# Epoch 46, Iteration 10, loss = 1.0344
# Checking accuracy on TRAIN set
# Got 35 / 64 correct (54.69)
# Checking accuracy on VAL set
# Got 145 / 306 correct (47.39)
#
# Epoch 46, Iteration 11, loss = 1.0075
# Checking accuracy on TRAIN set
# Got 40 / 64 correct (62.50)
# Checking accuracy on VAL set
# Got 146 / 306 correct (47.71)
#
# Epoch 46, Iteration 12, loss = 1.1399
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 148 / 306 correct (48.37)
#
# Epoch 46, Iteration 13, loss = 1.0656
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 145 / 306 correct (47.39)
#
# Epoch 46, Iteration 14, loss = 1.0743
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 148 / 306 correct (48.37)
#
# Epoch 46, Iteration 15, loss = 1.1425
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 139 / 306 correct (45.42)
#
# Epoch 46, Iteration 16, loss = 1.0571
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 134 / 306 correct (43.79)
#
# Epoch 46, Iteration 17, loss = 1.1713
# Checking accuracy on TRAIN set
# Got 39 / 64 correct (60.94)
# Checking accuracy on VAL set
# Got 135 / 306 correct (44.12)
#
# Epoch 46, Iteration 18, loss = 1.0776
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 141 / 306 correct (46.08)
#
# Epoch 46, Iteration 19, loss = 0.8534
# Checking accuracy on TRAIN set
# Got 7 / 8 correct (87.50)
# Checking accuracy on VAL set
# Got 139 / 306 correct (45.42)
#
# Checking accuracy on VAL set
# Got 139 / 306 correct (45.42)
# Checking accuracy on TRAIN set
# Got 667 / 1224 correct (54.49)
# Epoch 47, Iteration 0, loss = 1.0187
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 144 / 306 correct (47.06)
#
# Epoch 47, Iteration 1, loss = 1.0768
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 143 / 306 correct (46.73)
#
# Epoch 47, Iteration 2, loss = 1.0294
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 138 / 306 correct (45.10)
#
# Epoch 47, Iteration 3, loss = 1.0797
# Checking accuracy on TRAIN set
# Got 36 / 64 correct (56.25)
# Checking accuracy on VAL set
# Got 139 / 306 correct (45.42)
#
# Epoch 47, Iteration 4, loss = 1.1507
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 141 / 306 correct (46.08)
#
# Epoch 47, Iteration 5, loss = 1.0484
# Checking accuracy on TRAIN set
# Got 36 / 64 correct (56.25)
# Checking accuracy on VAL set
# Got 141 / 306 correct (46.08)
#
# Epoch 47, Iteration 6, loss = 0.8259
# Checking accuracy on TRAIN set
# Got 43 / 64 correct (67.19)
# Checking accuracy on VAL set
# Got 150 / 306 correct (49.02)
#
# Epoch 47, Iteration 7, loss = 1.1333
# Checking accuracy on TRAIN set
# Got 35 / 64 correct (54.69)
# Checking accuracy on VAL set
# Got 152 / 306 correct (49.67)
#
# Epoch 47, Iteration 8, loss = 1.2741
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 152 / 306 correct (49.67)
#
# Epoch 47, Iteration 9, loss = 0.9658
# Checking accuracy on TRAIN set
# Got 41 / 64 correct (64.06)
# Checking accuracy on VAL set
# Got 150 / 306 correct (49.02)
#
# Epoch 47, Iteration 10, loss = 1.1817
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 148 / 306 correct (48.37)
#
# Epoch 47, Iteration 11, loss = 1.0023
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 142 / 306 correct (46.41)
#
# Epoch 47, Iteration 12, loss = 1.0629
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 139 / 306 correct (45.42)
#
# Epoch 47, Iteration 13, loss = 1.0729
# Checking accuracy on TRAIN set
# Got 40 / 64 correct (62.50)
# Checking accuracy on VAL set
# Got 139 / 306 correct (45.42)
#
# Epoch 47, Iteration 14, loss = 1.0898
# Checking accuracy on TRAIN set
# Got 39 / 64 correct (60.94)
# Checking accuracy on VAL set
# Got 136 / 306 correct (44.44)
#
# Epoch 47, Iteration 15, loss = 1.0595
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 136 / 306 correct (44.44)
#
# Epoch 47, Iteration 16, loss = 1.0263
# Checking accuracy on TRAIN set
# Got 40 / 64 correct (62.50)
# Checking accuracy on VAL set
# Got 141 / 306 correct (46.08)
#
# Epoch 47, Iteration 17, loss = 1.1491
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 145 / 306 correct (47.39)
#
# Epoch 47, Iteration 18, loss = 1.1119
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 154 / 306 correct (50.33)
#
# Epoch 47, Iteration 19, loss = 1.0446
# Checking accuracy on TRAIN set
# Got 6 / 8 correct (75.00)
# Checking accuracy on VAL set
# Got 159 / 306 correct (51.96)
#
# Checking accuracy on VAL set
# Got 159 / 306 correct (51.96)
# Checking accuracy on TRAIN set
# Got 622 / 1224 correct (50.82)
# Epoch 48, Iteration 0, loss = 1.0936
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 156 / 306 correct (50.98)
#
# Epoch 48, Iteration 1, loss = 1.1301
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 153 / 306 correct (50.00)
#
# Epoch 48, Iteration 2, loss = 1.2627
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 153 / 306 correct (50.00)
#
# Epoch 48, Iteration 3, loss = 1.0428
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 152 / 306 correct (49.67)
#
# Epoch 48, Iteration 4, loss = 1.0840
# Checking accuracy on TRAIN set
# Got 40 / 64 correct (62.50)
# Checking accuracy on VAL set
# Got 145 / 306 correct (47.39)
#
# Epoch 48, Iteration 5, loss = 1.1029
# Checking accuracy on TRAIN set
# Got 45 / 64 correct (70.31)
# Checking accuracy on VAL set
# Got 140 / 306 correct (45.75)
#
# Epoch 48, Iteration 6, loss = 1.1279
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 129 / 306 correct (42.16)
#
# Epoch 48, Iteration 7, loss = 1.0895
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 127 / 306 correct (41.50)
#
# Epoch 48, Iteration 8, loss = 1.2069
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 131 / 306 correct (42.81)
#
# Epoch 48, Iteration 9, loss = 1.1555
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 132 / 306 correct (43.14)
#
# Epoch 48, Iteration 10, loss = 0.9917
# Checking accuracy on TRAIN set
# Got 39 / 64 correct (60.94)
# Checking accuracy on VAL set
# Got 136 / 306 correct (44.44)
#
# Epoch 48, Iteration 11, loss = 1.1475
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 137 / 306 correct (44.77)
#
# Epoch 48, Iteration 12, loss = 1.1454
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 137 / 306 correct (44.77)
#
# Epoch 48, Iteration 13, loss = 0.9891
# Checking accuracy on TRAIN set
# Got 41 / 64 correct (64.06)
# Checking accuracy on VAL set
# Got 147 / 306 correct (48.04)
#
# Epoch 48, Iteration 14, loss = 1.1368
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 154 / 306 correct (50.33)
#
# Epoch 48, Iteration 15, loss = 1.0468
# Checking accuracy on TRAIN set
# Got 38 / 64 correct (59.38)
# Checking accuracy on VAL set
# Got 154 / 306 correct (50.33)
#
# Epoch 48, Iteration 16, loss = 1.1216
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 150 / 306 correct (49.02)
#
# Epoch 48, Iteration 17, loss = 1.0166
# Checking accuracy on TRAIN set
# Got 35 / 64 correct (54.69)
# Checking accuracy on VAL set
# Got 144 / 306 correct (47.06)
#
# Epoch 48, Iteration 18, loss = 1.0583
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 144 / 306 correct (47.06)
#
# Epoch 48, Iteration 19, loss = 1.2239
# Checking accuracy on TRAIN set
# Got 3 / 8 correct (37.50)
# Checking accuracy on VAL set
# Got 144 / 306 correct (47.06)
#
# Checking accuracy on VAL set
# Got 144 / 306 correct (47.06)
# Checking accuracy on TRAIN set
# Got 658 / 1224 correct (53.76)
# Epoch 49, Iteration 0, loss = 1.1735
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 146 / 306 correct (47.71)
#
# Epoch 49, Iteration 1, loss = 1.0276
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 147 / 306 correct (48.04)
#
# Epoch 49, Iteration 2, loss = 1.0206
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 140 / 306 correct (45.75)
#
# Epoch 49, Iteration 3, loss = 1.1269
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 139 / 306 correct (45.42)
#
# Epoch 49, Iteration 4, loss = 1.1878
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 140 / 306 correct (45.75)
#
# Epoch 49, Iteration 5, loss = 1.0729
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 142 / 306 correct (46.41)
#
# Epoch 49, Iteration 6, loss = 1.0084
# Checking accuracy on TRAIN set
# Got 40 / 64 correct (62.50)
# Checking accuracy on VAL set
# Got 143 / 306 correct (46.73)
#
# Epoch 49, Iteration 7, loss = 1.0048
# Checking accuracy on TRAIN set
# Got 44 / 64 correct (68.75)
# Checking accuracy on VAL set
# Got 141 / 306 correct (46.08)
#
# Epoch 49, Iteration 8, loss = 1.0159
# Checking accuracy on TRAIN set
# Got 36 / 64 correct (56.25)
# Checking accuracy on VAL set
# Got 143 / 306 correct (46.73)
#
# Epoch 49, Iteration 9, loss = 0.8563
# Checking accuracy on TRAIN set
# Got 45 / 64 correct (70.31)
# Checking accuracy on VAL set
# Got 144 / 306 correct (47.06)
#
# Epoch 49, Iteration 10, loss = 1.1322
# Checking accuracy on TRAIN set
# Got 40 / 64 correct (62.50)
# Checking accuracy on VAL set
# Got 144 / 306 correct (47.06)
#
# Epoch 49, Iteration 11, loss = 1.1315
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 142 / 306 correct (46.41)
#
# Epoch 49, Iteration 12, loss = 1.0465
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 142 / 306 correct (46.41)
#
# Epoch 49, Iteration 13, loss = 1.1578
# Checking accuracy on TRAIN set
# Got 35 / 64 correct (54.69)
# Checking accuracy on VAL set
# Got 136 / 306 correct (44.44)
#
# Epoch 49, Iteration 14, loss = 0.9854
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 137 / 306 correct (44.77)
#
# Epoch 49, Iteration 15, loss = 1.0695
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 141 / 306 correct (46.08)
#
# Epoch 49, Iteration 16, loss = 1.0418
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 143 / 306 correct (46.73)
#
# Epoch 49, Iteration 17, loss = 1.1169
# Checking accuracy on TRAIN set
# Got 36 / 64 correct (56.25)
# Checking accuracy on VAL set
# Got 144 / 306 correct (47.06)
#
# Epoch 49, Iteration 18, loss = 1.0697
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 147 / 306 correct (48.04)
#
# Epoch 49, Iteration 19, loss = 0.9731
# Checking accuracy on TRAIN set
# Got 6 / 8 correct (75.00)
# Checking accuracy on VAL set
# Got 162 / 306 correct (52.94)
#
# Checking accuracy on VAL set
# Got 162 / 306 correct (52.94)
# Checking accuracy on TRAIN set
# Got 650 / 1224 correct (53.10)
# Epoch 50, Iteration 0, loss = 1.2362
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 167 / 306 correct (54.58)
#
# Epoch 50, Iteration 1, loss = 0.9990
# Checking accuracy on TRAIN set
# Got 39 / 64 correct (60.94)
# Checking accuracy on VAL set
# Got 166 / 306 correct (54.25)
#
# Epoch 50, Iteration 2, loss = 1.1531
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 161 / 306 correct (52.61)
#
# Epoch 50, Iteration 3, loss = 1.0422
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 156 / 306 correct (50.98)
#
# Epoch 50, Iteration 4, loss = 1.1067
# Checking accuracy on TRAIN set
# Got 38 / 64 correct (59.38)
# Checking accuracy on VAL set
# Got 154 / 306 correct (50.33)
#
# Epoch 50, Iteration 5, loss = 1.0259
# Checking accuracy on TRAIN set
# Got 35 / 64 correct (54.69)
# Checking accuracy on VAL set
# Got 149 / 306 correct (48.69)
#
# Epoch 50, Iteration 6, loss = 1.1125
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 139 / 306 correct (45.42)
#
# Epoch 50, Iteration 7, loss = 1.0235
# Checking accuracy on TRAIN set
# Got 39 / 64 correct (60.94)
# Checking accuracy on VAL set
# Got 136 / 306 correct (44.44)
#
# Epoch 50, Iteration 8, loss = 1.1170
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 127 / 306 correct (41.50)
#
# Epoch 50, Iteration 9, loss = 1.1165
# Checking accuracy on TRAIN set
# Got 35 / 64 correct (54.69)
# Checking accuracy on VAL set
# Got 128 / 306 correct (41.83)
#
# Epoch 50, Iteration 10, loss = 1.0684
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 131 / 306 correct (42.81)
#
# Epoch 50, Iteration 11, loss = 0.9661
# Checking accuracy on TRAIN set
# Got 38 / 64 correct (59.38)
# Checking accuracy on VAL set
# Got 137 / 306 correct (44.77)
#
# Epoch 50, Iteration 12, loss = 1.1585
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 140 / 306 correct (45.75)
#
# Epoch 50, Iteration 13, loss = 1.0669
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 142 / 306 correct (46.41)
#
# Epoch 50, Iteration 14, loss = 0.9401
# Checking accuracy on TRAIN set
# Got 40 / 64 correct (62.50)
# Checking accuracy on VAL set
# Got 151 / 306 correct (49.35)
#
# Epoch 50, Iteration 15, loss = 1.0038
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 163 / 306 correct (53.27)
#
# Epoch 50, Iteration 16, loss = 1.0045
# Checking accuracy on TRAIN set
# Got 35 / 64 correct (54.69)
# Checking accuracy on VAL set
# Got 162 / 306 correct (52.94)
#
# Epoch 50, Iteration 17, loss = 1.1016
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 162 / 306 correct (52.94)
#
# Epoch 50, Iteration 18, loss = 1.0055
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 156 / 306 correct (50.98)
#
# Epoch 50, Iteration 19, loss = 0.9782
# Checking accuracy on TRAIN set
# Got 6 / 8 correct (75.00)
# Checking accuracy on VAL set
# Got 149 / 306 correct (48.69)
#
# Checking accuracy on VAL set
# Got 149 / 306 correct (48.69)
# Checking accuracy on TRAIN set
# Got 681 / 1224 correct (55.64)
# Epoch 51, Iteration 0, loss = 0.8451
# Checking accuracy on TRAIN set
# Got 42 / 64 correct (65.62)
# Checking accuracy on VAL set
# Got 142 / 306 correct (46.41)
#
# Epoch 51, Iteration 1, loss = 0.9935
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 139 / 306 correct (45.42)
#
# Epoch 51, Iteration 2, loss = 1.1241
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 137 / 306 correct (44.77)
#
# Epoch 51, Iteration 3, loss = 1.0972
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 138 / 306 correct (45.10)
#
# Epoch 51, Iteration 4, loss = 1.2057
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 143 / 306 correct (46.73)
#
# Epoch 51, Iteration 5, loss = 0.9781
# Checking accuracy on TRAIN set
# Got 40 / 64 correct (62.50)
# Checking accuracy on VAL set
# Got 137 / 306 correct (44.77)
#
# Epoch 51, Iteration 6, loss = 1.0991
# Checking accuracy on TRAIN set
# Got 36 / 64 correct (56.25)
# Checking accuracy on VAL set
# Got 139 / 306 correct (45.42)
#
# Epoch 51, Iteration 7, loss = 1.0511
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 148 / 306 correct (48.37)
#
# Epoch 51, Iteration 8, loss = 1.1855
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 151 / 306 correct (49.35)
#
# Epoch 51, Iteration 9, loss = 1.2059
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 148 / 306 correct (48.37)
#
# Epoch 51, Iteration 10, loss = 1.0942
# Checking accuracy on TRAIN set
# Got 35 / 64 correct (54.69)
# Checking accuracy on VAL set
# Got 150 / 306 correct (49.02)
#
# Epoch 51, Iteration 11, loss = 1.1350
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 146 / 306 correct (47.71)
#
# Epoch 51, Iteration 12, loss = 0.9890
# Checking accuracy on TRAIN set
# Got 44 / 64 correct (68.75)
# Checking accuracy on VAL set
# Got 144 / 306 correct (47.06)
#
# Epoch 51, Iteration 13, loss = 1.0644
# Checking accuracy on TRAIN set
# Got 38 / 64 correct (59.38)
# Checking accuracy on VAL set
# Got 143 / 306 correct (46.73)
#
# Epoch 51, Iteration 14, loss = 1.0713
# Checking accuracy on TRAIN set
# Got 36 / 64 correct (56.25)
# Checking accuracy on VAL set
# Got 142 / 306 correct (46.41)
#
# Epoch 51, Iteration 15, loss = 1.0791
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 139 / 306 correct (45.42)
#
# Epoch 51, Iteration 16, loss = 1.0507
# Checking accuracy on TRAIN set
# Got 36 / 64 correct (56.25)
# Checking accuracy on VAL set
# Got 140 / 306 correct (45.75)
#
# Epoch 51, Iteration 17, loss = 1.1120
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 139 / 306 correct (45.42)
#
# Epoch 51, Iteration 18, loss = 1.0728
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 141 / 306 correct (46.08)
#
# Epoch 51, Iteration 19, loss = 1.3526
# Checking accuracy on TRAIN set
# Got 3 / 8 correct (37.50)
# Checking accuracy on VAL set
# Got 139 / 306 correct (45.42)
#
# Checking accuracy on VAL set
# Got 139 / 306 correct (45.42)
# Checking accuracy on TRAIN set
# Got 661 / 1224 correct (54.00)
# Epoch 52, Iteration 0, loss = 1.1384
# Checking accuracy on TRAIN set
# Got 36 / 64 correct (56.25)
# Checking accuracy on VAL set
# Got 141 / 306 correct (46.08)
#
# Epoch 52, Iteration 1, loss = 1.0359
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 144 / 306 correct (47.06)
#
# Epoch 52, Iteration 2, loss = 1.1401
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 143 / 306 correct (46.73)
#
# Epoch 52, Iteration 3, loss = 1.0869
# Checking accuracy on TRAIN set
# Got 35 / 64 correct (54.69)
# Checking accuracy on VAL set
# Got 143 / 306 correct (46.73)
#
# Epoch 52, Iteration 4, loss = 1.1163
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 142 / 306 correct (46.41)
#
# Epoch 52, Iteration 5, loss = 1.0797
# Checking accuracy on TRAIN set
# Got 40 / 64 correct (62.50)
# Checking accuracy on VAL set
# Got 142 / 306 correct (46.41)
#
# Epoch 52, Iteration 6, loss = 0.9849
# Checking accuracy on TRAIN set
# Got 41 / 64 correct (64.06)
# Checking accuracy on VAL set
# Got 145 / 306 correct (47.39)
#
# Epoch 52, Iteration 7, loss = 1.0241
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 140 / 306 correct (45.75)
#
# Epoch 52, Iteration 8, loss = 1.0444
# Checking accuracy on TRAIN set
# Got 36 / 64 correct (56.25)
# Checking accuracy on VAL set
# Got 144 / 306 correct (47.06)
#
# Epoch 52, Iteration 9, loss = 1.0456
# Checking accuracy on TRAIN set
# Got 40 / 64 correct (62.50)
# Checking accuracy on VAL set
# Got 149 / 306 correct (48.69)
#
# Epoch 52, Iteration 10, loss = 1.1717
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 151 / 306 correct (49.35)
#
# Epoch 52, Iteration 11, loss = 1.1032
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 155 / 306 correct (50.65)
#
# Epoch 52, Iteration 12, loss = 1.0513
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 151 / 306 correct (49.35)
#
# Epoch 52, Iteration 13, loss = 0.9966
# Checking accuracy on TRAIN set
# Got 39 / 64 correct (60.94)
# Checking accuracy on VAL set
# Got 147 / 306 correct (48.04)
#
# Epoch 52, Iteration 14, loss = 1.0213
# Checking accuracy on TRAIN set
# Got 36 / 64 correct (56.25)
# Checking accuracy on VAL set
# Got 148 / 306 correct (48.37)
#
# Epoch 52, Iteration 15, loss = 1.0756
# Checking accuracy on TRAIN set
# Got 35 / 64 correct (54.69)
# Checking accuracy on VAL set
# Got 145 / 306 correct (47.39)
#
# Epoch 52, Iteration 16, loss = 0.9496
# Checking accuracy on TRAIN set
# Got 38 / 64 correct (59.38)
# Checking accuracy on VAL set
# Got 145 / 306 correct (47.39)
#
# Epoch 52, Iteration 17, loss = 1.0851
# Checking accuracy on TRAIN set
# Got 35 / 64 correct (54.69)
# Checking accuracy on VAL set
# Got 147 / 306 correct (48.04)
#
# Epoch 52, Iteration 18, loss = 1.0819
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 146 / 306 correct (47.71)
#
# Epoch 52, Iteration 19, loss = 1.2466
# Checking accuracy on TRAIN set
# Got 2 / 8 correct (25.00)
# Checking accuracy on VAL set
# Got 140 / 306 correct (45.75)
#
# Checking accuracy on VAL set
# Got 140 / 306 correct (45.75)
# Checking accuracy on TRAIN set
# Got 696 / 1224 correct (56.86)
# Epoch 53, Iteration 0, loss = 0.9951
# Checking accuracy on TRAIN set
# Got 40 / 64 correct (62.50)
# Checking accuracy on VAL set
# Got 141 / 306 correct (46.08)
#
# Epoch 53, Iteration 1, loss = 1.0867
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 136 / 306 correct (44.44)
#
# Epoch 53, Iteration 2, loss = 0.9850
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 139 / 306 correct (45.42)
#
# Epoch 53, Iteration 3, loss = 0.9882
# Checking accuracy on TRAIN set
# Got 36 / 64 correct (56.25)
# Checking accuracy on VAL set
# Got 138 / 306 correct (45.10)
#
# Epoch 53, Iteration 4, loss = 1.1661
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 142 / 306 correct (46.41)
#
# Epoch 53, Iteration 5, loss = 0.9463
# Checking accuracy on TRAIN set
# Got 45 / 64 correct (70.31)
# Checking accuracy on VAL set
# Got 142 / 306 correct (46.41)
#
# Epoch 53, Iteration 6, loss = 0.8974
# Checking accuracy on TRAIN set
# Got 42 / 64 correct (65.62)
# Checking accuracy on VAL set
# Got 146 / 306 correct (47.71)
#
# Epoch 53, Iteration 7, loss = 1.0342
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 151 / 306 correct (49.35)
#
# Epoch 53, Iteration 8, loss = 1.1342
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 154 / 306 correct (50.33)
#
# Epoch 53, Iteration 9, loss = 1.0936
# Checking accuracy on TRAIN set
# Got 39 / 64 correct (60.94)
# Checking accuracy on VAL set
# Got 155 / 306 correct (50.65)
#
# Epoch 53, Iteration 10, loss = 1.2555
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 155 / 306 correct (50.65)
#
# Epoch 53, Iteration 11, loss = 1.1297
# Checking accuracy on TRAIN set
# Got 35 / 64 correct (54.69)
# Checking accuracy on VAL set
# Got 152 / 306 correct (49.67)
#
# Epoch 53, Iteration 12, loss = 0.9903
# Checking accuracy on TRAIN set
# Got 38 / 64 correct (59.38)
# Checking accuracy on VAL set
# Got 150 / 306 correct (49.02)
#
# Epoch 53, Iteration 13, loss = 1.0507
# Checking accuracy on TRAIN set
# Got 41 / 64 correct (64.06)
# Checking accuracy on VAL set
# Got 145 / 306 correct (47.39)
#
# Epoch 53, Iteration 14, loss = 0.9882
# Checking accuracy on TRAIN set
# Got 41 / 64 correct (64.06)
# Checking accuracy on VAL set
# Got 141 / 306 correct (46.08)
#
# Epoch 53, Iteration 15, loss = 1.0527
# Checking accuracy on TRAIN set
# Got 35 / 64 correct (54.69)
# Checking accuracy on VAL set
# Got 142 / 306 correct (46.41)
#
# Epoch 53, Iteration 16, loss = 1.0648
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 144 / 306 correct (47.06)
#
# Epoch 53, Iteration 17, loss = 1.0206
# Checking accuracy on TRAIN set
# Got 39 / 64 correct (60.94)
# Checking accuracy on VAL set
# Got 138 / 306 correct (45.10)
#
# Epoch 53, Iteration 18, loss = 1.0617
# Checking accuracy on TRAIN set
# Got 36 / 64 correct (56.25)
# Checking accuracy on VAL set
# Got 138 / 306 correct (45.10)
#
# Epoch 53, Iteration 19, loss = 1.4350
# Checking accuracy on TRAIN set
# Got 3 / 8 correct (37.50)
# Checking accuracy on VAL set
# Got 133 / 306 correct (43.46)
#
# Checking accuracy on VAL set
# Got 133 / 306 correct (43.46)
# Checking accuracy on TRAIN set
# Got 668 / 1224 correct (54.58)
# Epoch 54, Iteration 0, loss = 1.1655
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 129 / 306 correct (42.16)
#
# Epoch 54, Iteration 1, loss = 1.1767
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 130 / 306 correct (42.48)
#
# Epoch 54, Iteration 2, loss = 1.0340
# Checking accuracy on TRAIN set
# Got 35 / 64 correct (54.69)
# Checking accuracy on VAL set
# Got 137 / 306 correct (44.77)
#
# Epoch 54, Iteration 3, loss = 0.8906
# Checking accuracy on TRAIN set
# Got 42 / 64 correct (65.62)
# Checking accuracy on VAL set
# Got 145 / 306 correct (47.39)
#
# Epoch 54, Iteration 4, loss = 1.0256
# Checking accuracy on TRAIN set
# Got 35 / 64 correct (54.69)
# Checking accuracy on VAL set
# Got 152 / 306 correct (49.67)
#
# Epoch 54, Iteration 5, loss = 1.0508
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 158 / 306 correct (51.63)
#
# Epoch 54, Iteration 6, loss = 1.1290
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 159 / 306 correct (51.96)
#
# Epoch 54, Iteration 7, loss = 1.0079
# Checking accuracy on TRAIN set
# Got 38 / 64 correct (59.38)
# Checking accuracy on VAL set
# Got 149 / 306 correct (48.69)
#
# Epoch 54, Iteration 8, loss = 0.9479
# Checking accuracy on TRAIN set
# Got 45 / 64 correct (70.31)
# Checking accuracy on VAL set
# Got 152 / 306 correct (49.67)
#
# Epoch 54, Iteration 9, loss = 1.1545
# ...
# Got 164 / 306 correct (53.59)
#
# Epoch 75, Iteration 2, loss = 1.0640
# Checking accuracy on TRAIN set
# Got 35 / 64 correct (54.69)
# Checking accuracy on VAL set
# Got 163 / 306 correct (53.27)
#
# Epoch 75, Iteration 3, loss = 0.8827
# Checking accuracy on TRAIN set
# Got 39 / 64 correct (60.94)
# Checking accuracy on VAL set
# Got 159 / 306 correct (51.96)
#
# Epoch 75, Iteration 4, loss = 0.9430
# Checking accuracy on TRAIN set
# Got 39 / 64 correct (60.94)
# Checking accuracy on VAL set
# Got 151 / 306 correct (49.35)
#
# Epoch 75, Iteration 5, loss = 1.0929
# Checking accuracy on TRAIN set
# Got 36 / 64 correct (56.25)
# Checking accuracy on VAL set
# Got 149 / 306 correct (48.69)
#
# Epoch 75, Iteration 6, loss = 0.9281
# Checking accuracy on TRAIN set
# Got 35 / 64 correct (54.69)
# Checking accuracy on VAL set
# Got 147 / 306 correct (48.04)
#
# Epoch 75, Iteration 7, loss = 0.9226
# Checking accuracy on TRAIN set
# Got 40 / 64 correct (62.50)
# Checking accuracy on VAL set
# Got 140 / 306 correct (45.75)
#
# Epoch 75, Iteration 8, loss = 0.9977
# Checking accuracy on TRAIN set
# Got 39 / 64 correct (60.94)
# Checking accuracy on VAL set
# Got 146 / 306 correct (47.71)
#
# Epoch 75, Iteration 9, loss = 1.0634
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 153 / 306 correct (50.00)
#
# Epoch 75, Iteration 10, loss = 0.8877
# Checking accuracy on TRAIN set
# Got 40 / 64 correct (62.50)
# Checking accuracy on VAL set
# Got 151 / 306 correct (49.35)
#
# Epoch 75, Iteration 11, loss = 0.9526
# Checking accuracy on TRAIN set
# Got 39 / 64 correct (60.94)
# Checking accuracy on VAL set
# Got 153 / 306 correct (50.00)
#
# Epoch 75, Iteration 12, loss = 0.8681
# Checking accuracy on TRAIN set
# Got 39 / 64 correct (60.94)
# Checking accuracy on VAL set
# Got 158 / 306 correct (51.63)
#
# Epoch 75, Iteration 13, loss = 1.0600
# Checking accuracy on TRAIN set
# Got 35 / 64 correct (54.69)
# Checking accuracy on VAL set
# Got 161 / 306 correct (52.61)
#
# Epoch 75, Iteration 14, loss = 1.0157
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 159 / 306 correct (51.96)
#
# Epoch 75, Iteration 15, loss = 0.9722
# Checking accuracy on TRAIN set
# Got 39 / 64 correct (60.94)
# Checking accuracy on VAL set
# Got 159 / 306 correct (51.96)
#
# Epoch 75, Iteration 16, loss = 0.8492
# Checking accuracy on TRAIN set
# Got 44 / 64 correct (68.75)
# Checking accuracy on VAL set
# Got 153 / 306 correct (50.00)
#
# Epoch 75, Iteration 17, loss = 0.9699
# Checking accuracy on TRAIN set
# Got 39 / 64 correct (60.94)
# Checking accuracy on VAL set
# Got 153 / 306 correct (50.00)
#
# Epoch 75, Iteration 18, loss = 0.9439
# Checking accuracy on TRAIN set
# Got 39 / 64 correct (60.94)
# Checking accuracy on VAL set
# Got 151 / 306 correct (49.35)
#
# Epoch 75, Iteration 19, loss = 1.3477
# Checking accuracy on TRAIN set
# Got 3 / 8 correct (37.50)
# Checking accuracy on VAL set
# Got 147 / 306 correct (48.04)
#
# Checking accuracy on VAL set
# Got 147 / 306 correct (48.04)
# Checking accuracy on TRAIN set
# Got 754 / 1224 correct (61.60)
# Epoch 76, Iteration 0, loss = 1.0680
# Checking accuracy on TRAIN set
# Got 35 / 64 correct (54.69)
# Checking accuracy on VAL set
# Got 144 / 306 correct (47.06)
#
# Epoch 76, Iteration 1, loss = 0.9856
# Checking accuracy on TRAIN set
# Got 38 / 64 correct (59.38)
# Checking accuracy on VAL set
# Got 144 / 306 correct (47.06)
#
# Epoch 76, Iteration 2, loss = 0.9365
# Checking accuracy on TRAIN set
# Got 38 / 64 correct (59.38)
# Checking accuracy on VAL set
# Got 141 / 306 correct (46.08)
#
# Epoch 76, Iteration 3, loss = 0.8323
# Checking accuracy on TRAIN set
# Got 42 / 64 correct (65.62)
# Checking accuracy on VAL set
# Got 142 / 306 correct (46.41)
#
# Epoch 76, Iteration 4, loss = 0.9845
# Checking accuracy on TRAIN set
# Got 35 / 64 correct (54.69)
# Checking accuracy on VAL set
# Got 143 / 306 correct (46.73)
#
# Epoch 76, Iteration 5, loss = 1.0150
# Checking accuracy on TRAIN set
# Got 36 / 64 correct (56.25)
# Checking accuracy on VAL set
# Got 147 / 306 correct (48.04)
#
# Epoch 76, Iteration 6, loss = 0.8960
# Checking accuracy on TRAIN set
# Got 43 / 64 correct (67.19)
# Checking accuracy on VAL set
# Got 149 / 306 correct (48.69)
#
# Epoch 76, Iteration 7, loss = 0.9279
# Checking accuracy on TRAIN set
# Got 44 / 64 correct (68.75)
# Checking accuracy on VAL set
# Got 151 / 306 correct (49.35)
#
# Epoch 76, Iteration 8, loss = 1.0858
# Checking accuracy on TRAIN set
# Got 36 / 64 correct (56.25)
# Checking accuracy on VAL set
# Got 151 / 306 correct (49.35)
#
# Epoch 76, Iteration 9, loss = 1.0563
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 153 / 306 correct (50.00)
#
# Epoch 76, Iteration 10, loss = 0.9334
# Checking accuracy on TRAIN set
# Got 43 / 64 correct (67.19)
# Checking accuracy on VAL set
# Got 157 / 306 correct (51.31)
#
# Epoch 76, Iteration 11, loss = 0.9609
# Checking accuracy on TRAIN set
# Got 36 / 64 correct (56.25)
# Checking accuracy on VAL set
# Got 152 / 306 correct (49.67)
#
# Epoch 76, Iteration 12, loss = 0.9019
# Checking accuracy on TRAIN set
# Got 40 / 64 correct (62.50)
# Checking accuracy on VAL set
# Got 150 / 306 correct (49.02)
#
# Epoch 76, Iteration 13, loss = 0.8527
# Checking accuracy on TRAIN set
# Got 45 / 64 correct (70.31)
# Checking accuracy on VAL set
# Got 150 / 306 correct (49.02)
#
# Epoch 76, Iteration 14, loss = 0.7746
# Checking accuracy on TRAIN set
# Got 44 / 64 correct (68.75)
# Checking accuracy on VAL set
# Got 148 / 306 correct (48.37)
#
# Epoch 76, Iteration 15, loss = 0.9471
# Checking accuracy on TRAIN set
# Got 42 / 64 correct (65.62)
# Checking accuracy on VAL set
# Got 149 / 306 correct (48.69)
#
# Epoch 76, Iteration 16, loss = 0.9931
# Checking accuracy on TRAIN set
# Got 41 / 64 correct (64.06)
# Checking accuracy on VAL set
# Got 151 / 306 correct (49.35)
#
# Epoch 76, Iteration 17, loss = 1.0731
# Checking accuracy on TRAIN set
# Got 38 / 64 correct (59.38)
# Checking accuracy on VAL set
# Got 151 / 306 correct (49.35)
#
# Epoch 76, Iteration 18, loss = 0.8804
# Checking accuracy on TRAIN set
# Got 39 / 64 correct (60.94)
# Checking accuracy on VAL set
# Got 157 / 306 correct (51.31)
#
# Epoch 76, Iteration 19, loss = 0.9907
# Checking accuracy on TRAIN set
# Got 4 / 8 correct (50.00)
# Checking accuracy on VAL set
# Got 157 / 306 correct (51.31)
#
# Checking accuracy on VAL set
# Got 157 / 306 correct (51.31)
# Checking accuracy on TRAIN set
# Got 746 / 1224 correct (60.95)
# Epoch 77, Iteration 0, loss = 0.9054
# Checking accuracy on TRAIN set
# Got 43 / 64 correct (67.19)
# Checking accuracy on VAL set
# Got 163 / 306 correct (53.27)
#
# Epoch 77, Iteration 1, loss = 0.9360
# Checking accuracy on TRAIN set
# Got 38 / 64 correct (59.38)
# Checking accuracy on VAL set
# Got 161 / 306 correct (52.61)
#
# Epoch 77, Iteration 2, loss = 0.8965
# Checking accuracy on TRAIN set
# Got 41 / 64 correct (64.06)
# Checking accuracy on VAL set
# Got 158 / 306 correct (51.63)
#
# Epoch 77, Iteration 3, loss = 0.9041
# Checking accuracy on TRAIN set
# Got 40 / 64 correct (62.50)
# Checking accuracy on VAL set
# Got 154 / 306 correct (50.33)
#
# Epoch 77, Iteration 4, loss = 0.8984
# Checking accuracy on TRAIN set
# Got 46 / 64 correct (71.88)
# Checking accuracy on VAL set
# Got 154 / 306 correct (50.33)
#
# Epoch 77, Iteration 5, loss = 0.9396
# Checking accuracy on TRAIN set
# Got 38 / 64 correct (59.38)
# Checking accuracy on VAL set
# Got 151 / 306 correct (49.35)
#
# Epoch 77, Iteration 6, loss = 0.8687
# Checking accuracy on TRAIN set
# Got 42 / 64 correct (65.62)
# Checking accuracy on VAL set
# Got 153 / 306 correct (50.00)
#
# Epoch 77, Iteration 7, loss = 0.9752
# Checking accuracy on TRAIN set
# Got 41 / 64 correct (64.06)
# Checking accuracy on VAL set
# Got 153 / 306 correct (50.00)
#
# Epoch 77, Iteration 8, loss = 0.8996
# Checking accuracy on TRAIN set
# Got 42 / 64 correct (65.62)
# Checking accuracy on VAL set
# Got 151 / 306 correct (49.35)
#
# Epoch 77, Iteration 9, loss = 1.0900
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 154 / 306 correct (50.33)
#
# Epoch 77, Iteration 10, loss = 1.0082
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 155 / 306 correct (50.65)
#
# Epoch 77, Iteration 11, loss = 0.9369
# Checking accuracy on TRAIN set
# Got 44 / 64 correct (68.75)
# Checking accuracy on VAL set
# Got 157 / 306 correct (51.31)
#
# Epoch 77, Iteration 12, loss = 0.9108
# Checking accuracy on TRAIN set
# Got 43 / 64 correct (67.19)
# Checking accuracy on VAL set
# Got 156 / 306 correct (50.98)
#
# Epoch 77, Iteration 13, loss = 0.9023
# Checking accuracy on TRAIN set
# Got 42 / 64 correct (65.62)
# Checking accuracy on VAL set
# Got 157 / 306 correct (51.31)
#
# Epoch 77, Iteration 14, loss = 0.9330
# Checking accuracy on TRAIN set
# Got 36 / 64 correct (56.25)
# Checking accuracy on VAL set
# Got 154 / 306 correct (50.33)
#
# Epoch 77, Iteration 15, loss = 0.9062
# Checking accuracy on TRAIN set
# Got 39 / 64 correct (60.94)
# Checking accuracy on VAL set
# Got 154 / 306 correct (50.33)
#
# Epoch 77, Iteration 16, loss = 0.8932
# Checking accuracy on TRAIN set
# Got 38 / 64 correct (59.38)
# Checking accuracy on VAL set
# Got 153 / 306 correct (50.00)
#
# Epoch 77, Iteration 17, loss = 0.9854
# Checking accuracy on TRAIN set
# Got 38 / 64 correct (59.38)
# Checking accuracy on VAL set
# Got 154 / 306 correct (50.33)
#
# Epoch 77, Iteration 18, loss = 0.9162
# Checking accuracy on TRAIN set
# Got 38 / 64 correct (59.38)
# Checking accuracy on VAL set
# Got 158 / 306 correct (51.63)
#
# Epoch 77, Iteration 19, loss = 0.7712
# Checking accuracy on TRAIN set
# Got 7 / 8 correct (87.50)
# Checking accuracy on VAL set
# Got 156 / 306 correct (50.98)
#
# Checking accuracy on VAL set
# Got 156 / 306 correct (50.98)
# Checking accuracy on TRAIN set
# Got 759 / 1224 correct (62.01)
# Epoch 78, Iteration 0, loss = 0.8478
# Checking accuracy on TRAIN set
# Got 41 / 64 correct (64.06)
# Checking accuracy on VAL set
# Got 161 / 306 correct (52.61)
#
# Epoch 78, Iteration 1, loss = 0.9313
# Checking accuracy on TRAIN set
# Got 38 / 64 correct (59.38)
# Checking accuracy on VAL set
# Got 157 / 306 correct (51.31)
#
# Epoch 78, Iteration 2, loss = 0.8883
# Checking accuracy on TRAIN set
# Got 43 / 64 correct (67.19)
# Checking accuracy on VAL set
# Got 155 / 306 correct (50.65)
#
# Epoch 78, Iteration 3, loss = 1.0550
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 161 / 306 correct (52.61)
#
# Epoch 78, Iteration 4, loss = 0.9342
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 156 / 306 correct (50.98)
#
# Epoch 78, Iteration 5, loss = 1.0668
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 151 / 306 correct (49.35)
#
# Epoch 78, Iteration 6, loss = 0.9818
# Checking accuracy on TRAIN set
# Got 35 / 64 correct (54.69)
# Checking accuracy on VAL set
# Got 143 / 306 correct (46.73)
#
# Epoch 78, Iteration 7, loss = 0.9024
# Checking accuracy on TRAIN set
# Got 38 / 64 correct (59.38)
# Checking accuracy on VAL set
# Got 137 / 306 correct (44.77)
#
# Epoch 78, Iteration 8, loss = 0.9402
# Checking accuracy on TRAIN set
# Got 36 / 64 correct (56.25)
# Checking accuracy on VAL set
# Got 137 / 306 correct (44.77)
#
# Epoch 78, Iteration 9, loss = 0.8925
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 136 / 306 correct (44.44)
#
# Epoch 78, Iteration 10, loss = 1.0223
# Checking accuracy on TRAIN set
# Got 42 / 64 correct (65.62)
# Checking accuracy on VAL set
# Got 137 / 306 correct (44.77)
#
# Epoch 78, Iteration 11, loss = 0.9906
# Checking accuracy on TRAIN set
# Got 40 / 64 correct (62.50)
# Checking accuracy on VAL set
# Got 153 / 306 correct (50.00)
#
# Epoch 78, Iteration 12, loss = 0.7400
# Checking accuracy on TRAIN set
# Got 46 / 64 correct (71.88)
# Checking accuracy on VAL set
# Got 162 / 306 correct (52.94)
#
# Epoch 78, Iteration 13, loss = 0.8854
# Checking accuracy on TRAIN set
# Got 35 / 64 correct (54.69)
# Checking accuracy on VAL set
# Got 167 / 306 correct (54.58)
#
# Epoch 78, Iteration 14, loss = 1.0018
# Checking accuracy on TRAIN set
# Got 38 / 64 correct (59.38)
# Checking accuracy on VAL set
# Got 169 / 306 correct (55.23)
#
# Epoch 78, Iteration 15, loss = 0.7912
# Checking accuracy on TRAIN set
# Got 42 / 64 correct (65.62)
# Checking accuracy on VAL set
# Got 169 / 306 correct (55.23)
#
# Epoch 78, Iteration 16, loss = 1.0547
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 167 / 306 correct (54.58)
#
# Epoch 78, Iteration 17, loss = 1.0200
# Checking accuracy on TRAIN set
# Got 42 / 64 correct (65.62)
# Checking accuracy on VAL set
# Got 159 / 306 correct (51.96)
#
# Epoch 78, Iteration 18, loss = 0.9855
# Checking accuracy on TRAIN set
# Got 39 / 64 correct (60.94)
# Checking accuracy on VAL set
# Got 147 / 306 correct (48.04)
#
# Epoch 78, Iteration 19, loss = 0.8713
# Checking accuracy on TRAIN set
# Got 6 / 8 correct (75.00)
# Checking accuracy on VAL set
# Got 145 / 306 correct (47.39)
#
# Checking accuracy on VAL set
# Got 145 / 306 correct (47.39)
# Checking accuracy on TRAIN set
# Got 760 / 1224 correct (62.09)
# Epoch 79, Iteration 0, loss = 0.9341
# Checking accuracy on TRAIN set
# Got 36 / 64 correct (56.25)
# Checking accuracy on VAL set
# Got 144 / 306 correct (47.06)
#
# Epoch 79, Iteration 1, loss = 0.9559
# Checking accuracy on TRAIN set
# Got 43 / 64 correct (67.19)
# Checking accuracy on VAL set
# Got 133 / 306 correct (43.46)
#
# Epoch 79, Iteration 2, loss = 0.9294
# Checking accuracy on TRAIN set
# Got 43 / 64 correct (67.19)
# Checking accuracy on VAL set
# Got 130 / 306 correct (42.48)
#
# Epoch 79, Iteration 3, loss = 1.0715
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 130 / 306 correct (42.48)
#
# Epoch 79, Iteration 4, loss = 1.0292
# Checking accuracy on TRAIN set
# Got 35 / 64 correct (54.69)
# Checking accuracy on VAL set
# Got 127 / 306 correct (41.50)
#
# Epoch 79, Iteration 5, loss = 0.9319
# Checking accuracy on TRAIN set
# Got 38 / 64 correct (59.38)
# Checking accuracy on VAL set
# Got 137 / 306 correct (44.77)
#
# Epoch 79, Iteration 6, loss = 0.9218
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 142 / 306 correct (46.41)
#
# Epoch 79, Iteration 7, loss = 0.8786
# Checking accuracy on TRAIN set
# Got 41 / 64 correct (64.06)
# Checking accuracy on VAL set
# Got 154 / 306 correct (50.33)
#
# Epoch 79, Iteration 8, loss = 0.9500
# Checking accuracy on TRAIN set
# Got 38 / 64 correct (59.38)
# Checking accuracy on VAL set
# Got 151 / 306 correct (49.35)
#
# Epoch 79, Iteration 9, loss = 0.8673
# Checking accuracy on TRAIN set
# Got 42 / 64 correct (65.62)
# Checking accuracy on VAL set
# Got 159 / 306 correct (51.96)
#
# Epoch 79, Iteration 10, loss = 0.8023
# Checking accuracy on TRAIN set
# Got 43 / 64 correct (67.19)
# Checking accuracy on VAL set
# Got 162 / 306 correct (52.94)
#
# Epoch 79, Iteration 11, loss = 0.9856
# Checking accuracy on TRAIN set
# Got 35 / 64 correct (54.69)
# Checking accuracy on VAL set
# Got 163 / 306 correct (53.27)
#
# Epoch 79, Iteration 12, loss = 0.8011
# Checking accuracy on TRAIN set
# Got 46 / 64 correct (71.88)
# Checking accuracy on VAL set
# Got 160 / 306 correct (52.29)
#
# Epoch 79, Iteration 13, loss = 0.9443
# Checking accuracy on TRAIN set
# Got 40 / 64 correct (62.50)
# Checking accuracy on VAL set
# Got 164 / 306 correct (53.59)
#
# Epoch 79, Iteration 14, loss = 0.8500
# Checking accuracy on TRAIN set
# Got 42 / 64 correct (65.62)
# Checking accuracy on VAL set
# Got 166 / 306 correct (54.25)
#
# Epoch 79, Iteration 15, loss = 1.2474
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 164 / 306 correct (53.59)
#
# Epoch 79, Iteration 16, loss = 0.8346
# Checking accuracy on TRAIN set
# Got 44 / 64 correct (68.75)
# Checking accuracy on VAL set
# Got 158 / 306 correct (51.63)
#
# Epoch 79, Iteration 17, loss = 1.0888
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 151 / 306 correct (49.35)
#
# Epoch 79, Iteration 18, loss = 0.9519
# Checking accuracy on TRAIN set
# Got 40 / 64 correct (62.50)
# Checking accuracy on VAL set
# Got 151 / 306 correct (49.35)
#
# Epoch 79, Iteration 19, loss = 0.5576
# Checking accuracy on TRAIN set
# Got 6 / 8 correct (75.00)
# Checking accuracy on VAL set
# Got 151 / 306 correct (49.35)
#
# Checking accuracy on VAL set
# Got 151 / 306 correct (49.35)
# Checking accuracy on TRAIN set
# Got 757 / 1224 correct (61.85)
# DONE TRAINING

# %%
torch.save(best_model, "best_model_LSTM_without_noise_cleanup_whole_time_scale_150_epochs")
torch.save(model, "model_LSTM_without_noise_cleanup_whole_time_scale_150_epochs")
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:402: UserWarning: Couldn't retrieve source code for container of type Flatten. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "

# %%
print("DONE")
per_epoch_train_accuracy_list
# Out:
# DONE
# [0.39869281045751637,
#  0.39869281045751637,
#  0.3700980392156863,
#  0.3700980392156863,
#  0.41830065359477125,
#  0.39869281045751637,
#  0.39869281045751637,
#  0.39869281045751637,
#  0.39869281045751637,
#  0.39869281045751637,
#  0.40032679738562094,
#  0.39869281045751637,
#  0.4485294117647059,
#  0.39869281045751637,
#  0.40032679738562094,
#  0.4035947712418301,
#  0.4264705882352941,
#  0.4117647058823529,
#  0.4665032679738562,
#  0.45016339869281047,
#  0.4125816993464052,
#  0.440359477124183,
#  0.4354575163398693,
#  0.43709150326797386,
#  0.4583333333333333,
#  0.4910130718954248,
#  0.4820261437908497,
#  0.48447712418300654,
#  0.4934640522875817,
#  0.4852941176470588,
#  0.5253267973856209,
#  0.5040849673202614,
#  0.4991830065359477,
#  0.5171568627450981,
#  0.5334967320261438,
#  0.5147058823529411,
#  0.4950980392156863,
#  0.5,
#  0.5326797385620915,
#  0.5285947712418301,
#  0.5490196078431373,
#  0.5302287581699346,
#  0.5122549019607843,
#  0.5424836601307189,
#  0.5318627450980392,
#  0.5498366013071896,
#  0.5449346405228758,
#  0.5081699346405228,
#  0.5375816993464052,
#  0.5310457516339869,
#  0.5563725490196079,
#  0.5400326797385621,
#  0.5686274509803921,
#  0.545751633986928,
#  0.5563725490196079,
#  0.5784313725490197,
#  0.5661764705882353,
#  0.5849673202614379,
#  0.5727124183006536,
#  0.5400326797385621,
#  0.5735294117647058,
#  0.5857843137254902,
#  0.5571895424836601,
#  0.5816993464052288,
#  0.5857843137254902,
#  0.5743464052287581,
#  0.6013071895424836,
#  0.5874183006535948,
#  0.5808823529411765,
#  0.6078431372549019,
#  0.6086601307189542,
#  0.6053921568627451,
#  0.6078431372549019,
#  0.5923202614379085,
#  0.6070261437908496,
#  0.6160130718954249,
#  0.6094771241830066,
#  0.6200980392156863,
#  0.6209150326797386,
#  0.6184640522875817]

# %%
##PLOT LOSS, TRAIN ACCURACY, TEST ACCURACY
import matplotlib.pyplot as plt
max_train_accuracy = np.repeat(np.max(np.array([train_accuracy_list])),   len(train_accuracy_list))

max_test_accuracy = np.repeat(np.max(np.array([test_accuracy_list])),   len(test_accuracy_list))

max_p_e_train_accuracy = np.repeat(np.max(np.array([per_epoch_train_accuracy_list])),   len(per_epoch_train_accuracy_list))

max_p_e_test_accuracy = np.repeat(np.max(np.array([per_epoch_test_accuracy_list])),   len(per_epoch_test_accuracy_list))

# plot the loss history
plt.subplot()
plt.plot(loss_list)
plt.xlabel('iteration')
plt.ylabel('training loss')
plt.title('Training Loss history')
plt.legend()
plt.show()

plt.subplot()
plt.plot(train_accuracy_list, label='train')
plt.plot(test_accuracy_list, label='val')
plt.plot(max_train_accuracy, label='max train acc')
plt.plot(max_test_accuracy, label='max val acc')
plt.title('Classification accuracy history')
plt.xlabel('Iteration')
plt.ylabel('Classification accuracy')
plt.legend()
plt.show()

plt.subplot()
plt.plot(per_epoch_train_accuracy_list, label='train')
plt.plot(per_epoch_test_accuracy_list, label='val')
plt.plot(max_p_e_train_accuracy, label='max train acc')
plt.plot(max_p_e_test_accuracy, label='max val acc')
plt.title('Per Epoch Classification accuracy history')
plt.xlabel('Epoch')
plt.ylabel('Classification accuracy')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
from sklearn.metrics import confusion_matrix
#from resources.plotcm import plot_confusion_matrix
import itertools
import numpy as np
import matplotlib.pyplot as plt

def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion matrix', cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt), horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
def check_train_accuracy1(loader, model, for_confusion_matrix=0):
    #if loader.dataset.train:
    #    print('Checking accuracy on validation set')
    #else:
    #    print('Checking accuracy on test set')
    print('Checking accuracy on TRAIN set')
    num_correct = 0
    num_samples = 0
    model.eval()  # set model to evaluation mode
    true_label_list = []
    predicted_label_list = []
    with torch.no_grad():
        for x, y in loader:
            true_label_list.append(y.cpu().data.numpy())
            x = x.to(device=device, dtype=dtype)  # move to device, e.g. GPU
            y = y.to(device=device, dtype=torch.long)
            #pdb.set_trace()
            #y = torch.stack(y) #.to(device=device)
            #y = y.reshape((x.shape[0]))
            scores = model(x)
            _, preds = scores.max(1)
            predicted_label_list.append(preds.cpu().data.numpy())            
            num_correct += (preds == y).sum()
            num_samples += preds.size(0)
        acc = float(num_correct) / num_samples
        print('Got %d / %d correct (%.2f)' % (num_correct, num_samples, 100 * acc))
        if for_confusion_matrix == 1:
          return acc, true_label_list, predicted_label_list
        else:
          return acc

# %%
#best_model1 = torch.load("model2")
accuracy, true_label, predicted_label = check_train_accuracy1(loader_train, best_model, for_confusion_matrix=1)
true_label = np.concatenate(true_label, axis=None)
#print(true_label)

predicted_label = np.concatenate(predicted_label, axis=None)
#print(predicted_label)

emotion_dict = ('hap',
                'sad',
                'ang',
                'neu'
                )
cm = confusion_matrix(true_label, predicted_label)

#t_t = train_set_targets.cpu().data.numpy()
#predict = preds.cpu().data.numpy()
#t_t = 1 + t_t
#predict = 1 + predict

#for i in range(t_t.shape[0]):
#  print(t_t[i], predict[i])
#print(t_t)
#print(predict)
#print(cm)
plt.figure(figsize=(6,6))
plot_confusion_matrix(cm, emotion_dict)
# Out:
# Checking accuracy on TRAIN set
# Got 731 / 1224 correct (59.72)
# Confusion matrix, without normalization
# [[ 50  74  38  59]
#  [  4 291   5  38]
#  [ 13  27 168  47]
#  [ 19 151  18 222]]

# %%
#best_model1 = torch.load("model1")
accuracy, true_label, predicted_label = check_train_accuracy1(loader_val, best_model, for_confusion_matrix=1)
true_label = np.concatenate(true_label, axis=None)
#print(true_label)

predicted_label = np.concatenate(predicted_label, axis=None)
#print(predicted_label)


cm = confusion_matrix(true_label, predicted_label)

#t_t = train_set_targets.cpu().data.numpy()
#predict = preds.cpu().data.numpy()
#t_t = 1 + t_t
#predict = 1 + predict

#for i in range(t_t.shape[0]):
#  print(t_t[i], predict[i])
#print(t_t)
#print(predict)
#print(cm)
plt.figure(figsize=(6,6))
plot_confusion_matrix(cm, emotion_dict)
# Out:
# Checking accuracy on TRAIN set
# Got 169 / 306 correct (55.23)
# Confusion matrix, without normalization
# [[ 4  9 12 17]
#  [ 1 48  3 16]
#  [ 6  8 65 20]
#  [ 8 17 20 52]]

# %%
accuracy, true_label, predicted_label = check_train_accuracy1(loader_train, model, for_confusion_matrix=1)
true_label = np.concatenate(true_label, axis=None)
#print(true_label)

predicted_label = np.concatenate(predicted_label, axis=None)
#print(predicted_label)

emotion_dict = ('hap',
                'sad',
                'ang',
                'neu'
                )
cm = confusion_matrix(true_label, predicted_label)

#t_t = train_set_targets.cpu().data.numpy()
#predict = preds.cpu().data.numpy()
#t_t = 1 + t_t
#predict = 1 + predict

#for i in range(t_t.shape[0]):
#  print(t_t[i], predict[i])
#print(t_t)
#print(predict)
#print(cm)
plt.figure(figsize=(6,6))
plot_confusion_matrix(cm, emotion_dict)
# Out:
# Checking accuracy on TRAIN set
# Got 757 / 1224 correct (61.85)
# Confusion matrix, without normalization
# [[ 53  46  54  68]
#  [ 12 261  12  53]
#  [ 12  15 194  34]
#  [ 28 109  24 249]]

# %%
#best_model1 = torch.load("model1")
accuracy, true_label, predicted_label = check_train_accuracy1(loader_val, model, for_confusion_matrix=1)
true_label = np.concatenate(true_label, axis=None)
#print(true_label)

predicted_label = np.concatenate(predicted_label, axis=None)
#print(predicted_label)


cm = confusion_matrix(true_label, predicted_label)

#t_t = train_set_targets.cpu().data.numpy()
#predict = preds.cpu().data.numpy()
#t_t = 1 + t_t
#predict = 1 + predict

#for i in range(t_t.shape[0]):
#  print(t_t[i], predict[i])
#print(t_t)
#print(predict)
#print(cm)
plt.figure(figsize=(6,6))
plot_confusion_matrix(cm, emotion_dict)
# Out:
# Checking accuracy on TRAIN set
# Got 151 / 306 correct (49.35)
# Confusion matrix, without normalization
# [[ 4  6 22 10]
#  [ 3 38 10 17]
#  [ 9  4 67 19]
#  [ 8 14 33 42]]
