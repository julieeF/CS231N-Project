# %%
# this mounts your Google Drive to the Colab VM.
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# enter the foldername in your Drive where you have saved the unzipped
# assignment folder, e.g. 'cs231n/assignments/assignment3/'
FOLDERNAME = 'PROJECT/'
assert FOLDERNAME is not None, "[!] Enter the foldername."

# now that we've mounted your Drive, this ensures that
# the Python interpreter of the Colab VM can load
# python files from within it.
import sys
sys.path.append('/content/drive/My Drive/{}'.format(FOLDERNAME))

# this downloads the CIFAR-10 dataset to your Drive
# if it doesn't already exist.
#%cd /content/drive/My\ Drive/$FOLDERNAME/
#!bash get_datasets.sh
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os 
os.chdir("/content/drive/My Drive/")
os.chdir(FOLDERNAME)
#!bash get_datasets.sh

# %%
#"neu_3.0_2.0_2.3333_Whole_Length.png".split('_')

# %%
#import sys
#!{sys.executable} -m pip install torchsummary


from torch.utils.data import Dataset,DataLoader
from torchvision import transforms
import os
import numpy as np
import time
from PIL import Image
#from PIL import ImageFile
#ImageFile.LOAD_TRUNCATED_IMAGES = True
from collections import defaultdict
import cv2
import pdb
IMG_SIZE = (200,300)

from torchvision import models
from torchsummary import summary
import copy

# %%
#dataset_train.__len__
#dataset_test.shape
#dataset_val.shape

#'''test corrupted images'''
#data_path = "/home/mandeep_stanford/cs231n_project/code/pre-processed_data/images_denoised/session1/"
#dataset_train, dataset_test, dataset_val = get_imagenet_datasets(data_path, "cpc")
#
#print(f"Number of train samplest {dataset_train.__len__()}")
#print(f"Number of samples in test split {dataset_test.__len__()}")
#
#BATCH_SIZE = 200
#
#data_loader_train = DataLoader(dataset_train, BATCH_SIZE, shuffle = True)
#data_loader_test = DataLoader(dataset_test, BATCH_SIZE, shuffle = True)
#
#
#import matplotlib.pyplot as plt
#
#fig, axes = plt.subplots(BATCH_SIZE//20,20, figsize=(6,10))
#
#for batch in data_loader_train:
#
#    print(f"Shape of batch['image'] {batch['image'].shape}")
#    print(f"Shape of batch['cls'] {batch['cls'].shape}")
#
#    for i in range(BATCH_SIZE):
#
#        col = i % 20
#        row = i // 20
#
#        img = batch['image'][i].numpy()
#
#        axes[row,col].set_axis_off()
#        #axes[row,col].set_title(batch['class_name'][i])
#        axes[row,col].imshow(np.transpose(img,(1,2,0)))
#
#    plt.show()
#
#    break

# %%
#data_path = "/home/mandeep_stanford/cs231n_project/code/pre-processed_data/images/session1/"
#data_path = "/home/mandeep_stanford/cs231n_project/code/pre-processed_data/combined_session1_2/"
data_path1 = "without_noise_cleanup/session1/"
data_path2 = "without_noise_cleanup/session2/"
data_path3 = "without_noise_cleanup/session3/"
data_path4 = "without_noise_cleanup/session4/"

#img_files = os.listdir("/home/mandeep_stanford/cs231n_project/code/pre-processed_data/images/session1/")
#img_files = os.listdir("/home/mandeep_stanford/cs231n_project/code/pre-processed_data/combined_session1_2/")
#img_files = os.listdir("/home/mandeep_stanford/cs231n_project/code/pre-processed_data/4_EMOTIONS/cb_removed/with_noise_cleanup/session1/")

pkl_file = "without_noise_cleanup_denoised_WHOLE.pkl"

# %%
import pickle
X = []
Y = []
i = 0
#extract_emotion = ['hap','sad','ang','neu','fea', 'exc', 'fru']
extract_emotion = ['hap','sad','ang','neu']
if 0:
    path = [data_path1, data_path2, data_path3, data_path4]
    for p_files in path:
        for file_name in os.listdir(p_files):
                    
            print("Working on ", i)
            i = i+1
            #if i >= 7000:
            #    break
            if "Whole" in file_name.split('_'):
              print("")
            else:
              print("Skipping ", file_name)
              continue
            cat = file_name.split('_')[0]
            if cat in extract_emotion:
                #print("")
                if cat == "hap":
                    cat = 0
                if cat == "sad":
                    cat = 1
                if cat == "ang":
                    cat = 2
                if cat == "neu":
                    cat = 3
            else:
                continue
            
            Y.append(cat)
            img = Image.open(p_files+file_name)
            img = img.convert('RGB')
            tr = transforms.Resize((200,300))
            img=tr(img)
            tr = transforms.ToTensor()
            img1 = tr(img)
            img1 = np.array(img1)
            #X=np.vstack((X,img1))
            X.append(img1)
    
            del img1
            del img
            del tr

    Y = np.asarray(Y)
    X = np.asarray(X)
    data = {}
    data["X"] = X
    data["Y"] = Y
    with open(pkl_file, 'wb') as f:
        pickle.dump(data, f)
        f.close()

# %%
import pickle
import torch
assert '.'.join(torch.__version__.split('.')[:2]) == '1.5'
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torch.utils.data import sampler
import torch.utils.data as data_utils
import torchvision.datasets as dset
import torchvision.transforms as T
import torch.nn.functional as F 
import numpy as np
#pkl_file = "/home/mandeep_stanford/cs231n_project/code/pre-processed_data/images_denoised/session1_pkl_tensor1.pkl"
data = pickle.load(open(pkl_file, 'rb'))
X = data["X"]
Y = data["Y"]

# %%
X.shape
# Out:
# (1530, 3, 200, 300)

# %%
np.unique(Y)
# Out:
# array([0, 1, 2, 3])

# %%
import numpy as np
total_images = X.shape[0]
test_data_images = np.int(total_images*0.2)
train_data_images = total_images - test_data_images
#X_train = X[0:train_data_images,-1]
#y_train = Y[0:train_data_images]
#X_test = X[train_data_images:train_data_images+test_data_images, -1]
#y_test= Y[train_data_images:train_data_images+test_data_images]

#X_train = np.asarray(X_train)
#X_test = np.asarray(X_test)
#y_train = np.asarray(y_train)
#y_test = np.asarray(y_test)

#y_train = y_train.reshape((y_train[0]))
#y_test = y_test.reshape((y_test[0]))
#print(X_train.shape)
#print(y_train.shape)
#print(X_test.shape)
#print(y_test.shape)

# %%
USE_GPU = True

dtype = torch.float32 # we will be using float throughout this tutorial

if USE_GPU and torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')

# Constant to control how frequently we print train loss
print_every = 100

print('using device:', device)
# Out:
# using device: cuda

# %%
train_data = []
keys_array = np.unique(Y)
for i in range(len(X)):
   ind = np.where(keys_array==Y[i]) 
   train_data.append([X[i], Y[i]])
print("DONE")
#dataset = data_utils.TensorDataset(train_data, batch_size=100)
print(train_data_images)
print(train_data_images+test_data_images)
loader_train = DataLoader(train_data, batch_size=64, 
                          sampler=sampler.SubsetRandomSampler(range(0,train_data_images)))

loader_val = DataLoader(train_data, batch_size=64, 
                        sampler=sampler.SubsetRandomSampler(range(train_data_images, train_data_images+test_data_images)))


#for t, (x,y) in enumerate(loader_train):
#  print(t, x, y)
# Out:
# DONE
# 1224
# 1530

# %%
print_every = 1

# %%
def check_train_accuracy(loader, model):
    #if loader.dataset.train:
    #    print('Checking accuracy on validation set')
    #else:
    #    print('Checking accuracy on test set')
    print('Checking accuracy on TRAIN set')
    num_correct = 0
    num_samples = 0
    model.eval()  # set model to evaluation mode
    with torch.no_grad():
        for x, y in loader:
            x = x.to(device=device, dtype=dtype)  # move to device, e.g. GPU
            y = y.to(device=device, dtype=torch.long)
            #pdb.set_trace()
            #y = torch.stack(y) #.to(device=device)
            #y = y.reshape((x.shape[0]))
            scores = model(x)
            _, preds = scores.max(1)
            
            num_correct += (preds == y).sum()
            num_samples += preds.size(0)
        acc = float(num_correct) / num_samples
        print('Got %d / %d correct (%.2f)' % (num_correct, num_samples, 100 * acc))
        return acc

# %%
def check_accuracy_part34(loader, model):
    #if loader.dataset.train:
    #    print('Checking accuracy on validation set')
    #else:
    #    print('Checking accuracy on test set')
    print('Checking accuracy on VAL set')
    num_correct = 0
    num_samples = 0
    model.eval()  # set model to evaluation mode
    with torch.no_grad():
        for x, y in loader:
            x = x.to(device=device, dtype=dtype)  # move to device, e.g. GPU
            y = y.to(device=device, dtype=torch.long)
            #pdb.set_trace()
            #y = torch.stack(y) #.to(device=device)
            #y = y.reshape((x.shape[0]))
            scores = model(x)
            _, preds = scores.max(1)
            
            num_correct += (preds == y).sum()
            num_samples += preds.size(0)
        acc = float(num_correct) / num_samples
        print('Got %d / %d correct (%.2f)' % (num_correct, num_samples, 100 * acc))
        return acc

# %%
def train_part34(model, optimizer, epochs=1):
    """
    Train a model on CIFAR-10 using the PyTorch Module API.
    
    Inputs:
    - model: A PyTorch Module giving the model to train.
    - optimizer: An Optimizer object we will use to train the model
    - epochs: (Optional) A Python integer giving the number of epochs to train for
    
    Returns: Nothing, but prints model accuracies during training.
    """
    acc = 0
    per_epoch_train_accuracy_list = []
    per_epoch_test_accuracy_list = []
    train_accuracy_list = []
    test_accuracy_list = []
    loss_list = []
    best_model = model = model.to(device=device)  # move the model parameters to CPU/GPU
    for e in range(epochs):
        for t, (x, y) in enumerate(loader_train):
            import pdb
            #pdb.set_trace()
            model.train()  # put model to training mode
            x = x.to(device=device, dtype=dtype)  # move to device, e.g. GPU
            y = y.to(device=device, dtype=torch.long)
            #y = torch.stack(y) #.to(device=device)
            #y = y.reshape((x.shape[0]))
            scores = model(x)
            
            loss = F.cross_entropy(scores, y)
            loss_list.append(loss.item())
            # Zero out all of the gradients for the variables which the optimizer
            # will update.
            optimizer.zero_grad()

            # This is the backwards pass: compute the gradient of the loss with
            # respect to each  parameter of the model.
            loss.backward()

            # Actually update the parameters of the model using the gradients
            # computed by the backwards pass.
            optimizer.step()
            #pdb.set_trace()
            #print("IN ITERATION", t)
            if t % print_every == 0:
                print('Epoch %d, Iteration %d, loss = %.4f' % (e, t, loss.item()))
                #pdb.set_trace()
                xx = x.cpu().data.numpy()
                yy = y.cpu().data.numpy()
                tt_data = []
                for i in range(len(xx)):
                  ind = np.where(keys_array==Y[i]) 
                  tt_data.append([xx[i], yy[i]])
                
                train_d = DataLoader(tt_data, batch_size = 1)
                
                train_acc = check_train_accuracy(train_d, model)
                train_accuracy_list.append(train_acc)
                test_acc = check_accuracy_part34(loader_val, model)
                test_accuracy_list.append(test_acc)
                if test_acc > acc:
                  acc = test_acc
                  best_model = copy.deepcopy(model)
                print()
        
        e_test_accuracy = check_accuracy_part34(loader_val, model)        
        per_epoch_test_accuracy_list.append(e_test_accuracy)     
        e_train_accuracy = check_train_accuracy(loader_train, model)        
        per_epoch_train_accuracy_list.append(e_train_accuracy)     
    return best_model, acc, train_accuracy_list, test_accuracy_list, per_epoch_train_accuracy_list, per_epoch_test_accuracy_list, loss_list

# %%
class Flatten(nn.Module):
    def flatten(x):
        N = x.shape[0] # read in N, C, H, W
        return x.view(N, -1)  # "flatten" the C * H * W values into a single vector per image

    def forward(self, x):
        N = x.shape[0]
        return x.view(N, -1)

class LSTM(nn.Module):
    def __init__(self):
        super().__init__()
        #self.model = nn.LSTM(input_size=(32*25*37),hidden_size=128,num_layers=2,batch_first=True,bidirectional =True, dropout=0.1)
        self.model = nn.RNN(input_size=(32*25*37),hidden_size=128,num_layers=2,batch_first=True,bidirectional =True, dropout=0.1)
    def forward(self, x):

        # From [batches, seqs, seq len, features]
        # to [seq len, batch data, features]
        x = x.unsqueeze(1)
       
        # Data is fed to the LSTM
        out, _ = self.model(x)

        # From [seq len, batch, num_directions * hidden_size]
        # to [batches, seqs, seq_len,prediction]
        out = out.squeeze(1)


        return out

#hidden_layer_size = 500
#learning_rate = 1e-2

#model = nn.Sequential(
#    Flatten(),
#    nn.Linear(3 * 200 * 300, hidden_layer_size),
#    nn.ReLU(),
#    nn.Linear(hidden_layer_size, keys_array.shape[0]),
#)


l1 = nn.Sequential(
            nn.Conv2d(3, 16, kernel_size=(12,16), padding=(6,8), stride=1),
            nn.ReLU(),
            #nn.Conv2d(channel_1, channel_1, kernel_size=5, padding=2, stride=1),
            nn.MaxPool2d(2, 2)
)

#for t, (x, y) in enumerate(loader_train):
#            # put model to training mode
#            x = x.to(device=device, dtype=dtype)
#            import pdb
#            pdb.set_trace()
#            break
    
#pdb.set_trace()
#h = l1(x)
#h.shape

l2 = nn.Sequential(
            nn.Conv2d(16, 24, kernel_size=(8,12), padding=(4,6), stride=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2)
)
#h = l2(h)

l3 = nn.Sequential(
            nn.Conv2d(24, 32, kernel_size=(5,7), padding=(2,3), stride=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            Flatten(),
            LSTM()
            
)

#l4 = nn.Sequential(
#            nn.Conv2d(channel_3, channel_4, kernel_size=3, padding=1, stride=1),
#            nn.MaxPool2d(2, 1)
#)

#import pdb
#pdb.set_trace()
hidden_layer_size = keys_array.shape[0]
learning_rate = 1e-4 #1e-4   1e-3 looks gud
model = nn.Sequential(
            l1,
            l2,
            l3,
            nn.Linear(256, 64),
            nn.ReLU(),
            nn.Dropout(p=0.2),
            nn.Linear(64, keys_array.shape[0])
)




# you can use Nesterov momentum in optim.SGD
#optimizer = optim.Adam(model.parameters(), lr=learning_rate,momentum=0.9, nesterov=True)
optimizer = optim.Adam(model.parameters(), lr=learning_rate, 
                     betas=(0.9, 0.999), eps=1e-08, weight_decay=0, amsgrad=False) #weight_decay = 0 luks gud. Trying with 0.1


#best_model, best_test_acc, train_accuracy_list, test_accuracy_list, loss_list = train_part34(model, optimizer, 2)
best_model, best_test_acc, train_accuracy_list, test_accuracy_list, per_epoch_train_accuracy_list, per_epoch_test_accuracy_list, loss_list = train_part34(model, optimizer, 50)
print("DONE TRAINING")
# Out:
# Streaming output truncated to the last 5000 lines.
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 145 / 306 correct (47.39)
#
# Epoch

# Checking accuracy on VAL set
# Got 138 / 306 correct (45.10)
#
# Checking accuracy on VAL set
# Got 138 / 306 correct (45.10)
# Checking accuracy on TRAIN set
# Got 611 / 1224 correct (49.92)
# Epoch 19, Iteration 0, loss = 1.0081
# Checking accuracy on TRAIN set
# Got 42 / 64 correct (65.62)
# Checking accuracy on VAL set
# Got 134 / 306 correct (43.79)
#
# Epoch 19, Iteration 1, loss = 1.2734
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 137 / 306 correct (44.77)
#
# Epoch 19, Iteration 2, loss = 1.1895
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 142 / 306 correct (46.41)
#
# Epoch 19, Iteration 3, loss = 1.1604
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 141 / 306 correct (46.08)
#
# Epoch 19, Iteration 4, loss = 1.0749
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 146 / 306 correct (47.71)
#
# Epoch 19, Iteration 5, loss = 0.9958
# Checking accuracy on TRAIN set
# Got 44 / 64 correct (68.75)
# Checking accuracy on VAL set
# Got 149 / 306 correct (48.69)
#
# Epoch 19, Iteration 6, loss = 1.1235
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 150 / 306 correct (49.02)
#
# Epoch 19, Iteration 7, loss = 1.1141
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 149 / 306 correct (48.69)
#
# Epoch 19, Iteration 8, loss = 1.2030
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 146 / 306 correct (47.71)
#
# Epoch 19, Iteration 9, loss = 1.1446
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 142 / 306 correct (46.41)
#
# Epoch 19, Iteration 10, loss = 1.1698
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 141 / 306 correct (46.08)
#
# Epoch 19, Iteration 11, loss = 1.1355
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 134 / 306 correct (43.79)
#
# Epoch 19, Iteration 12, loss = 1.1174
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 133 / 306 correct (43.46)
#
# Epoch 19, Iteration 13, loss = 0.9347
# Checking accuracy on TRAIN set
# Got 41 / 64 correct (64.06)
# Checking accuracy on VAL set
# Got 138 / 306 correct (45.10)
#
# Epoch 19, Iteration 14, loss = 1.0499
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 143 / 306 correct (46.73)
#
# Epoch 19, Iteration 15, loss = 1.1552
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 150 / 306 correct (49.02)
#
# Epoch 19, Iteration 16, loss = 1.0973
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 153 / 306 correct (50.00)
#
# Epoch 19, Iteration 17, loss = 1.1340
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 154 / 306 correct (50.33)
#
# Epoch 19, Iteration 18, loss = 1.0257
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 146 / 306 correct (47.71)
#
# Epoch 19, Iteration 19, loss = 1.0177
# Checking accuracy on TRAIN set
# Got 6 / 8 correct (75.00)
# Checking accuracy on VAL set
# Got 156 / 306 correct (50.98)
#
# Checking accuracy on VAL set
# Got 156 / 306 correct (50.98)
# Checking accuracy on TRAIN set
# Got 634 / 1224 correct (51.80)
# Epoch 20, Iteration 0, loss = 1.1551
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 156 / 306 correct (50.98)
#
# Epoch 20, Iteration 1, loss = 1.1765
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 154 / 306 correct (50.33)
#
# Epoch 20, Iteration 2, loss = 1.1372
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 149 / 306 correct (48.69)
#
# Epoch 20, Iteration 3, loss = 1.1180
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 144 / 306 correct (47.06)
#
# Epoch 20, Iteration 4, loss = 1.0095
# Checking accuracy on TRAIN set
# Got 41 / 64 correct (64.06)
# Checking accuracy on VAL set
# Got 144 / 306 correct (47.06)
#
# Epoch 20, Iteration 5, loss = 1.0624
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 143 / 306 correct (46.73)
#
# Epoch 20, Iteration 6, loss = 1.2581
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 145 / 306 correct (47.39)
#
# Epoch 20, Iteration 7, loss = 1.0941
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 150 / 306 correct (49.02)
#
# Epoch 20, Iteration 8, loss = 1.2343
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 149 / 306 correct (48.69)
#
# Epoch 20, Iteration 9, loss = 1.0178
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 148 / 306 correct (48.37)
#
# Epoch 20, Iteration 10, loss = 1.0270
# Checking accuracy on TRAIN set
# Got 41 / 64 correct (64.06)
# Checking accuracy on VAL set
# Got 152 / 306 correct (49.67)
#
# Epoch 20, Iteration 11, loss = 1.1290
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 148 / 306 correct (48.37)
#
# Epoch 20, Iteration 12, loss = 1.1150
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 149 / 306 correct (48.69)
#
# Epoch 20, Iteration 13, loss = 1.0554
# Checking accuracy on TRAIN set
# Got 36 / 64 correct (56.25)
# Checking accuracy on VAL set
# Got 148 / 306 correct (48.37)
#
# Epoch 20, Iteration 14, loss = 1.1681
# Checking accuracy on TRAIN set
# Got 20 / 64 correct (31.25)
# Checking accuracy on VAL set
# Got 147 / 306 correct (48.04)
#
# Epoch 20, Iteration 15, loss = 1.0423
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 149 / 306 correct (48.69)
#
# Epoch 20, Iteration 16, loss = 1.0482
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 148 / 306 correct (48.37)
#
# Epoch 20, Iteration 17, loss = 1.0029
# Checking accuracy on TRAIN set
# Got 38 / 64 correct (59.38)
# Checking accuracy on VAL set
# Got 150 / 306 correct (49.02)
#
# Epoch 20, Iteration 18, loss = 1.1760
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 141 / 306 correct (46.08)
#
# Epoch 20, Iteration 19, loss = 1.2635
# Checking accuracy on TRAIN set
# Got 2 / 8 correct (25.00)
# Checking accuracy on VAL set
# Got 151 / 306 correct (49.35)
#
# Checking accuracy on VAL set
# Got 151 / 306 correct (49.35)
# Checking accuracy on TRAIN set
# Got 624 / 1224 correct (50.98)
# Epoch 21, Iteration 0, loss = 1.0583
# Checking accuracy on TRAIN set
# Got 36 / 64 correct (56.25)
# Checking accuracy on VAL set
# Got 154 / 306 correct (50.33)
#
# Epoch 21, Iteration 1, loss = 1.1337
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 157 / 306 correct (51.31)
#
# Epoch 21, Iteration 2, loss = 1.0470
# Checking accuracy on TRAIN set
# Got 26 / 64 correct (40.62)
# Checking accuracy on VAL set
# Got 160 / 306 correct (52.29)
#
# Epoch 21, Iteration 3, loss = 1.1838
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 159 / 306 correct (51.96)
#
# Epoch 21, Iteration 4, loss = 1.0277
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 156 / 306 correct (50.98)
#
# Epoch 21, Iteration 5, loss = 1.0880
# Checking accuracy on TRAIN set
# Got 35 / 64 correct (54.69)
# Checking accuracy on VAL set
# Got 147 / 306 correct (48.04)
#
# Epoch 21, Iteration 6, loss = 1.1861
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 132 / 306 correct (43.14)
#
# Epoch 21, Iteration 7, loss = 1.0710
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 137 / 306 correct (44.77)
#
# Epoch 21, Iteration 8, loss = 1.1950
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 136 / 306 correct (44.44)
#
# Epoch 21, Iteration 9, loss = 1.0427
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 134 / 306 correct (43.79)
#
# Epoch 21, Iteration 10, loss = 1.0227
# Checking accuracy on TRAIN set
# Got 38 / 64 correct (59.38)
# Checking accuracy on VAL set
# Got 130 / 306 correct (42.48)
#
# Epoch 21, Iteration 11, loss = 1.1356
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 134 / 306 correct (43.79)
#
# Epoch 21, Iteration 12, loss = 1.2345
# Checking accuracy on TRAIN set
# Got 25 / 64 correct (39.06)
# Checking accuracy on VAL set
# Got 128 / 306 correct (41.83)
#
# Epoch 21, Iteration 13, loss = 1.0491
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 132 / 306 correct (43.14)
#
# Epoch 21, Iteration 14, loss = 1.1068
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 144 / 306 correct (47.06)
#
# Epoch 21, Iteration 15, loss = 1.2919
# Checking accuracy on TRAIN set
# Got 21 / 64 correct (32.81)
# Checking accuracy on VAL set
# Got 142 / 306 correct (46.41)
#
# Epoch 21, Iteration 16, loss = 1.1449
# Checking accuracy on TRAIN set
# Got 38 / 64 correct (59.38)
# Checking accuracy on VAL set
# Got 140 / 306 correct (45.75)
#
# Epoch 21, Iteration 17, loss = 1.1613
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 132 / 306 correct (43.14)
#
# Epoch 21, Iteration 18, loss = 1.0618
# Checking accuracy on TRAIN set
# Got 35 / 64 correct (54.69)
# Checking accuracy on VAL set
# Got 141 / 306 correct (46.08)
#
# Epoch 21, Iteration 19, loss = 1.1049
# Checking accuracy on TRAIN set
# Got 3 / 8 correct (37.50)
# Checking accuracy on VAL set
# Got 131 / 306 correct (42.81)
#
# Checking accuracy on VAL set
# Got 131 / 306 correct (42.81)
# Checking accuracy on TRAIN set
# Got 622 / 1224 correct (50.82)
# Epoch 22, Iteration 0, loss = 1.1167
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 128 / 306 correct (41.83)
#
# Epoch 22, Iteration 1, loss = 1.1059
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 129 / 306 correct (42.16)
#
# Epoch 22, Iteration 2, loss = 1.0049
# Checking accuracy on TRAIN set
# Got 39 / 64 correct (60.94)
# Checking accuracy on VAL set
# Got 135 / 306 correct (44.12)
#
# Epoch 22, Iteration 3, loss = 1.1225
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 136 / 306 correct (44.44)
#
# Epoch 22, Iteration 4, loss = 1.0236
# Checking accuracy on TRAIN set
# Got 38 / 64 correct (59.38)
# Checking accuracy on VAL set
# Got 141 / 306 correct (46.08)
#
# Epoch 22, Iteration 5, loss = 0.9902
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 142 / 306 correct (46.41)
#
# Epoch 22, Iteration 6, loss = 1.1337
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 142 / 306 correct (46.41)
#
# Epoch 22, Iteration 7, loss = 1.1223
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 142 / 306 correct (46.41)
#
# Epoch 22, Iteration 8, loss = 1.1212
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 145 / 306 correct (47.39)
#
# Epoch 22, Iteration 9, loss = 1.0090
# Checking accuracy on TRAIN set
# Got 40 / 64 correct (62.50)
# Checking accuracy on VAL set
# Got 144 / 306 correct (47.06)
#
# Epoch 22, Iteration 10, loss = 1.2827
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 143 / 306 correct (46.73)
#
# Epoch 22, Iteration 11, loss = 1.1096
# Checking accuracy on TRAIN set
# Got 35 / 64 correct (54.69)
# Checking accuracy on VAL set
# Got 146 / 306 correct (47.71)
#
# Epoch 22, Iteration 12, loss = 1.1184
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 145 / 306 correct (47.39)
#
# Epoch 22, Iteration 13, loss = 1.2478
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 143 / 306 correct (46.73)
#
# Epoch 22, Iteration 14, loss = 0.9677
# Checking accuracy on TRAIN set
# Got 35 / 64 correct (54.69)
# Checking accuracy on VAL set
# Got 140 / 306 correct (45.75)
#
# Epoch 22, Iteration 15, loss = 1.1210
# Checking accuracy on TRAIN set
# Got 35 / 64 correct (54.69)
# Checking accuracy on VAL set
# Got 135 / 306 correct (44.12)
#
# Epoch 22, Iteration 16, loss = 1.0890
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 143 / 306 correct (46.73)
#
# Epoch 22, Iteration 17, loss = 1.1499
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 149 / 306 correct (48.69)
#
# Epoch 22, Iteration 18, loss = 0.9767
# Checking accuracy on TRAIN set
# Got 36 / 64 correct (56.25)
# Checking accuracy on VAL set
# Got 151 / 306 correct (49.35)
#
# Epoch 22, Iteration 19, loss = 0.8962
# Checking accuracy on TRAIN set
# Got 5 / 8 correct (62.50)
# Checking accuracy on VAL set
# Got 156 / 306 correct (50.98)
#
# Checking accuracy on VAL set
# Got 156 / 306 correct (50.98)
# Checking accuracy on TRAIN set
# Got 630 / 1224 correct (51.47)
# Epoch 23, Iteration 0, loss = 1.2489
# Checking accuracy on TRAIN set
# Got 26 / 64 correct (40.62)
# Checking accuracy on VAL set
# Got 157 / 306 correct (51.31)
#
# Epoch 23, Iteration 1, loss = 1.2499
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 156 / 306 correct (50.98)
#
# Epoch 23, Iteration 2, loss = 1.0244
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 155 / 306 correct (50.65)
#
# Epoch 23, Iteration 3, loss = 1.0073
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 154 / 306 correct (50.33)
#
# Epoch 23, Iteration 4, loss = 1.0927
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 145 / 306 correct (47.39)
#
# Epoch 23, Iteration 5, loss = 1.1238
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 142 / 306 correct (46.41)
#
# Epoch 23, Iteration 6, loss = 1.0598
# Checking accuracy on TRAIN set
# Got 35 / 64 correct (54.69)
# Checking accuracy on VAL set
# Got 140 / 306 correct (45.75)
#
# Epoch 23, Iteration 7, loss = 1.1900
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 138 / 306 correct (45.10)
#
# Epoch 23, Iteration 8, loss = 1.0205
# Checking accuracy on TRAIN set
# Got 36 / 64 correct (56.25)
# Checking accuracy on VAL set
# Got 141 / 306 correct (46.08)
#
# Epoch 23, Iteration 9, loss = 1.0109
# Checking accuracy on TRAIN set
# Got 35 / 64 correct (54.69)
# Checking accuracy on VAL set
# Got 144 / 306 correct (47.06)
#
# Epoch 23, Iteration 10, loss = 1.1458
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 144 / 306 correct (47.06)
#
# Epoch 23, Iteration 11, loss = 1.0921
# Checking accuracy on TRAIN set
# Got 38 / 64 correct (59.38)
# Checking accuracy on VAL set
# Got 147 / 306 correct (48.04)
#
# Epoch 23, Iteration 12, loss = 1.1203
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 148 / 306 correct (48.37)
#
# Epoch 23, Iteration 13, loss = 1.0758
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 151 / 306 correct (49.35)
#
# Epoch 23, Iteration 14, loss = 1.1196
# Checking accuracy on TRAIN set
# Got 36 / 64 correct (56.25)
# Checking accuracy on VAL set
# Got 148 / 306 correct (48.37)
#
# Epoch 23, Iteration 15, loss = 1.0722
# Checking accuracy on TRAIN set
# Got 40 / 64 correct (62.50)
# Checking accuracy on VAL set
# Got 144 / 306 correct (47.06)
#
# Epoch 23, Iteration 16, loss = 1.0686
# Checking accuracy on TRAIN set
# Got 35 / 64 correct (54.69)
# Checking accuracy on VAL set
# Got 136 / 306 correct (44.44)
#
# Epoch 23, Iteration 17, loss = 1.0577
# Checking accuracy on TRAIN set
# Got 35 / 64 correct (54.69)
# Checking accuracy on VAL set
# Got 138 / 306 correct (45.10)
#
# Epoch 23, Iteration 18, loss = 1.0954
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 133 / 306 correct (43.46)
#
# Epoch 23, Iteration 19, loss = 1.0131
# Checking accuracy on TRAIN set
# Got 5 / 8 correct (62.50)
# Checking accuracy on VAL set
# Got 135 / 306 correct (44.12)
#
# Checking accuracy on VAL set
# Got 135 / 306 correct (44.12)
# Checking accuracy on TRAIN set
# Got 662 / 1224 correct (54.08)
# Epoch 24, Iteration 0, loss = 1.0850
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 143 / 306 correct (46.73)
#
# Epoch 24, Iteration 1, loss = 0.9677
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 156 / 306 correct (50.98)
#
# Epoch 24, Iteration 2, loss = 1.1784
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 158 / 306 correct (51.63)
#
# Epoch 24, Iteration 3, loss = 1.1006
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 158 / 306 correct (51.63)
#
# Epoch 24, Iteration 4, loss = 1.1475
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 143 / 306 correct (46.73)
#
# Epoch 24, Iteration 5, loss = 1.0387
# Checking accuracy on TRAIN set
# Got 35 / 64 correct (54.69)
# Checking accuracy on VAL set
# Got 140 / 306 correct (45.75)
#
# Epoch 24, Iteration 6, loss = 1.1060
# Checking accuracy on TRAIN set
# Got 38 / 64 correct (59.38)
# Checking accuracy on VAL set
# Got 136 / 306 correct (44.44)
#
# Epoch 24, Iteration 7, loss = 1.0168
# Checking accuracy on TRAIN set
# Got 35 / 64 correct (54.69)
# Checking accuracy on VAL set
# Got 138 / 306 correct (45.10)
#
# Epoch 24, Iteration 8, loss = 1.1849
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 145 / 306 correct (47.39)
#
# Epoch 24, Iteration 9, loss = 1.0331
# Checking accuracy on TRAIN set
# ...
# Got 141 / 306 correct (46.08)
#
# Epoch 45, Iteration 2, loss = 0.8440
# Checking accuracy on TRAIN set
# Got 43 / 64 correct (67.19)
# Checking accuracy on VAL set
# Got 138 / 306 correct (45.10)
#
# Epoch 45, Iteration 3, loss = 0.9379
# Checking accuracy on TRAIN set
# Got 40 / 64 correct (62.50)
# Checking accuracy on VAL set
# Got 141 / 306 correct (46.08)
#
# Epoch 45, Iteration 4, loss = 0.9014
# Checking accuracy on TRAIN set
# Got 36 / 64 correct (56.25)
# Checking accuracy on VAL set
# Got 147 / 306 correct (48.04)
#
# Epoch 45, Iteration 5, loss = 0.8482
# Checking accuracy on TRAIN set
# Got 41 / 64 correct (64.06)
# Checking accuracy on VAL set
# Got 161 / 306 correct (52.61)
#
# Epoch 45, Iteration 6, loss = 0.8370
# Checking accuracy on TRAIN set
# Got 41 / 64 correct (64.06)
# Checking accuracy on VAL set
# Got 160 / 306 correct (52.29)
#
# Epoch 45, Iteration 7, loss = 0.9283
# Checking accuracy on TRAIN set
# Got 39 / 64 correct (60.94)
# Checking accuracy on VAL set
# Got 160 / 306 correct (52.29)
#
# Epoch 45, Iteration 8, loss = 0.7634
# Checking accuracy on TRAIN set
# Got 47 / 64 correct (73.44)
# Checking accuracy on VAL set
# Got 156 / 306 correct (50.98)
#
# Epoch 45, Iteration 9, loss = 1.0765
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 158 / 306 correct (51.63)
#
# Epoch 45, Iteration 10, loss = 0.9499
# Checking accuracy on TRAIN set
# Got 44 / 64 correct (68.75)
# Checking accuracy on VAL set
# Got 154 / 306 correct (50.33)
#
# Epoch 45, Iteration 11, loss = 1.1110
# Checking accuracy on TRAIN set
# Got 41 / 64 correct (64.06)
# Checking accuracy on VAL set
# Got 148 / 306 correct (48.37)
#
# Epoch 45, Iteration 12, loss = 0.9943
# Checking accuracy on TRAIN set
# Got 39 / 64 correct (60.94)
# Checking accuracy on VAL set
# Got 150 / 306 correct (49.02)
#
# Epoch 45, Iteration 13, loss = 1.0445
# Checking accuracy on TRAIN set
# Got 38 / 64 correct (59.38)
# Checking accuracy on VAL set
# Got 143 / 306 correct (46.73)
#
# Epoch 45, Iteration 14, loss = 0.8385
# Checking accuracy on TRAIN set
# Got 42 / 64 correct (65.62)
# Checking accuracy on VAL set
# Got 142 / 306 correct (46.41)
#
# Epoch 45, Iteration 15, loss = 0.8867
# Checking accuracy on TRAIN set
# Got 42 / 64 correct (65.62)
# Checking accuracy on VAL set
# Got 141 / 306 correct (46.08)
#
# Epoch 45, Iteration 16, loss = 0.9544
# Checking accuracy on TRAIN set
# Got 43 / 64 correct (67.19)
# Checking accuracy on VAL set
# Got 145 / 306 correct (47.39)
#
# Epoch 45, Iteration 17, loss = 1.0415
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 146 / 306 correct (47.71)
#
# Epoch 45, Iteration 18, loss = 0.9570
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 155 / 306 correct (50.65)
#
# Epoch 45, Iteration 19, loss = 1.0248
# Checking accuracy on TRAIN set
# Got 4 / 8 correct (50.00)
# Checking accuracy on VAL set
# Got 152 / 306 correct (49.67)
#
# Checking accuracy on VAL set
# Got 152 / 306 correct (49.67)
# Checking accuracy on TRAIN set
# Got 779 / 1224 correct (63.64)
# Epoch 46, Iteration 0, loss = 0.9430
# Checking accuracy on TRAIN set
# Got 36 / 64 correct (56.25)
# Checking accuracy on VAL set
# Got 146 / 306 correct (47.71)
#
# Epoch 46, Iteration 1, loss = 0.7996
# Checking accuracy on TRAIN set
# Got 48 / 64 correct (75.00)
# Checking accuracy on VAL set
# Got 144 / 306 correct (47.06)
#
# Epoch 46, Iteration 2, loss = 0.9401
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 140 / 306 correct (45.75)
#
# Epoch 46, Iteration 3, loss = 1.1512
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 138 / 306 correct (45.10)
#
# Epoch 46, Iteration 4, loss = 1.0436
# Checking accuracy on TRAIN set
# Got 35 / 64 correct (54.69)
# Checking accuracy on VAL set
# Got 139 / 306 correct (45.42)
#
# Epoch 46, Iteration 5, loss = 0.8680
# Checking accuracy on TRAIN set
# Got 41 / 64 correct (64.06)
# Checking accuracy on VAL set
# Got 135 / 306 correct (44.12)
#
# Epoch 46, Iteration 6, loss = 0.8871
# Checking accuracy on TRAIN set
# Got 42 / 64 correct (65.62)
# Checking accuracy on VAL set
# Got 139 / 306 correct (45.42)
#
# Epoch 46, Iteration 7, loss = 0.8900
# Checking accuracy on TRAIN set
# Got 44 / 64 correct (68.75)
# Checking accuracy on VAL set
# Got 137 / 306 correct (44.77)
#
# Epoch 46, Iteration 8, loss = 0.9170
# Checking accuracy on TRAIN set
# Got 39 / 64 correct (60.94)
# Checking accuracy on VAL set
# Got 135 / 306 correct (44.12)
#
# Epoch 46, Iteration 9, loss = 0.9576
# Checking accuracy on TRAIN set
# Got 40 / 64 correct (62.50)
# Checking accuracy on VAL set
# Got 135 / 306 correct (44.12)
#
# Epoch 46, Iteration 10, loss = 0.8685
# Checking accuracy on TRAIN set
# Got 47 / 64 correct (73.44)
# Checking accuracy on VAL set
# Got 145 / 306 correct (47.39)
#
# Epoch 46, Iteration 11, loss = 1.0094
# Checking accuracy on TRAIN set
# Got 38 / 64 correct (59.38)
# Checking accuracy on VAL set
# Got 152 / 306 correct (49.67)
#
# Epoch 46, Iteration 12, loss = 1.0086
# Checking accuracy on TRAIN set
# Got 41 / 64 correct (64.06)
# Checking accuracy on VAL set
# Got 156 / 306 correct (50.98)
#
# Epoch 46, Iteration 13, loss = 0.8433
# Checking accuracy on TRAIN set
# Got 41 / 64 correct (64.06)
# Checking accuracy on VAL set
# Got 165 / 306 correct (53.92)
#
# Epoch 46, Iteration 14, loss = 0.8314
# Checking accuracy on TRAIN set
# Got 45 / 64 correct (70.31)
# Checking accuracy on VAL set
# Got 164 / 306 correct (53.59)
#
# Epoch 46, Iteration 15, loss = 0.9489
# Checking accuracy on TRAIN set
# Got 38 / 64 correct (59.38)
# Checking accuracy on VAL set
# Got 164 / 306 correct (53.59)
#
# Epoch 46, Iteration 16, loss = 0.9814
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 162 / 306 correct (52.94)
#
# Epoch 46, Iteration 17, loss = 0.9635
# Checking accuracy on TRAIN set
# Got 41 / 64 correct (64.06)
# Checking accuracy on VAL set
# Got 159 / 306 correct (51.96)
#
# Epoch 46, Iteration 18, loss = 0.8568
# Checking accuracy on TRAIN set
# Got 44 / 64 correct (68.75)
# Checking accuracy on VAL set
# Got 148 / 306 correct (48.37)
#
# Epoch 46, Iteration 19, loss = 1.1197
# Checking accuracy on TRAIN set
# Got 4 / 8 correct (50.00)
# Checking accuracy on VAL set
# Got 142 / 306 correct (46.41)
#
# Checking accuracy on VAL set
# Got 142 / 306 correct (46.41)
# Checking accuracy on TRAIN set
# Got 779 / 1224 correct (63.64)
# Epoch 47, Iteration 0, loss = 0.9902
# Checking accuracy on TRAIN set
# Got 43 / 64 correct (67.19)
# Checking accuracy on VAL set
# Got 143 / 306 correct (46.73)
#
# Epoch 47, Iteration 1, loss = 0.9025
# Checking accuracy on TRAIN set
# Got 40 / 64 correct (62.50)
# Checking accuracy on VAL set
# Got 141 / 306 correct (46.08)
#
# Epoch 47, Iteration 2, loss = 0.8679
# Checking accuracy on TRAIN set
# Got 42 / 64 correct (65.62)
# Checking accuracy on VAL set
# Got 141 / 306 correct (46.08)
#
# Epoch 47, Iteration 3, loss = 0.9641
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 141 / 306 correct (46.08)
#
# Epoch 47, Iteration 4, loss = 0.8487
# Checking accuracy on TRAIN set
# Got 43 / 64 correct (67.19)
# Checking accuracy on VAL set
# Got 139 / 306 correct (45.42)
#
# Epoch 47, Iteration 5, loss = 1.0247
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 140 / 306 correct (45.75)
#
# Epoch 47, Iteration 6, loss = 0.8550
# Checking accuracy on TRAIN set
# Got 46 / 64 correct (71.88)
# Checking accuracy on VAL set
# Got 145 / 306 correct (47.39)
#
# Epoch 47, Iteration 7, loss = 0.8979
# Checking accuracy on TRAIN set
# Got 41 / 64 correct (64.06)
# Checking accuracy on VAL set
# Got 154 / 306 correct (50.33)
#
# Epoch 47, Iteration 8, loss = 1.0873
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 159 / 306 correct (51.96)
#
# Epoch 47, Iteration 9, loss = 0.9465
# Checking accuracy on TRAIN set
# Got 43 / 64 correct (67.19)
# Checking accuracy on VAL set
# Got 161 / 306 correct (52.61)
#
# Epoch 47, Iteration 10, loss = 0.8273
# Checking accuracy on TRAIN set
# Got 44 / 64 correct (68.75)
# Checking accuracy on VAL set
# Got 162 / 306 correct (52.94)
#
# Epoch 47, Iteration 11, loss = 1.0269
# Checking accuracy on TRAIN set
# Got 39 / 64 correct (60.94)
# Checking accuracy on VAL set
# Got 160 / 306 correct (52.29)
#
# Epoch 47, Iteration 12, loss = 0.7471
# Checking accuracy on TRAIN set
# Got 48 / 64 correct (75.00)
# Checking accuracy on VAL set
# Got 157 / 306 correct (51.31)
#
# Epoch 47, Iteration 13, loss = 0.9810
# Checking accuracy on TRAIN set
# Got 36 / 64 correct (56.25)
# Checking accuracy on VAL set
# Got 152 / 306 correct (49.67)
#
# Epoch 47, Iteration 14, loss = 0.8078
# Checking accuracy on TRAIN set
# Got 41 / 64 correct (64.06)
# Checking accuracy on VAL set
# Got 153 / 306 correct (50.00)
#
# Epoch 47, Iteration 15, loss = 0.9266
# Checking accuracy on TRAIN set
# Got 42 / 64 correct (65.62)
# Checking accuracy on VAL set
# Got 148 / 306 correct (48.37)
#
# Epoch 47, Iteration 16, loss = 1.0117
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 154 / 306 correct (50.33)
#
# Epoch 47, Iteration 17, loss = 0.8464
# Checking accuracy on TRAIN set
# Got 44 / 64 correct (68.75)
# Checking accuracy on VAL set
# Got 153 / 306 correct (50.00)
#
# Epoch 47, Iteration 18, loss = 0.9011
# Checking accuracy on TRAIN set
# Got 45 / 64 correct (70.31)
# Checking accuracy on VAL set
# Got 153 / 306 correct (50.00)
#
# Epoch 47, Iteration 19, loss = 0.7750
# Checking accuracy on TRAIN set
# Got 5 / 8 correct (62.50)
# Checking accuracy on VAL set
# Got 154 / 306 correct (50.33)
#
# Checking accuracy on VAL set
# Got 154 / 306 correct (50.33)
# Checking accuracy on TRAIN set
# Got 784 / 1224 correct (64.05)
# Epoch 48, Iteration 0, loss = 0.9531
# Checking accuracy on TRAIN set
# Got 38 / 64 correct (59.38)
# Checking accuracy on VAL set
# Got 153 / 306 correct (50.00)
#
# Epoch 48, Iteration 1, loss = 0.9325
# Checking accuracy on TRAIN set
# Got 36 / 64 correct (56.25)
# Checking accuracy on VAL set
# Got 153 / 306 correct (50.00)
#
# Epoch 48, Iteration 2, loss = 0.9391
# Checking accuracy on TRAIN set
# Got 40 / 64 correct (62.50)
# Checking accuracy on VAL set
# Got 151 / 306 correct (49.35)
#
# Epoch 48, Iteration 3, loss = 0.9544
# Checking accuracy on TRAIN set
# Got 39 / 64 correct (60.94)
# Checking accuracy on VAL set
# Got 152 / 306 correct (49.67)
#
# Epoch 48, Iteration 4, loss = 0.7992
# Checking accuracy on TRAIN set
# Got 42 / 64 correct (65.62)
# Checking accuracy on VAL set
# Got 149 / 306 correct (48.69)
#
# Epoch 48, Iteration 5, loss = 0.7699
# Checking accuracy on TRAIN set
# Got 47 / 64 correct (73.44)
# Checking accuracy on VAL set
# Got 148 / 306 correct (48.37)
#
# Epoch 48, Iteration 6, loss = 0.9543
# Checking accuracy on TRAIN set
# Got 40 / 64 correct (62.50)
# Checking accuracy on VAL set
# Got 156 / 306 correct (50.98)
#
# Epoch 48, Iteration 7, loss = 0.9926
# Checking accuracy on TRAIN set
# Got 39 / 64 correct (60.94)
# Checking accuracy on VAL set
# Got 154 / 306 correct (50.33)
#
# Epoch 48, Iteration 8, loss = 0.9434
# Checking accuracy on TRAIN set
# Got 38 / 64 correct (59.38)
# Checking accuracy on VAL set
# Got 152 / 306 correct (49.67)
#
# Epoch 48, Iteration 9, loss = 0.8622
# Checking accuracy on TRAIN set
# Got 44 / 64 correct (68.75)
# Checking accuracy on VAL set
# Got 151 / 306 correct (49.35)
#
# Epoch 48, Iteration 10, loss = 0.9862
# Checking accuracy on TRAIN set
# Got 45 / 64 correct (70.31)
# Checking accuracy on VAL set
# Got 148 / 306 correct (48.37)
#
# Epoch 48, Iteration 11, loss = 0.9064
# Checking accuracy on TRAIN set
# Got 39 / 64 correct (60.94)
# Checking accuracy on VAL set
# Got 146 / 306 correct (47.71)
#
# Epoch 48, Iteration 12, loss = 1.0454
# Checking accuracy on TRAIN set
# Got 36 / 64 correct (56.25)
# Checking accuracy on VAL set
# Got 148 / 306 correct (48.37)
#
# Epoch 48, Iteration 13, loss = 0.8514
# Checking accuracy on TRAIN set
# Got 49 / 64 correct (76.56)
# Checking accuracy on VAL set
# Got 147 / 306 correct (48.04)
#
# Epoch 48, Iteration 14, loss = 0.8778
# Checking accuracy on TRAIN set
# Got 41 / 64 correct (64.06)
# Checking accuracy on VAL set
# Got 147 / 306 correct (48.04)
#
# Epoch 48, Iteration 15, loss = 1.0049
# Checking accuracy on TRAIN set
# Got 44 / 64 correct (68.75)
# Checking accuracy on VAL set
# Got 150 / 306 correct (49.02)
#
# Epoch 48, Iteration 16, loss = 0.8765
# Checking accuracy on TRAIN set
# Got 40 / 64 correct (62.50)
# Checking accuracy on VAL set
# Got 156 / 306 correct (50.98)
#
# Epoch 48, Iteration 17, loss = 0.7004
# Checking accuracy on TRAIN set
# Got 47 / 64 correct (73.44)
# Checking accuracy on VAL set
# Got 157 / 306 correct (51.31)
#
# Epoch 48, Iteration 18, loss = 0.7881
# Checking accuracy on TRAIN set
# Got 44 / 64 correct (68.75)
# Checking accuracy on VAL set
# Got 158 / 306 correct (51.63)
#
# Epoch 48, Iteration 19, loss = 0.9167
# Checking accuracy on TRAIN set
# Got 4 / 8 correct (50.00)
# Checking accuracy on VAL set
# Got 164 / 306 correct (53.59)
#
# Checking accuracy on VAL set
# Got 164 / 306 correct (53.59)
# Checking accuracy on TRAIN set
# Got 791 / 1224 correct (64.62)
# Epoch 49, Iteration 0, loss = 0.9671
# Checking accuracy on TRAIN set
# Got 39 / 64 correct (60.94)
# Checking accuracy on VAL set
# Got 163 / 306 correct (53.27)
#
# Epoch 49, Iteration 1, loss = 0.9025
# Checking accuracy on TRAIN set
# Got 44 / 64 correct (68.75)
# Checking accuracy on VAL set
# Got 160 / 306 correct (52.29)
#
# Epoch 49, Iteration 2, loss = 0.9366
# Checking accuracy on TRAIN set
# Got 42 / 64 correct (65.62)
# Checking accuracy on VAL set
# Got 160 / 306 correct (52.29)
#
# Epoch 49, Iteration 3, loss = 0.8212
# Checking accuracy on TRAIN set
# Got 42 / 64 correct (65.62)
# Checking accuracy on VAL set
# Got 158 / 306 correct (51.63)
#
# Epoch 49, Iteration 4, loss = 1.1772
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 151 / 306 correct (49.35)
#
# Epoch 49, Iteration 5, loss = 0.7738
# Checking accuracy on TRAIN set
# Got 46 / 64 correct (71.88)
# Checking accuracy on VAL set
# Got 149 / 306 correct (48.69)
#
# Epoch 49, Iteration 6, loss = 0.8657
# Checking accuracy on TRAIN set
# Got 41 / 64 correct (64.06)
# Checking accuracy on VAL set
# Got 150 / 306 correct (49.02)
#
# Epoch 49, Iteration 7, loss = 0.7511
# Checking accuracy on TRAIN set
# Got 48 / 64 correct (75.00)
# Checking accuracy on VAL set
# Got 144 / 306 correct (47.06)
#
# Epoch 49, Iteration 8, loss = 0.9450
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 148 / 306 correct (48.37)
#
# Epoch 49, Iteration 9, loss = 0.8810
# Checking accuracy on TRAIN set
# Got 40 / 64 correct (62.50)
# Checking accuracy on VAL set
# Got 153 / 306 correct (50.00)
#
# Epoch 49, Iteration 10, loss = 0.8860
# Checking accuracy on TRAIN set
# Got 41 / 64 correct (64.06)
# Checking accuracy on VAL set
# Got 153 / 306 correct (50.00)
#
# Epoch 49, Iteration 11, loss = 0.8458
# Checking accuracy on TRAIN set
# Got 45 / 64 correct (70.31)
# Checking accuracy on VAL set
# Got 153 / 306 correct (50.00)
#
# Epoch 49, Iteration 12, loss = 0.9164
# Checking accuracy on TRAIN set
# Got 45 / 64 correct (70.31)
# Checking accuracy on VAL set
# Got 154 / 306 correct (50.33)
#
# Epoch 49, Iteration 13, loss = 0.8678
# Checking accuracy on TRAIN set
# Got 42 / 64 correct (65.62)
# Checking accuracy on VAL set
# Got 151 / 306 correct (49.35)
#
# Epoch 49, Iteration 14, loss = 0.8514
# Checking accuracy on TRAIN set
# Got 40 / 64 correct (62.50)
# Checking accuracy on VAL set
# Got 150 / 306 correct (49.02)
#
# Epoch 49, Iteration 15, loss = 0.7890
# Checking accuracy on TRAIN set
# Got 44 / 64 correct (68.75)
# Checking accuracy on VAL set
# Got 148 / 306 correct (48.37)
#
# Epoch 49, Iteration 16, loss = 0.9017
# Checking accuracy on TRAIN set
# Got 41 / 64 correct (64.06)
# Checking accuracy on VAL set
# Got 147 / 306 correct (48.04)
#
# Epoch 49, Iteration 17, loss = 0.8545
# Checking accuracy on TRAIN set
# Got 43 / 64 correct (67.19)
# Checking accuracy on VAL set
# Got 149 / 306 correct (48.69)
#
# Epoch 49, Iteration 18, loss = 0.7809
# Checking accuracy on TRAIN set
# Got 46 / 64 correct (71.88)
# Checking accuracy on VAL set
# Got 152 / 306 correct (49.67)
#
# Epoch 49, Iteration 19, loss = 1.2590
# Checking accuracy on TRAIN set
# Got 5 / 8 correct (62.50)
# Checking accuracy on VAL set
# Got 155 / 306 correct (50.65)
#
# Checking accuracy on VAL set
# Got 155 / 306 correct (50.65)
# Checking accuracy on TRAIN set
# Got 809 / 1224 correct (66.09)
# DONE TRAINING

# %%
torch.save(best_model, "best_model_LSTM_without_noise_cleanup_whole_time_scale_150_epochs")
torch.save(model, "model_LSTM_without_noise_cleanup_whole_time_scale_150_epochs")
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:402: UserWarning: Couldn't retrieve source code for container of type Flatten. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:402: UserWarning: Couldn't retrieve source code for container of type LSTM. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "

# %%
print("DONE")
per_epoch_train_accuracy_list
# Out:
# DONE
# [0.39869281045751637,
#  0.39869281045751637,
#  0.39869281045751637,
#  0.39869281045751637,
#  0.39869281045751637,
#  0.39869281045751637,
#  0.41748366013071897,
#  0.45098039215686275,
#  0.46486928104575165,
#  0.46568627450980393,
#  0.4272875816993464,
#  0.4256535947712418,
#  0.47467320261437906,
#  0.46078431372549017,
#  0.4738562091503268,
#  0.46486928104575165,
#  0.48856209150326796,
#  0.5024509803921569,
#  0.4991830065359477,
#  0.5179738562091504,
#  0.5098039215686274,
#  0.5081699346405228,
#  0.5147058823529411,
#  0.5408496732026143,
#  0.5310457516339869,
#  0.5318627450980392,
#  0.5400326797385621,
#  0.5367647058823529,
#  0.5465686274509803,
#  0.5473856209150327,
#  0.5645424836601307,
#  0.5580065359477124,
#  0.5686274509803921,
#  0.553921568627451,
#  0.5555555555555556,
#  0.5784313725490197,
#  0.5498366013071896,
#  0.5964052287581699,
#  0.5947712418300654,
#  0.6078431372549019,
#  0.579248366013072,
#  0.5808823529411765,
#  0.6086601307189542,
#  0.6143790849673203,
#  0.6372549019607843,
#  0.636437908496732,
#  0.636437908496732,
#  0.6405228758169934,
#  0.6462418300653595,
#  0.6609477124183006]

# %%
##PLOT LOSS, TRAIN ACCURACY, TEST ACCURACY
import matplotlib.pyplot as plt
max_train_accuracy = np.repeat(np.max(np.array([train_accuracy_list])),   len(train_accuracy_list))

max_test_accuracy = np.repeat(np.max(np.array([test_accuracy_list])),   len(test_accuracy_list))

max_p_e_train_accuracy = np.repeat(np.max(np.array([per_epoch_train_accuracy_list])),   len(per_epoch_train_accuracy_list))

max_p_e_test_accuracy = np.repeat(np.max(np.array([per_epoch_test_accuracy_list])),   len(per_epoch_test_accuracy_list))

# plot the loss history
plt.subplot()
plt.plot(loss_list)
plt.xlabel('iteration')
plt.ylabel('training loss')
plt.title('Training Loss history')
plt.legend()
plt.show()

plt.subplot()
plt.plot(train_accuracy_list, label='train')
plt.plot(test_accuracy_list, label='val')
plt.plot(max_train_accuracy, label='max train acc')
plt.plot(max_test_accuracy, label='max val acc')
plt.title('Classification accuracy history')
plt.xlabel('Iteration')
plt.ylabel('Classification accuracy')
plt.legend()
plt.show()

plt.subplot()
plt.plot(per_epoch_train_accuracy_list, label='train')
plt.plot(per_epoch_test_accuracy_list, label='val')
plt.plot(max_p_e_train_accuracy, label='max train acc')
plt.plot(max_p_e_test_accuracy, label='max val acc')
plt.title('Per Epoch Classification accuracy history')
plt.xlabel('Epoch')
plt.ylabel('Classification accuracy')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
from sklearn.metrics import confusion_matrix
#from resources.plotcm import plot_confusion_matrix
import itertools
import numpy as np
import matplotlib.pyplot as plt

def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion matrix', cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt), horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
def check_train_accuracy1(loader, model, for_confusion_matrix=0):
    #if loader.dataset.train:
    #    print('Checking accuracy on validation set')
    #else:
    #    print('Checking accuracy on test set')
    print('Checking accuracy on TRAIN set')
    num_correct = 0
    num_samples = 0
    model.eval()  # set model to evaluation mode
    true_label_list = []
    predicted_label_list = []
    with torch.no_grad():
        for x, y in loader:
            true_label_list.append(y.cpu().data.numpy())
            x = x.to(device=device, dtype=dtype)  # move to device, e.g. GPU
            y = y.to(device=device, dtype=torch.long)
            #pdb.set_trace()
            #y = torch.stack(y) #.to(device=device)
            #y = y.reshape((x.shape[0]))
            scores = model(x)
            _, preds = scores.max(1)
            predicted_label_list.append(preds.cpu().data.numpy())            
            num_correct += (preds == y).sum()
            num_samples += preds.size(0)
        acc = float(num_correct) / num_samples
        print('Got %d / %d correct (%.2f)' % (num_correct, num_samples, 100 * acc))
        if for_confusion_matrix == 1:
          return acc, true_label_list, predicted_label_list
        else:
          return acc

# %%
#best_model1 = torch.load("model2")
accuracy, true_label, predicted_label = check_train_accuracy1(loader_train, best_model, for_confusion_matrix=1)
true_label = np.concatenate(true_label, axis=None)
#print(true_label)

predicted_label = np.concatenate(predicted_label, axis=None)
#print(predicted_label)

emotion_dict = ('hap',
                'sad',
                'ang',
                'neu'
                )
cm = confusion_matrix(true_label, predicted_label)

#t_t = train_set_targets.cpu().data.numpy()
#predict = preds.cpu().data.numpy()
#t_t = 1 + t_t
#predict = 1 + predict

#for i in range(t_t.shape[0]):
#  print(t_t[i], predict[i])
#print(t_t)
#print(predict)
#print(cm)
plt.figure(figsize=(6,6))
plot_confusion_matrix(cm, emotion_dict)
# Out:
# Checking accuracy on TRAIN set
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# Got 688 / 1224 correct (56.21)
# Confusion matrix, without normalization
# [[ 33  62  62  64]
#  [  2 294   6  36]
#  [  9  28 176  42]
#  [  9 174  42 185]]

# %%
#best_model1 = torch.load("model1")
accuracy, true_label, predicted_label = check_train_accuracy1(loader_val, best_model, for_confusion_matrix=1)
true_label = np.concatenate(true_label, axis=None)
#print(true_label)

predicted_label = np.concatenate(predicted_label, axis=None)
#print(predicted_label)


cm = confusion_matrix(true_label, predicted_label)

#t_t = train_set_targets.cpu().data.numpy()
#predict = preds.cpu().data.numpy()
#t_t = 1 + t_t
#predict = 1 + predict

#for i in range(t_t.shape[0]):
#  print(t_t[i], predict[i])
#print(t_t)
#print(predict)
#print(cm)
plt.figure(figsize=(6,6))
plot_confusion_matrix(cm, emotion_dict)
# Out:
# Checking accuracy on TRAIN set
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1269: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# Got 172 / 306 correct (56.21)
# Confusion matrix, without normalization
# [[11  9 10 12]
#  [ 3 50  1 14]
#  [ 4  6 67 22]
#  [11 24 18 44]]

# %%
accuracy, true_label, predicted_label = check_train_accuracy1(loader_train, model, for_confusion_matrix=1)
true_label = np.concatenate(true_label, axis=None)
#print(true_label)

predicted_label = np.concatenate(predicted_label, axis=None)
#print(predicted_label)

emotion_dict = ('hap',
                'sad',
                'ang',
                'neu'
                )
cm = confusion_matrix(true_label, predicted_label)

#t_t = train_set_targets.cpu().data.numpy()
#predict = preds.cpu().data.numpy()
#t_t = 1 + t_t
#predict = 1 + predict

#for i in range(t_t.shape[0]):
#  print(t_t[i], predict[i])
#print(t_t)
#print(predict)
#print(cm)
plt.figure(figsize=(6,6))
plot_confusion_matrix(cm, emotion_dict)
# Out:
# Checking accuracy on TRAIN set
# Got 809 / 1224 correct (66.09)
# Confusion matrix, without normalization
# [[ 95  44  40  42]
#  [ 15 280   6  37]
#  [ 24  12 191  28]
#  [ 48  99  20 243]]

# %%
#best_model1 = torch.load("model1")
accuracy, true_label, predicted_label = check_train_accuracy1(loader_val, model, for_confusion_matrix=1)
true_label = np.concatenate(true_label, axis=None)
#print(true_label)

predicted_label = np.concatenate(predicted_label, axis=None)
#print(predicted_label)


cm = confusion_matrix(true_label, predicted_label)

#t_t = train_set_targets.cpu().data.numpy()
#predict = preds.cpu().data.numpy()
#t_t = 1 + t_t
#predict = 1 + predict

#for i in range(t_t.shape[0]):
#  print(t_t[i], predict[i])
#print(t_t)
#print(predict)
#print(cm)
plt.figure(figsize=(6,6))
plot_confusion_matrix(cm, emotion_dict)
# Out:
# Checking accuracy on TRAIN set
# Got 155 / 306 correct (50.65)
# Confusion matrix, without normalization
# [[13  6 13 10]
#  [ 4 35  5 24]
#  [12  1 66 20]
#  [19 16 21 41]]
