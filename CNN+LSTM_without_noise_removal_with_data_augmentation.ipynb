# %%
from google.colab import drive

drive.mount('/content/drive', force_remount=True)

# enter the foldername in your Drive where you have saved the unzipped
# 'cs231n' folder containing the '.py', 'classifiers' and 'datasets'
# folders.
# e.g. 'cs231n/assignments/assignment1/cs231n/'
FOLDERNAME ='cs231n_project/'

assert FOLDERNAME is not None, "[!] Enter the foldername."

# %cd drive/My\ Drive
# %cd $FOLDERNAME
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# /content/drive/My Drive
# /content/drive/My Drive/cs231n_project

# %%
#import sys
#!{sys.executable} -m pip install torchsummary


from torch.utils.data import Dataset,DataLoader
from torchvision import transforms
import os
import numpy as np
import time
from PIL import Image
#from PIL import ImageFile
#ImageFile.LOAD_TRUNCATED_IMAGES = True
from collections import defaultdict
import cv2
import pdb
IMG_SIZE = (256,256)

from torchvision import models
from torchsummary import summary

# %%
#dataset_train.__len__
#dataset_test.shape
#dataset_val.shape

#'''test corrupted images'''
#data_path = "/home/mandeep_stanford/cs231n_project/code/pre-processed_data/images_denoised/session1/"
#dataset_train, dataset_test, dataset_val = get_imagenet_datasets(data_path, "cpc")
#
#print(f"Number of train samplest {dataset_train.__len__()}")
#print(f"Number of samples in test split {dataset_test.__len__()}")
#
#BATCH_SIZE = 200
#
#data_loader_train = DataLoader(dataset_train, BATCH_SIZE, shuffle = True)
#data_loader_test = DataLoader(dataset_test, BATCH_SIZE, shuffle = True)
#
#
#import matplotlib.pyplot as plt
#
#fig, axes = plt.subplots(BATCH_SIZE//20,20, figsize=(6,10))
#
#for batch in data_loader_train:
#
#    print(f"Shape of batch['image'] {batch['image'].shape}")
#    print(f"Shape of batch['cls'] {batch['cls'].shape}")
#
#    for i in range(BATCH_SIZE):
#
#        col = i % 20
#        row = i // 20
#
#        img = batch['image'][i].numpy()
#
#        axes[row,col].set_axis_off()
#        #axes[row,col].set_title(batch['class_name'][i])
#        axes[row,col].imshow(np.transpose(img,(1,2,0)))
#
#    plt.show()
#
#    break

# %%
# data_path = "/home/mandeep_stanford/cs231n_project/code/pre-processed_data/images/session1/"
# data_path = "/home/mandeep_stanford/cs231n_project/code/pre-processed_data/combined_session1_2/"
# img_files = os.listdir("/home/mandeep_stanford/cs231n_project/code/pre-processed_data/images/session1/")
# img_files = os.listdir("/home/mandeep_stanford/cs231n_project/code/pre-processed_data/combined_session1_2/")
# pkl_file = "/home/mandeep_stanford/cs231n_project/code/pre-processed_data/images_denoised/session1_pkl_tensor1_with_noise_1_2_new.pkl"

# %%
#pkl_file="session1_pkl_tensor1_with_noise_1_2_new.pkl"
pkl_file="without_noise_cleanup_WHOLE.pkl"
#pkl_file="without_noise_cleanup_denoised.pkl"

# %%
import pickle
X = []
Y = []
i = 0

if 0:
    for file_name in os.listdir(data_path):
        print("Working on ", i)
        i = i+1
        if i >= 3000:
            break
        cat = file_name.split('_')[0]
        Y.append(cat)
        img = Image.open(data_path+file_name)
        img = img.convert('RGB')
        tr = transforms.Resize((200,300))
        img=tr(img)
        tr = transforms.ToTensor()
        img1 = tr(img)
        img1 = np.array(img1)
        #X=np.vstack((X,img1))
        X.append(img1)
    
        del img1
        del img
        del tr

    Y = np.asarray(Y)
    X = np.asarray(X)
    data = {}
    data["X"] = X
    data["Y"] = Y
    with open(pkl_file, 'wb') as f:
        pickle.dump(data, f)
        f.close()

# %%
import pickle
import torch
#assert '.'.join(torch.__version__.split('.')[:2]) == '1.4'
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torch.utils.data import sampler
import torch.utils.data as data_utils
import torchvision.datasets as dset
import torchvision.transforms as T
import torch.nn.functional as F 
import numpy as np
#pkl_file = "/home/mandeep_stanford/cs231n_project/code/pre-processed_data/images_denoised/session1_pkl_tensor1.pkl"
data = pickle.load(open(pkl_file, 'rb'))
X = data["X"]
Y = data["Y"]
# X=np.asarray(X)
# Y=np.asarray(Y)

# %%
X.shape

# %%
np.unique(Y)

# %%
import numpy as np
total_images = X.shape[0]
test_data_images = np.int(total_images*0.2)
train_data_images = total_images - test_data_images
#X_train = X[0:train_data_images,-1]
#y_train = Y[0:train_data_images]
#X_test = X[train_data_images:train_data_images+test_data_images, -1]
#y_test= Y[train_data_images:train_data_images+test_data_images]

#X_train = np.asarray(X_train)
#X_test = np.asarray(X_test)
#y_train = np.asarray(y_train)
#y_test = np.asarray(y_test)

#y_train = y_train.reshape((y_train[0]))
#y_test = y_test.reshape((y_test[0]))
#print(X_train.shape)
#print(y_train.shape)
#print(X_test.shape)
#print(y_test.shape)

# %%
USE_GPU = True

dtype = torch.float32 # we will be using float throughout this tutorial

if USE_GPU and torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')

# Constant to control how frequently we print train loss
print_every = 100

print('using device:', device)
# Out:
# using device: cuda

# %%
np.unique(Y)

# %%
keys_array
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-0db1285f7001> in <module>()
# ----> 1 keys_array
#
# NameError: name 'keys_array' is not defined

# %%
num_class={0:0,1:0,2:0,3:0}
for i in range(len(X)):
   num_class[Y[i]]+=1
num_class
# Out:
# {0: 526, 1: 812, 2: 708, 3: 1014}

# %%
import random
train_data = []
total_images=1015
keys_array = np.unique(Y)

train_data_dict={0:[],1:[],2:[],3:[]}
for i in range(len(X)):
   ind = np.where(keys_array==Y[i]) 
   train_data_dict[Y[i]].append([X[i], Y[i]])
# train_data_dict[0]=train_data_dict[0]+train_data_dict[0]
len(train_data_dict[0])
# Out:
# 526

# %%
train_data_full={}
for key in train_data_dict.keys():
  train_data_full[key]=train_data_dict[key]+random.sample(train_data_dict[key],total_images-len(train_data_dict[key]))

# %%
# import random
# train_data = []
# keys_array = np.unique(Y)
# for i in range(len(X)):
#    ind = np.where(keys_array==Y[i]) 
#    train_data.append([X[i], Y[i]])

train_data=train_data_full[0]+train_data_full[1]+train_data_full[2]+train_data_full[3]



    
random.shuffle(train_data)
import numpy as np
total_images = len(train_data)
test_data_images = np.int(total_images*0.2)
train_data_images = total_images - test_data_images
# t,(a1,a2)=list(enumerate(train_data))[0]
# print(t)
# print(a2)
# for t,(a1,a2) in enumerate(train_data):
#   if t==0:
#     print(a2)
print("DONE")
#train_data=np.asarray(train_data)
#dataset = data_utils.TensorDataset(train_data, batch_size=100)
train_data_split=train_data[:train_data_images]
test_data_split=train_data[train_data_images:]
print(train_data_images)
print(train_data_images+test_data_images)
loader_train = DataLoader(train_data_split, batch_size=64, 
                          shuffle=True)

loader_val = DataLoader(test_data_split, batch_size=64, 
                        shuffle=True)


#for t, (x,y) in enumerate(loader_train):
#  print(t, x, y)
# Out:
# DONE
# 3248
# 4060

# %% [markdown]
# # Frequency of test/train accuracy printed

# %%
print_every = 1

# %% [markdown]
# # Plot Functions for train/test accuracy, and train loss

# %%
#DATA_PATH_PIC=
import matplotlib.pyplot as plt
import copy
def plot_train_test_acc(train_acc_ls,test_acc_ls,best_train,best_test,train_acc_epoch,test_acc_epoch):
  #plt.figure(figsize=(16,10))
  plt.plot(train_acc_ls)
  plt.plot(test_acc_ls)
  plt.plot([best_train]*len(train_acc_ls))
  plt.plot([best_test]*len(test_acc_ls))
  plt.title('model accuracy (iteration)')
  plt.ylabel('accuracy')
  plt.xlabel("iteration")
  plt.legend(['train', 'test',"best_train","best_test"], loc='upper left')
  plt.show()
  plt.plot(train_acc_epoch)
  plt.plot(test_acc_epoch)
  plt.plot([best_train]*len(train_acc_epoch))
  plt.plot([best_test]*len(test_acc_epoch))
  plt.title('model accuracy (epoch)')
  plt.ylabel('accuracy')
  plt.xlabel("epoch")
  plt.legend(['train', 'test',"best_train","best_test"], loc='upper left')
  #plt.savefig(DATA_PATH_PIC+'model_acc.png')
  #.plot(train_acc)
  plt.show()
def plot_loss(loss_ls,loss_epoch):
  plt.plot(loss_ls)
  plt.title('model train loss (iteration)')
  plt.ylabel('train loss')
  plt.xlabel("iteration")
  plt.show()
  plt.plot(loss_epoch)
  plt.title('model train loss (epoch)')
  plt.ylabel('train loss')
  plt.xlabel("epoch")
  plt.show()
  #plt.savefig(DATA_PATH_PIC+'model_train_loss.png')

# %%
@torch.no_grad()
def get_all_preds(model, loader):
    all_preds = torch.tensor([]).to(device=device)
    model = model.to(device=device)
    for batch in loader:
        images, labels = batch
        images = images.to(device=device, dtype=dtype)  # move to device, e.g. GPU
        labels = labels.to(device=device, dtype=torch.long)
        preds = model(images).to(device=device)
        all_preds = torch.cat(
            (all_preds, preds)
            ,dim=0
        )
    return all_preds

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import itertools
import numpy as np
import matplotlib.pyplot as plt

def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion matrix', cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt), horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()

# %% [markdown]
# # Functions for Model Train and Accuracy Calculation

# %%
def get_confusion_matrix(best_model,loader_train,loader_val):
    best_model.eval()
    train_preds = get_all_preds(best_model, loader_train)
    test_preds = get_all_preds(best_model, loader_val)
    _, train_preds = train_preds.max(1)
    _, test_preds = test_preds.max(1)

    tensor_list_train =[]
    tensor_list_test=[]
    for t, (x,y) in enumerate(loader_train):
       tensor_list_train.append(y)
    for t, (x,y) in enumerate(loader_val):
       tensor_list_test.append(y)
    train_set_targets = torch.cat(tensor_list_train, dim=0).cpu()
    test_set_targets = torch.cat(tensor_list_test, dim=0).cpu()

    cm_train = confusion_matrix(train_set_targets, train_preds.cpu())
    cm_test = confusion_matrix(test_set_targets, test_preds.cpu())
    emotion_dict = ('hap',
                'sad',
                'ang',
                'neu'
                )
    plot_confusion_matrix(cm_train, emotion_dict)
    plot_confusion_matrix(cm_test, emotion_dict)

# %%
def check_accuracy_part34(loader, model):
    # if loader.dataset.train:
    #    print('Checking accuracy on validation set')
    # else:
    #    print('Checking accuracy on test set')
    # print('Checking accuracy on test or val set')
    num_correct = 0
    num_samples = 0
    model.eval()  # set model to evaluation mode
    with torch.no_grad():
        for x, y in loader:
            x = x.to(device=device, dtype=dtype)  # move to device, e.g. GPU
            y = y.to(device=device, dtype=torch.long)
            #pdb.set_trace()
            #y = torch.stack(y)#.to(device=device)
            #y=torch.FloatTensor(y)
            #y = y.reshape((x.shape[0]))
            scores = model(x)
            _, preds = scores.max(1)
            
            num_correct += (preds == y).sum()
            num_samples += preds.size(0)
        acc = float(num_correct) / num_samples
        # print('Test Accuracy Got %d / %d correct (%.2f)' % (num_correct, num_samples, 100 * acc))
        return acc*100,num_correct,num_samples

# %%
def train_part34(model, optimizer, epochs=1):
    """
    Train a model on CIFAR-10 using the PyTorch Module API.
    
    Inputs:
    - model: A PyTorch Module giving the model to train.
    - optimizer: An Optimizer object we will use to train the model
    - epochs: (Optional) A Python integer giving the number of epochs to train for
    
    Returns: Nothing, but prints model accuracies during training.
    """
    best_model = copy.deepcopy(model)
    model = model.to(device=device)  # move the model parameters to CPU/GPU
    train_acc_ls=[]
    test_acc_ls=[]
    train_acc_epoch=[]
    test_acc_epoch=[]
    loss_ls=[]
    loss_epoch=[]
    best_test_acc=0
    best_train_acc=0
    for e in range(epochs):
        for t, (x, y) in enumerate(loader_train):
            #import pdb
            #pdb.set_trace()
            model.train()  # put model to training mode
            x = x.to(device=device, dtype=dtype)  # move to device, e.g. GPU
            y = y.to(device=device, dtype=torch.long)

            #print(t)
            #print(f"pre y: {y}")
            #y = torch.stack(y)#.to(device=device)
            #print(f"aft y: {y}")
            #y=torch.FloatTensor(y)
            #y = y.reshape((x.shape[0]))
            scores = model(x)           
            loss = F.cross_entropy(scores, y)
            

            # Zero out all of the gradients for the variables which the optimizer
            # will update.
            optimizer.zero_grad()

            # This is the backwards pass: compute the gradient of the loss with
            # respect to each  parameter of the model.
            loss.backward()

            # Actually update the parameters of the model using the gradients
            # computed by the backwards pass.
            optimizer.step()
            #pdb.set_trace()
            #print("IN ITERATION", t)
            if t % print_every == 0:
                print('Iteration %d, loss = %.4f' % (t, loss.item()))
                # print("train acc")
                # check_accuracy_part34(batch_train, model)
                _, preds = scores.max(1)
                num_correct = 0
                num_samples = 0
                num_correct += (preds == y).sum()
                num_samples += preds.size(0)
                train_acc = float(num_correct) / num_samples
                train_acc_ls.append(train_acc*100)
                if train_acc*100>best_train_acc:
                  best_train_acc=train_acc*100
                print('Train Accuracy Got %d / %d correct (%.2f)' % (num_correct, num_samples, 100 * train_acc))
                test_acc,num_correct_test,num_samples_test=check_accuracy_part34(loader_val, model)
                print('Test Accuracy Got %d / %d correct (%.2f)' % (num_correct_test, num_samples_test, test_acc))
                test_acc_ls.append(test_acc)
                if test_acc>best_test_acc:
                  best_test_acc=test_acc
                  best_model = copy.deepcopy(model)
                loss_ls.append(loss)
        train_acc_ea,_,_=check_accuracy_part34(loader_train, model)
        train_acc_epoch.append(train_acc_ea)
        test_acc_ea,_,_= check_accuracy_part34(loader_val, model)
        test_acc_epoch.append(test_acc_ea)
        loss_epoch.append(loss)          
                
                
    plot_train_test_acc(train_acc_ls,test_acc_ls,best_train_acc,best_test_acc,train_acc_epoch,test_acc_epoch)
    plot_loss(loss_ls,loss_epoch)
    print(f"Best Train Accuracy is {best_train_acc}")
    print(f"Best Test Accuracy is {best_test_acc}")

    get_confusion_matrix(best_model,loader_train,loader_val)
    return best_model,best_test_acc

# %% [markdown]
# # Model

# %%
class Flatten(nn.Module):
    def flatten(x):
        N = x.shape[0] # read in N, C, H, W
        return x.view(N, -1)  # "flatten" the C * H * W values into a single vector per image

    def forward(self, x):
        N = x.shape[0]
        return x.view(N, -1)
class LSTM(nn.Module):

    def __init__(self):
        super().__init__()
        self.model = nn.LSTM(input_size=(32*25*37),hidden_size=128,num_layers=2,batch_first=True,bidirectional =True,dropout=0.3)
        #self.model = nn.RNN(input_size=(32*25*37),hidden_size=128,num_layers=2,batch_first=True,bidirectional =True)
    def forward(self, x):

        # From [batches, seqs, seq len, features]
        # to [seq len, batch data, features]
        x = x.unsqueeze(1)
       
        # Data is fed to the LSTM
        out, _ = self.model(x)

        # From [seq len, batch, num_directions * hidden_size]
        # to [batches, seqs, seq_len,prediction]
        out = out.squeeze(1)


        return out
# class LSTM1(nn.Module):

#     def __init__(self):
#         super().__init__()
#         self.model = nn.LSTM(input_size=(256),hidden_size=128,num_layers=1,batch_first=True,bidirectional =True)
#         #self.model = nn.RNN(input_size=(256),hidden_size=128,num_layers=2,batch_first=True,bidirectional =True)
#     def forward(self, x):

#         # From [batches, seqs, seq len, features]
#         # to [seq len, batch data, features]
#         x = x.unsqueeze(1)
       
#         # Data is fed to the LSTM
#         out, _ = self.model(x)

#         # From [seq len, batch, num_directions * hidden_size]
#         # to [batches, seqs, seq_len,prediction]
#         out = out.squeeze(1)


#         return out
#hidden_layer_size = 500
#learning_rate = 1e-2




l1 = nn.Sequential(
            nn.Conv2d(3, 16, kernel_size=(12,16), padding=(6,8), stride=1),
            nn.BatchNorm2d(16),
            nn.ReLU(),
            #nn.Conv2d(channel_1, channel_1, kernel_size=5, padding=2, stride=1),
            nn.MaxPool2d(2, 2)
)


l2 = nn.Sequential(
            nn.Conv2d(16, 24, kernel_size=(8,12), padding=(4,6), stride=1),
            nn.BatchNorm2d(24),
            nn.ReLU(),
            nn.MaxPool2d(2, 2)
)

l3 = nn.Sequential(
            nn.Conv2d(24, 32, kernel_size=(5,7), padding=(2,3), stride=1),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            Flatten(),
            nn.BatchNorm1d(32*25*37),
            LSTM())      
            # input & output will has batch size as 1s dimension. e.g. (batch, time_step, input_size)
            #nn.LSTM(input_size=(32*25*37), 128, 2, batch_first=True))

            


#l4 = nn.Sequential(
#            nn.Conv2d(channel_3, channel_4, kernel_size=3, padding=1, stride=1),
#            nn.MaxPool2d(2, 1)
#)
hidden_layer_size = keys_array.shape[0]
learning_rate = 1e-4
model1 = nn.Sequential(
            l1,
            l2,
            l3,
            nn.BatchNorm1d(256),
            #nn.ReLU(),
            nn.Linear(256, 64),
            nn.ReLU(),
            nn.Dropout(p=0.2),
            nn.Linear(64, keys_array.shape[0])
)
'''the last three layers for 5-layers conv'''
l32= nn.Sequential(
            nn.Conv2d(24, 32, kernel_size=(5,7), padding=(2,3), stride=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2))

l4 = nn.Sequential(
            nn.Conv2d(32, 40, kernel_size=(2,3), padding=(2,2), stride=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2))
l5=nn.Sequential(
            nn.Conv2d(40, 48, kernel_size=(1,1), padding=(1,1), stride=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2))

model2 = nn.Sequential(
            l1,
            l2,
            l32,
            l4,
            l5,
            Flatten(),
            nn.Linear(3840, 64),
            nn.ReLU(),
            nn.Dropout(p=0.2),
            nn.Linear(64, keys_array.shape[0])
)

# %%
# you can use Nesterov momentum in optim.SGD
#optimizer = optim.Adam(model.parameters(), lr=learning_rate,momentum=0.9, nesterov=True)
optimizer = optim.Adam(model1.parameters(), lr=learning_rate, 
                     betas=(0.9, 0.999), eps=1e-08, weight_decay=0, amsgrad=False)

best_model,best_test_acc=train_part34(model1, optimizer, 30)
# Out:
# Iteration 0, loss = 1.3845
# Train Accuracy Got 19 / 64 correct (29.69)
# Test Accuracy Got 205 / 812 correct (25.25)
# Iteration 1, loss = 1.4027
# Train Accuracy Got 14 / 64 correct (21.88)
# Test Accuracy Got 205 / 812 correct (25.25)
# Iteration 2, loss = 1.4448
# Train Accuracy Got 13 / 64 correct (20.31)
# Test Accuracy Got 205 / 812 correct (25.25)
# Iteration 3, loss = 1.4370
# Train Accuracy Got 14 / 64 correct (21.88)
# Test Accuracy Got 205 / 812 correct (25.25)
# Iteration 4, loss = 1.3851
# Train Accuracy Got 22 / 64 correct (34.38)
# Test Accuracy Got 205 / 812 correct (25.25)
# Iteration 5, loss = 1.3676
# Train Accuracy Got 16 / 64 correct (25.00)
# Test Accuracy Got 205 / 812 correct (25.25)
# Iteration 6, loss = 1.3673
# Train Accuracy Got 18 / 64 correct (28.12)
# Test Accuracy Got 205 / 812 correct (25.25)
# Iteration 7, loss = 1.3898
# Train Accuracy Got 18 / 64 correct (28.12)
# Test Accuracy Got 205 / 812 correct (25.25)
# Iteration 8, loss = 1.3155
# Train Accuracy Got 27 / 64 correct (42.19)
# Test Accuracy Got 205 / 812 correct (25.25)
# Iteration 9, loss = 1.3027
# Train Accuracy Got 28 / 64 correct (43.75)
# Test Accuracy Got 205 / 812 correct (25.25)
# Iteration 10, loss = 1.4160
# Train Accuracy Got 16 / 64 correct (25.00)
# Test Accuracy Got 205 / 812 correct (25.25)
# Iteration 11, loss = 1.3211
# Train Accuracy Got 19 / 64 correct (29.69)
# Test Accuracy Got 205 / 812 correct (25.25)
# Iteration 12, loss = 1.3811
# Train Accuracy Got 16 / 64 correct (25.00)
# Test Accuracy Got 205 / 812 correct (25.25)
# Iteration 13, loss = 1.3784
# Train Accuracy Got 17 / 64 correct (26.56)
# Test Accuracy Got 205 / 812 correct (25.25)
# Iteration 14, loss = 1.3202
# Train Accuracy Got 23 / 64 correct (35.94)
# Test Accuracy Got 205 / 812 correct (25.25)
# Iteration 15, loss = 1.3388
# Train Accuracy Got 26 / 64 correct (40.62)
# Test Accuracy Got 205 / 812 correct (25.25)
# Iteration 16, loss = 1.3569
# Train Accuracy Got 19 / 64 correct (29.69)
# Test Accuracy Got 205 / 812 correct (25.25)
# Iteration 17, loss = 1.3303
# Train Accuracy Got 24 / 64 correct (37.50)
# Test Accuracy Got 205 / 812 correct (25.25)
# Iteration 18, loss = 1.3507
# Train Accuracy Got 19 / 64 correct (29.69)
# Test Accuracy Got 205 / 812 correct (25.25)
# Iteration 19, loss = 1.3706
# Train Accuracy Got 19 / 64 correct (29.69)
# Test Accuracy Got 205 / 812 correct (25.25)
# Iteration 20, loss = 1.3672
# Train Accuracy Got 19 / 64 correct (29.69)
# Test Accuracy Got 207 / 812 correct (25.49)
# Iteration 21, loss = 1.3623
# Train Accuracy Got 16 / 64 correct (25.00)
# Test Accuracy Got 216 / 812 correct (26.60)
# Iteration 22, loss = 1.3927
# Train Accuracy Got 21 / 64 correct (32.81)
# Test Accuracy Got 220 / 812 correct (27.09)
# Iteration 23, loss = 1.3432
# Train Accuracy Got 24 / 64 correct (37.50)
# Test Accuracy Got 219 / 812 correct (26.97)
# Iteration 24, loss = 1.3445
# Train Accuracy Got 24 / 64 correct (37.50)
# Test Accuracy Got 222 / 812 correct (27.34)
# Iteration 25, loss = 1.3855
# Train Accuracy Got 15 / 64 correct (23.44)
# Test Accuracy Got 240 / 812 correct (29.56)
# Iteration 26, loss = 1.3301
# Train Accuracy Got 19 / 64 correct (29.69)
# Test Accuracy Got 254 / 812 correct (31.28)
# Iteration 27, loss = 1.3797
# Train Accuracy Got 18 / 64 correct (28.12)
# Test Accuracy Got 267 / 812 correct (32.88)
# Iteration 28, loss = 1.3667
# Train Accuracy Got 18 / 64 correct (28.12)
# Test Accuracy Got 262 / 812 correct (32.27)
# Iteration 29, loss = 1.2896
# Train Accuracy Got 22 / 64 correct (34.38)
# Test Accuracy Got 265 / 812 correct (32.64)
# Iteration 30, loss = 1.3177
# Train Accuracy Got 23 / 64 correct (35.94)
# Test Accuracy Got 277 / 812 correct (34.11)
# Iteration 31, loss = 1.3235
# Train Accuracy Got 25 / 64 correct (39.06)
# Test Accuracy Got 270 / 812 correct (33.25)
# Iteration 32, loss = 1.3089
# Train Accuracy Got 21 / 64 correct (32.81)
# Test Accuracy Got 266 / 812 correct (32.76)
# Iteration 33, loss = 1.3644
# Train Accuracy Got 19 / 64 correct (29.69)
# Test Accuracy Got 271 / 812 correct (33.37)
# Iteration 34, loss = 1.2791
# Train Accuracy Got 24 / 64 correct (37.50)
# Test Accuracy Got 276 / 812 correct (33.99)
# Iteration 35, loss = 1.3377
# Train Accuracy Got 16 / 64 correct (25.00)
# Test Accuracy Got 272 / 812 correct (33.50)
# Iteration 36, loss = 1.2973
# Train Accuracy Got 25 / 64 correct (39.06)
# Test Accuracy Got 268 / 812 correct (33.00)
# Iteration 37, loss = 1.3013
# Train Accuracy Got 26 / 64 correct (40.62)
# Test Accuracy Got 271 / 812 correct (33.37)
# Iteration 38, loss = 1.3055
# Train Accuracy Got 24 / 64 correct (37.50)
# Test Accuracy Got 278 / 812 correct (34.24)
# Iteration 39, loss = 1.3018
# Train Accuracy Got 22 / 64 correct (34.38)
# Test Accuracy Got 272 / 812 correct (33.50)
# Iteration 40, loss = 1.3476
# Train Accuracy Got 24 / 64 correct (37.50)
# Test Accuracy Got 277 / 812 correct (34.11)
# Iteration 41, loss = 1.3427
# Train Accuracy Got 24 / 64 correct (37.50)
# Test Accuracy Got 276 / 812 correct (33.99)
# Iteration 42, loss = 1.2941
# Train Accuracy Got 21 / 64 correct (32.81)
# Test Accuracy Got 279 / 812 correct (34.36)
# Iteration 43, loss = 1.3644
# Train Accuracy Got 22 / 64 correct (34.38)
# Test Accuracy Got 276 / 812 correct (33.99)
# Iteration 44, loss = 1.2659
# Train Accuracy Got 23 / 64 correct (35.94)
# Test Accuracy Got 276 / 812 correct (33.99)
# Iteration 45, loss = 1.3233
# Train Accuracy Got 20 / 64 correct (31.25)
# Test Accuracy Got 279 / 812 correct (34.36)
# Iteration 46, loss = 1.2324
# Train Accuracy Got 23 / 64 correct (35.94)
# Test Accuracy Got 283 / 812 correct (34.85)
# Iteration 47, loss = 1.3246
# Train Accuracy Got 18 / 64 correct (28.12)
# Test Accuracy Got 280 / 812 correct (34.48)
# Iteration 48, loss = 1.2973
# Train Accuracy Got 23 / 64 correct (35.94)
# Test Accuracy Got 278 / 812 correct (34.24)
# Iteration 49, loss = 1.3302
# Train Accuracy Got 25 / 64 correct (39.06)
# Test Accuracy Got 277 / 812 correct (34.11)
# Iteration 50, loss = 1.3273
# Train Accuracy Got 16 / 48 correct (33.33)
# Test Accuracy Got 278 / 812 correct (34.24)
# Iteration 0, loss = 1.2761
# Train Accuracy Got 27 / 64 correct (42.19)
# Test Accuracy Got 275 / 812 correct (33.87)
# Iteration 1, loss = 1.3956
# Train Accuracy Got 19 / 64 correct (29.69)
# Test Accuracy Got 287 / 812 correct (35.34)
# Iteration 2, loss = 1.3264
# Train Accuracy Got 24 / 64 correct (37.50)
# Test Accuracy Got 292 / 812 correct (35.96)
# Iteration 3, loss = 1.3178
# Train Accuracy Got 20 / 64 correct (31.25)
# Test Accuracy Got 267 / 812 correct (32.88)
# Iteration 4, loss = 1.3539
# Train Accuracy Got 20 / 64 correct (31.25)
# Test Accuracy Got 262 / 812 correct (32.27)
# Iteration 5, loss = 1.3346
# Train Accuracy Got 22 / 64 correct (34.38)
# Test Accuracy Got 261 / 812 correct (32.14)
# Iteration 6, loss = 1.3474
# Train Accuracy Got 16 / 64 correct (25.00)
# Test Accuracy Got 261 / 812 correct (32.14)
# Iteration 7, loss = 1.3008
# Train Accuracy Got 24 / 64 correct (37.50)
# Test Accuracy Got 261 / 812 correct (32.14)
# Iteration 8, loss = 1.2657
# Train Accuracy Got 24 / 64 correct (37.50)
# Test Accuracy Got 259 / 812 correct (31.90)
# Iteration 9, loss = 1.3527
# Train Accuracy Got 20 / 64 correct (31.25)
# Test Accuracy Got 269 / 812 correct (33.13)
# Iteration 10, loss = 1.2856
# Train Accuracy Got 23 / 64 correct (35.94)
# Test Accuracy Got 268 / 812 correct (33.00)
# Iteration 11, loss = 1.3264
# Train Accuracy Got 17 / 64 correct (26.56)
# Test Accuracy Got 278 / 812 correct (34.24)
# Iteration 12, loss = 1.2354
# Train Accuracy Got 28 / 64 correct (43.75)
# Test Accuracy Got 283 / 812 correct (34.85)
# Iteration 13, loss = 1.2757
# Train Accuracy Got 25 / 64 correct (39.06)
# Test Accuracy Got 280 / 812 correct (34.48)
# Iteration 14, loss = 1.2939
# Train Accuracy Got 19 / 64 correct (29.69)
# Test Accuracy Got 274 / 812 correct (33.74)
# Iteration 15, loss = 1.2739
# Train Accuracy Got 25 / 64 correct (39.06)
# Test Accuracy Got 245 / 812 correct (30.17)
# Iteration 16, loss = 1.2968
# Train Accuracy Got 22 / 64 correct (34.38)
# Test Accuracy Got 221 / 812 correct (27.22)
# Iteration 17, loss = 1.3189
# Train Accuracy Got 23 / 64 correct (35.94)
# Test Accuracy Got 203 / 812 correct (25.00)
# Iteration 18, loss = 1.2168
# Train Accuracy Got 27 / 64 correct (42.19)
# Test Accuracy Got 214 / 812 correct (26.35)
# Iteration 19, loss = 1.2805
# Train Accuracy Got 22 / 64 correct (34.38)
# Test Accuracy Got 205 / 812 correct (25.25)
# Iteration 20, loss = 1.2254
# Train Accuracy Got 31 / 64 correct (48.44)
# Test Accuracy Got 197 / 812 correct (24.26)
# Iteration 21, loss = 1.2055
# Train Accuracy Got 30 / 64 correct (46.88)
# Test Accuracy Got 192 / 812 correct (23.65)
# Iteration 22, loss = 1.2956
# Train Accuracy Got 24 / 64 correct (37.50)
# Test Accuracy Got 217 / 812 correct (26.72)
# Iteration 23, loss = 1.2812
# Train Accuracy Got 21 / 64 correct (32.81)
# Test Accuracy Got 224 / 812 correct (27.59)
# Iteration 24, loss = 1.2307
# Train Accuracy Got 28 / 64 correct (43.75)
# Test Accuracy Got 233 / 812 correct (28.69)
# Iteration 25, loss = 1.3672
# Train Accuracy Got 20 / 64 correct (31.25)
# Test Accuracy Got 194 / 812 correct (23.89)
# Iteration 26, loss = 1.3786
# Train Accuracy Got 18 / 64 correct (28.12)
# Test Accuracy Got 197 / 812 correct (24.26)
# Iteration 27, loss = 1.3121
# Train Accuracy Got 21 / 64 correct (32.81)
# Test Accuracy Got 213 / 812 correct (26.23)
# Iteration 28, loss = 1.2951
# Train Accuracy Got 23 / 64 correct (35.94)
# Test Accuracy Got 207 / 812 correct (25.49)
# Iteration 29, loss = 1.2670
# Train Accuracy Got 25 / 64 correct (39.06)
# Test Accuracy Got 220 / 812 correct (27.09)
# Iteration 30, loss = 1.3521
# Train Accuracy Got 21 / 64 correct (32.81)
# Test Accuracy Got 224 / 812 correct (27.59)
# Iteration 31, loss = 1.2829
# Train Accuracy Got 26 / 64 correct (40.62)
# Test Accuracy Got 216 / 812 correct (26.60)
# Iteration 32, loss = 1.2872
# Train Accuracy Got 21 / 64 correct (32.81)
# Test Accuracy Got 217 / 812 correct (26.72)
# Iteration 33, loss = 1.2865
# Train Accuracy Got 26 / 64 correct (40.62)
# Test Accuracy Got 232 / 812 correct (28.57)
# Iteration 34, loss = 1.2980
# Train Accuracy Got 24 / 64 correct (37.50)
# Test Accuracy Got 235 / 812 correct (28.94)
# Iteration 35, loss = 1.2549
# Train Accuracy Got 22 / 64 correct (34.38)
# Test Accuracy Got 232 / 812 correct (28.57)
# Iteration 36, loss = 1.3062
# Train Accuracy Got 24 / 64 correct (37.50)
# Test Accuracy Got 244 / 812 correct (30.05)
# Iteration 37, loss = 1.2063
# Train Accuracy Got 31 / 64 correct (48.44)
# Test Accuracy Got 234 / 812 correct (28.82)
# Iteration 38, loss = 1.3593
# Train Accuracy Got 18 / 64 correct (28.12)
# Test Accuracy Got 242 / 812 correct (29.80)
# Iteration 39, loss = 1.2908
# Train Accuracy Got 30 / 64 correct (46.88)
# Test Accuracy Got 223 / 812 correct (27.46)
# Iteration 40, loss = 1.2637
# Train Accuracy Got 25 / 64 correct (39.06)
# Test Accuracy Got 213 / 812 correct (26.23)
# Iteration 41, loss = 1.2798
# Train Accuracy Got 25 / 64 correct (39.06)
# Test Accuracy Got 220 / 812 correct (27.09)
# Iteration 42, loss = 1.1871
# Train Accuracy Got 28 / 64 correct (43.75)
# Test Accuracy Got 196 / 812 correct (24.14)
# Iteration 43, loss = 1.2677
# Train Accuracy Got 24 / 64 correct (37.50)
# Test Accuracy Got 206 / 812 correct (25.37)
# Iteration 44, loss = 1.2376
# Train Accuracy Got 25 / 64 correct (39.06)
# Test Accuracy Got 203 / 812 correct (25.00)
# Iteration 45, loss = 1.3160
# Train Accuracy Got 18 / 64 correct (28.12)
# Test Accuracy Got 211 / 812 correct (25.99)
# Iteration 46, loss = 1.2774
# Train Accuracy Got 26 / 64 correct (40.62)
# Test Accuracy Got 215 / 812 correct (26.48)
# Iteration 47, loss = 1.1971
# Train Accuracy Got 32 / 64 correct (50.00)
# Test Accuracy Got 215 / 812 correct (26.48)
# Iteration 48, loss = 1.2215
# Train Accuracy Got 26 / 64 correct (40.62)
# Test Accuracy Got 213 / 812 correct (26.23)
# Iteration 49, loss = 1.1995
# Train Accuracy Got 33 / 64 correct (51.56)
# Test Accuracy Got 212 / 812 correct (26.11)
# Iteration 50, loss = 1.3024
# Train Accuracy Got 15 / 48 correct (31.25)
# Test Accuracy Got 212 / 812 correct (26.11)
# Iteration 0, loss = 1.3024
# Train Accuracy Got 23 / 64 correct (35.94)
# Test Accuracy Got 212 / 812 correct (26.11)
# Iteration 1, loss = 1.2103
# Train Accuracy Got 29 / 64 correct (45.31)
# Test Accuracy Got 214 / 812 correct (26.35)
# Iteration 2, loss = 1.3482
# Train Accuracy Got 23 / 64 correct (35.94)
# Test Accuracy Got 227 / 812 correct (27.96)
# Iteration 3, loss = 1.3045
# Train Accuracy Got 23 / 64 correct (35.94)
# Test Accuracy Got 198 / 812 correct (24.38)
# Iteration 4, loss = 1.2397
# Train Accuracy Got 23 / 64 correct (35.94)
# Test Accuracy Got 210 / 812 correct (25.86)
# Iteration 5, loss = 1.2997
# Train Accuracy Got 17 / 64 correct (26.56)
# Test Accuracy Got 223 / 812 correct (27.46)
# Iteration 6, loss = 1.2029
# Train Accuracy Got 32 / 64 correct (50.00)
# Test Accuracy Got 208 / 812 correct (25.62)
# Iteration 7, loss = 1.3483
# Train Accuracy Got 17 / 64 correct (26.56)
# Test Accuracy Got 237 / 812 correct (29.19)
# Iteration 8, loss = 1.2571
# Train Accuracy Got 25 / 64 correct (39.06)
# Test Accuracy Got 225 / 812 correct (27.71)
# Iteration 9, loss = 1.2843
# Train Accuracy Got 23 / 64 correct (35.94)
# Test Accuracy Got 242 / 812 correct (29.80)
# Iteration 10, loss = 1.2580
# Train Accuracy Got 25 / 64 correct (39.06)
# Test Accuracy Got 212 / 812 correct (26.11)
# Iteration 11, loss = 1.1946
# Train Accuracy Got 23 / 64 correct (35.94)
# Test Accuracy Got 210 / 812 correct (25.86)
# Iteration 12, loss = 1.2295
# Train Accuracy Got 24 / 64 correct (37.50)
# Test Accuracy Got 205 / 812 correct (25.25)
# Iteration 13, loss = 1.2974
# Train Accuracy Got 19 / 64 correct (29.69)
# Test Accuracy Got 168 / 812 correct (20.69)
# Iteration 14, loss = 1.2947
# Train Accuracy Got 22 / 64 correct (34.38)
# Test Accuracy Got 172 / 812 correct (21.18)
# Iteration 15, loss = 1.2558
# Train Accuracy Got 20 / 64 correct (31.25)
# Test Accuracy Got 174 / 812 correct (21.43)
# Iteration 16, loss = 1.2946
# Train Accuracy Got 23 / 64 correct (35.94)
# Test Accuracy Got 201 / 812 correct (24.75)
# Iteration 17, loss = 1.3003
# Train Accuracy Got 24 / 64 correct (37.50)
# Test Accuracy Got 185 / 812 correct (22.78)
# Iteration 18, loss = 1.2109
# Train Accuracy Got 25 / 64 correct (39.06)
# Test Accuracy Got 171 / 812 correct (21.06)
# Iteration 19, loss = 1.2740
# Train Accuracy Got 22 / 64 correct (34.38)
# Test Accuracy Got 183 / 812 correct (22.54)
# Iteration 20, loss = 1.2280
# Train Accuracy Got 28 / 64 correct (43.75)
# Test Accuracy Got 263 / 812 correct (32.39)
# Iteration 21, loss = 1.3001
# Train Accuracy Got 20 / 64 correct (31.25)
# Test Accuracy Got 225 / 812 correct (27.71)
# Iteration 22, loss = 1.2922
# Train Accuracy Got 25 / 64 correct (39.06)
# Test Accuracy Got 172 / 812 correct (21.18)
# Iteration 23, loss = 1.2671
# Train Accuracy Got 23 / 64 correct (35.94)
# Test Accuracy Got 208 / 812 correct (25.62)
# Iteration 24, loss = 1.3325
# Train Accuracy Got 19 / 64 correct (29.69)
# Test Accuracy Got 240 / 812 correct (29.56)
# Iteration 25, loss = 1.3032
# Train Accuracy Got 20 / 64 correct (31.25)
# Test Accuracy Got 208 / 812 correct (25.62)
# Iteration 26, loss = 1.3299
# Train Accuracy Got 22 / 64 correct (34.38)
# Test Accuracy Got 212 / 812 correct (26.11)
# Iteration 27, loss = 1.2118
# Train Accuracy Got 25 / 64 correct (39.06)
# Test Accuracy Got 204 / 812 correct (25.12)
# Iteration 28, loss = 1.1998
# Train Accuracy Got 26 / 64 correct (40.62)
# Test Accuracy Got 190 / 812 correct (23.40)
# Iteration 29, loss = 1.2589
# Train Accuracy Got 26 / 64 correct (40.62)
# Test Accuracy Got 213 / 812 correct (26.23)
# Iteration 30, loss = 1.2422
# Train Accuracy Got 28 / 64 correct (43.75)
# Test Accuracy Got 219 / 812 correct (26.97)
# Iteration 31, loss = 1.3044
# Train Accuracy Got 20 / 64 correct (31.25)
# Test Accuracy Got 229 / 812 correct (28.20)
# Iteration 32, loss = 1.2638
# Train Accuracy Got 25 / 64 correct (39.06)
# Test Accuracy Got 244 / 812 correct (30.05)
# Iteration 33, loss = 1.2676
# Train Accuracy Got 25 / 64 correct (39.06)
# Test Accuracy Got 206 / 812 correct (25.37)
# Iteration 34, loss = 1.3077
# Train Accuracy Got 18 / 64 correct (28.12)
# Test Accuracy Got 228 / 812 correct (28.08)
# Iteration 35, loss = 1.2146
# Train Accuracy Got 27 / 64 correct (42.19)
# Test Accuracy Got 225 / 812 correct (27.71)
# Iteration 36, loss = 1.3005
# Train Accuracy Got 25 / 64 correct (39.06)
# Test Accuracy Got 216 / 812 correct (26.60)
# Iteration 37, loss = 1.3056
# Train Accuracy Got 21 / 64 correct (32.81)
# Test Accuracy Got 220 / 812 correct (27.09)
# Iteration 38, loss = 1.3364
# Train Accuracy Got 26 / 64 correct (40.62)
# Test Accuracy Got 230 / 812 correct (28.33)
# Iteration 39, loss = 1.2642
# Train Accuracy Got 25 / 64 correct (39.06)
# Test Accuracy Got 242 / 812 correct (29.80)
# Iteration 40, loss = 1.2701
# Train Accuracy Got 23 / 64 correct (35.94)
# Test Accuracy Got 252 / 812 correct (31.03)
# Iteration 41, loss = 1.4230
# Train Accuracy Got 13 / 64 correct (20.31)
# Test Accuracy Got 211 / 812 correct (25.99)
# Iteration 42, loss = 1.2211
# Train Accuracy Got 31 / 64 correct (48.44)
# Test Accuracy Got 200 / 812 correct (24.63)
# Iteration 43, loss = 1.1417
# Train Accuracy Got 38 / 64 correct (59.38)
# Test Accuracy Got 209 / 812 correct (25.74)
# Iteration 44, loss = 1.2432
# Train Accuracy Got 24 / 64 correct (37.50)
# Test Accuracy Got 200 / 812 correct (24.63)
# Iteration 45, loss = 1.1584
# Train Accuracy Got 30 / 64 correct (46.88)
# Test Accuracy Got 219 / 812 correct (26.97)
# Iteration 46, loss = 1.3206
# Train Accuracy Got 22 / 64 correct (34.38)
# Test Accuracy Got 211 / 812 correct (25.99)
# Iteration 47, loss = 1.3694
# Train Accuracy Got 19 / 64 correct (29.69)
# Test Accuracy Got 206 / 812 correct (25.37)
# Iteration 48, loss = 1.2240
# Train Accuracy Got 32 / 64 correct (50.00)
# Test Accuracy Got 215 / 812 correct (26.48)
# Iteration 49, loss = 1.2763
# Train Accuracy Got 22 / 64 correct (34.38)
# Test Accuracy Got 222 / 812 correct (27.34)
# Iteration 50, loss = 1.3101
# Train Accuracy Got 15 / 48 correct (31.25)
# Test Accuracy Got 233 / 812 correct (28.69)
# Iteration 0, loss = 1.2887
# Train Accuracy Got 26 / 64 correct (40.62)
# Test Accuracy Got 246 / 812 correct (30.30)
# Iteration 1, loss = 1.2287
# Train Accuracy Got 25 / 64 correct (39.06)
# Test Accuracy Got 227 / 812 correct (27.96)
# Iteration 2, loss = 1.2167
# Train Accuracy Got 30 / 64 correct (46.88)
# Test Accuracy Got 213 / 812 correct (26.23)
# Iteration 3, loss = 1.3357
# Train Accuracy Got 21 / 64 correct (32.81)
# Test Accuracy Got 212 / 812 correct (26.11)
# Iteration 4, loss = 1.2166
# Train Accuracy Got 27 / 64 correct (42.19)
# Test Accuracy Got 212 / 812 correct (26.11)
# Iteration 5, loss = 1.2882
# Train Accuracy Got 26 / 64 correct (40.62)
# Test Accuracy Got 212 / 812 correct (26.11)
# Iteration 6, loss = 1.2312
# Train Accuracy Got 25 / 64 correct (39.06)
# Test Accuracy Got 212 / 812 correct (26.11)
# Iteration 7, loss = 1.3021
# Train Accuracy Got 30 / 64 correct (46.88)
# Test Accuracy Got 252 / 812 correct (31.03)
# Iteration 8, loss = 1.2640
# Train Accuracy Got 26 / 64 correct (40.62)
# Test Accuracy Got 233 / 812 correct (28.69)
# Iteration 9, loss = 1.2424
# Train Accuracy Got 24 / 64 correct (37.50)
# Test Accuracy Got 237 / 812 correct (29.19)
# Iteration 10, loss = 1.2913
# Train Accuracy Got 16 / 64 correct (25.00)
# Test Accuracy Got 215 / 812 correct (26.48)
# Iteration 11, loss = 1.2790
# Train Accuracy Got 30 / 64 correct (46.88)
# Test Accuracy Got 207 / 812 correct (25.49)
# Iteration 12, loss = 1.3265
# Train Accuracy Got 19 / 64 correct (29.69)
# Test Accuracy Got 198 / 812 correct (24.38)
# Iteration 13, loss = 1.1917
# Train Accuracy Got 23 / 64 correct (35.94)
# Test Accuracy Got 204 / 812 correct (25.12)
# Iteration 14, loss = 1.2313
# Train Accuracy Got 27 / 64 correct (42.19)
# Test Accuracy Got 176 / 812 correct (21.67)
# Iteration 15, loss = 1.2758
# Train Accuracy Got 27 / 64 correct (42.19)
# Test Accuracy Got 172 / 812 correct (21.18)
# Iteration 16, loss = 1.3117
# Train Accuracy Got 20 / 64 correct (31.25)
# Test Accuracy Got 167 / 812 correct (20.57)
# Iteration 17, loss = 1.1929
# Train Accuracy Got 30 / 64 correct (46.88)
# Test Accuracy Got 183 / 812 correct (22.54)
# Iteration 18, loss = 1.2242
# Train Accuracy Got 26 / 64 correct (40.62)
# Test Accuracy Got 194 / 812 correct (23.89)
# Iteration 19, loss = 1.2762
# Train Accuracy Got 23 / 64 correct (35.94)
# Test Accuracy Got 201 / 812 correct (24.75)
# Iteration 20, loss = 1.1920
# Train Accuracy Got 23 / 64 correct (35.94)
# Test Accuracy Got 234 / 812 correct (28.82)
# Iteration 21, loss = 1.1860
# Train Accuracy Got 24 / 64 correct (37.50)
# Test Accuracy Got 230 / 812 correct (28.33)
# Iteration 22, loss = 1.1839
# Train Accuracy Got 28 / 64 correct (43.75)
# Test Accuracy Got 212 / 812 correct (26.11)
# Iteration 23, loss = 1.3328
# Train Accuracy Got 25 / 64 correct (39.06)
# Test Accuracy Got 179 / 812 correct (22.04)
# Iteration 24, loss = 1.2804
# Train Accuracy Got 21 / 64 correct (32.81)
# Test Accuracy Got 236 / 812 correct (29.06)
# Iteration 25, loss = 1.2537
# Train Accuracy Got 23 / 64 correct (35.94)
# Test Accuracy Got 207 / 812 correct (25.49)
# Iteration 26, loss = 1.2262
# Train Accuracy Got 24 / 64 correct (37.50)
# Test Accuracy Got 212 / 812 correct (26.11)
# Iteration 27, loss = 1.2242
# Train Accuracy Got 22 / 64 correct (34.38)
# Test Accuracy Got 215 / 812 correct (26.48)
# Iteration 28, loss = 1.2325
# Train Accuracy Got 26 / 64 correct (40.62)
# Test Accuracy Got 212 / 812 correct (26.11)
# Iteration 29, loss = 1.2142
# Train Accuracy Got 27 / 64 correct (42.19)
# Test Accuracy Got 214 / 812 correct (26.35)
# Iteration 30, loss = 1.2099
# Train Accuracy Got 29 / 64 correct (45.31)
# Test Accuracy Got 212 / 812 correct (26.11)
# Iteration 31, loss = 1.1354
# Train Accuracy Got 33 / 64 correct (51.56)
# Test Accuracy Got 212 / 812 correct (26.11)
# Iteration 32, loss = 1.2784
# Train Accuracy Got 26 / 64 correct (40.62)
# Test Accuracy Got 212 / 812 correct (26.11)
# Iteration 33, loss = 1.2857
# Train Accuracy Got 25 / 64 correct (39.06)
# Test Accuracy Got 212 / 812 correct (26.11)
# Iteration 34, loss = 1.2418
# Train Accuracy Got 19 / 64 correct (29.69)
# Test Accuracy Got 212 / 812 correct (26.11)
# Iteration 35, loss = 1.2904
# Train Accuracy Got 22 / 64 correct (34.38)
# Test Accuracy Got 212 / 812 correct (26.11)
# Iteration 36, loss = 1.3177
# Train Accuracy Got 22 / 64 correct (34.38)
# Test Accuracy Got 212 / 812 correct (26.11)
# Iteration 37, loss = 1.3137
# Train Accuracy Got 21 / 64 correct (32.81)
# Test Accuracy Got 212 / 812 correct (26.11)
# Iteration 38, loss = 1.2986
# Train Accuracy Got 22 / 64 correct (34.38)
# Test Accuracy Got 212 / 812 correct (26.11)
# Iteration 39, loss = 1.2128
# Train Accuracy Got 25 / 64 correct (39.06)
# Test Accuracy Got 212 / 812 correct (26.11)
# Iteration 40, loss = 1.2242
# Train Accuracy Got 25 / 64 correct (39.06)
# Test Accuracy Got 213 / 812 correct (26.23)
# Iteration 41, loss = 1.2358
# Train Accuracy Got 27 / 64 correct (42.19)
# Test Accuracy Got 209 / 812 correct (25.74)
# Iteration 42, loss = 1.1814
# Train Accuracy Got 35 / 64 correct (54.69)
# Test Accuracy Got 212 / 812 correct (26.11)
# Iteration 43, loss = 1.2418
# Train Accuracy Got 28 / 64 correct (43.75)
# Test Accuracy Got 234 / 812 correct (28.82)
# Iteration 44, loss = 1.2560
# Train Accuracy Got 21 / 64 correct (32.81)
# Test Accuracy Got 217 / 812 correct (26.72)
# Iteration 45, loss = 1.2266
# Train Accuracy Got 29 / 64 correct (45.31)
# Test Accuracy Got 220 / 812 correct (27.09)
# Iteration 46, loss = 1.2590
# Train Accuracy Got 26 / 64 correct (40.62)
# Test Accuracy Got 224 / 812 correct (27.59)
# Iteration 47, loss = 1.2682
# Train Accuracy Got 24 / 64 correct (37.50)
# Test Accuracy Got 200 / 812 correct (24.63)
# Iteration 48, loss = 1.3460
# Train Accuracy Got 22 / 64 correct (34.38)
# Test Accuracy Got 165 / 812 correct (20.32)
# Iteration 49, loss = 1.2499
# Train Accuracy Got 29 / 64 correct (45.31)
# Test Accuracy Got 164 / 812 correct (20.20)
# Iteration 50, loss = 1.2200
# Train Accuracy Got 19 / 48 correct (39.58)
# Test Accuracy Got 178 / 812 correct (21.92)
# Iteration 0, loss = 1.2614
# Train Accuracy Got 28 / 64 correct (43.75)
# Test Accuracy Got 205 / 812 correct (25.25)
# Iteration 1, loss = 1.2824
# Train Accuracy Got 24 / 64 correct (37.50)
# Test Accuracy Got 232 / 812 correct (28.57)
# Iteration 2, loss = 1.2103
# Train Accuracy Got 28 / 64 correct (43.75)
# Test Accuracy Got 204 / 812 correct (25.12)
# Iteration 3, loss = 1.1842
# Train Accuracy Got 33 / 64 correct (51.56)
# Test Accuracy Got 212 / 812 correct (26.11)
# Iteration 4, loss = 1.2222
# Train Accuracy Got 28 / 64 correct (43.75)
# Test Accuracy Got 201 / 812 correct (24.75)
# Iteration 5, loss = 1.1583
# Train Accuracy Got 31 / 64 correct (48.44)
# Test Accuracy Got 210 / 812 correct (25.86)
# Iteration 6, loss = 1.2591
# Train Accuracy Got 25 / 64 correct (39.06)
# Test Accuracy Got 225 / 812 correct (27.71)
# Iteration 7, loss = 1.2311
# Train Accuracy Got 27 / 64 correct (42.19)
# Test Accuracy Got 232 / 812 correct (28.57)
# Iteration 8, loss = 1.1767
# Train Accuracy Got 34 / 64 correct (53.12)
# Test Accuracy Got 247 / 812 correct (30.42)
# Iteration 9, loss = 1.1644
# Train Accuracy Got 28 / 64 correct (43.75)
# Test Accuracy Got 243 / 812 correct (29.93)
# Iteration 10, loss = 1.1689
# Train Accuracy Got 32 / 64 correct (50.00)
# Test Accuracy Got 247 / 812 correct (30.42)
# Iteration 11, loss = 1.1784
# Train Accuracy Got 30 / 64 correct (46.88)
# Test Accuracy Got 248 / 812 correct (30.54)
# Iteration 12, loss = 1.1988
# Train Accuracy Got 31 / 64 correct (48.44)
# Test Accuracy Got 275 / 812 correct (33.87)
# Iteration 13, loss = 1.2129
# Train Accuracy Got 26 / 64 correct (40.62)
# Test Accuracy Got 268 / 812 correct (33.00)
# Iteration 14, loss = 1.1928
# Train Accuracy Got 34 / 64 correct (53.12)
# Test Accuracy Got 265 / 812 correct (32.64)
# Iteration 15, loss = 1.2919
# Train Accuracy Got 23 / 64 correct (35.94)
# Test Accuracy Got 230 / 812 correct (28.33)
# Iteration 16, loss = 1.2236
# Train Accuracy Got 30 / 64 correct (46.88)
# Test Accuracy Got 214 / 812 correct (26.35)
# Iteration 17, loss = 1.2375
# Train Accuracy Got 23 / 64 correct (35.94)
# Test Accuracy Got 213 / 812 correct (26.23)
# Iteration 18, loss = 1.2582
# Train Accuracy Got 28 / 64 correct (43.75)
# Test Accuracy Got 242 / 812 correct (29.80)
# Iteration 19, loss = 1.3282
# Train Accuracy Got 22 / 64 correct (34.38)
# Test Accuracy Got 287 / 812 correct (35.34)
# Iteration 20, loss = 1.1962
# Train Accuracy Got 21 / 64 correct (32.81)
# Test Accuracy Got 256 / 812 correct (31.53)
# Iteration 21, loss = 1.2732
# Train Accuracy Got 26 / 64 correct (40.62)
# Test Accuracy Got 251 / 812 correct (30.91)
# Iteration 22, loss = 1.2687
# Train Accuracy Got 21 / 64 correct (32.81)
# Test Accuracy Got 280 / 812 correct (34.48)
# Iteration 23, loss = 1.3036
# Train Accuracy Got 18 / 64 correct (28.12)
# Test Accuracy Got 271 / 812 correct (33.37)
# Iteration 24, loss = 1.1041
# Train Accuracy Got 31 / 64 correct (48.44)
# Test Accuracy Got 245 / 812 correct (30.17)
# Iteration 25, loss = 1.1675
# Train Accuracy Got 27 / 64 correct (42.19)
# Test Accuracy Got 275 / 812 correct (33.87)
# Iteration 26, loss = 1.2136
# Train Accuracy Got 31 / 64 correct (48.44)
# Test Accuracy Got 258 / 812 correct (31.77)
# Iteration 27, loss = 1.2157
# Train Accuracy Got 26 / 64 correct (40.62)
# Test Accuracy Got 277 / 812 correct (34.11)
# Iteration 28, loss = 1.2396
# Train Accuracy Got 28 / 64 correct (43.75)
# Test Accuracy Got 218 / 812 correct (26.85)
# Iteration 29, loss = 1.1714
# Train Accuracy Got 25 / 64 correct (39.06)
# Test Accuracy Got 236 / 812 correct (29.06)
# Iteration 30, loss = 1.3154
# Train Accuracy Got 26 / 64 correct (40.62)
# Test Accuracy Got 212 / 812 correct (26.11)
# Iteration 31, loss = 1.2382
# Train Accuracy Got 26 / 64 correct (40.62)
# Test Accuracy Got 212 / 812 correct (26.11)
# Iteration 32, loss = 1.2524
# Train Accuracy Got 29 / 64 correct (45.31)
# Test Accuracy Got 212 / 812 correct (26.11)
# Iteration 33, loss = 1.2965
# Train Accuracy Got 24 / 64 correct (37.50)
# Test Accuracy Got 212 / 812 correct (26.11)
# Iteration 34, loss = 1.1916
# Train Accuracy Got 26 / 64 correct (40.62)
# Test Accuracy Got 236 / 812 correct (29.06)
# Iteration 35, loss = 1.2946
# Train Accuracy Got 25 / 64 correct (39.06)
# Test Accuracy Got 206 / 812 correct (25.37)
# Iteration 36, loss = 1.1471
# Train Accuracy Got 33 / 64 correct (51.56)
# Test Accuracy Got 208 / 812 correct (25.62)
# Iteration 37, loss = 1.3597
# Train Accuracy Got 16 / 64 correct (25.00)
# Test Accuracy Got 215 / 812 correct (26.48)
# Iteration 38, loss = 1.1686
# Train Accuracy Got 30 / 64 correct (46.88)
# Test Accuracy Got 211 / 812 correct (25.99)
# Iteration 39, loss = 1.2255
# Train Accuracy Got 29 / 64 correct (45.31)
# Test Accuracy Got 210 / 812 correct (25.86)
# Iteration 40, loss = 1.1890
# Train Accuracy Got 28 / 64 correct (43.75)
# Test Accuracy Got 236 / 812 correct (29.06)
# Iteration 41, loss = 1.2885
# Train Accuracy Got 31 / 64 correct (48.44)
# Test Accuracy Got 235 / 812 correct (28.94)
# Iteration 42, loss = 1.3421
# Train Accuracy Got 20 / 64 correct (31.25)
# Test Accuracy Got 246 / 812 correct (30.30)
# Iteration 43, loss = 1.4129
# Train Accuracy Got 14 / 64 correct (21.88)
# Test Accuracy Got 246 / 812 correct (30.30)
# Iteration 44, loss = 1.2187
# Train Accuracy Got 24 / 64 correct (37.50)
# Test Accuracy Got 234 / 812 correct (28.82)
# Iteration 45, loss = 1.2696
# Train Accuracy Got 23 / 64 correct (35.94)
# Test Accuracy Got 192 / 812 correct (23.65)
# Iteration 46, loss = 1.2289
# Train Accuracy Got 27 / 64 correct (42.19)
# Test Accuracy Got 210 / 812 correct (25.86)
# Iteration 47, loss = 1.3399
# Train Accuracy Got 22 / 64 correct (34.38)
# Test Accuracy Got 208 / 812 correct (25.62)
# Iteration 48, loss = 1.2964
# Train Accuracy Got 20 / 64 correct (31.25)
# Test Accuracy Got 224 / 812 correct (27.59)
# Iteration 49, loss = 1.2537
# Train Accuracy Got 25 / 64 correct (39.06)
# Test Accuracy Got 260 / 812 correct (32.02)
# Iteration 50, loss = 1.3122
# Train Accuracy Got 16 / 48 correct (33.33)
# Test Accuracy Got 256 / 812 correct (31.53)
# Iteration 0, loss = 1.3263
# Train Accuracy Got 18 / 64 correct (28.12)
# Test Accuracy Got 261 / 812 correct (32.14)
# Iteration 1, loss = 1.1489
# Train Accuracy Got 33 / 64 correct (51.56)
# Test Accuracy Got 232 / 812 correct (28.57)
# Iteration 2, loss = 1.2368
# Train Accuracy Got 24 / 64 correct (37.50)
# Test Accuracy Got 223 / 812 correct (27.46)
# Iteration 3, loss = 1.2845
# Train Accuracy Got 28 / 64 correct (43.75)
# Test Accuracy Got 215 / 812 correct (26.48)
# Iteration 4, loss = 1.2569
# Train Accuracy Got 25 / 64 correct (39.06)
# Test Accuracy Got 222 / 812 correct (27.34)
# Iteration 5, loss = 1.2676
# Train Accuracy Got 24 / 64 correct (37.50)
# Test Accuracy Got 231 / 812 correct (28.45)
# Iteration 6, loss = 1.1889
# Train Accuracy Got 25 / 64 correct (39.06)
# Test Accuracy Got 213 / 812 correct (26.23)
# Iteration 7, loss = 1.2067
# Train Accuracy Got 28 / 64 correct (43.75)
# Test Accuracy Got 193 / 812 correct (23.77)
# Iteration 8, loss = 1.2251
# Train Accuracy Got 25 / 64 correct (39.06)
# Test Accuracy Got 192 / 812 correct (23.65)
# Iteration 9, loss = 1.2269
# Train Accuracy Got 21 / 64 correct (32.81)
# Test Accuracy Got 189 / 812 correct (23.28)
# Iteration 10, loss = 1.1644
# Train Accuracy Got 35 / 64 correct (54.69)
# Test Accuracy Got 169 / 812 correct (20.81)
# Iteration 11, loss = 1.1921
# Train Accuracy Got 28 / 64 correct (43.75)
# Test Accuracy Got 162 / 812 correct (19.95)
# Iteration 12, loss = 1.1728
# Train Accuracy Got 27 / 64 correct (42.19)
# Test Accuracy Got 168 / 812 correct (20.69)
# Iteration 13, loss = 1.1440
# Train Accuracy Got 33 / 64 correct (51.56)
# Test Accuracy Got 195 / 812 correct (24.01)
# Iteration 14, loss = 1.3127
# Train Accuracy Got 24 / 64 correct (37.50)
# Test Accuracy Got 225 / 812 correct (27.71)
# Iteration 15, loss = 1.2271
# Train Accuracy Got 26 / 64 correct (40.62)
# Test Accuracy Got 227 / 812 correct (27.96)
# Iteration 16, loss = 1.2261
# Train Accuracy Got 24 / 64 correct (37.50)
# Test Accuracy Got 213 / 812 correct (26.23)
# Iteration 17, loss = 1.2399
# Train Accuracy Got 24 / 64 correct (37.50)
# Test Accuracy Got 238 / 812 correct (29.31)
# Iteration 18, loss = 1.1901
# Train Accuracy Got 28 / 64 correct (43.75)
# Test Accuracy Got 281 / 812 correct (34.61)
# Iteration 19, loss = 1.2313
# Train Accuracy Got 27 / 64 correct (42.19)
# Test Accuracy Got 252 / 812 correct (31.03)
# Iteration 20, loss = 1.2027
# Train Accuracy Got 29 / 64 correct (45.31)
# Test Accuracy Got 270 / 812 correct (33.25)
# Iteration 21, loss = 1.3007
# Train Accuracy Got 22 / 64 correct (34.38)
# Test Accuracy Got 215 / 812 correct (26.48)
# Iteration 22, loss = 1.3567
# Train Accuracy Got 29 / 64 correct (45.31)
# Test Accuracy Got 234 / 812 correct (28.82)
# Iteration 23, loss = 1.2126
# Train Accuracy Got 30 / 64 correct (46.88)
# Test Accuracy Got 223 / 812 correct (27.46)
# Iteration 24, loss = 1.2853
# Train Accuracy Got 24 / 64 correct (37.50)
# Test Accuracy Got 184 / 812 correct (22.66)
# Iteration 25, loss = 1.2123
# Train Accuracy Got 27 / 64 correct (42.19)
# Test Accuracy Got 215 / 812 correct (26.48)
# Iteration 26, loss = 1.1281
# Train Accuracy Got 30 / 64 correct (46.88)
# Test Accuracy Got 217 / 812 correct (26.72)
# Iteration 27, loss = 1.2228
# Train Accuracy Got 24 / 64 correct (37.50)
# Test Accuracy Got 206 / 812 correct (25.37)
# Iteration 28, loss = 1.2524
# Train Accuracy Got 26 / 64 correct (40.62)
# Test Accuracy Got 217 / 812 correct (26.72)
# Iteration 29, loss = 1.1838
# Train Accuracy Got 28 / 64 correct (43.75)
# Test Accuracy Got 223 / 812 correct (27.46)
# Iteration 30, loss = 1.2950
# Train Accuracy Got 25 / 64 correct (39.06)
# Test Accuracy Got 235 / 812 correct (28.94)
# Iteration 31, loss = 1.1833
# Train Accuracy Got 33 / 64 correct (51.56)
# Test Accuracy Got 224 / 812 correct (27.59)
# Iteration 32, loss = 1.2460
# Train Accuracy Got 28 / 64 correct (43.75)
# Test Accuracy Got 187 / 812 correct (23.03)
# Iteration 33, loss = 1.1737
# Train Accuracy Got 34 / 64 correct (53.12)
# Test Accuracy Got 213 / 812 correct (26.23)
# Iteration 34, loss = 1.1892
# Train Accuracy Got 29 / 64 correct (45.31)
# Test Accuracy Got 194 / 812 correct (23.89)
# Iteration 35, loss = 1.2294
# Train Accuracy Got 27 / 64 correct (42.19)
# Test Accuracy Got 203 / 812 correct (25.00)
# Iteration 36, loss = 1.2743
# Train Accuracy Got 28 / 64 correct (43.75)
# Test Accuracy Got 243 / 812 correct (29.93)
# Iteration 37, loss = 1.1776
# Train Accuracy Got 29 / 64 correct (45.31)
# Test Accuracy Got 223 / 812 correct (27.46)
# Iteration 38, loss = 1.2804
# Train Accuracy Got 25 / 64 correct (39.06)
# Test Accuracy Got 235 / 812 correct (28.94)
# Iteration 39, loss = 1.2778
# Train Accuracy Got 22 / 64 correct (34.38)
# Test Accuracy Got 268 / 812 correct (33.00)
# Iteration 40, loss = 1.2342
# Train Accuracy Got 25 / 64 correct (39.06)
# Test Accuracy Got 271 / 812 correct (33.37)
# Iteration 41, loss = 1.1919
# Train Accuracy Got 27 / 64 correct (42.19)
# Test Accuracy Got 251 / 812 correct (30.91)
# Iteration 42, loss = 1.2676
# Train Accuracy Got 23 / 64 correct (35.94)
# Test Accuracy Got 271 / 812 correct (33.37)
# Iteration 43, loss = 1.1587
# Train Accuracy Got 31 / 64 correct (48.44)
# Test Accuracy Got 253 / 812 correct (31.16)
# Iteration 44, loss = 1.1956
# Train Accuracy Got 30 / 64 correct (46.88)
# Test Accuracy Got 237 / 812 correct (29.19)
# Iteration 45, loss = 1.2192
# Train Accuracy Got 28 / 64 correct (43.75)
# Test Accuracy Got 252 / 812 correct (31.03)
# Iteration 46, loss = 1.2705
# Train Accuracy Got 21 / 64 correct (32.81)
# Test Accuracy Got 206 / 812 correct (25.37)
# Iteration 47, loss = 1.2516
# Train Accuracy Got 25 / 64 correct (39.06)
# Test Accuracy Got 224 / 812 correct (27.59)
# Iteration 48, loss = 1.2346
# Train Accuracy Got 27 / 64 correct (42.19)
# Test Accuracy Got 222 / 812 correct (27.34)
# Iteration 49, loss = 1.1612
# Train Accuracy Got 35 / 64 correct (54.69)
# Test Accuracy Got 225 / 812 correct (27.71)
# Iteration 50, loss = 1.3001
# Train Accuracy Got 18 / 48 correct (37.50)
# Test Accuracy Got 226 / 812 correct (27.83)
# Iteration 0, loss = 1.2110
# Train Accuracy Got 27 / 64 correct (42.19)
# Test Accuracy Got 236 / 812 correct (29.06)
# Iteration 1, loss = 1.2195
# Train Accuracy Got 30 / 64 correct (46.88)
# Test Accuracy Got 213 / 812 correct (26.23)
# Iteration 2, loss = 1.2215
# Train Accuracy Got 31 / 64 correct (48.44)
# Test Accuracy Got 207 / 812 correct (25.49)
# Iteration 3, loss = 1.2133
# Train Accuracy Got 21 / 64 correct (32.81)
# Test Accuracy Got 180 / 812 correct (22.17)
# Iteration 4, loss = 1.3052
# Train Accuracy Got 23 / 64 correct (35.94)
# Test Accuracy Got 209 / 812 correct (25.74)
# Iteration 5, loss = 1.2666
# Train Accuracy Got 25 / 64 correct (39.06)
# Test Accuracy Got 183 / 812 correct (22.54)
# Iteration 6, loss = 1.1757
# Train Accuracy Got 31 / 64 correct (48.44)
# Test Accuracy Got 191 / 812 correct (23.52)
# Iteration 7, loss = 1.2585
# Train Accuracy Got 30 / 64 correct (46.88)
# Test Accuracy Got 219 / 812 correct (26.97)
# Iteration 8, loss = 1.1259
# Train Accuracy Got 33 / 64 correct (51.56)
# Test Accuracy Got 194 / 812 correct (23.89)
# Iteration 9, loss = 1.1954
# Train Accuracy Got 26 / 64 correct (40.62)
# Test Accuracy Got 182 / 812 correct (22.41)
# Iteration 10, loss = 1.2348
# Train Accuracy Got 27 / 64 correct (42.19)
# Test Accuracy Got 182 / 812 correct (22.41)
# Iteration 11, loss = 1.2449
# Train Accuracy Got 23 / 64 correct (35.94)
# Test Accuracy Got 209 / 812 correct (25.74)
# Iteration 12, loss = 1.2521
# Train Accuracy Got 24 / 64 correct (37.50)
# Test Accuracy Got 183 / 812 correct (22.54)
# Iteration 13, loss = 1.2139
# Train Accuracy Got 32 / 64 correct (50.00)
# Test Accuracy Got 209 / 812 correct (25.74)
# Iteration 14, loss = 1.1665
# Train Accuracy Got 29 / 64 correct (45.31)
# Test Accuracy Got 260 / 812 correct (32.02)
# Iteration 15, loss = 1.1467
# Train Accuracy Got 28 / 64 correct (43.75)
# Test Accuracy Got 236 / 812 correct (29.06)
# Iteration 16, loss = 1.2687
# Train Accuracy Got 26 / 64 correct (40.62)
# Test Accuracy Got 231 / 812 correct (28.45)
# Iteration 17, loss = 1.2478
# Train Accuracy Got 26 / 64 correct (40.62)
# Test Accuracy Got 210 / 812 correct (25.86)
# Iteration 18, loss = 1.2615
# Train Accuracy Got 21 / 64 correct (32.81)
# Test Accuracy Got 226 / 812 correct (27.83)
# Iteration 19, loss = 1.2004
# Train Accuracy Got 29 / 64 correct (45.31)
# Test Accuracy Got 232 / 812 correct (28.57)
# Iteration 20, loss = 1.1741
# Train Accuracy Got 32 / 64 correct (50.00)
# Test Accuracy Got 230 / 812 correct (28.33)
# Iteration 21, loss = 1.2524
# Train Accuracy Got 23 / 64 correct (35.94)
# Test Accuracy Got 243 / 812 correct (29.93)
# Iteration 22, loss = 1.3037
# Train Accuracy Got 21 / 64 correct (32.81)
# Test Accuracy Got 212 / 812 correct (26.11)
# Iteration 23, loss = 1.2550
# Train Accuracy Got 26 / 64 correct (40.62)
# Test Accuracy Got 262 / 812 correct (32.27)
# Iteration 24, loss = 1.2493
# Train Accuracy Got 24 / 64 correct (37.50)
# Test Accuracy Got 259 / 812 correct (31.90)
# Iteration 25, loss = 1.2386
# Train Accuracy Got 24 / 64 correct (37.50)
# Test Accuracy Got 243 / 812 correct (29.93)
# Iteration 26, loss = 1.1982
# Train Accuracy Got 24 / 64 correct (37.50)
# Test Accuracy Got 245 / 812 correct (30.17)
# Iteration 27, loss = 1.2746
# Train Accuracy Got 25 / 64 correct (39.06)
# Test Accuracy Got 233 / 812 correct (28.69)
# Iteration 28, loss = 1.3240
# Train Accuracy Got 19 / 64 correct (29.69)
# Test Accuracy Got 217 / 812 correct (26.72)
# Iteration 29, loss = 1.2664
# Train Accuracy Got 25 / 64 correct (39.06)
# Test Accuracy Got 225 / 812 correct (27.71)
# Iteration 30, loss = 1.1960
# Train Accuracy Got 31 / 64 correct (48.44)
# Test Accuracy Got 211 / 812 correct (25.99)
# Iteration 31, loss = 1.1865
# Train Accuracy Got 23 / 64 correct (35.94)
# Test Accuracy Got 209 / 812 correct (25.74)
# Iteration 32, loss = 1.2109
# Train Accuracy Got 28 / 64 correct (43.75)
# Test Accuracy Got 210 / 812 correct (25.86)
# Iteration 33, loss = 1.2192
# Train Accuracy Got 23 / 64 correct (35.94)
# Test Accuracy Got 206 / 812 correct (25.37)
# Iteration 34, loss = 1.1967
# Train Accuracy Got 30 / 64 correct (46.88)
# Test Accuracy Got 239 / 812 correct (29.43)
# Iteration 35, loss = 1.1478
# Train Accuracy Got 32 / 64 correct (50.00)
# Test Accuracy Got 273 / 812 correct (33.62)
# Iteration 36, loss = 1.2071
# Train Accuracy Got 29 / 64 correct (45.31)
# Test Accuracy Got 245 / 812 correct (30.17)
# Iteration 37, loss = 1.1990
# Train Accuracy Got 28 / 64 correct (43.75)
# Test Accuracy Got 240 / 812 correct (29.56)
# Iteration 38, loss = 1.1605
# Train Accuracy Got 27 / 64 correct (42.19)
# Test Accuracy Got 223 / 812 correct (27.46)
# Iteration 39, loss = 1.2466
# Train Accuracy Got 22 / 64 correct (34.38)
# Test Accuracy Got 221 / 812 correct (27.22)
# Iteration 40, loss = 1.2686
# Train Accuracy Got 23 / 64 correct (35.94)
# Test Accuracy Got 216 / 812 correct (26.60)
# Iteration 41, loss = 1.2779
# Train Accuracy Got 26 / 64 correct (40.62)
# Test Accuracy Got 224 / 812 correct (27.59)
# Iteration 42, loss = 1.2199
# Train Accuracy Got 24 / 64 correct (37.50)
# Test Accuracy Got 219 / 812 correct (26.97)
# Iteration 43, loss = 1.2316
# Train Accuracy Got 25 / 64 correct (39.06)
# Test Accuracy Got 207 / 812 correct (25.49)
# Iteration 44, loss = 1.2468
# Train Accuracy Got 24 / 64 correct (37.50)
# Test Accuracy Got 237 / 812 correct (29.19)
# Iteration 45, loss = 1.1835
# Train Accuracy Got 28 / 64 correct (43.75)
# Test Accuracy Got 250 / 812 correct (30.79)
# Iteration 46, loss = 1.1878
# Train Accuracy Got 24 / 64 correct (37.50)
# Test Accuracy Got 249 / 812 correct (30.67)
# Iteration 47, loss = 1.2036
# Train Accuracy Got 28 / 64 correct (43.75)
# Test Accuracy Got 265 / 812 correct (32.64)
# Iteration 48, loss = 1.2260
# Train Accuracy Got 29 / 64 correct (45.31)
# Test Accuracy Got 224 / 812 correct (27.59)
# Iteration 49, loss = 1.2150
# Train Accuracy Got 31 / 64 correct (48.44)
# Test Accuracy Got 217 / 812 correct (26.72)
# Iteration 50, loss = 1.1605
# Train Accuracy Got 22 / 48 correct (45.83)
# Test Accuracy Got 232 / 812 correct (28.57)
# Iteration 0, loss = 1.2355
# Train Accuracy Got 29 / 64 correct (45.31)
# Test Accuracy Got 262 / 812 correct (32.27)
# Iteration 1, loss = 1.2553
# Train Accuracy Got 26 / 64 correct (40.62)
# Test Accuracy Got 204 / 812 correct (25.12)
# Iteration 2, loss = 1.2729
# Train Accuracy Got 29 / 64 correct (45.31)
# Test Accuracy Got 231 / 812 correct (28.45)
# Iteration 3, loss = 1.2396
# Train Accuracy Got 24 / 64 correct (37.50)
# Test Accuracy Got 207 / 812 correct (25.49)
# Iteration 4, loss = 1.2845
# Train Accuracy Got 23 / 64 correct (35.94)
# Test Accuracy Got 205 / 812 correct (25.25)
# Iteration 5, loss = 1.1493
# Train Accuracy Got 30 / 64 correct (46.88)
# Test Accuracy Got 237 / 812 correct (29.19)
# Iteration 6, loss = 1.1273
# Train Accuracy Got 36 / 64 correct (56.25)
# Test Accuracy Got 261 / 812 correct (32.14)
# Iteration 7, loss = 1.1489
# Train Accuracy Got 35 / 64 correct (54.69)
# Test Accuracy Got 245 / 812 correct (30.17)
# Iteration 8, loss = 1.2604
# Train Accuracy Got 31 / 64 correct (48.44)
# Test Accuracy Got 207 / 812 correct (25.49)
# Iteration 9, loss = 1.2164
# Train Accuracy Got 22 / 64 correct (34.38)
# Test Accuracy Got 211 / 812 correct (25.99)
# Iteration 10, loss = 1.1567
# Train Accuracy Got 26 / 64 correct (40.62)
# Test Accuracy Got 213 / 812 correct (26.23)
# Iteration 11, loss = 1.2530
# Train Accuracy Got 22 / 64 correct (34.38)
# Test Accuracy Got 232 / 812 correct (28.57)
# Iteration 12, loss = 1.1464
# Train Accuracy Got 32 / 64 correct (50.00)
# Test Accuracy Got 214 / 812 correct (26.35)
# Iteration 13, loss = 1.3233
# Train Accuracy Got 24 / 64 correct (37.50)
# Test Accuracy Got 233 / 812 correct (28.69)
# Iteration 14, loss = 1.2820
# Train Accuracy Got 26 / 64 correct (40.62)
# Test Accuracy Got 218 / 812 correct (26.85)
# Iteration 15, loss = 1.2484
# Train Accuracy Got 25 / 64 correct (39.06)
# Test Accuracy Got 254 / 812 correct (31.28)
# Iteration 16, loss = 1.2669
# Train Accuracy Got 24 / 64 correct (37.50)
# Test Accuracy Got 250 / 812 correct (30.79)
# Iteration 17, loss = 1.1990
# Train Accuracy Got 30 / 64 correct (46.88)
# Test Accuracy Got 253 / 812 correct (31.16)
# Iteration 18, loss = 1.1787
# Train Accuracy Got 29 / 64 correct (45.31)
# Test Accuracy Got 224 / 812 correct (27.59)
# Iteration 19, loss = 1.2429
# Train Accuracy Got 26 / 64 correct (40.62)
# Test Accuracy Got 247 / 812 correct (30.42)
# Iteration 20, loss = 1.1537
# Train Accuracy Got 32 / 64 correct (50.00)
# Test Accuracy Got 209 / 812 correct (25.74)
# Iteration 21, loss = 1.1677
# Train Accuracy Got 32 / 64 correct (50.00)
# Test Accuracy Got 175 / 812 correct (21.55)
# Iteration 22, loss = 1.1429
# Train Accuracy Got 23 / 64 correct (35.94)
# Test Accuracy Got 174 / 812 correct (21.43)
# Iteration 23, loss = 1.2468
# Train Accuracy Got 28 / 64 correct (43.75)
# Test Accuracy Got 218 / 812 correct (26.85)
# Iteration 24, loss = 1.1572
# Train Accuracy Got 32 / 64 correct (50.00)
# Test Accuracy Got 243 / 812 correct (29.93)
# Iteration 25, loss = 1.1427
# Train Accuracy Got 31 / 64 correct (48.44)
# Test Accuracy Got 192 / 812 correct (23.65)
# Iteration 26, loss = 1.2123
# Train Accuracy Got 29 / 64 correct (45.31)
# Test Accuracy Got 189 / 812 correct (23.28)
# Iteration 27, loss = 1.1754
# Train Accuracy Got 27 / 64 correct (42.19)
# Test Accuracy Got 212 / 812 correct (26.11)
# Iteration 28, loss = 1.1358
# Train Accuracy Got 32 / 64 correct (50.00)
# Test Accuracy Got 240 / 812 correct (29.56)
# Iteration 29, loss = 1.1974
# Train Accuracy Got 25 / 64 correct (39.06)
# Test Accuracy Got 229 / 812 correct (28.20)
# Iteration 30, loss = 1.2243
# Train Accuracy Got 29 / 64 correct (45.31)
# Test Accuracy Got 229 / 812 correct (28.20)
# Iteration 31, loss = 1.2635
# Train Accuracy Got 21 / 64 correct (32.81)
# Test Accuracy Got 259 / 812 correct (31.90)
# Iteration 32, loss = 1.2086
# Train Accuracy Got 22 / 64 correct (34.38)
# Test Accuracy Got 226 / 812 correct (27.83)
# Iteration 33, loss = 1.1816
# Train Accuracy Got 27 / 64 correct (42.19)
# Test Accuracy Got 181 / 812 correct (22.29)
# Iteration 34, loss = 1.1995
# Train Accuracy Got 29 / 64 correct (45.31)
# Test Accuracy Got 218 / 812 correct (26.85)
# Iteration 35, loss = 1.2796
# Train Accuracy Got 23 / 64 correct (35.94)
# Test Accuracy Got 195 / 812 correct (24.01)
# Iteration 36, loss = 1.2278
# Train Accuracy Got 26 / 64 correct (40.62)
# Test Accuracy Got 195 / 812 correct (24.01)
# Iteration 37, loss = 1.1802
# Train Accuracy Got 33 / 64 correct (51.56)
# Test Accuracy Got 222 / 812 correct (27.34)
# Iteration 38, loss = 1.1482
# Train Accuracy Got 31 / 64 correct (48.44)
# Test Accuracy Got 209 / 812 correct (25.74)
# Iteration 39, loss = 1.1808
# Train Accuracy Got 27 / 64 correct (42.19)
# Test Accuracy Got 179 / 812 correct (22.04)
# Iteration 40, loss = 1.2432
# Train Accuracy Got 25 / 64 correct (39.06)
# Test Accuracy Got 183 / 812 correct (22.54)
# Iteration 41, loss = 1.1846
# Train Accuracy Got 23 / 64 correct (35.94)
# Test Accuracy Got 206 / 812 correct (25.37)
# Iteration 42, loss = 1.2467
# Train Accuracy Got 26 / 64 correct (40.62)
# Test Accuracy Got 193 / 812 correct (23.77)
# Iteration 43, loss = 1.2036
# Train Accuracy Got 28 / 64 correct (43.75)
# Test Accuracy Got 184 / 812 correct (22.66)
# Iteration 44, loss = 1.1847
# Train Accuracy Got 34 / 64 correct (53.12)
# Test Accuracy Got 213 / 812 correct (26.23)
# Iteration 45, loss = 1.1674
# Train Accuracy Got 32 / 64 correct (50.00)
# Test Accuracy Got 196 / 812 correct (24.14)
# Iteration 46, loss = 1.1376
# Train Accuracy Got 29 / 64 correct (45.31)
# Test Accuracy Got 205 / 812 correct (25.25)
# Iteration 47, loss = 1.1979
# Train Accuracy Got 31 / 64 correct (48.44)
# Test Accuracy Got 196 / 812 correct (24.14)
# Iteration 48, loss = 1.2202
# Train Accuracy Got 24 / 64 correct (37.50)
# Test Accuracy Got 216 / 812 correct (26.60)
# Iteration 49, loss = 1.1718
# Train Accuracy Got 32 / 64 correct (50.00)
# Test Accuracy Got 214 / 812 correct (26.35)
# Iteration 50, loss = 1.3641
# Train Accuracy Got 18 / 48 correct (37.50)
# Test Accuracy Got 212 / 812 correct (26.11)
# Iteration 0, loss = 1.2066
# Train Accuracy Got 28 / 64 correct (43.75)
# Test Accuracy Got 215 / 812 correct (26.48)
# Iteration 1, loss = 1.1789
# Train Accuracy Got 34 / 64 correct (53.12)
# Test Accuracy Got 212 / 812 correct (26.11)
# Iteration 2, loss = 1.3121
# Train Accuracy Got 23 / 64 correct (35.94)
# Test Accuracy Got 212 / 812 correct (26.11)
# Iteration 3, loss = 1.2189
# Train Accuracy Got 25 / 64 correct (39.06)
# Test Accuracy Got 212 / 812 correct (26.11)
# Iteration 4, loss = 1.2409
# Train Accuracy Got 28 / 64 correct (43.75)
# Test Accuracy Got 212 / 812 correct (26.11)
# Iteration 5, loss = 1.1716
# Train Accuracy Got 30 / 64 correct (46.88)
# Test Accuracy Got 212 / 812 correct (26.11)
# Iteration 6, loss = 1.1540
# Train Accuracy Got 26 / 64 correct (40.62)
# Test Accuracy Got 233 / 812 correct (28.69)
# Iteration 7, loss = 1.2384
# Train Accuracy Got 29 / 64 correct (45.31)
# Test Accuracy Got 216 / 812 correct (26.60)
# Iteration 8, loss = 1.2791
# Train Accuracy Got 22 / 64 correct (34.38)
# Test Accuracy Got 195 / 812 correct (24.01)
# Iteration 9, loss = 1.2742
# Train Accuracy Got 31 / 64 correct (48.44)
# Test Accuracy Got 242 / 812 correct (29.80)
# ...
# Train Accuracy Got 30 / 64 correct (46.88)
# Test Accuracy Got 252 / 812 correct (31.03)
# Iteration 17, loss = 1.0170
# Train Accuracy Got 40 / 64 correct (62.50)
# Test Accuracy Got 201 / 812 correct (24.75)
# Iteration 18, loss = 1.1067
# Train Accuracy Got 33 / 64 correct (51.56)
# Test Accuracy Got 177 / 812 correct (21.80)
# Iteration 19, loss = 1.1882
# Train Accuracy Got 29 / 64 correct (45.31)
# Test Accuracy Got 156 / 812 correct (19.21)
# Iteration 20, loss = 1.0550
# Train Accuracy Got 39 / 64 correct (60.94)
# Test Accuracy Got 164 / 812 correct (20.20)
# Iteration 21, loss = 1.1089
# Train Accuracy Got 32 / 64 correct (50.00)
# Test Accuracy Got 130 / 812 correct (16.01)
# Iteration 22, loss = 1.0709
# Train Accuracy Got 33 / 64 correct (51.56)
# Test Accuracy Got 159 / 812 correct (19.58)
# Iteration 23, loss = 1.1976
# Train Accuracy Got 28 / 64 correct (43.75)
# Test Accuracy Got 191 / 812 correct (23.52)
# Iteration 24, loss = 1.1218
# Train Accuracy Got 32 / 64 correct (50.00)
# Test Accuracy Got 204 / 812 correct (25.12)
# Iteration 25, loss = 1.0041
# Train Accuracy Got 31 / 64 correct (48.44)
# Test Accuracy Got 186 / 812 correct (22.91)
# Iteration 26, loss = 1.1423
# Train Accuracy Got 28 / 64 correct (43.75)
# Test Accuracy Got 279 / 812 correct (34.36)
# Iteration 27, loss = 1.1291
# Train Accuracy Got 29 / 64 correct (45.31)
# Test Accuracy Got 267 / 812 correct (32.88)
# Iteration 28, loss = 1.1076
# Train Accuracy Got 32 / 64 correct (50.00)
# Test Accuracy Got 211 / 812 correct (25.99)
# Iteration 29, loss = 0.9955
# Train Accuracy Got 32 / 64 correct (50.00)
# Test Accuracy Got 185 / 812 correct (22.78)
# Iteration 30, loss = 1.1164
# Train Accuracy Got 33 / 64 correct (51.56)
# Test Accuracy Got 213 / 812 correct (26.23)
# Iteration 31, loss = 1.1805
# Train Accuracy Got 29 / 64 correct (45.31)
# Test Accuracy Got 226 / 812 correct (27.83)
# Iteration 32, loss = 1.1052
# Train Accuracy Got 29 / 64 correct (45.31)
# Test Accuracy Got 215 / 812 correct (26.48)
# Iteration 33, loss = 0.9744
# Train Accuracy Got 36 / 64 correct (56.25)
# Test Accuracy Got 218 / 812 correct (26.85)
# Iteration 34, loss = 1.1889
# Train Accuracy Got 25 / 64 correct (39.06)
# Test Accuracy Got 231 / 812 correct (28.45)
# Iteration 35, loss = 1.1506
# Train Accuracy Got 28 / 64 correct (43.75)
# Test Accuracy Got 229 / 812 correct (28.20)
# Iteration 36, loss = 1.1121
# Train Accuracy Got 31 / 64 correct (48.44)
# Test Accuracy Got 219 / 812 correct (26.97)
# Iteration 37, loss = 1.1428
# Train Accuracy Got 28 / 64 correct (43.75)
# Test Accuracy Got 221 / 812 correct (27.22)
# Iteration 38, loss = 1.1271
# Train Accuracy Got 37 / 64 correct (57.81)
# Test Accuracy Got 235 / 812 correct (28.94)
# Iteration 39, loss = 1.0842
# Train Accuracy Got 32 / 64 correct (50.00)
# Test Accuracy Got 238 / 812 correct (29.31)
# Iteration 40, loss = 1.0974
# Train Accuracy Got 28 / 64 correct (43.75)
# Test Accuracy Got 261 / 812 correct (32.14)
# Iteration 41, loss = 1.1436
# Train Accuracy Got 30 / 64 correct (46.88)
# Test Accuracy Got 264 / 812 correct (32.51)
# Iteration 42, loss = 1.0955
# Train Accuracy Got 30 / 64 correct (46.88)
# Test Accuracy Got 252 / 812 correct (31.03)
# Iteration 43, loss = 0.9993
# Train Accuracy Got 39 / 64 correct (60.94)
# Test Accuracy Got 212 / 812 correct (26.11)
# Iteration 44, loss = 1.0177
# Train Accuracy Got 36 / 64 correct (56.25)
# Test Accuracy Got 212 / 812 correct (26.11)
# Iteration 45, loss = 1.1569
# Train Accuracy Got 30 / 64 correct (46.88)
# Test Accuracy Got 209 / 812 correct (25.74)
# Iteration 46, loss = 1.1439
# Train Accuracy Got 28 / 64 correct (43.75)
# Test Accuracy Got 235 / 812 correct (28.94)
# Iteration 47, loss = 1.2061
# Train Accuracy Got 30 / 64 correct (46.88)
# Test Accuracy Got 231 / 812 correct (28.45)
# Iteration 48, loss = 1.0644
# Train Accuracy Got 33 / 64 correct (51.56)
# Test Accuracy Got 249 / 812 correct (30.67)
# Iteration 49, loss = 1.1003
# Train Accuracy Got 36 / 64 correct (56.25)
# Test Accuracy Got 238 / 812 correct (29.31)
# Iteration 50, loss = 1.0203
# Train Accuracy Got 28 / 48 correct (58.33)
# Test Accuracy Got 248 / 812 correct (30.54)
# Iteration 0, loss = 1.0948
# Train Accuracy Got 37 / 64 correct (57.81)
# Test Accuracy Got 255 / 812 correct (31.40)
# Iteration 1, loss = 1.1317
# Train Accuracy Got 31 / 64 correct (48.44)
# Test Accuracy Got 235 / 812 correct (28.94)
# Iteration 2, loss = 1.0324
# Train Accuracy Got 36 / 64 correct (56.25)
# Test Accuracy Got 243 / 812 correct (29.93)
# Iteration 3, loss = 1.0199
# Train Accuracy Got 37 / 64 correct (57.81)
# Test Accuracy Got 230 / 812 correct (28.33)
# Iteration 4, loss = 0.9682
# Train Accuracy Got 39 / 64 correct (60.94)
# Test Accuracy Got 232 / 812 correct (28.57)
# Iteration 5, loss = 1.1478
# Train Accuracy Got 38 / 64 correct (59.38)
# Test Accuracy Got 213 / 812 correct (26.23)
# Iteration 6, loss = 1.0999
# Train Accuracy Got 32 / 64 correct (50.00)
# Test Accuracy Got 216 / 812 correct (26.60)
# Iteration 7, loss = 0.9144
# Train Accuracy Got 41 / 64 correct (64.06)
# Test Accuracy Got 227 / 812 correct (27.96)
# Iteration 8, loss = 1.1408
# Train Accuracy Got 29 / 64 correct (45.31)
# Test Accuracy Got 233 / 812 correct (28.69)
# Iteration 9, loss = 1.1642
# Train Accuracy Got 29 / 64 correct (45.31)
# Test Accuracy Got 228 / 812 correct (28.08)
# Iteration 10, loss = 1.1369
# Train Accuracy Got 30 / 64 correct (46.88)
# Test Accuracy Got 237 / 812 correct (29.19)
# Iteration 11, loss = 1.0602
# Train Accuracy Got 32 / 64 correct (50.00)
# Test Accuracy Got 243 / 812 correct (29.93)
# Iteration 12, loss = 1.1262
# Train Accuracy Got 30 / 64 correct (46.88)
# Test Accuracy Got 237 / 812 correct (29.19)
# Iteration 13, loss = 0.9669
# Train Accuracy Got 38 / 64 correct (59.38)
# Test Accuracy Got 228 / 812 correct (28.08)
# Iteration 14, loss = 1.0594
# Train Accuracy Got 34 / 64 correct (53.12)
# Test Accuracy Got 277 / 812 correct (34.11)
# Iteration 15, loss = 0.9960
# Train Accuracy Got 36 / 64 correct (56.25)
# Test Accuracy Got 288 / 812 correct (35.47)
# Iteration 16, loss = 1.0292
# Train Accuracy Got 38 / 64 correct (59.38)
# Test Accuracy Got 298 / 812 correct (36.70)
# Iteration 17, loss = 0.9863
# Train Accuracy Got 41 / 64 correct (64.06)
# Test Accuracy Got 276 / 812 correct (33.99)
# Iteration 18, loss = 1.1814
# Train Accuracy Got 34 / 64 correct (53.12)
# Test Accuracy Got 258 / 812 correct (31.77)
# Iteration 19, loss = 1.1828
# Train Accuracy Got 30 / 64 correct (46.88)
# Test Accuracy Got 249 / 812 correct (30.67)
# Iteration 20, loss = 0.8913
# Train Accuracy Got 41 / 64 correct (64.06)
# Test Accuracy Got 279 / 812 correct (34.36)
# Iteration 21, loss = 1.3557
# Train Accuracy Got 24 / 64 correct (37.50)
# Test Accuracy Got 274 / 812 correct (33.74)
# Iteration 22, loss = 1.3250
# Train Accuracy Got 26 / 64 correct (40.62)
# Test Accuracy Got 253 / 812 correct (31.16)
# Iteration 23, loss = 1.2278
# Train Accuracy Got 26 / 64 correct (40.62)
# Test Accuracy Got 234 / 812 correct (28.82)
# Iteration 24, loss = 1.0069
# Train Accuracy Got 37 / 64 correct (57.81)
# Test Accuracy Got 230 / 812 correct (28.33)
# Iteration 25, loss = 1.0833
# Train Accuracy Got 34 / 64 correct (53.12)
# Test Accuracy Got 227 / 812 correct (27.96)
# Iteration 26, loss = 1.0652
# Train Accuracy Got 35 / 64 correct (54.69)
# Test Accuracy Got 230 / 812 correct (28.33)
# Iteration 27, loss = 1.1467
# Train Accuracy Got 32 / 64 correct (50.00)
# Test Accuracy Got 213 / 812 correct (26.23)
# Iteration 28, loss = 1.0960
# Train Accuracy Got 32 / 64 correct (50.00)
# Test Accuracy Got 206 / 812 correct (25.37)
# Iteration 29, loss = 1.0873
# Train Accuracy Got 33 / 64 correct (51.56)
# Test Accuracy Got 210 / 812 correct (25.86)
# Iteration 30, loss = 0.9963
# Train Accuracy Got 39 / 64 correct (60.94)
# Test Accuracy Got 183 / 812 correct (22.54)
# Iteration 31, loss = 1.0560
# Train Accuracy Got 35 / 64 correct (54.69)
# Test Accuracy Got 206 / 812 correct (25.37)
# Iteration 32, loss = 1.0474
# Train Accuracy Got 31 / 64 correct (48.44)
# Test Accuracy Got 224 / 812 correct (27.59)
# Iteration 33, loss = 1.2345
# Train Accuracy Got 29 / 64 correct (45.31)
# Test Accuracy Got 222 / 812 correct (27.34)
# Iteration 34, loss = 1.0761
# Train Accuracy Got 36 / 64 correct (56.25)
# Test Accuracy Got 203 / 812 correct (25.00)
# Iteration 35, loss = 1.0339
# Train Accuracy Got 34 / 64 correct (53.12)
# Test Accuracy Got 191 / 812 correct (23.52)
# Iteration 36, loss = 1.1197
# Train Accuracy Got 39 / 64 correct (60.94)
# Test Accuracy Got 230 / 812 correct (28.33)
# Iteration 37, loss = 0.9303
# Train Accuracy Got 41 / 64 correct (64.06)
# Test Accuracy Got 203 / 812 correct (25.00)
# Iteration 38, loss = 1.1466
# Train Accuracy Got 34 / 64 correct (53.12)
# Test Accuracy Got 218 / 812 correct (26.85)
# Iteration 39, loss = 1.1134
# Train Accuracy Got 34 / 64 correct (53.12)
# Test Accuracy Got 237 / 812 correct (29.19)
# Iteration 40, loss = 1.1002
# Train Accuracy Got 32 / 64 correct (50.00)
# Test Accuracy Got 223 / 812 correct (27.46)
# Iteration 41, loss = 1.2491
# Train Accuracy Got 24 / 64 correct (37.50)
# Test Accuracy Got 230 / 812 correct (28.33)
# Iteration 42, loss = 1.1440
# Train Accuracy Got 32 / 64 correct (50.00)
# Test Accuracy Got 225 / 812 correct (27.71)
# Iteration 43, loss = 1.1435
# Train Accuracy Got 34 / 64 correct (53.12)
# Test Accuracy Got 249 / 812 correct (30.67)
# Iteration 44, loss = 1.1632
# Train Accuracy Got 26 / 64 correct (40.62)
# Test Accuracy Got 239 / 812 correct (29.43)
# Iteration 45, loss = 1.1008
# Train Accuracy Got 31 / 64 correct (48.44)
# Test Accuracy Got 265 / 812 correct (32.64)
# Iteration 46, loss = 1.1111
# Train Accuracy Got 33 / 64 correct (51.56)
# Test Accuracy Got 278 / 812 correct (34.24)
# Iteration 47, loss = 1.1459
# Train Accuracy Got 33 / 64 correct (51.56)
# Test Accuracy Got 251 / 812 correct (30.91)
# Iteration 48, loss = 1.0809
# Train Accuracy Got 34 / 64 correct (53.12)
# Test Accuracy Got 238 / 812 correct (29.31)
# Iteration 49, loss = 1.0585
# Train Accuracy Got 37 / 64 correct (57.81)
# Test Accuracy Got 242 / 812 correct (29.80)
# Iteration 50, loss = 1.0638
# Train Accuracy Got 26 / 48 correct (54.17)
# Test Accuracy Got 248 / 812 correct (30.54)
# Iteration 0, loss = 0.9945
# Train Accuracy Got 31 / 64 correct (48.44)
# Test Accuracy Got 220 / 812 correct (27.09)
# Iteration 1, loss = 1.0318
# Train Accuracy Got 40 / 64 correct (62.50)
# Test Accuracy Got 211 / 812 correct (25.99)
# Iteration 2, loss = 1.2298
# Train Accuracy Got 30 / 64 correct (46.88)
# Test Accuracy Got 214 / 812 correct (26.35)
# Iteration 3, loss = 1.2494
# Train Accuracy Got 31 / 64 correct (48.44)
# Test Accuracy Got 217 / 812 correct (26.72)
# Iteration 4, loss = 1.0799
# Train Accuracy Got 35 / 64 correct (54.69)
# Test Accuracy Got 217 / 812 correct (26.72)
# Iteration 5, loss = 1.0136
# Train Accuracy Got 37 / 64 correct (57.81)
# Test Accuracy Got 241 / 812 correct (29.68)
# Iteration 6, loss = 1.1070
# Train Accuracy Got 34 / 64 correct (53.12)
# Test Accuracy Got 224 / 812 correct (27.59)
# Iteration 7, loss = 1.0782
# Train Accuracy Got 36 / 64 correct (56.25)
# Test Accuracy Got 253 / 812 correct (31.16)
# Iteration 8, loss = 1.2014
# Train Accuracy Got 29 / 64 correct (45.31)
# Test Accuracy Got 231 / 812 correct (28.45)
# Iteration 9, loss = 1.1086
# Train Accuracy Got 34 / 64 correct (53.12)
# Test Accuracy Got 239 / 812 correct (29.43)
# Iteration 10, loss = 1.0377
# Train Accuracy Got 36 / 64 correct (56.25)
# Test Accuracy Got 240 / 812 correct (29.56)
# Iteration 11, loss = 1.0971
# Train Accuracy Got 35 / 64 correct (54.69)
# Test Accuracy Got 253 / 812 correct (31.16)
# Iteration 12, loss = 1.1273
# Train Accuracy Got 27 / 64 correct (42.19)
# Test Accuracy Got 246 / 812 correct (30.30)
# Iteration 13, loss = 1.1742
# Train Accuracy Got 27 / 64 correct (42.19)
# Test Accuracy Got 234 / 812 correct (28.82)
# Iteration 14, loss = 1.0636
# Train Accuracy Got 37 / 64 correct (57.81)
# Test Accuracy Got 254 / 812 correct (31.28)
# Iteration 15, loss = 1.0302
# Train Accuracy Got 38 / 64 correct (59.38)
# Test Accuracy Got 229 / 812 correct (28.20)
# Iteration 16, loss = 0.9963
# Train Accuracy Got 35 / 64 correct (54.69)
# Test Accuracy Got 249 / 812 correct (30.67)
# Iteration 17, loss = 1.0150
# Train Accuracy Got 40 / 64 correct (62.50)
# Test Accuracy Got 241 / 812 correct (29.68)
# Iteration 18, loss = 1.0653
# Train Accuracy Got 35 / 64 correct (54.69)
# Test Accuracy Got 248 / 812 correct (30.54)
# Iteration 19, loss = 1.1291
# Train Accuracy Got 31 / 64 correct (48.44)
# Test Accuracy Got 225 / 812 correct (27.71)
# Iteration 20, loss = 1.0575
# Train Accuracy Got 39 / 64 correct (60.94)
# Test Accuracy Got 231 / 812 correct (28.45)
# Iteration 21, loss = 1.0982
# Train Accuracy Got 33 / 64 correct (51.56)
# Test Accuracy Got 227 / 812 correct (27.96)
# Iteration 22, loss = 1.0720
# Train Accuracy Got 31 / 64 correct (48.44)
# Test Accuracy Got 224 / 812 correct (27.59)
# Iteration 23, loss = 1.0374
# Train Accuracy Got 33 / 64 correct (51.56)
# Test Accuracy Got 208 / 812 correct (25.62)
# Iteration 24, loss = 1.0830
# Train Accuracy Got 32 / 64 correct (50.00)
# Test Accuracy Got 218 / 812 correct (26.85)
# Iteration 25, loss = 1.1523
# Train Accuracy Got 30 / 64 correct (46.88)
# Test Accuracy Got 241 / 812 correct (29.68)
# Iteration 26, loss = 1.1391
# Train Accuracy Got 32 / 64 correct (50.00)
# Test Accuracy Got 247 / 812 correct (30.42)
# Iteration 27, loss = 1.0274
# Train Accuracy Got 35 / 64 correct (54.69)
# Test Accuracy Got 215 / 812 correct (26.48)
# Iteration 28, loss = 1.0170
# Train Accuracy Got 34 / 64 correct (53.12)
# Test Accuracy Got 253 / 812 correct (31.16)
# Iteration 29, loss = 1.1174
# Train Accuracy Got 31 / 64 correct (48.44)
# Test Accuracy Got 252 / 812 correct (31.03)
# Iteration 30, loss = 1.1279
# Train Accuracy Got 31 / 64 correct (48.44)
# Test Accuracy Got 246 / 812 correct (30.30)
# Iteration 31, loss = 0.9751
# Train Accuracy Got 35 / 64 correct (54.69)
# Test Accuracy Got 262 / 812 correct (32.27)
# Iteration 32, loss = 1.0879
# Train Accuracy Got 35 / 64 correct (54.69)
# Test Accuracy Got 235 / 812 correct (28.94)
# Iteration 33, loss = 0.9617
# Train Accuracy Got 40 / 64 correct (62.50)
# Test Accuracy Got 241 / 812 correct (29.68)
# Iteration 34, loss = 1.1324
# Train Accuracy Got 26 / 64 correct (40.62)
# Test Accuracy Got 224 / 812 correct (27.59)
# Iteration 35, loss = 1.1391
# Train Accuracy Got 28 / 64 correct (43.75)
# Test Accuracy Got 212 / 812 correct (26.11)
# Iteration 36, loss = 1.0236
# Train Accuracy Got 41 / 64 correct (64.06)
# Test Accuracy Got 231 / 812 correct (28.45)
# Iteration 37, loss = 1.0460
# Train Accuracy Got 35 / 64 correct (54.69)
# Test Accuracy Got 248 / 812 correct (30.54)
# Iteration 38, loss = 1.1497
# Train Accuracy Got 34 / 64 correct (53.12)
# Test Accuracy Got 260 / 812 correct (32.02)
# Iteration 39, loss = 1.0911
# Train Accuracy Got 33 / 64 correct (51.56)
# Test Accuracy Got 256 / 812 correct (31.53)
# Iteration 40, loss = 1.0401
# Train Accuracy Got 37 / 64 correct (57.81)
# Test Accuracy Got 259 / 812 correct (31.90)
# Iteration 41, loss = 1.0352
# Train Accuracy Got 32 / 64 correct (50.00)
# Test Accuracy Got 277 / 812 correct (34.11)
# Iteration 42, loss = 1.0144
# Train Accuracy Got 36 / 64 correct (56.25)
# Test Accuracy Got 272 / 812 correct (33.50)
# Iteration 43, loss = 1.2052
# Train Accuracy Got 31 / 64 correct (48.44)
# Test Accuracy Got 275 / 812 correct (33.87)
# Iteration 44, loss = 1.0524
# Train Accuracy Got 36 / 64 correct (56.25)
# Test Accuracy Got 230 / 812 correct (28.33)
# Iteration 45, loss = 1.2316
# Train Accuracy Got 28 / 64 correct (43.75)
# Test Accuracy Got 255 / 812 correct (31.40)
# Iteration 46, loss = 1.0372
# Train Accuracy Got 31 / 64 correct (48.44)
# Test Accuracy Got 248 / 812 correct (30.54)
# Iteration 47, loss = 1.0085
# Train Accuracy Got 38 / 64 correct (59.38)
# Test Accuracy Got 249 / 812 correct (30.67)
# Iteration 48, loss = 1.1713
# Train Accuracy Got 30 / 64 correct (46.88)
# Test Accuracy Got 258 / 812 correct (31.77)
# Iteration 49, loss = 1.1957
# Train Accuracy Got 31 / 64 correct (48.44)
# Test Accuracy Got 266 / 812 correct (32.76)
# Iteration 50, loss = 1.0598
# Train Accuracy Got 29 / 48 correct (60.42)
# Test Accuracy Got 234 / 812 correct (28.82)
# Best Train Accuracy is 67.1875
# Best Test Accuracy is 39.6551724137931
# Confusion matrix, without normalization
# [[  0 344 233 226]
#  [  0 339 263 230]
#  [  0 338 233 232]
#  [  0 338 248 224]]
# Confusion matrix, without normalization
# [[ 0 88 66 58]
#  [ 0 73 59 51]
#  [ 0 92 62 58]
#  [ 0 81 67 57]]

# %% [markdown]
# # Save the best model to torch

# %%
torch.save(best_model, "model1")

# %% [markdown]
# # Plot Confusion Matrix

# %%
def get_num_correct(preds, labels):
    preds = preds.to(device=device)
    labels = labels.to(device=device)
    num_correct = 0
    num_samples = 0
    num_correct += (preds == labels).sum()
    num_samples += preds.size(0)
    return num_correct.item(), num_samples

# %%
with torch.no_grad():
    model2 = torch.load("model1")
    model2.eval()
    train_preds = get_all_preds(model2, loader_train)
    test_preds = get_all_preds(model2, loader_test)

# %%
with torch.no_grad():
    model2 = torch.load("model1")
    model2.eval()
    train_preds = get_all_preds(model2, loader_train)
    test_preds = get_all_preds(model2, loader_test)
_, preds = train_preds.max(1)

tensor_list =[]
for t, (x,y) in enumerate(loader_train):
  tensor_list.append(y)
train_set_targets = torch.cat(tensor_list, dim=0)
preds_correct, num_samples = get_num_correct(preds, train_set_targets)

# %%
t_t = train_set_targets.cpu()
predict = preds.cpu()
cm = confusion_matrix(t_t, predict)

# %%
cm = confusion_matrix(t_t, predict)
emotion_dict = ('hap',
                'sad',
                'ang',
                'neu'
                )
plt.figure(figsize=(6,6))
plot_confusion_matrix(cm, emotion_dict)

# %% [markdown]
# # Used Functions

# %%
cmt = torch.zeros(keys_array.shape[0],keys_array.shape[0], dtype=torch.int64) '''used??'''

# %%
for p in stacked:
    tl, pl = p.tolist()
    cmt[tl, pl] = cmt[tl, pl] + 1   '''used??'''

# %%
stacked = torch.stack(
    (
        train_set_targets.to(device=device)
        ,preds.to(device=device)
    ),dim=1)'''used??'''
