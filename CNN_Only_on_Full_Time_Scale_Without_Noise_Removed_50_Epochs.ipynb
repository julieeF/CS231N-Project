# %%
# this mounts your Google Drive to the Colab VM.
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# enter the foldername in your Drive where you have saved the unzipped
# assignment folder, e.g. 'cs231n/assignments/assignment3/'
FOLDERNAME = 'PROJECT/'
assert FOLDERNAME is not None, "[!] Enter the foldername."

# now that we've mounted your Drive, this ensures that
# the Python interpreter of the Colab VM can load
# python files from within it.
import sys
sys.path.append('/content/drive/My Drive/{}'.format(FOLDERNAME))

# this downloads the CIFAR-10 dataset to your Drive
# if it doesn't already exist.
#%cd /content/drive/My\ Drive/$FOLDERNAME/
#!bash get_datasets.sh
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os 
os.chdir("/content/drive/My Drive/")
os.chdir(FOLDERNAME)
#!bash get_datasets.sh

# %%
#"neu_3.0_2.0_2.3333_Whole_Length.png".split('_')

# %%
#import sys
#!{sys.executable} -m pip install torchsummary


from torch.utils.data import Dataset,DataLoader
from torchvision import transforms
import os
import numpy as np
import time
from PIL import Image
#from PIL import ImageFile
#ImageFile.LOAD_TRUNCATED_IMAGES = True
from collections import defaultdict
import cv2
import pdb
IMG_SIZE = (200,300)

from torchvision import models
from torchsummary import summary
import copy

# %%
#dataset_train.__len__
#dataset_test.shape
#dataset_val.shape

#'''test corrupted images'''
#data_path = "/home/mandeep_stanford/cs231n_project/code/pre-processed_data/images_denoised/session1/"
#dataset_train, dataset_test, dataset_val = get_imagenet_datasets(data_path, "cpc")
#
#print(f"Number of train samplest {dataset_train.__len__()}")
#print(f"Number of samples in test split {dataset_test.__len__()}")
#
#BATCH_SIZE = 200
#
#data_loader_train = DataLoader(dataset_train, BATCH_SIZE, shuffle = True)
#data_loader_test = DataLoader(dataset_test, BATCH_SIZE, shuffle = True)
#
#
#import matplotlib.pyplot as plt
#
#fig, axes = plt.subplots(BATCH_SIZE//20,20, figsize=(6,10))
#
#for batch in data_loader_train:
#
#    print(f"Shape of batch['image'] {batch['image'].shape}")
#    print(f"Shape of batch['cls'] {batch['cls'].shape}")
#
#    for i in range(BATCH_SIZE):
#
#        col = i % 20
#        row = i // 20
#
#        img = batch['image'][i].numpy()
#
#        axes[row,col].set_axis_off()
#        #axes[row,col].set_title(batch['class_name'][i])
#        axes[row,col].imshow(np.transpose(img,(1,2,0)))
#
#    plt.show()
#
#    break

# %%
#data_path = "/home/mandeep_stanford/cs231n_project/code/pre-processed_data/images/session1/"
#data_path = "/home/mandeep_stanford/cs231n_project/code/pre-processed_data/combined_session1_2/"
data_path1 = "without_noise_cleanup/session1/"
data_path2 = "without_noise_cleanup/session2/"
data_path3 = "without_noise_cleanup/session3/"
data_path4 = "without_noise_cleanup/session4/"

#img_files = os.listdir("/home/mandeep_stanford/cs231n_project/code/pre-processed_data/images/session1/")
#img_files = os.listdir("/home/mandeep_stanford/cs231n_project/code/pre-processed_data/combined_session1_2/")
#img_files = os.listdir("/home/mandeep_stanford/cs231n_project/code/pre-processed_data/4_EMOTIONS/cb_removed/with_noise_cleanup/session1/")

pkl_file = "without_noise_cleanup_denoised_WHOLE.pkl"

# %%
import pickle
X = []
Y = []
i = 0
#extract_emotion = ['hap','sad','ang','neu','fea', 'exc', 'fru']
extract_emotion = ['hap','sad','ang','neu']
if 0:
    path = [data_path1, data_path2, data_path3, data_path4]
    for p_files in path:
        for file_name in os.listdir(p_files):
                    
            print("Working on ", i)
            i = i+1
            #if i >= 7000:
            #    break
            if "Whole" in file_name.split('_'):
              print("")
            else:
              print("Skipping ", file_name)
              continue
            cat = file_name.split('_')[0]
            if cat in extract_emotion:
                #print("")
                if cat == "hap":
                    cat = 0
                if cat == "sad":
                    cat = 1
                if cat == "ang":
                    cat = 2
                if cat == "neu":
                    cat = 3
            else:
                continue
            
            Y.append(cat)
            img = Image.open(p_files+file_name)
            img = img.convert('RGB')
            tr = transforms.Resize((200,300))
            img=tr(img)
            tr = transforms.ToTensor()
            img1 = tr(img)
            img1 = np.array(img1)
            #X=np.vstack((X,img1))
            X.append(img1)
    
            del img1
            del img
            del tr

    Y = np.asarray(Y)
    X = np.asarray(X)
    data = {}
    data["X"] = X
    data["Y"] = Y
    with open(pkl_file, 'wb') as f:
        pickle.dump(data, f)
        f.close()

# %%
import pickle
import torch
assert '.'.join(torch.__version__.split('.')[:2]) == '1.5'
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torch.utils.data import sampler
import torch.utils.data as data_utils
import torchvision.datasets as dset
import torchvision.transforms as T
import torch.nn.functional as F 
import numpy as np
#pkl_file = "/home/mandeep_stanford/cs231n_project/code/pre-processed_data/images_denoised/session1_pkl_tensor1.pkl"
data = pickle.load(open(pkl_file, 'rb'))
X = data["X"]
Y = data["Y"]

# %%
X.shape
# Out:
# (1530, 3, 200, 300)

# %%
np.unique(Y)
# Out:
# array([0, 1, 2, 3])

# %%
import numpy as np
total_images = X.shape[0]
test_data_images = np.int(total_images*0.2)
train_data_images = total_images - test_data_images
#X_train = X[0:train_data_images,-1]
#y_train = Y[0:train_data_images]
#X_test = X[train_data_images:train_data_images+test_data_images, -1]
#y_test= Y[train_data_images:train_data_images+test_data_images]

#X_train = np.asarray(X_train)
#X_test = np.asarray(X_test)
#y_train = np.asarray(y_train)
#y_test = np.asarray(y_test)

#y_train = y_train.reshape((y_train[0]))
#y_test = y_test.reshape((y_test[0]))
#print(X_train.shape)
#print(y_train.shape)
#print(X_test.shape)
#print(y_test.shape)

# %%
USE_GPU = True

dtype = torch.float32 # we will be using float throughout this tutorial

if USE_GPU and torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')

# Constant to control how frequently we print train loss
print_every = 100

print('using device:', device)
# Out:
# using device: cuda

# %%
train_data = []
keys_array = np.unique(Y)
for i in range(len(X)):
   ind = np.where(keys_array==Y[i]) 
   train_data.append([X[i], Y[i]])
print("DONE")
#dataset = data_utils.TensorDataset(train_data, batch_size=100)
print(train_data_images)
print(train_data_images+test_data_images)
loader_train = DataLoader(train_data, batch_size=64, 
                          sampler=sampler.SubsetRandomSampler(range(0,train_data_images)))

loader_val = DataLoader(train_data, batch_size=64, 
                        sampler=sampler.SubsetRandomSampler(range(train_data_images, train_data_images+test_data_images)))


#for t, (x,y) in enumerate(loader_train):
#  print(t, x, y)
# Out:
# DONE
# 1224
# 1530

# %%
print_every = 1

# %%
def check_train_accuracy(loader, model):
    #if loader.dataset.train:
    #    print('Checking accuracy on validation set')
    #else:
    #    print('Checking accuracy on test set')
    print('Checking accuracy on TRAIN set')
    num_correct = 0
    num_samples = 0
    model.eval()  # set model to evaluation mode
    with torch.no_grad():
        for x, y in loader:
            x = x.to(device=device, dtype=dtype)  # move to device, e.g. GPU
            y = y.to(device=device, dtype=torch.long)
            #pdb.set_trace()
            #y = torch.stack(y) #.to(device=device)
            #y = y.reshape((x.shape[0]))
            scores = model(x)
            _, preds = scores.max(1)
            
            num_correct += (preds == y).sum()
            num_samples += preds.size(0)
        acc = float(num_correct) / num_samples
        print('Got %d / %d correct (%.2f)' % (num_correct, num_samples, 100 * acc))
        return acc

# %%
def check_accuracy_part34(loader, model):
    #if loader.dataset.train:
    #    print('Checking accuracy on validation set')
    #else:
    #    print('Checking accuracy on test set')
    print('Checking accuracy on VAL set')
    num_correct = 0
    num_samples = 0
    model.eval()  # set model to evaluation mode
    with torch.no_grad():
        for x, y in loader:
            x = x.to(device=device, dtype=dtype)  # move to device, e.g. GPU
            y = y.to(device=device, dtype=torch.long)
            #pdb.set_trace()
            #y = torch.stack(y) #.to(device=device)
            #y = y.reshape((x.shape[0]))
            scores = model(x)
            _, preds = scores.max(1)
            
            num_correct += (preds == y).sum()
            num_samples += preds.size(0)
        acc = float(num_correct) / num_samples
        print('Got %d / %d correct (%.2f)' % (num_correct, num_samples, 100 * acc))
        return acc

# %%
def train_part34(model, optimizer, epochs=1):
    """
    Train a model on CIFAR-10 using the PyTorch Module API.
    
    Inputs:
    - model: A PyTorch Module giving the model to train.
    - optimizer: An Optimizer object we will use to train the model
    - epochs: (Optional) A Python integer giving the number of epochs to train for
    
    Returns: Nothing, but prints model accuracies during training.
    """
    acc = 0
    per_epoch_train_accuracy_list = []
    per_epoch_test_accuracy_list = []
    train_accuracy_list = []
    test_accuracy_list = []
    loss_list = []
    best_model = model = model.to(device=device)  # move the model parameters to CPU/GPU
    for e in range(epochs):
        for t, (x, y) in enumerate(loader_train):
            import pdb
            #pdb.set_trace()
            model.train()  # put model to training mode
            x = x.to(device=device, dtype=dtype)  # move to device, e.g. GPU
            y = y.to(device=device, dtype=torch.long)
            #y = torch.stack(y) #.to(device=device)
            #y = y.reshape((x.shape[0]))
            scores = model(x)
            
            loss = F.cross_entropy(scores, y)
            loss_list.append(loss.item())
            # Zero out all of the gradients for the variables which the optimizer
            # will update.
            optimizer.zero_grad()

            # This is the backwards pass: compute the gradient of the loss with
            # respect to each  parameter of the model.
            loss.backward()

            # Actually update the parameters of the model using the gradients
            # computed by the backwards pass.
            optimizer.step()
            #pdb.set_trace()
            #print("IN ITERATION", t)
            if t % print_every == 0:
                print('Epoch %d, Iteration %d, loss = %.4f' % (e, t, loss.item()))
                #pdb.set_trace()
                xx = x.cpu().data.numpy()
                yy = y.cpu().data.numpy()
                tt_data = []
                for i in range(len(xx)):
                  ind = np.where(keys_array==Y[i]) 
                  tt_data.append([xx[i], yy[i]])
                
                train_d = DataLoader(tt_data, batch_size = 1)
                
                train_acc = check_train_accuracy(train_d, model)
                train_accuracy_list.append(train_acc)
                test_acc = check_accuracy_part34(loader_val, model)
                test_accuracy_list.append(test_acc)
                if test_acc > acc:
                  acc = test_acc
                  best_model = copy.deepcopy(model)
                print()
        
        e_test_accuracy = check_accuracy_part34(loader_val, model)        
        per_epoch_test_accuracy_list.append(e_test_accuracy)     
        e_train_accuracy = check_train_accuracy(loader_train, model)        
        per_epoch_train_accuracy_list.append(e_train_accuracy)     
    return best_model, acc, train_accuracy_list, test_accuracy_list, per_epoch_train_accuracy_list, per_epoch_test_accuracy_list, loss_list

# %%
class Flatten(nn.Module):
    def flatten(x):
        N = x.shape[0] # read in N, C, H, W
        return x.view(N, -1)  # "flatten" the C * H * W values into a single vector per image

    def forward(self, x):
        N = x.shape[0]
        return x.view(N, -1)

class LSTM(nn.Module):
    def __init__(self):
        super().__init__()
        #self.model = nn.LSTM(input_size=(32*25*37),hidden_size=128,num_layers=2,batch_first=True,bidirectional =True, dropout=0.1)
        self.model = nn.RNN(input_size=(32*25*37),hidden_size=128,num_layers=2,batch_first=True,bidirectional =True, dropout=0.1)
    def forward(self, x):

        # From [batches, seqs, seq len, features]
        # to [seq len, batch data, features]
        x = x.unsqueeze(1)
       
        # Data is fed to the LSTM
        out, _ = self.model(x)

        # From [seq len, batch, num_directions * hidden_size]
        # to [batches, seqs, seq_len,prediction]
        out = out.squeeze(1)


        return out

#hidden_layer_size = 500
#learning_rate = 1e-2

#model = nn.Sequential(
#    Flatten(),
#    nn.Linear(3 * 200 * 300, hidden_layer_size),
#    nn.ReLU(),
#    nn.Linear(hidden_layer_size, keys_array.shape[0]),
#)


l1 = nn.Sequential(
            nn.Conv2d(3, 16, kernel_size=(12,16), padding=(6,8), stride=1),
            nn.ReLU(),
            #nn.Conv2d(channel_1, channel_1, kernel_size=5, padding=2, stride=1),
            nn.MaxPool2d(2, 2)
)

#for t, (x, y) in enumerate(loader_train):
#            # put model to training mode
#            x = x.to(device=device, dtype=dtype)
#            import pdb
#            pdb.set_trace()
#            break
    
#pdb.set_trace()
#h = l1(x)
#h.shape

l2 = nn.Sequential(
            nn.Conv2d(16, 24, kernel_size=(8,12), padding=(4,6), stride=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2)
)
#h = l2(h)

#l3 = nn.Sequential(
#            nn.Conv2d(24, 32, kernel_size=(5,7), padding=(2,3), stride=1),
#            nn.ReLU(),
#            nn.MaxPool2d(2, 2),
#            Flatten(),
#            LSTM()           
#)

l3 = nn.Sequential(
            nn.Conv2d(24, 32, kernel_size=(5,7), padding=(2,3), stride=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2)
            
)

#l4 = nn.Sequential(
#            nn.Conv2d(channel_3, channel_4, kernel_size=3, padding=1, stride=1),
#            nn.MaxPool2d(2, 1)
#)

#import pdb
#pdb.set_trace()
hidden_layer_size = keys_array.shape[0]
learning_rate = 1e-4 #1e-4   1e-3 looks gud
'''
model = nn.Sequential(
            l1,
            l2,
            l3,
            nn.Linear(256, 64),
            nn.ReLU(),
            nn.Dropout(p=0.2),
            nn.Linear(64, keys_array.shape[0])
)
'''
model = nn.Sequential(
            l1,
            l2,
            l3,
            Flatten(),
            nn.Linear(32*25*37, 64),
            nn.ReLU(),
            nn.Dropout(p=0.2),
            nn.Linear(64, keys_array.shape[0])
)


# you can use Nesterov momentum in optim.SGD
#optimizer = optim.Adam(model.parameters(), lr=learning_rate,momentum=0.9, nesterov=True)
optimizer = optim.Adam(model.parameters(), lr=learning_rate, 
                     betas=(0.9, 0.999), eps=1e-08, weight_decay=0, amsgrad=False) #weight_decay = 0 luks gud. Trying with 0.1


#best_model, best_test_acc, train_accuracy_list, test_accuracy_list, loss_list = train_part34(model, optimizer, 2)
best_model, best_test_acc, train_accuracy_list, test_accuracy_list, per_epoch_train_accuracy_list, per_epoch_test_accuracy_list, loss_list = train_part34(model, optimizer, 50)
print("DONE TRAINING")
# Out:
# Streaming output truncated to the last 5000 lines.
# Got 26 / 64 correct (40.62)
# Checking accuracy on VAL set
# Got 119 / 306 correct (38.89)
#
# Epoch 9, Iteration 15, loss = 1.1583
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 9, Iteration 16, loss = 1.2048
# Checking accuracy on TRAIN set
# Got 25 / 64 correct (39.06)
# Checking accuracy on VAL set
# Got 105 / 306 correct (34.31)
#
# Epoch 9, Iteration 17, loss = 1.3595
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 100 / 306 correct (32.68)
#
# Epoch 9, Iteration 18, loss = 1.1850
# Checking accuracy on TRAIN set
# Got 22 / 64 correct (34.38)
# Checking accuracy on VAL set
# Got 101 / 306 correct (33.01)
#
# Epoch 9, Iteration 19, loss = 1.2208
# Checking accuracy on TRAIN set
# Got 3 / 8 correct (37.50)
# Checking accuracy on VAL set
# Got 102 / 306 correct (33.33)
#
# Checking accuracy on VAL set
# Got 102 / 306 correct (33.33)
# Checking accuracy on TRAIN set
# Got 466 / 1224 correct (38.07)
# Epoch 10, Iteration 0, loss = 1.2973
# Checking accuracy on TRAIN set
# Got 17 / 64 correct (26.56)
# Checking accuracy on VAL set
# Got 122 / 306 correct (39.87)
#
# Epoch 10, Iteration 1, loss = 1.2648
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 130 / 306 correct (42.48)
#
# Epoch 10, Iteration 2, loss = 1.2900
# Checking accuracy on TRAIN set
# Got 25 / 64 correct (39.06)
# Checking accuracy on VAL set
# Got 119 / 306 correct (38.89)
#
# Epoch 10, Iteration 3, loss = 1.2578
# Checking accuracy on TRAIN set
# Got 22 / 64 correct (34.38)
# Checking accuracy on VAL set
# Got 118 / 306 correct (38.56)
#
# Epoch 10, Iteration 4, loss = 1.3252
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 10, Iteration 5, loss = 1.3306
# Checking accuracy on TRAIN set
# Got 20 / 64 correct (31.25)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 10, Iteration 6, loss = 1.1992
# Checking accuracy on TRAIN set
# Got 26 / 64 correct (40.62)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 10, Iteration 7, loss = 1.2099
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 10, Iteration 8, loss = 1.2574
# Checking accuracy on TRAIN set
# Got 21 / 64 correct (32.81)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 10, Iteration 9, loss = 1.1900
# Checking accuracy on TRAIN set
# Got 26 / 64 correct (40.62)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 10, Iteration 10, loss = 1.2707
# Checking accuracy on TRAIN set
# Got 22 / 64 correct (34.38)
# Checking accuracy on VAL set
# Got 118 / 306 correct (38.56)
#
# Epoch 10, Iteration 11, loss = 1.1447
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 119 / 306 correct (38.89)
#
# Epoch 10, Iteration 12, loss = 1.1132
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 119 / 306 correct (38.89)
#
# Epoch 10, Iteration 13, loss = 1.1851
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 10, Iteration 14, loss = 1.1958
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 10, Iteration 15, loss = 1.3784
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 10, Iteration 16, loss = 1.2283
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 10, Iteration 17, loss = 1.1816
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 119 / 306 correct (38.89)
#
# Epoch 10, Iteration 18, loss = 1.2718
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 123 / 306 correct (40.20)
#
# Epoch 10, Iteration 19, loss = 1.3651
# Checking accuracy on TRAIN set
# Got 3 / 8 correct (37.50)
# Checking accuracy on VAL set
# Got 119 / 306 correct (38.89)
#
# Checking accuracy on VAL set
# Got 119 / 306 correct (38.89)
# Checking accuracy on TRAIN set
# Got 498 / 1224 correct (40.69)
# Epoch 11, Iteration 0, loss = 1.2032
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 119 / 306 correct (38.89)
#
# Epoch 11, Iteration 1, loss = 1.1580
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 11, Iteration 2, loss = 1.2506
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 118 / 306 correct (38.56)
#
# Epoch 11, Iteration 3, loss = 1.2747
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 118 / 306 correct (38.56)
#
# Epoch 11, Iteration 4, loss = 1.2104
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 116 / 306 correct (37.91)
#
# Epoch 11, Iteration 5, loss = 1.2170
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 116 / 306 correct (37.91)
#
# Epoch 11, Iteration 6, loss = 1.1575
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 118 / 306 correct (38.56)
#
# Epoch 11, Iteration 7, loss = 1.3733
# Checking accuracy on TRAIN set
# Got 26 / 64 correct (40.62)
# Checking accuracy on VAL set
# Got 118 / 306 correct (38.56)
#
# Epoch 11, Iteration 8, loss = 1.3009
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 118 / 306 correct (38.56)
#
# Epoch 11, Iteration 9, loss = 1.2997
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 118 / 306 correct (38.56)
#
# Epoch 11, Iteration 10, loss = 1.2753
# Checking accuracy on TRAIN set
# Got 22 / 64 correct (34.38)
# Checking accuracy on VAL set
# Got 124 / 306 correct (40.52)
#
# Epoch 11, Iteration 11, loss = 1.1857
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 125 / 306 correct (40.85)
#
# Epoch 11, Iteration 12, loss = 1.2279
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 122 / 306 correct (39.87)
#
# Epoch 11, Iteration 13, loss = 1.1820
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 119 / 306 correct (38.89)
#
# Epoch 11, Iteration 14, loss = 1.2082
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 11, Iteration 15, loss = 1.3293
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 114 / 306 correct (37.25)
#
# Epoch 11, Iteration 16, loss = 1.2268
# Checking accuracy on TRAIN set
# Got 23 / 64 correct (35.94)
# Checking accuracy on VAL set
# Got 116 / 306 correct (37.91)
#
# Epoch 11, Iteration 17, loss = 1.2987
# Checking accuracy on TRAIN set
# Got 21 / 64 correct (32.81)
# Checking accuracy on VAL set
# Got 119 / 306 correct (38.89)
#
# Epoch 11, Iteration 18, loss = 1.2323
# Checking accuracy on TRAIN set
# Got 35 / 64 correct (54.69)
# Checking accuracy on VAL set
# Got 122 / 306 correct (39.87)
#
# Epoch 11, Iteration 19, loss = 1.2693
# Checking accuracy on TRAIN set
# Got 4 / 8 correct (50.00)
# Checking accuracy on VAL set
# Got 131 / 306 correct (42.81)
#
# Checking accuracy on VAL set
# Got 131 / 306 correct (42.81)
# Checking accuracy on TRAIN set
# Got 509 / 1224 correct (41.58)
# Epoch 12, Iteration 0, loss = 1.2852
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 137 / 306 correct (44.77)
#
# Epoch 12, Iteration 1, loss = 1.2792
# Checking accuracy on TRAIN set
# Got 22 / 64 correct (34.38)
# Checking accuracy on VAL set
# Got 128 / 306 correct (41.83)
#
# Epoch 12, Iteration 2, loss = 1.2773
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 125 / 306 correct (40.85)
#
# Epoch 12, Iteration 3, loss = 1.3122
# Checking accuracy on TRAIN set
# Got 21 / 64 correct (32.81)
# Checking accuracy on VAL set
# Got 118 / 306 correct (38.56)
#
# Epoch 12, Iteration 4, loss = 1.1944
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 12, Iteration 5, loss = 1.2699
# Checking accuracy on TRAIN set
# Got 23 / 64 correct (35.94)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 12, Iteration 6, loss = 1.2277
# Checking accuracy on TRAIN set
# Got 25 / 64 correct (39.06)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 12, Iteration 7, loss = 1.1673
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 118 / 306 correct (38.56)
#
# Epoch 12, Iteration 8, loss = 1.2769
# Checking accuracy on TRAIN set
# Got 25 / 64 correct (39.06)
# Checking accuracy on VAL set
# Got 119 / 306 correct (38.89)
#
# Epoch 12, Iteration 9, loss = 1.2201
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 12, Iteration 10, loss = 1.2992
# Checking accuracy on TRAIN set
# Got 21 / 64 correct (32.81)
# Checking accuracy on VAL set
# Got 118 / 306 correct (38.56)
#
# Epoch 12, Iteration 11, loss = 1.2584
# Checking accuracy on TRAIN set
# Got 25 / 64 correct (39.06)
# Checking accuracy on VAL set
# Got 116 / 306 correct (37.91)
#
# Epoch 12, Iteration 12, loss = 1.2313
# Checking accuracy on TRAIN set
# Got 25 / 64 correct (39.06)
# Checking accuracy on VAL set
# Got 115 / 306 correct (37.58)
#
# Epoch 12, Iteration 13, loss = 1.1279
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 112 / 306 correct (36.60)
#
# Epoch 12, Iteration 14, loss = 1.2381
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 115 / 306 correct (37.58)
#
# Epoch 12, Iteration 15, loss = 1.1644
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 114 / 306 correct (37.25)
#
# Epoch 12, Iteration 16, loss = 1.1788
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 113 / 306 correct (36.93)
#
# Epoch 12, Iteration 17, loss = 1.1940
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 116 / 306 correct (37.91)
#
# Epoch 12, Iteration 18, loss = 1.2892
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 119 / 306 correct (38.89)
#
# Epoch 12, Iteration 19, loss = 0.9543
# Checking accuracy on TRAIN set
# Got 7 / 8 correct (87.50)
# Checking accuracy on VAL set
# Got 115 / 306 correct (37.58)
#
# Checking accuracy on VAL set
# Got 115 / 306 correct (37.58)
# Checking accuracy on TRAIN set
# Got 480 / 1224 correct (39.22)
# Epoch 13, Iteration 0, loss = 1.2863
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 110 / 306 correct (35.95)
#
# Epoch 13, Iteration 1, loss = 1.3657
# Checking accuracy on TRAIN set
# Got 18 / 64 correct (28.12)
# Checking accuracy on VAL set
# Got 114 / 306 correct (37.25)
#
# Epoch 13, Iteration 2, loss = 1.2516
# Checking accuracy on TRAIN set
# Got 25 / 64 correct (39.06)
# Checking accuracy on VAL set
# Got 112 / 306 correct (36.60)
#
# Epoch 13, Iteration 3, loss = 1.2262
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 13, Iteration 4, loss = 1.2878
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 13, Iteration 5, loss = 1.2569
# Checking accuracy on TRAIN set
# Got 26 / 64 correct (40.62)
# Checking accuracy on VAL set
# Got 118 / 306 correct (38.56)
#
# Epoch 13, Iteration 6, loss = 1.1722
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 119 / 306 correct (38.89)
#
# Epoch 13, Iteration 7, loss = 1.2575
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 119 / 306 correct (38.89)
#
# Epoch 13, Iteration 8, loss = 1.1671
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 120 / 306 correct (39.22)
#
# Epoch 13, Iteration 9, loss = 1.2353
# Checking accuracy on TRAIN set
# Got 26 / 64 correct (40.62)
# Checking accuracy on VAL set
# Got 122 / 306 correct (39.87)
#
# Epoch 13, Iteration 10, loss = 1.2083
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 124 / 306 correct (40.52)
#
# Epoch 13, Iteration 11, loss = 1.1409
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 128 / 306 correct (41.83)
#
# Epoch 13, Iteration 12, loss = 1.2120
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 126 / 306 correct (41.18)
#
# Epoch 13, Iteration 13, loss = 1.1794
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 125 / 306 correct (40.85)
#
# Epoch 13, Iteration 14, loss = 1.2696
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 131 / 306 correct (42.81)
#
# Epoch 13, Iteration 15, loss = 1.2442
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 141 / 306 correct (46.08)
#
# Epoch 13, Iteration 16, loss = 1.1440
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 141 / 306 correct (46.08)
#
# Epoch 13, Iteration 17, loss = 1.2258
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 138 / 306 correct (45.10)
#
# Epoch 13, Iteration 18, loss = 1.2344
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 134 / 306 correct (43.79)
#
# Epoch 13, Iteration 19, loss = 1.1987
# Checking accuracy on TRAIN set
# Got 4 / 8 correct (50.00)
# Checking accuracy on VAL set
# Got 132 / 306 correct (43.14)
#
# Checking accuracy on VAL set
# Got 132 / 306 correct (43.14)
# Checking accuracy on TRAIN set
# Got 541 / 1224 correct (44.20)
# Epoch 14, Iteration 0, loss = 1.1895
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 133 / 306 correct (43.46)
#
# Epoch 14, Iteration 1, loss = 1.3268
# Checking accuracy on TRAIN set
# Got 23 / 64 correct (35.94)
# Checking accuracy on VAL set
# Got 138 / 306 correct (45.10)
#
# Epoch 14, Iteration 2, loss = 1.1697
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 137 / 306 correct (44.77)
#
# Epoch 14, Iteration 3, loss = 1.2493
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 133 / 306 correct (43.46)
#
# Epoch 14, Iteration 4, loss = 1.1779
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 124 / 306 correct (40.52)
#
# Epoch 14, Iteration 5, loss = 1.2817
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 130 / 306 correct (42.48)
#
# Epoch 14, Iteration 6, loss = 1.2312
# Checking accuracy on TRAIN set
# Got 23 / 64 correct (35.94)
# Checking accuracy on VAL set
# Got 144 / 306 correct (47.06)
#
# Epoch 14, Iteration 7, loss = 1.2246
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 142 / 306 correct (46.41)
#
# Epoch 14, Iteration 8, loss = 1.1720
# Checking accuracy on TRAIN set
# Got 25 / 64 correct (39.06)
# Checking accuracy on VAL set
# Got 147 / 306 correct (48.04)
#
# Epoch 14, Iteration 9, loss = 1.1499
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 136 / 306 correct (44.44)
#
# Epoch 14, Iteration 10, loss = 1.1816
# Checking accuracy on TRAIN set
# Got 35 / 64 correct (54.69)
# Checking accuracy on VAL set
# Got 133 / 306 correct (43.46)
#
# Epoch 14, Iteration 11, loss = 1.2109
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 129 / 306 correct (42.16)
#
# Epoch 14, Iteration 12, loss = 1.2683
# Checking accuracy on TRAIN set
# Got 26 / 64 correct (40.62)
# Checking accuracy on VAL set
# Got 133 / 306 correct (43.46)
#
# Epoch 14, Iteration 13, loss = 1.1419
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 140 / 306 correct (45.75)
#
# Epoch 14, Iteration 14, loss = 1.3873
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 138 / 306 correct (45.10)
#
# Epoch 14, Iteration 15, loss = 1.1331
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 141 / 306 correct (46.08)
#
# Epoch 14, Iteration 16, loss = 1.1896
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 138 / 306 correct (45.10)
#
# Epoch 14, Iteration 17, loss = 1.2142
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 133 / 306 correct (43.46)
#
# Epoch 14, Iteration 18, loss = 1.1727
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 127 / 306 correct (41.50)
#
# Epoch 14, Iteration 19, loss = 1.0521
# Checking accuracy on TRAIN set
# Got 4 / 8 correct (50.00)
# Checking accuracy on VAL set
# Got 120 / 306 correct (39.22)
#
# Checking accuracy on VAL set
# Got 120 / 306 correct (39.22)
# Checking accuracy on TRAIN set
# Got 492 / 1224 correct (40.20)
# Epoch 15, Iteration 0, loss = 1.2700
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 15, Iteration 1, loss = 1.2585
# Checking accuracy on TRAIN set
# Got 23 / 64 correct (35.94)
# Checking accuracy on VAL set
# Got 124 / 306 correct (40.52)
#
# Epoch 15, Iteration 2, loss = 1.1937
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 124 / 306 correct (40.52)
#
# Epoch 15, Iteration 3, loss = 1.2411
# Checking accuracy on TRAIN set
# Got 20 / 64 correct (31.25)
# Checking accuracy on VAL set
# Got 118 / 306 correct (38.56)
#
# Epoch 15, Iteration 4, loss = 1.1887
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 15, Iteration 5, loss = 1.2097
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 126 / 306 correct (41.18)
#
# Epoch 15, Iteration 6, loss = 1.2646
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 129 / 306 correct (42.16)
#
# Epoch 15, Iteration 7, loss = 1.2298
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 140 / 306 correct (45.75)
#
# Epoch 15, Iteration 8, loss = 1.0923
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 136 / 306 correct (44.44)
#
# Epoch 15, Iteration 9, loss = 1.1546
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 129 / 306 correct (42.16)
#
# Epoch 15, Iteration 10, loss = 1.2372
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 129 / 306 correct (42.16)
#
# Epoch 15, Iteration 11, loss = 1.1475
# Checking accuracy on TRAIN set
# Got 36 / 64 correct (56.25)
# Checking accuracy on VAL set
# Got 138 / 306 correct (45.10)
#
# Epoch 15, Iteration 12, loss = 1.2288
# Checking accuracy on TRAIN set
# Got 22 / 64 correct (34.38)
# Checking accuracy on VAL set
# Got 141 / 306 correct (46.08)
#
# Epoch 15, Iteration 13, loss = 1.3244
# Checking accuracy on TRAIN set
# Got 23 / 64 correct (35.94)
# Checking accuracy on VAL set
# Got 137 / 306 correct (44.77)
#
# Epoch 15, Iteration 14, loss = 1.1993
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 139 / 306 correct (45.42)
#
# Epoch 15, Iteration 15, loss = 1.1957
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 141 / 306 correct (46.08)
#
# Epoch 15, Iteration 16, loss = 1.1254
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 134 / 306 correct (43.79)
#
# Epoch 15, Iteration 17, loss = 1.2622
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 142 / 306 correct (46.41)
#
# Epoch 15, Iteration 18, loss = 1.0810
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 123 / 306 correct (40.20)
#
# Epoch 15, Iteration 19, loss = 1.1884
# Checking accuracy on TRAIN set
# Got 3 / 8 correct (37.50)
# Checking accuracy on VAL set
# Got 146 / 306 correct (47.71)
#
# Checking accuracy on VAL set
# Got 146 / 306 correct (47.71)
# Checking accuracy on TRAIN set
# Got 532 / 1224 correct (43.46)
# Epoch 16, Iteration 0, loss = 1.2553
# Checking accuracy on TRAIN set
# Got 23 / 64 correct (35.94)
# Checking accuracy on VAL set
# Got 134 / 306 correct (43.79)
#
# Epoch 16, Iteration 1, loss = 1.2898
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 126 / 306 correct (41.18)
#
# Epoch 16, Iteration 2, loss = 1.1546
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 118 / 306 correct (38.56)
#
# Epoch 16, Iteration 3, loss = 1.2730
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 119 / 306 correct (38.89)
#
# Epoch 16, Iteration 4, loss = 1.1113
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 119 / 306 correct (38.89)
#
# Epoch 16, Iteration 5, loss = 1.1801
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 118 / 306 correct (38.56)
#
# Epoch 16, Iteration 6, loss = 1.2333
# Checking accuracy on TRAIN set
# Got 25 / 64 correct (39.06)
# Checking accuracy on VAL set
# Got 116 / 306 correct (37.91)
#
# Epoch 16, Iteration 7, loss = 1.1717
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 16, Iteration 8, loss = 1.1994
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 16, Iteration 9, loss = 1.3078
# Checking accuracy on TRAIN set
# Got 21 / 64 correct (32.81)
# Checking accuracy on VAL set
# Got 119 / 306 correct (38.89)
#
# Epoch 16, Iteration 10, loss = 1.2160
# Checking accuracy on TRAIN set
# Got 21 / 64 correct (32.81)
# Checking accuracy on VAL set
# Got 124 / 306 correct (40.52)
#
# Epoch 16, Iteration 11, loss = 1.1987
# Checking accuracy on TRAIN set
# Got 26 / 64 correct (40.62)
# Checking accuracy on VAL set
# Got 127 / 306 correct (41.50)
#
# Epoch 16, Iteration 12, loss = 1.1954
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 132 / 306 correct (43.14)
#
# Epoch 16, Iteration 13, loss = 1.2073
# Checking accuracy on TRAIN set
# Got 25 / 64 correct (39.06)
# Checking accuracy on VAL set
# Got 135 / 306 correct (44.12)
#
# Epoch 16, Iteration 14, loss = 1.2117
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 138 / 306 correct (45.10)
#
# Epoch 16, Iteration 15, loss = 1.1942
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 138 / 306 correct (45.10)
#
# Epoch 16, Iteration 16, loss = 1.2155
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 136 / 306 correct (44.44)
#
# Epoch 16, Iteration 17, loss = 1.1215
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 140 / 306 correct (45.75)
#
# Epoch 16, Iteration 18, loss = 1.2165
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 142 / 306 correct (46.41)
#
# Epoch 16, Iteration 19, loss = 1.4961
# Checking accuracy on TRAIN set
# Got 0 / 8 correct (0.00)
# Checking accuracy on VAL set
# Got 143 / 306 correct (46.73)
#
# Checking accuracy on VAL set
# Got 143 / 306 correct (46.73)
# Checking accuracy on TRAIN set
# Got 565 / 1224 correct (46.16)
# Epoch 17, Iteration 0, loss = 1.2213
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 145 / 306 correct (47.39)
#
# Epoch 17, Iteration 1, loss = 1.1314
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 143 / 306 correct (46.73)
#
# Epoch 17, Iteration 2, loss = 1.1374
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 147 / 306 correct (48.04)
#
# Epoch 17, Iteration 3, loss = 1.3205
# Checking accuracy on TRAIN set
# Got 25 / 64 correct (39.06)
# Checking accuracy on VAL set
# Got 146 / 306 correct (47.71)
#
# Epoch 17, Iteration 4, loss = 1.1968
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 141 / 306 correct (46.08)
#
# Epoch 17, Iteration 5, loss = 1.2332
# Checking accuracy on TRAIN set
# Got 25 / 64 correct (39.06)
# Checking accuracy on VAL set
# Got 142 / 306 correct (46.41)
#
# Epoch 17, Iteration 6, loss = 1.0808
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 142 / 306 correct (46.41)
#
# Epoch 17, Iteration 7, loss = 1.1556
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 144 / 306 correct (47.06)
#
# Epoch 17, Iteration 8, loss = 1.2141
# Checking accuracy on TRAIN set
# Got 22 / 64 correct (34.38)
# Checking accuracy on VAL set
# Got 143 / 306 correct (46.73)
#
# Epoch 17, Iteration 9, loss = 1.3019
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 142 / 306 correct (46.41)
#
# Epoch 17, Iteration 10, loss = 1.3372
# Checking accuracy on TRAIN set
# Got 25 / 64 correct (39.06)
# Checking accuracy on VAL set
# Got 142 / 306 correct (46.41)
#
# Epoch 17, Iteration 11, loss = 1.2352
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 146 / 306 correct (47.71)
#
# Epoch 17, Iteration 12, loss = 1.0761
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 143 / 306 correct (46.73)
#
# Epoch 17, Iteration 13, loss = 1.1313
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 143 / 306 correct (46.73)
#
# Epoch 17, Iteration 14, loss = 1.1482
# Checking accuracy on TRAIN set
# Got 36 / 64 correct (56.25)
# Checking accuracy on VAL set
# Got 140 / 306 correct (45.75)
#
# Epoch 17, Iteration 15, loss = 1.1902
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 144 / 306 correct (47.06)
#
# Epoch 17, Iteration 16, loss = 1.2182
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 147 / 306 correct (48.04)
#
# Epoch 17, Iteration 17, loss = 1.1462
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 152 / 306 correct (49.67)
#
# Epoch 17, Iteration 18, loss = 1.0714
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 146 / 306 correct (47.71)
#
# Epoch 17, Iteration 19, loss = 1.2174
# Checking accuracy on TRAIN set
# Got 5 / 8 correct (62.50)
# Checking accuracy on VAL set
# Got 138 / 306 correct (45.10)
#
# Checking accuracy on VAL set
# Got 138 / 306 correct (45.10)
# Checking accuracy on TRAIN set
# Got 549 / 1224 correct (44.85)
# Epoch 18, Iteration 0, loss = 1.1792
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 148 / 306 correct (48.37)
#
# Epoch 18, Iteration 1, loss = 1.2119
# Checking accuracy on TRAIN set
# Got 25 / 64 correct (39.06)
# Checking accuracy on VAL set
# Got 147 / 306 correct (48.04)
#
# Epoch 18, Iteration 2, loss = 1.2075
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 149 / 306 correct (48.69)
#
# Epoch 18, Iteration 3, loss = 1.1911
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 147 / 306 correct (48.04)
#
# Epoch 18, Iteration 4, loss = 1.0848
# Checking accuracy on TRAIN set
# Got 35 / 64 correct (54.69)
# Checking accuracy on VAL set
# Got 145 / 306 correct (47.39)
#
# Epoch 18, Iteration 5, loss = 1.1252
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 143 / 306 correct (46.73)
#
# Epoch 18, Iteration 6, loss = 1.1921
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 141 / 306 correct (46.08)
#
# Epoch 18, Iteration 7, loss = 1.2794
# Checking accuracy on TRAIN set
# Got 23 / 64 correct (35.94)
# Checking accuracy on VAL set
# Got 140 / 306 correct (45.75)
#
# Epoch 18, Iteration 8, loss = 1.1133
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 136 / 306 correct (44.44)
#
# Epoch 18, Iteration 9, loss = 1.2279
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 135 / 306 correct (44.12)
#
# Epoch 18, Iteration 10, loss = 1.1957
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 144 / 306 correct (47.06)
#
# Epoch 18, Iteration 11, loss = 1.1635
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 146 / 306 correct (47.71)
#
# Epoch 18, Iteration 12, loss = 1.1656
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 153 / 306 correct (50.00)
#
# Epoch 18, Iteration 13, loss = 1.1246
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 149 / 306 correct (48.69)
#
# Epoch 18, Iteration 14, loss = 1.2397
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 148 / 306 correct (48.37)
#
# Epoch 18, Iteration 15, loss = 1.1942
# Checking accuracy on TRAIN set
# Got 23 / 64 correct (35.94)
# Checking accuracy on VAL set
# Got 146 / 306 correct (47.71)
#
# Epoch 18, Iteration 16, loss = 1.2237
# Checking accuracy on TRAIN set
# Got 20 / 64 correct (31.25)
# Checking accuracy on VAL set
# Got 136 / 306 correct (44.44)
#
# Epoch 18, Iteration 17, loss = 1.2020
# Checking accuracy on TRAIN set
# Got 22 / 64 correct (34.38)
# Checking accuracy on VAL set
# Got 140 / 306 correct (45.75)
#
# Epoch 18, Iteration 18, loss = 1.1576
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 146 / 306 correct (47.71)
#
# Epoch 18, Iteration 19, loss = 1.5310
# Checking accuracy on TRAIN set
# Got 2 / 8 correct (25.00)
# Checking accuracy on VAL set
# Got 146 / 306 correct (47.71)
#
# Checking accuracy on VAL set
# Got 146 / 306 correct (47.71)
# Checking accuracy on TRAIN set
# Got 564 / 1224 correct (46.08)
# Epoch 19, Iteration 0, loss = 1.2016
# Checking accuracy on TRAIN set
# Got 25 / 64 correct (39.06)
# Checking accuracy on VAL set
# Got 144 / 306 correct (47.06)
#
# Epoch 19, Iteration 1, loss = 1.1781
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 142 / 306 correct (46.41)
#
# Epoch 19, Iteration 2, loss = 1.1226
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 147 / 306 correct (48.04)
#
# Epoch 19, Iteration 3, loss = 1.1578
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 142 / 306 correct (46.41)
#
# Epoch 19, Iteration 4, loss = 1.1423
# Checking accuracy on TRAIN set
# Got 36 / 64 correct (56.25)
# Checking accuracy on VAL set
# Got 138 / 306 correct (45.10)
#
# Epoch 19, Iteration 5, loss = 1.1720
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 137 / 306 correct (44.77)
#
# Epoch 19, Iteration 6, loss = 1.1519
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 132 / 306 correct (43.14)
#
# Epoch 19, Iteration 7, loss = 1.0967
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 134 / 306 correct (43.79)
#
# Epoch 19, Iteration 8, loss = 1.2772
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 132 / 306 correct (43.14)
#
# Epoch 19, Iteration 9, loss = 1.2229
# Checking accuracy on TRAIN set
# Got 25 / 64 correct (39.06)
# Checking accuracy on VAL set
# Got 129 / 306 correct (42.16)
#
# Epoch 19, Iteration 10, loss = 1.2129
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 130 / 306 correct (42.48)
#
# Epoch 19, Iteration 11, loss = 1.1094
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 136 / 306 correct (44.44)
#
# Epoch 19, Iteration 12, loss = 1.2656
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 139 / 306 correct (45.42)
#
# Epoch 19, Iteration 13, loss = 1.2071
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 141 / 306 correct (46.08)
#
# Epoch 19, Iteration 14, loss = 1.1865
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 139 / 306 correct (45.42)
#
# Epoch 19, Iteration 15, loss = 1.2398
# Checking accuracy on TRAIN set
# Got 21 / 64 correct (32.81)
# Checking accuracy on VAL set
# Got 137 / 306 correct (44.77)
#
# Epoch 19, Iteration 16, loss = 1.2164
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 134 / 306 correct (43.79)
#
# Epoch 19, Iteration 17, loss = 1.1238
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 135 / 306 correct (44.12)
#
# Epoch 19, Iteration 18, loss = 1.2134
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 130 / 306 correct (42.48)
#
# Epoch 19, Iteration 19, loss = 1.0289
# Checking accuracy on TRAIN set
# Got 6 / 8 correct (75.00)
# Checking accuracy on VAL set
# Got 139 / 306 correct (45.42)
#
# Checking accuracy on VAL set
# Got 139 / 306 correct (45.42)
# Checking accuracy on TRAIN set
# Got 589 / 1224 correct (48.12)
# Epoch 20, Iteration 0, loss = 1.1980
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 145 / 306 correct (47.39)
#
# Epoch 20, Iteration 1, loss = 1.0975
# Checking accuracy on TRAIN set
# Got 35 / 64 correct (54.69)
# Checking accuracy on VAL set
# Got 144 / 306 correct (47.06)
#
# Epoch 20, Iteration 2, loss = 1.1991
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 141 / 306 correct (46.08)
#
# Epoch 20, Iteration 3, loss = 1.0710
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 142 / 306 correct (46.41)
#
# Epoch 20, Iteration 4, loss = 1.2121
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 143 / 306 correct (46.73)
#
# Epoch 20, Iteration 5, loss = 1.1409
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 145 / 306 correct (47.39)
#
# Epoch 20, Iteration 6, loss = 1.2074
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 139 / 306 correct (45.42)
#
# Epoch 20, Iteration 7, loss = 1.1215
# Checking accuracy on TRAIN set
# Got 36 / 64 correct (56.25)
# Checking accuracy on VAL set
# Got 139 / 306 correct (45.42)
#
# Epoch 20, Iteration 8, loss = 1.1517
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 138 / 306 correct (45.10)
#
# Epoch 20, Iteration 9, loss = 1.1744
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 137 / 306 correct (44.77)
#
# Epoch 20, Iteration 10, loss = 1.1474
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 143 / 306 correct (46.73)
#
# Epoch 20, Iteration 11, loss = 1.2277
# Checking accuracy on TRAIN set
# Got 26 / 64 correct (40.62)
# Checking accuracy on VAL set
# Got 141 / 306 correct (46.08)
#
# Epoch 20, Iteration 12, loss = 1.1753
# Checking accuracy on TRAIN set
# Got 26 / 64 correct (40.62)
# Checking accuracy on VAL set
# Got 139 / 306 correct (45.42)
#
# Epoch 20, Iteration 13, loss = 1.1873
# Checking accuracy on TRAIN set
# Got 35 / 64 correct (54.69)
# Checking accuracy on VAL set
# Got 138 / 306 correct (45.10)
#
# Epoch 20, Iteration 14, loss = 1.2275
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 136 / 306 correct (44.44)
#
# Epoch 20, Iteration 15, loss = 1.1665
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 136 / 306 correct (44.44)
#
# Epoch 20, Iteration 16, loss = 1.1991
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 137 / 306 correct (44.77)
#
# Epoch 20, Iteration 17, loss = 1.1484
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 140 / 306 correct (45.75)
#
# Epoch 20, Iteration 18, loss = 1.1929
# Checking accuracy on TRAIN set
# Got 35 / 64 correct (54.69)
# Checking accuracy on VAL set
# Got 138 / 306 correct (45.10)
#
# Epoch 20, Iteration 19, loss = 1.1818
# Checking accuracy on TRAIN set
# Got 5 / 8 correct (62.50)
# Checking accuracy on VAL set
# Got 136 / 306 correct (44.44)
#
# Checking accuracy on VAL set
# Got 136 / 306 correct (44.44)
# Checking accuracy on TRAIN set
# Got 570 / 1224 correct (46.57)
# Epoch 21, Iteration 0, loss = 1.1728
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 135 / 306 correct (44.12)
#
# Epoch 21, Iteration 1, loss = 1.1163
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 131 / 306 correct (42.81)
#
# Epoch 21, Iteration 2, loss = 1.1097
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 135 / 306 correct (44.12)
#
# Epoch 21, Iteration 3, loss = 1.1314
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 141 / 306 correct (46.08)
#
# Epoch 21, Iteration 4, loss = 1.2264
# Checking accuracy on TRAIN set
# Got 19 / 64 correct (29.69)
# Checking accuracy on VAL set
# Got 144 / 306 correct (47.06)
#
# Epoch 21, Iteration 5, loss = 1.1311
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 149 / 306 correct (48.69)
#
# Epoch 21, Iteration 6, loss = 1.1756
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 154 / 306 correct (50.33)
#
# Epoch 21, Iteration 7, loss = 1.1993
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 151 / 306 correct (49.35)
#
# Epoch 21, Iteration 8, loss = 1.2407
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 153 / 306 correct (50.00)
#
# Epoch 21, Iteration 9, loss = 1.1856
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 156 / 306 correct (50.98)
#
# Epoch 21, Iteration 10, loss = 1.2012
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 149 / 306 correct (48.69)
#
# Epoch 21, Iteration 11, loss = 1.0928
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 137 / 306 correct (44.77)
#
# Epoch 21, Iteration 12, loss = 1.2159
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 135 / 306 correct (44.12)
#
# Epoch 21, Iteration 13, loss = 1.2406
# Checking accuracy on TRAIN set
# Got 26 / 64 correct (40.62)
# Checking accuracy on VAL set
# Got 133 / 306 correct (43.46)
#
# Epoch 21, Iteration 14, loss = 1.2340
# Checking accuracy on TRAIN set
# Got 21 / 64 correct (32.81)
# Checking accuracy on VAL set
# Got 132 / 306 correct (43.14)
#
# Epoch 21, Iteration 15, loss = 1.1695
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 135 / 306 correct (44.12)
#
# Epoch 21, Iteration 16, loss = 1.2086
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 135 / 306 correct (44.12)
#
# Epoch 21, Iteration 17, loss = 1.2288
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 139 / 306 correct (45.42)
#
# Epoch 21, Iteration 18, loss = 1.0336
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 139 / 306 correct (45.42)
#
# Epoch 21, Iteration 19, loss = 1.1351
# Checking accuracy on TRAIN set
# Got 5 / 8 correct (62.50)
# Checking accuracy on VAL set
# Got 135 / 306 correct (44.12)
#
# Checking accuracy on VAL set
# Got 135 / 306 correct (44.12)
# Checking accuracy on TRAIN set
# Got 541 / 1224 correct (44.20)
# Epoch 22, Iteration 0, loss = 1.0818
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 134 / 306 correct (43.79)
#
# Epoch 22, Iteration 1, loss = 1.0424
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 131 / 306 correct (42.81)
#
# Epoch 22, Iteration 2, loss = 1.1629
# Checking accuracy on TRAIN set
# Got 26 / 64 correct (40.62)
# Checking accuracy on VAL set
# Got 130 / 306 correct (42.48)
#
# Epoch 22, Iteration 3, loss = 1.2471
# Checking accuracy on TRAIN set
# Got 25 / 64 correct (39.06)
# Checking accuracy on VAL set
# Got 131 / 306 correct (42.81)
#
# Epoch 22, Iteration 4, loss = 1.1710
# Checking accuracy on TRAIN set
# Got 35 / 64 correct (54.69)
# Checking accuracy on VAL set
# Got 133 / 306 correct (43.46)
#
# Epoch 22, Iteration 5, loss = 1.1687
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 136 / 306 correct (44.44)
#
# Epoch 22, Iteration 6, loss = 1.1405
# Checking accuracy on TRAIN set
# Got 35 / 64 correct (54.69)
# Checking accuracy on VAL set
# Got 138 / 306 correct (45.10)
#
# Epoch 22, Iteration 7, loss = 1.1434
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 141 / 306 correct (46.08)
#
# Epoch 22, Iteration 8, loss = 1.0962
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 147 / 306 correct (48.04)
#
# Epoch 22, Iteration 9, loss = 1.2147
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 152 / 306 correct (49.67)
#
# Epoch 22, Iteration 10, loss = 1.2580
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 154 / 306 correct (50.33)
#
# Epoch 22, Iteration 11, loss = 1.1619
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 149 / 306 correct (48.69)
#
# Epoch 22, Iteration 12, loss = 1.2492
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 151 / 306 correct (49.35)
#
# Epoch 22, Iteration 13, loss = 1.2240
# Checking accuracy on TRAIN set
# Got 23 / 64 correct (35.94)
# Checking accuracy on VAL set
# Got 145 / 306 correct (47.39)
#
# Epoch 22, Iteration 14, loss = 1.1436
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 142 / 306 correct (46.41)
#
# Epoch 22, Iteration 15, loss = 1.1824
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 137 / 306 correct (44.77)
#
# Epoch 22, Iteration 16, loss = 1.0543
# Checking accuracy on TRAIN set
# Got 38 / 64 correct (59.38)
# Checking accuracy on VAL set
# Got 135 / 306 correct (44.12)
#
# Epoch 22, Iteration 17, loss = 1.1374
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 137 / 306 correct (44.77)
#
# Epoch 22, Iteration 18, loss = 1.1335
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 142 / 306 correct (46.41)
#
# Epoch 22, Iteration 19, loss = 0.9503
# Checking accuracy on TRAIN set
# Got 6 / 8 correct (75.00)
# Checking accuracy on VAL set
# Got 139 / 306 correct (45.42)
#
# Checking accuracy on VAL set
# Got 139 / 306 correct (45.42)
# Checking accuracy on TRAIN set
# Got 609 / 1224 correct (49.75)
# Epoch 23, Iteration 0, loss = 1.1494
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 141 / 306 correct (46.08)
#
# Epoch 23, Iteration 1, loss = 1.1939
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 142 / 306 correct (46.41)
#
# Epoch 23, Iteration 2, loss = 1.3737
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 141 / 306 correct (46.08)
#
# Epoch 23, Iteration 3, loss = 1.0643
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 134 / 306 correct (43.79)
#
# Epoch 23, Iteration 4, loss = 1.1858
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 138 / 306 correct (45.10)
#
# Epoch 23, Iteration 5, loss = 1.3527
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 140 / 306 correct (45.75)
#
# Epoch 23, Iteration 6, loss = 1.1398
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 142 / 306 correct (46.41)
#
# Epoch 23, Iteration 7, loss = 1.2347
# Checking accuracy on TRAIN set
# Got 26 / 64 correct (40.62)
# Checking accuracy on VAL set
# Got 138 / 306 correct (45.10)
#
# Epoch 23, Iteration 8, loss = 1.2801
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 132 / 306 correct (43.14)
#
# Epoch 23, Iteration 9, loss = 1.0755
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 127 / 306 correct (41.50)
#
# Epoch 23, Iteration 10, loss = 1.2988
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 129 / 306 correct (42.16)
#
# Epoch 23, Iteration 11, loss = 1.1627
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 129 / 306 correct (42.16)
#
# Epoch 23, Iteration 12, loss = 1.2013
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 129 / 306 correct (42.16)
#
# Epoch 23, Iteration 13, loss = 1.1384
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 135 / 306 correct (44.12)
#
# Epoch 23, Iteration 14, loss = 1.1684
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 138 / 306 correct (45.10)
#
# Epoch 23, Iteration 15, loss = 1.1348
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 136 / 306 correct (44.44)
#
# Epoch 23, Iteration 16, loss = 1.1664
# Checking accuracy on TRAIN set
# Got 22 / 64 correct (34.38)
# Checking accuracy on VAL set
# Got 129 / 306 correct (42.16)
#
# Epoch 23, Iteration 17, loss = 1.1256
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 126 / 306 correct (41.18)
#
# Epoch 23, Iteration 18, loss = 1.2100
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 128 / 306 correct (41.83)
#
# Epoch 23, Iteration 19, loss = 1.0178
# Checking accuracy on TRAIN set
# Got 5 / 8 correct (62.50)
# Checking accuracy on VAL set
# Got 130 / 306 correct (42.48)
#
# Checking accuracy on VAL set
# Got 130 / 306 correct (42.48)
# Checking accuracy on TRAIN set
# Got 588 / 1224 correct (48.04)
# Epoch 24, Iteration 0, loss = 1.1759
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 129 / 306 correct (42.16)
#
# Epoch 24, Iteration 1, loss = 1.0838
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 126 / 306 correct (41.18)
#
# Epoch 24, Iteration 2, loss = 1.1791
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 130 / 306 correct (42.48)
#
# Epoch 24, Iteration 3, loss = 1.2172
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 137 / 306 correct (44.77)
#
# Epoch 24, Iteration 4, loss = 1.1475
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 142 / 306 correct (46.41)
#
# Epoch 24, Iteration 5, loss = 1.0526
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 144 / 306 correct (47.06)
#
# Epoch 24, Iteration 6, loss = 1.2357
# Checking accuracy on TRAIN set
# Got 22 / 64 correct (34.38)
# Checking accuracy on VAL set
# Got 146 / 306 correct (47.71)
#
# Epoch 24, Iteration 7, loss = 1.2327
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 152 / 306 correct (49.67)
#
# Epoch 24, Iteration 8, loss = 1.1583
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 152 / 306 correct (49.67)
#
# Epoch 24, Iteration 9, loss = 1.0992
# Checking accuracy on TRAIN set
# ...
# Got 143 / 306 correct (46.73)
#
# Epoch 45, Iteration 2, loss = 0.9944
# Checking accuracy on TRAIN set
# Got 40 / 64 correct (62.50)
# Checking accuracy on VAL set
# Got 141 / 306 correct (46.08)
#
# Epoch 45, Iteration 3, loss = 0.8985
# Checking accuracy on TRAIN set
# Got 41 / 64 correct (64.06)
# Checking accuracy on VAL set
# Got 145 / 306 correct (47.39)
#
# Epoch 45, Iteration 4, loss = 1.0262
# Checking accuracy on TRAIN set
# Got 36 / 64 correct (56.25)
# Checking accuracy on VAL set
# Got 145 / 306 correct (47.39)
#
# Epoch 45, Iteration 5, loss = 1.1460
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 160 / 306 correct (52.29)
#
# Epoch 45, Iteration 6, loss = 1.0144
# Checking accuracy on TRAIN set
# Got 39 / 64 correct (60.94)
# Checking accuracy on VAL set
# Got 164 / 306 correct (53.59)
#
# Epoch 45, Iteration 7, loss = 0.9985
# Checking accuracy on TRAIN set
# Got 36 / 64 correct (56.25)
# Checking accuracy on VAL set
# Got 166 / 306 correct (54.25)
#
# Epoch 45, Iteration 8, loss = 1.1329
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 169 / 306 correct (55.23)
#
# Epoch 45, Iteration 9, loss = 0.9965
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 172 / 306 correct (56.21)
#
# Epoch 45, Iteration 10, loss = 0.9439
# Checking accuracy on TRAIN set
# Got 39 / 64 correct (60.94)
# Checking accuracy on VAL set
# Got 168 / 306 correct (54.90)
#
# Epoch 45, Iteration 11, loss = 1.0481
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 160 / 306 correct (52.29)
#
# Epoch 45, Iteration 12, loss = 0.9747
# Checking accuracy on TRAIN set
# Got 40 / 64 correct (62.50)
# Checking accuracy on VAL set
# Got 154 / 306 correct (50.33)
#
# Epoch 45, Iteration 13, loss = 0.9206
# Checking accuracy on TRAIN set
# Got 40 / 64 correct (62.50)
# Checking accuracy on VAL set
# Got 153 / 306 correct (50.00)
#
# Epoch 45, Iteration 14, loss = 1.0872
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 149 / 306 correct (48.69)
#
# Epoch 45, Iteration 15, loss = 1.2180
# Checking accuracy on TRAIN set
# Got 26 / 64 correct (40.62)
# Checking accuracy on VAL set
# Got 145 / 306 correct (47.39)
#
# Epoch 45, Iteration 16, loss = 1.0984
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 145 / 306 correct (47.39)
#
# Epoch 45, Iteration 17, loss = 1.2476
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 146 / 306 correct (47.71)
#
# Epoch 45, Iteration 18, loss = 0.9117
# Checking accuracy on TRAIN set
# Got 40 / 64 correct (62.50)
# Checking accuracy on VAL set
# Got 148 / 306 correct (48.37)
#
# Epoch 45, Iteration 19, loss = 0.8098
# Checking accuracy on TRAIN set
# Got 7 / 8 correct (87.50)
# Checking accuracy on VAL set
# Got 151 / 306 correct (49.35)
#
# Checking accuracy on VAL set
# Got 151 / 306 correct (49.35)
# Checking accuracy on TRAIN set
# Got 701 / 1224 correct (57.27)
# Epoch 46, Iteration 0, loss = 1.0791
# Checking accuracy on TRAIN set
# Got 36 / 64 correct (56.25)
# Checking accuracy on VAL set
# Got 163 / 306 correct (53.27)
#
# Epoch 46, Iteration 1, loss = 0.9963
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 168 / 306 correct (54.90)
#
# Epoch 46, Iteration 2, loss = 1.0872
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 172 / 306 correct (56.21)
#
# Epoch 46, Iteration 3, loss = 1.2241
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 166 / 306 correct (54.25)
#
# Epoch 46, Iteration 4, loss = 1.1185
# Checking accuracy on TRAIN set
# Got 35 / 64 correct (54.69)
# Checking accuracy on VAL set
# Got 163 / 306 correct (53.27)
#
# Epoch 46, Iteration 5, loss = 1.0240
# Checking accuracy on TRAIN set
# Got 35 / 64 correct (54.69)
# Checking accuracy on VAL set
# Got 158 / 306 correct (51.63)
#
# Epoch 46, Iteration 6, loss = 0.8511
# Checking accuracy on TRAIN set
# Got 40 / 64 correct (62.50)
# Checking accuracy on VAL set
# Got 150 / 306 correct (49.02)
#
# Epoch 46, Iteration 7, loss = 1.0756
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 147 / 306 correct (48.04)
#
# Epoch 46, Iteration 8, loss = 0.9209
# Checking accuracy on TRAIN set
# Got 45 / 64 correct (70.31)
# Checking accuracy on VAL set
# Got 153 / 306 correct (50.00)
#
# Epoch 46, Iteration 9, loss = 1.1656
# Checking accuracy on TRAIN set
# Got 36 / 64 correct (56.25)
# Checking accuracy on VAL set
# Got 150 / 306 correct (49.02)
#
# Epoch 46, Iteration 10, loss = 1.0697
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 150 / 306 correct (49.02)
#
# Epoch 46, Iteration 11, loss = 1.0900
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 149 / 306 correct (48.69)
#
# Epoch 46, Iteration 12, loss = 1.0086
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 151 / 306 correct (49.35)
#
# Epoch 46, Iteration 13, loss = 1.0779
# Checking accuracy on TRAIN set
# Got 35 / 64 correct (54.69)
# Checking accuracy on VAL set
# Got 147 / 306 correct (48.04)
#
# Epoch 46, Iteration 14, loss = 0.9710
# Checking accuracy on TRAIN set
# Got 40 / 64 correct (62.50)
# Checking accuracy on VAL set
# Got 148 / 306 correct (48.37)
#
# Epoch 46, Iteration 15, loss = 0.9800
# Checking accuracy on TRAIN set
# Got 39 / 64 correct (60.94)
# Checking accuracy on VAL set
# Got 149 / 306 correct (48.69)
#
# Epoch 46, Iteration 16, loss = 1.0118
# Checking accuracy on TRAIN set
# Got 38 / 64 correct (59.38)
# Checking accuracy on VAL set
# Got 146 / 306 correct (47.71)
#
# Epoch 46, Iteration 17, loss = 0.9667
# Checking accuracy on TRAIN set
# Got 35 / 64 correct (54.69)
# Checking accuracy on VAL set
# Got 145 / 306 correct (47.39)
#
# Epoch 46, Iteration 18, loss = 0.9314
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 142 / 306 correct (46.41)
#
# Epoch 46, Iteration 19, loss = 0.8759
# Checking accuracy on TRAIN set
# Got 7 / 8 correct (87.50)
# Checking accuracy on VAL set
# Got 152 / 306 correct (49.67)
#
# Checking accuracy on VAL set
# Got 152 / 306 correct (49.67)
# Checking accuracy on TRAIN set
# Got 712 / 1224 correct (58.17)
# Epoch 47, Iteration 0, loss = 1.0893
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 155 / 306 correct (50.65)
#
# Epoch 47, Iteration 1, loss = 1.1411
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 159 / 306 correct (51.96)
#
# Epoch 47, Iteration 2, loss = 1.2009
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 159 / 306 correct (51.96)
#
# Epoch 47, Iteration 3, loss = 0.9246
# Checking accuracy on TRAIN set
# Got 45 / 64 correct (70.31)
# Checking accuracy on VAL set
# Got 154 / 306 correct (50.33)
#
# Epoch 47, Iteration 4, loss = 1.0481
# Checking accuracy on TRAIN set
# Got 39 / 64 correct (60.94)
# Checking accuracy on VAL set
# Got 154 / 306 correct (50.33)
#
# Epoch 47, Iteration 5, loss = 1.0714
# Checking accuracy on TRAIN set
# Got 36 / 64 correct (56.25)
# Checking accuracy on VAL set
# Got 151 / 306 correct (49.35)
#
# Epoch 47, Iteration 6, loss = 0.9508
# Checking accuracy on TRAIN set
# Got 38 / 64 correct (59.38)
# Checking accuracy on VAL set
# Got 148 / 306 correct (48.37)
#
# Epoch 47, Iteration 7, loss = 0.9798
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 146 / 306 correct (47.71)
#
# Epoch 47, Iteration 8, loss = 0.9725
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 145 / 306 correct (47.39)
#
# Epoch 47, Iteration 9, loss = 1.0330
# Checking accuracy on TRAIN set
# Got 39 / 64 correct (60.94)
# Checking accuracy on VAL set
# Got 145 / 306 correct (47.39)
#
# Epoch 47, Iteration 10, loss = 1.1875
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 139 / 306 correct (45.42)
#
# Epoch 47, Iteration 11, loss = 1.0379
# Checking accuracy on TRAIN set
# Got 39 / 64 correct (60.94)
# Checking accuracy on VAL set
# Got 139 / 306 correct (45.42)
#
# Epoch 47, Iteration 12, loss = 0.9665
# Checking accuracy on TRAIN set
# Got 40 / 64 correct (62.50)
# Checking accuracy on VAL set
# Got 140 / 306 correct (45.75)
#
# Epoch 47, Iteration 13, loss = 0.9649
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 141 / 306 correct (46.08)
#
# Epoch 47, Iteration 14, loss = 1.0714
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 146 / 306 correct (47.71)
#
# Epoch 47, Iteration 15, loss = 1.0185
# Checking accuracy on TRAIN set
# Got 36 / 64 correct (56.25)
# Checking accuracy on VAL set
# Got 152 / 306 correct (49.67)
#
# Epoch 47, Iteration 16, loss = 0.9727
# Checking accuracy on TRAIN set
# Got 42 / 64 correct (65.62)
# Checking accuracy on VAL set
# Got 155 / 306 correct (50.65)
#
# Epoch 47, Iteration 17, loss = 0.8823
# Checking accuracy on TRAIN set
# Got 46 / 64 correct (71.88)
# Checking accuracy on VAL set
# Got 165 / 306 correct (53.92)
#
# Epoch 47, Iteration 18, loss = 0.9621
# Checking accuracy on TRAIN set
# Got 36 / 64 correct (56.25)
# Checking accuracy on VAL set
# Got 167 / 306 correct (54.58)
#
# Epoch 47, Iteration 19, loss = 1.0240
# Checking accuracy on TRAIN set
# Got 5 / 8 correct (62.50)
# Checking accuracy on VAL set
# Got 163 / 306 correct (53.27)
#
# Checking accuracy on VAL set
# Got 163 / 306 correct (53.27)
# Checking accuracy on TRAIN set
# Got 688 / 1224 correct (56.21)
# Epoch 48, Iteration 0, loss = 1.1452
# Checking accuracy on TRAIN set
# Got 39 / 64 correct (60.94)
# Checking accuracy on VAL set
# Got 159 / 306 correct (51.96)
#
# Epoch 48, Iteration 1, loss = 1.0079
# Checking accuracy on TRAIN set
# Got 36 / 64 correct (56.25)
# Checking accuracy on VAL set
# Got 156 / 306 correct (50.98)
#
# Epoch 48, Iteration 2, loss = 0.9484
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 149 / 306 correct (48.69)
#
# Epoch 48, Iteration 3, loss = 1.1081
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 149 / 306 correct (48.69)
#
# Epoch 48, Iteration 4, loss = 0.9615
# Checking accuracy on TRAIN set
# Got 40 / 64 correct (62.50)
# Checking accuracy on VAL set
# Got 148 / 306 correct (48.37)
#
# Epoch 48, Iteration 5, loss = 0.9477
# Checking accuracy on TRAIN set
# Got 41 / 64 correct (64.06)
# Checking accuracy on VAL set
# Got 150 / 306 correct (49.02)
#
# Epoch 48, Iteration 6, loss = 1.2982
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 156 / 306 correct (50.98)
#
# Epoch 48, Iteration 7, loss = 0.9129
# Checking accuracy on TRAIN set
# Got 42 / 64 correct (65.62)
# Checking accuracy on VAL set
# Got 154 / 306 correct (50.33)
#
# Epoch 48, Iteration 8, loss = 1.0534
# Checking accuracy on TRAIN set
# Got 36 / 64 correct (56.25)
# Checking accuracy on VAL set
# Got 161 / 306 correct (52.61)
#
# Epoch 48, Iteration 9, loss = 0.9383
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 169 / 306 correct (55.23)
#
# Epoch 48, Iteration 10, loss = 1.0833
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 169 / 306 correct (55.23)
#
# Epoch 48, Iteration 11, loss = 1.0563
# Checking accuracy on TRAIN set
# Got 36 / 64 correct (56.25)
# Checking accuracy on VAL set
# Got 159 / 306 correct (51.96)
#
# Epoch 48, Iteration 12, loss = 1.0230
# Checking accuracy on TRAIN set
# Got 38 / 64 correct (59.38)
# Checking accuracy on VAL set
# Got 154 / 306 correct (50.33)
#
# Epoch 48, Iteration 13, loss = 1.1354
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 146 / 306 correct (47.71)
#
# Epoch 48, Iteration 14, loss = 0.9688
# Checking accuracy on TRAIN set
# Got 40 / 64 correct (62.50)
# Checking accuracy on VAL set
# Got 141 / 306 correct (46.08)
#
# Epoch 48, Iteration 15, loss = 1.0620
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 138 / 306 correct (45.10)
#
# Epoch 48, Iteration 16, loss = 1.1128
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 137 / 306 correct (44.77)
#
# Epoch 48, Iteration 17, loss = 1.1280
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 134 / 306 correct (43.79)
#
# Epoch 48, Iteration 18, loss = 1.0350
# Checking accuracy on TRAIN set
# Got 42 / 64 correct (65.62)
# Checking accuracy on VAL set
# Got 139 / 306 correct (45.42)
#
# Epoch 48, Iteration 19, loss = 0.9173
# Checking accuracy on TRAIN set
# Got 5 / 8 correct (62.50)
# Checking accuracy on VAL set
# Got 138 / 306 correct (45.10)
#
# Checking accuracy on VAL set
# Got 138 / 306 correct (45.10)
# Checking accuracy on TRAIN set
# Got 696 / 1224 correct (56.86)
# Epoch 49, Iteration 0, loss = 1.1043
# Checking accuracy on TRAIN set
# Got 36 / 64 correct (56.25)
# Checking accuracy on VAL set
# Got 136 / 306 correct (44.44)
#
# Epoch 49, Iteration 1, loss = 1.0836
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 141 / 306 correct (46.08)
#
# Epoch 49, Iteration 2, loss = 1.0148
# Checking accuracy on TRAIN set
# Got 41 / 64 correct (64.06)
# Checking accuracy on VAL set
# Got 150 / 306 correct (49.02)
#
# Epoch 49, Iteration 3, loss = 0.9749
# Checking accuracy on TRAIN set
# Got 36 / 64 correct (56.25)
# Checking accuracy on VAL set
# Got 155 / 306 correct (50.65)
#
# Epoch 49, Iteration 4, loss = 1.0143
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 156 / 306 correct (50.98)
#
# Epoch 49, Iteration 5, loss = 1.0200
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 158 / 306 correct (51.63)
#
# Epoch 49, Iteration 6, loss = 0.9879
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 160 / 306 correct (52.29)
#
# Epoch 49, Iteration 7, loss = 1.0640
# Checking accuracy on TRAIN set
# Got 35 / 64 correct (54.69)
# Checking accuracy on VAL set
# Got 162 / 306 correct (52.94)
#
# Epoch 49, Iteration 8, loss = 0.9276
# Checking accuracy on TRAIN set
# Got 43 / 64 correct (67.19)
# Checking accuracy on VAL set
# Got 158 / 306 correct (51.63)
#
# Epoch 49, Iteration 9, loss = 1.0070
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 159 / 306 correct (51.96)
#
# Epoch 49, Iteration 10, loss = 1.0408
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 164 / 306 correct (53.59)
#
# Epoch 49, Iteration 11, loss = 1.0493
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 163 / 306 correct (53.27)
#
# Epoch 49, Iteration 12, loss = 1.2843
# Checking accuracy on TRAIN set
# Got 35 / 64 correct (54.69)
# Checking accuracy on VAL set
# Got 150 / 306 correct (49.02)
#
# Epoch 49, Iteration 13, loss = 0.9810
# Checking accuracy on TRAIN set
# Got 35 / 64 correct (54.69)
# Checking accuracy on VAL set
# Got 149 / 306 correct (48.69)
#
# Epoch 49, Iteration 14, loss = 0.9623
# Checking accuracy on TRAIN set
# Got 38 / 64 correct (59.38)
# Checking accuracy on VAL set
# Got 145 / 306 correct (47.39)
#
# Epoch 49, Iteration 15, loss = 1.0582
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 146 / 306 correct (47.71)
#
# Epoch 49, Iteration 16, loss = 0.9607
# Checking accuracy on TRAIN set
# Got 45 / 64 correct (70.31)
# Checking accuracy on VAL set
# Got 148 / 306 correct (48.37)
#
# Epoch 49, Iteration 17, loss = 1.0075
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 149 / 306 correct (48.69)
#
# Epoch 49, Iteration 18, loss = 0.9623
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 148 / 306 correct (48.37)
#
# Epoch 49, Iteration 19, loss = 1.1421
# Checking accuracy on TRAIN set
# Got 2 / 8 correct (25.00)
# Checking accuracy on VAL set
# Got 156 / 306 correct (50.98)
#
# Checking accuracy on VAL set
# Got 156 / 306 correct (50.98)
# Checking accuracy on TRAIN set
# Got 685 / 1224 correct (55.96)
# DONE TRAINING

# %%
torch.save(best_model, "best_model_LSTM_without_noise_cleanup_whole_time_scale_150_epochs")
torch.save(model, "model_LSTM_without_noise_cleanup_whole_time_scale_150_epochs")
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:402: UserWarning: Couldn't retrieve source code for container of type Flatten. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "

# %%
print("DONE")
per_epoch_train_accuracy_list
# Out:
# DONE
# [0.39869281045751637,
#  0.3700980392156863,
#  0.39869281045751637,
#  0.39869281045751637,
#  0.39869281045751637,
#  0.39869281045751637,
#  0.39869281045751637,
#  0.4305555555555556,
#  0.3758169934640523,
#  0.380718954248366,
#  0.4068627450980392,
#  0.4158496732026144,
#  0.39215686274509803,
#  0.44199346405228757,
#  0.4019607843137255,
#  0.434640522875817,
#  0.4616013071895425,
#  0.4485294117647059,
#  0.46078431372549017,
#  0.4812091503267974,
#  0.46568627450980393,
#  0.44199346405228757,
#  0.49754901960784315,
#  0.4803921568627451,
#  0.4550653594771242,
#  0.48284313725490197,
#  0.511437908496732,
#  0.511437908496732,
#  0.5106209150326797,
#  0.5089869281045751,
#  0.5106209150326797,
#  0.4632352941176471,
#  0.5351307189542484,
#  0.5245098039215687,
#  0.5318627450980392,
#  0.5367647058823529,
#  0.5008169934640523,
#  0.5220588235294118,
#  0.5285947712418301,
#  0.5212418300653595,
#  0.5367647058823529,
#  0.5343137254901961,
#  0.5498366013071896,
#  0.5490196078431373,
#  0.5400326797385621,
#  0.5727124183006536,
#  0.5816993464052288,
#  0.5620915032679739,
#  0.5686274509803921,
#  0.559640522875817]

# %%
##PLOT LOSS, TRAIN ACCURACY, TEST ACCURACY
import matplotlib.pyplot as plt
max_train_accuracy = np.repeat(np.max(np.array([train_accuracy_list])),   len(train_accuracy_list))

max_test_accuracy = np.repeat(np.max(np.array([test_accuracy_list])),   len(test_accuracy_list))

max_p_e_train_accuracy = np.repeat(np.max(np.array([per_epoch_train_accuracy_list])),   len(per_epoch_train_accuracy_list))

max_p_e_test_accuracy = np.repeat(np.max(np.array([per_epoch_test_accuracy_list])),   len(per_epoch_test_accuracy_list))

# plot the loss history
plt.subplot()
plt.plot(loss_list)
plt.xlabel('iteration')
plt.ylabel('training loss')
plt.title('Training Loss history')
plt.legend()
plt.show()

plt.subplot()
plt.plot(train_accuracy_list, label='train')
plt.plot(test_accuracy_list, label='val')
plt.plot(max_train_accuracy, label='max train acc')
plt.plot(max_test_accuracy, label='max val acc')
plt.title('Classification accuracy history')
plt.xlabel('Iteration')
plt.ylabel('Classification accuracy')
plt.legend()
plt.show()

plt.subplot()
plt.plot(per_epoch_train_accuracy_list, label='train')
plt.plot(per_epoch_test_accuracy_list, label='val')
plt.plot(max_p_e_train_accuracy, label='max train acc')
plt.plot(max_p_e_test_accuracy, label='max val acc')
plt.title('Per Epoch Classification accuracy history')
plt.xlabel('Epoch')
plt.ylabel('Classification accuracy')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
from sklearn.metrics import confusion_matrix
#from resources.plotcm import plot_confusion_matrix
import itertools
import numpy as np
import matplotlib.pyplot as plt

def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion matrix', cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt), horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
def check_train_accuracy1(loader, model, for_confusion_matrix=0):
    #if loader.dataset.train:
    #    print('Checking accuracy on validation set')
    #else:
    #    print('Checking accuracy on test set')
    print('Checking accuracy on TRAIN set')
    num_correct = 0
    num_samples = 0
    model.eval()  # set model to evaluation mode
    true_label_list = []
    predicted_label_list = []
    with torch.no_grad():
        for x, y in loader:
            true_label_list.append(y.cpu().data.numpy())
            x = x.to(device=device, dtype=dtype)  # move to device, e.g. GPU
            y = y.to(device=device, dtype=torch.long)
            #pdb.set_trace()
            #y = torch.stack(y) #.to(device=device)
            #y = y.reshape((x.shape[0]))
            scores = model(x)
            _, preds = scores.max(1)
            predicted_label_list.append(preds.cpu().data.numpy())            
            num_correct += (preds == y).sum()
            num_samples += preds.size(0)
        acc = float(num_correct) / num_samples
        print('Got %d / %d correct (%.2f)' % (num_correct, num_samples, 100 * acc))
        if for_confusion_matrix == 1:
          return acc, true_label_list, predicted_label_list
        else:
          return acc

# %%
#best_model1 = torch.load("model2")
accuracy, true_label, predicted_label = check_train_accuracy1(loader_train, best_model, for_confusion_matrix=1)
true_label = np.concatenate(true_label, axis=None)
#print(true_label)

predicted_label = np.concatenate(predicted_label, axis=None)
#print(predicted_label)

emotion_dict = ('hap',
                'sad',
                'ang',
                'neu'
                )
cm = confusion_matrix(true_label, predicted_label)

#t_t = train_set_targets.cpu().data.numpy()
#predict = preds.cpu().data.numpy()
#t_t = 1 + t_t
#predict = 1 + predict

#for i in range(t_t.shape[0]):
#  print(t_t[i], predict[i])
#print(t_t)
#print(predict)
#print(cm)
plt.figure(figsize=(6,6))
plot_confusion_matrix(cm, emotion_dict)
# Out:
# Checking accuracy on TRAIN set
# Got 680 / 1224 correct (55.56)
# Confusion matrix, without normalization
# [[ 13  72  53  83]
#  [  0 281   9  48]
#  [  6  32 168  49]
#  [  5 165  22 218]]

# %%
#best_model1 = torch.load("model1")
accuracy, true_label, predicted_label = check_train_accuracy1(loader_val, best_model, for_confusion_matrix=1)
true_label = np.concatenate(true_label, axis=None)
#print(true_label)

predicted_label = np.concatenate(predicted_label, axis=None)
#print(predicted_label)


cm = confusion_matrix(true_label, predicted_label)

#t_t = train_set_targets.cpu().data.numpy()
#predict = preds.cpu().data.numpy()
#t_t = 1 + t_t
#predict = 1 + predict

#for i in range(t_t.shape[0]):
#  print(t_t[i], predict[i])
#print(t_t)
#print(predict)
#print(cm)
plt.figure(figsize=(6,6))
plot_confusion_matrix(cm, emotion_dict)
# Out:
# Checking accuracy on TRAIN set
# Got 172 / 306 correct (56.21)
# Confusion matrix, without normalization
# [[ 4  9 13 16]
#  [ 0 52  3 13]
#  [ 1  7 66 25]
#  [ 7 20 20 50]]

# %%
accuracy, true_label, predicted_label = check_train_accuracy1(loader_train, model, for_confusion_matrix=1)
true_label = np.concatenate(true_label, axis=None)
#print(true_label)

predicted_label = np.concatenate(predicted_label, axis=None)
#print(predicted_label)

emotion_dict = ('hap',
                'sad',
                'ang',
                'neu'
                )
cm = confusion_matrix(true_label, predicted_label)

#t_t = train_set_targets.cpu().data.numpy()
#predict = preds.cpu().data.numpy()
#t_t = 1 + t_t
#predict = 1 + predict

#for i in range(t_t.shape[0]):
#  print(t_t[i], predict[i])
#print(t_t)
#print(predict)
#print(cm)
plt.figure(figsize=(6,6))
plot_confusion_matrix(cm, emotion_dict)
# Out:
# Checking accuracy on TRAIN set
# Got 685 / 1224 correct (55.96)
# Confusion matrix, without normalization
# [[ 21  61  69  70]
#  [  4 270  18  46]
#  [ 12  22 184  37]
#  [ 13 146  41 210]]

# %%
#best_model1 = torch.load("model1")
accuracy, true_label, predicted_label = check_train_accuracy1(loader_val, model, for_confusion_matrix=1)
true_label = np.concatenate(true_label, axis=None)
#print(true_label)

predicted_label = np.concatenate(predicted_label, axis=None)
#print(predicted_label)


cm = confusion_matrix(true_label, predicted_label)

#t_t = train_set_targets.cpu().data.numpy()
#predict = preds.cpu().data.numpy()
#t_t = 1 + t_t
#predict = 1 + predict

#for i in range(t_t.shape[0]):
#  print(t_t[i], predict[i])
#print(t_t)
#print(predict)
#print(cm)
plt.figure(figsize=(6,6))
plot_confusion_matrix(cm, emotion_dict)
# Out:
# Checking accuracy on TRAIN set
# Got 156 / 306 correct (50.98)
# Confusion matrix, without normalization
# [[ 3  8 23  8]
#  [ 3 43  8 14]
#  [ 4  4 72 19]
#  [10 16 33 38]]
