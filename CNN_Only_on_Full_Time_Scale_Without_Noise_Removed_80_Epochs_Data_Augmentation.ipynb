# %%
'''
# this mounts your Google Drive to the Colab VM.
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# enter the foldername in your Drive where you have saved the unzipped
# assignment folder, e.g. 'cs231n/assignments/assignment3/'
FOLDERNAME = 'PROJECT/WITHOUT_NOISE_CLEANUP/'
assert FOLDERNAME is not None, "[!] Enter the foldername."

# now that we've mounted your Drive, this ensures that
# the Python interpreter of the Colab VM can load
# python files from within it.
import sys
sys.path.append('/content/drive/My Drive/{}'.format(FOLDERNAME))

# this downloads the CIFAR-10 dataset to your Drive
# if it doesn't already exist.
#%cd /content/drive/My\ Drive/$FOLDERNAME/
#!bash get_datasets.sh

'''
# Out:
# '\n# this mounts your Google Drive to the Colab VM.\nfrom google.colab import drive\ndrive.mount(\'/content/drive\', force_remount=True)\n\n# enter the foldername in your Drive where you have saved the unzipped\n# assignment folder, e.g. \'cs231n/assignments/assignment3/\'\nFOLDERNAME = \'PROJECT/WITHOUT_NOISE_CLEANUP/\'\nassert FOLDERNAME is not None, "[!] Enter the foldername."\n\n# now that we\'ve mounted your Drive, this ensures that\n# the Python interpreter of the Colab VM can load\n# python files from within it.\nimport sys\nsys.path.append(\'/content/drive/My Drive/{}\'.format(FOLDERNAME))\n\n# this downloads the CIFAR-10 dataset to your Drive\n# if it doesn\'t already exist.\n#%cd /content/drive/My\\ Drive/$FOLDERNAME/\n#!bash get_datasets.sh\n\n'

# %%
'''
import os 
os.chdir("/content/drive/My Drive/")
os.chdir(FOLDERNAME)
#!bash get_datasets.sh
'''
# Out:
# '\nimport os \nos.chdir("/content/drive/My Drive/")\nos.chdir(FOLDERNAME)\n#!bash get_datasets.sh\n'

# %%
#"neu_3.0_2.0_2.3333_Whole_Length.png".split('_')

# %%
#import sys
#!{sys.executable} -m pip install torchsummary


from torch.utils.data import Dataset,DataLoader
from torchvision import transforms
import os
import numpy as np
import time
from PIL import Image
#from PIL import ImageFile
#ImageFile.LOAD_TRUNCATED_IMAGES = True
from collections import defaultdict
import cv2
import pdb
IMG_SIZE = (200,300)

from torchvision import models
from torchsummary import summary
import copy
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#dataset_train.__len__
#dataset_test.shape
#dataset_val.shape

#'''test corrupted images'''
#data_path = "/home/mandeep_stanford/cs231n_project/code/pre-processed_data/images_denoised/session1/"
#dataset_train, dataset_test, dataset_val = get_imagenet_datasets(data_path, "cpc")
#
#print(f"Number of train samplest {dataset_train.__len__()}")
#print(f"Number of samples in test split {dataset_test.__len__()}")
#
#BATCH_SIZE = 200
#
#data_loader_train = DataLoader(dataset_train, BATCH_SIZE, shuffle = True)
#data_loader_test = DataLoader(dataset_test, BATCH_SIZE, shuffle = True)
#
#
#import matplotlib.pyplot as plt
#
#fig, axes = plt.subplots(BATCH_SIZE//20,20, figsize=(6,10))
#
#for batch in data_loader_train:
#
#    print(f"Shape of batch['image'] {batch['image'].shape}")
#    print(f"Shape of batch['cls'] {batch['cls'].shape}")
#
#    for i in range(BATCH_SIZE):
#
#        col = i % 20
#        row = i // 20
#
#        img = batch['image'][i].numpy()
#
#        axes[row,col].set_axis_off()
#        #axes[row,col].set_title(batch['class_name'][i])
#        axes[row,col].imshow(np.transpose(img,(1,2,0)))
#
#    plt.show()
#
#    break

# %%
#data_path = "/home/mandeep_stanford/cs231n_project/code/pre-processed_data/images/session1/"
#data_path = "/home/mandeep_stanford/cs231n_project/code/pre-processed_data/combined_session1_2/"
data_path1 = "/home/mandeep_stanford/cs231n_project/code/pre-processed_data/4_EMOTIONS/without_noise_cleanup/session1/"
data_path2 = "/home/mandeep_stanford/cs231n_project/code/pre-processed_data/4_EMOTIONS/without_noise_cleanup/session2/"
data_path3 = "/home/mandeep_stanford/cs231n_project/code/pre-processed_data/4_EMOTIONS/without_noise_cleanup/session3/"
data_path4 = "/home/mandeep_stanford/cs231n_project/code/pre-processed_data/4_EMOTIONS/without_noise_cleanup/session4/"

#img_files = os.listdir("/home/mandeep_stanford/cs231n_project/code/pre-processed_data/images/session1/")
#img_files = os.listdir("/home/mandeep_stanford/cs231n_project/code/pre-processed_data/combined_session1_2/")
#img_files = os.listdir("/home/mandeep_stanford/cs231n_project/code/pre-processed_data/4_EMOTIONS/cb_removed/with_noise_cleanup/session1/")

pkl_file = "/home/mandeep_stanford/cs231n_project/code/pre-processed_data/4_EMOTIONS/without_noise_cleanup/without_noise_cleanup_WHOLE.pkl"

# %%
import pickle
import pdb
X = []
Y = []
i = 0
#extract_emotion = ['hap','sad','ang','neu','fea', 'exc', 'fru']
extract_emotion = ['hap','sad','ang','neu']
if 0:
    path = [data_path1, data_path2, data_path3, data_path4]
    for p_files in path:
        for file_name in os.listdir(p_files):
                    
            print("Working on ", i)
            i = i+1
            #if i >= 7000:
            #    break
            if "Whole" in file_name.split('_'):
              print("")
            else:
              print("Skipping ", file_name)
              continue
            cat = file_name.split('_')[0]
            if cat in extract_emotion:
                #print("")
                if cat == "hap":
                    cat = 0
                if cat == "sad":
                    cat = 1
                if cat == "ang":
                    cat = 2
                if cat == "neu":
                    cat = 3
            else:
                continue
            
            Y.append(cat)
            img = Image.open(p_files+file_name)
            img = img.convert('RGB')
            tr = transforms.Resize((200,300))
            img=tr(img)
            
            trf = transforms.RandomHorizontalFlip(p=1)
            img2 = trf(img)
            #pdb.set_trace()
            tr = transforms.ToTensor()
            
            img1 = tr(img)
            img2 = tr(img2)
            
            img1 = np.array(img1)
            img2 = np.array(img2)
            if cat == "hap":
                Y.append(cat)
                X.append(img1)
                Y.append(cat)
                X.append(img1)
                Y.append(cat)
                X.append(img1)
                Y.append(cat)
                X.append(img1)
                Y.append(cat)
                X.append(img1)
                Y.append(cat)
                X.append(img2)
                
            if cat == "ang":
                Y.append(cat)
                X.append(img1)
                Y.append(cat)
                X.append(img1)
            #X=np.vstack((X,img1))
            X.append(img1)
            Y.append(cat)
            X.append(img2)
    
            del img1
            del img2
            del img
            del tr

    Y = np.asarray(Y)
    X = np.asarray(X)
    data = {}
    data["X"] = X
    data["Y"] = Y
    with open(pkl_file, 'wb') as f:
        pickle.dump(data, f)
        f.close()

# %%
import pickle
import torch
assert '.'.join(torch.__version__.split('.')[:2]) == '1.4'
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torch.utils.data import sampler
import torch.utils.data as data_utils
import torchvision.datasets as dset
import torchvision.transforms as T
import torch.nn.functional as F 
import numpy as np
#pkl_file = "/home/mandeep_stanford/cs231n_project/code/pre-processed_data/images_denoised/session1_pkl_tensor1.pkl"
data = pickle.load(open(pkl_file, 'rb'))
X = data["X"]
Y = data["Y"]

# %%
X.shape
# Out:
# (1530, 3, 200, 300)

# %%
np.unique(Y)
# Out:
# array([0, 1, 2, 3])

# %%
import numpy as np
total_images = X.shape[0]
test_data_images = np.int(total_images*0.2)
train_data_images = total_images - test_data_images
#X_train = X[0:train_data_images,-1]
#y_train = Y[0:train_data_images]
#X_test = X[train_data_images:train_data_images+test_data_images, -1]
#y_test= Y[train_data_images:train_data_images+test_data_images]

#X_train = np.asarray(X_train)
#X_test = np.asarray(X_test)
#y_train = np.asarray(y_train)
#y_test = np.asarray(y_test)

#y_train = y_train.reshape((y_train[0]))
#y_test = y_test.reshape((y_test[0]))
#print(X_train.shape)
#print(y_train.shape)
#print(X_test.shape)
#print(y_test.shape)

# %%
USE_GPU = True

dtype = torch.float32 # we will be using float throughout this tutorial

if USE_GPU and torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')

# Constant to control how frequently we print train loss
print_every = 100

print('using device:', device)
# Out:
# using device: cuda

# %%
train_data = []
keys_array = np.unique(Y)
for i in range(len(X)):
   ind = np.where(keys_array==Y[i]) 
   train_data.append([X[i], Y[i]])
print("DONE")
#dataset = data_utils.TensorDataset(train_data, batch_size=100)
print(train_data_images)
print(train_data_images+test_data_images)
loader_train = DataLoader(train_data, batch_size=64, 
                          sampler=sampler.SubsetRandomSampler(range(0,train_data_images)))

loader_val = DataLoader(train_data, batch_size=64, 
                        sampler=sampler.SubsetRandomSampler(range(train_data_images, train_data_images+test_data_images)))


#for t, (x,y) in enumerate(loader_train):
#  print(t, x, y)
# Out:
# DONE
# 1224
# 1530

# %%
print_every = 1

# %%
def check_train_accuracy(loader, model):
    #if loader.dataset.train:
    #    print('Checking accuracy on validation set')
    #else:
    #    print('Checking accuracy on test set')
    print('Checking accuracy on TRAIN set')
    num_correct = 0
    num_samples = 0
    model.eval()  # set model to evaluation mode
    with torch.no_grad():
        for x, y in loader:
            x = x.to(device=device, dtype=dtype)  # move to device, e.g. GPU
            y = y.to(device=device, dtype=torch.long)
            #pdb.set_trace()
            #y = torch.stack(y) #.to(device=device)
            #y = y.reshape((x.shape[0]))
            scores = model(x)
            _, preds = scores.max(1)
            
            num_correct += (preds == y).sum()
            num_samples += preds.size(0)
        acc = float(num_correct) / num_samples
        print('Got %d / %d correct (%.2f)' % (num_correct, num_samples, 100 * acc))
        return acc

# %%
def check_accuracy_part34(loader, model):
    #if loader.dataset.train:
    #    print('Checking accuracy on validation set')
    #else:
    #    print('Checking accuracy on test set')
    print('Checking accuracy on VAL set')
    num_correct = 0
    num_samples = 0
    model.eval()  # set model to evaluation mode
    with torch.no_grad():
        for x, y in loader:
            x = x.to(device=device, dtype=dtype)  # move to device, e.g. GPU
            y = y.to(device=device, dtype=torch.long)
            #pdb.set_trace()
            #y = torch.stack(y) #.to(device=device)
            #y = y.reshape((x.shape[0]))
            scores = model(x)
            _, preds = scores.max(1)
            
            num_correct += (preds == y).sum()
            num_samples += preds.size(0)
        acc = float(num_correct) / num_samples
        print('Got %d / %d correct (%.2f)' % (num_correct, num_samples, 100 * acc))
        return acc

# %%
def train_part34(model, optimizer, epochs=1):
    """
    Train a model on CIFAR-10 using the PyTorch Module API.
    
    Inputs:
    - model: A PyTorch Module giving the model to train.
    - optimizer: An Optimizer object we will use to train the model
    - epochs: (Optional) A Python integer giving the number of epochs to train for
    
    Returns: Nothing, but prints model accuracies during training.
    """
    acc = 0
    per_epoch_train_accuracy_list = []
    per_epoch_test_accuracy_list = []
    train_accuracy_list = []
    test_accuracy_list = []
    loss_list = []
    best_model = model = model.to(device=device)  # move the model parameters to CPU/GPU
    for e in range(epochs):
        for t, (x, y) in enumerate(loader_train):
            import pdb
            #pdb.set_trace()
            model.train()  # put model to training mode
            x = x.to(device=device, dtype=dtype)  # move to device, e.g. GPU
            y = y.to(device=device, dtype=torch.long)
            #y = torch.stack(y) #.to(device=device)
            #y = y.reshape((x.shape[0]))
            scores = model(x)
            
            loss = F.cross_entropy(scores, y)
            loss_list.append(loss.item())
            # Zero out all of the gradients for the variables which the optimizer
            # will update.
            optimizer.zero_grad()

            # This is the backwards pass: compute the gradient of the loss with
            # respect to each  parameter of the model.
            loss.backward()

            # Actually update the parameters of the model using the gradients
            # computed by the backwards pass.
            optimizer.step()
            #pdb.set_trace()
            #print("IN ITERATION", t)
            if t % print_every == 0:
                print('Epoch %d, Iteration %d, loss = %.4f' % (e, t, loss.item()))
                #pdb.set_trace()
                xx = x.cpu().data.numpy()
                yy = y.cpu().data.numpy()
                tt_data = []
                for i in range(len(xx)):
                  ind = np.where(keys_array==Y[i]) 
                  tt_data.append([xx[i], yy[i]])
                
                train_d = DataLoader(tt_data, batch_size = 1)
                
                train_acc = check_train_accuracy(train_d, model)
                train_accuracy_list.append(train_acc)
                test_acc = check_accuracy_part34(loader_val, model)
                test_accuracy_list.append(test_acc)
                if test_acc > acc:
                  acc = test_acc
                  best_model = copy.deepcopy(model)
                print()
        
        e_test_accuracy = check_accuracy_part34(loader_val, model)        
        per_epoch_test_accuracy_list.append(e_test_accuracy)     
        e_train_accuracy = check_train_accuracy(loader_train, model)        
        per_epoch_train_accuracy_list.append(e_train_accuracy)     
    return best_model, acc, train_accuracy_list, test_accuracy_list, per_epoch_train_accuracy_list, per_epoch_test_accuracy_list, loss_list

# %%
class Flatten(nn.Module):
    def flatten(x):
        N = x.shape[0] # read in N, C, H, W
        return x.view(N, -1)  # "flatten" the C * H * W values into a single vector per image

    def forward(self, x):
        N = x.shape[0]
        return x.view(N, -1)

class LSTM(nn.Module):
    def __init__(self):
        super().__init__()
        #self.model = nn.LSTM(input_size=(32*25*37),hidden_size=128,num_layers=2,batch_first=True,bidirectional =True, dropout=0.1)
        self.model = nn.RNN(input_size=(32*25*37),hidden_size=128,num_layers=2,batch_first=True,bidirectional =True, dropout=0.1)
    def forward(self, x):

        # From [batches, seqs, seq len, features]
        # to [seq len, batch data, features]
        x = x.unsqueeze(1)
       
        # Data is fed to the LSTM
        out, _ = self.model(x)

        # From [seq len, batch, num_directions * hidden_size]
        # to [batches, seqs, seq_len,prediction]
        out = out.squeeze(1)


        return out

#hidden_layer_size = 500
#learning_rate = 1e-2

#model = nn.Sequential(
#    Flatten(),
#    nn.Linear(3 * 200 * 300, hidden_layer_size),
#    nn.ReLU(),
#    nn.Linear(hidden_layer_size, keys_array.shape[0]),
#)


l1 = nn.Sequential(
            nn.Conv2d(3, 16, kernel_size=(12,16), padding=(6,8), stride=1),
            nn.ReLU(),
            #nn.Conv2d(channel_1, channel_1, kernel_size=5, padding=2, stride=1),
            nn.MaxPool2d(2, 2)
)

#for t, (x, y) in enumerate(loader_train):
#            # put model to training mode
#            x = x.to(device=device, dtype=dtype)
#            import pdb
#            pdb.set_trace()
#            break
    
#pdb.set_trace()
#h = l1(x)
#h.shape

l2 = nn.Sequential(
            nn.Conv2d(16, 24, kernel_size=(8,12), padding=(4,6), stride=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2)
)
#h = l2(h)

#l3 = nn.Sequential(
#            nn.Conv2d(24, 32, kernel_size=(5,7), padding=(2,3), stride=1),
#            nn.ReLU(),
#            nn.MaxPool2d(2, 2),
#            Flatten(),
#            LSTM()           
#)

l3 = nn.Sequential(
            nn.Conv2d(24, 32, kernel_size=(5,7), padding=(2,3), stride=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2)
            
)

#l4 = nn.Sequential(
#            nn.Conv2d(channel_3, channel_4, kernel_size=3, padding=1, stride=1),
#            nn.MaxPool2d(2, 1)
#)

#import pdb
#pdb.set_trace()
hidden_layer_size = keys_array.shape[0]
learning_rate = 1e-4 #1e-4   1e-3 looks gud
'''
model = nn.Sequential(
            l1,
            l2,
            l3,
            nn.Linear(256, 64),
            nn.ReLU(),
            nn.Dropout(p=0.2),
            nn.Linear(64, keys_array.shape[0])
)
'''
model = nn.Sequential(
            l1,
            l2,
            l3,
            Flatten(),
            nn.Linear(32*25*37, 64),
            nn.ReLU(),
            nn.Dropout(p=0.2),
            nn.Linear(64, keys_array.shape[0])
)


# you can use Nesterov momentum in optim.SGD
#optimizer = optim.Adam(model.parameters(), lr=learning_rate,momentum=0.9, nesterov=True)
optimizer = optim.Adam(model.parameters(), lr=learning_rate, 
                     betas=(0.9, 0.999), eps=1e-08, weight_decay=0, amsgrad=False) #weight_decay = 0 luks gud. Trying with 0.1


#best_model, best_test_acc, train_accuracy_list, test_accuracy_list, loss_list = train_part34(model, optimizer, 2)
best_model, best_test_acc, train_accuracy_list, test_accuracy_list, per_epoch_train_accuracy_list, per_epoch_test_accuracy_list, loss_list = train_part34(model, optimizer, 80)
print("DONE TRAINING")
# Out:
# Epoch 0, Iteration 0, loss = 1.3669
# Checking accuracy on TRAIN set
# Got 26 / 64 correct (40.62)
# Checking accuracy on VAL set
# Got 97 / 306 correct (31.70)
#
# Epoch 0, Iteration 1, loss = 1.3626
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 97 / 306 correct (31.70)
#
# Epoch 0, Iteration 2, loss = 1.3603
# Checking accuracy on TRAIN set
# Got 20 / 64 correct (31.25)
# Checking accuracy on VAL set
# Got 97 / 306 correct (31.70)
#
# Epoch 0, Iteration 3, loss = 1.3622
# Checking accuracy on TRAIN set
# Got 21 / 64 correct (32.81)
# Checking accuracy on VAL set
# Got 97 / 306 correct (31.70)
#
# Epoch 0, Iteration 4, loss = 1.3727
# Checking accuracy on TRAIN set
# Got 20 / 64 correct (31.25)
# Checking accuracy on VAL set
# Got 97 / 306 correct (31.70)
#
# Epoch 0, Iteration 5, loss = 1.3692
# Checking accuracy on TRAIN set
# Got 23 / 64 correct (35.94)
# Checking accuracy on VAL set
# Got 97 / 306 correct (31.70)
#
# Epoch 0, Iteration 6, loss = 1.3718
# Checking accuracy on TRAIN set
# Got 17 / 64 correct (26.56)
# Checking accuracy on VAL set
# Got 97 / 306 correct (31.70)
#
# Epoch 0, Iteration 7, loss = 1.3398
# Checking accuracy on TRAIN set
# Got 21 / 64 correct (32.81)
# Checking accuracy on VAL set
# Got 97 / 306 correct (31.70)
#
# Epoch 0, Iteration 8, loss = 1.3330
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 97 / 306 correct (31.70)
#
# Epoch 0, Iteration 9, loss = 1.3825
# Checking accuracy on TRAIN set
# Got 15 / 64 correct (23.44)
# Checking accuracy on VAL set
# Got 97 / 306 correct (31.70)
#
# Epoch 0, Iteration 10, loss = 1.3252
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 80 / 306 correct (26.14)
#
# Epoch 0, Iteration 11, loss = 1.2999
# Checking accuracy on TRAIN set
# Got 23 / 64 correct (35.94)
# Checking accuracy on VAL set
# Got 68 / 306 correct (22.22)
#
# Epoch 0, Iteration 12, loss = 1.3189
# Checking accuracy on TRAIN set
# Got 22 / 64 correct (34.38)
# Checking accuracy on VAL set
# Got 80 / 306 correct (26.14)
#
# Epoch 0, Iteration 13, loss = 1.3220
# Checking accuracy on TRAIN set
# Got 21 / 64 correct (32.81)
# Checking accuracy on VAL set
# Got 80 / 306 correct (26.14)
#
# Epoch 0, Iteration 14, loss = 1.3252
# Checking accuracy on TRAIN set
# Got 14 / 64 correct (21.88)
# Checking accuracy on VAL set
# Got 81 / 306 correct (26.47)
#
# Epoch 0, Iteration 15, loss = 1.3800
# Checking accuracy on TRAIN set
# Got 19 / 64 correct (29.69)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 0, Iteration 16, loss = 1.2294
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 0, Iteration 17, loss = 1.2926
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 0, Iteration 18, loss = 1.2911
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 0, Iteration 19, loss = 1.2027
# Checking accuracy on TRAIN set
# Got 3 / 8 correct (37.50)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
# Checking accuracy on TRAIN set
# Got 488 / 1224 correct (39.87)
# Epoch 1, Iteration 0, loss = 1.3459
# Checking accuracy on TRAIN set
# Got 20 / 64 correct (31.25)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 1, Iteration 1, loss = 1.3228
# Checking accuracy on TRAIN set
# Got 23 / 64 correct (35.94)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 1, Iteration 2, loss = 1.1976
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 1, Iteration 3, loss = 1.2677
# Checking accuracy on TRAIN set
# Got 26 / 64 correct (40.62)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 1, Iteration 4, loss = 1.2866
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 1, Iteration 5, loss = 1.2241
# Checking accuracy on TRAIN set
# Got 25 / 64 correct (39.06)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 1, Iteration 6, loss = 1.2674
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 1, Iteration 7, loss = 1.3072
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 100 / 306 correct (32.68)
#
# Epoch 1, Iteration 8, loss = 1.3183
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 100 / 306 correct (32.68)
#
# Epoch 1, Iteration 9, loss = 1.3053
# Checking accuracy on TRAIN set
# Got 20 / 64 correct (31.25)
# Checking accuracy on VAL set
# Got 100 / 306 correct (32.68)
#
# Epoch 1, Iteration 10, loss = 1.3028
# Checking accuracy on TRAIN set
# Got 25 / 64 correct (39.06)
# Checking accuracy on VAL set
# Got 100 / 306 correct (32.68)
#
# Epoch 1, Iteration 11, loss = 1.2393
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 100 / 306 correct (32.68)
#
# Epoch 1, Iteration 12, loss = 1.2856
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 100 / 306 correct (32.68)
#
# Epoch 1, Iteration 13, loss = 1.3407
# Checking accuracy on TRAIN set
# Got 20 / 64 correct (31.25)
# Checking accuracy on VAL set
# Got 100 / 306 correct (32.68)
#
# Epoch 1, Iteration 14, loss = 1.2535
# Checking accuracy on TRAIN set
# Got 20 / 64 correct (31.25)
# Checking accuracy on VAL set
# Got 100 / 306 correct (32.68)
#
# Epoch 1, Iteration 15, loss = 1.2458
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 1, Iteration 16, loss = 1.2734
# Checking accuracy on TRAIN set
# Got 23 / 64 correct (35.94)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 1, Iteration 17, loss = 1.3054
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 1, Iteration 18, loss = 1.2585
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 1, Iteration 19, loss = 1.2533
# Checking accuracy on TRAIN set
# Got 4 / 8 correct (50.00)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
# Checking accuracy on TRAIN set
# Got 488 / 1224 correct (39.87)
# Epoch 2, Iteration 0, loss = 1.2650
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 2, Iteration 1, loss = 1.2264
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 2, Iteration 2, loss = 1.3512
# Checking accuracy on TRAIN set
# Got 21 / 64 correct (32.81)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 2, Iteration 3, loss = 1.2433
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 2, Iteration 4, loss = 1.2369
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 2, Iteration 5, loss = 1.1939
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 2, Iteration 6, loss = 1.3076
# Checking accuracy on TRAIN set
# Got 22 / 64 correct (34.38)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 2, Iteration 7, loss = 1.3136
# Checking accuracy on TRAIN set
# Got 21 / 64 correct (32.81)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 2, Iteration 8, loss = 1.3373
# Checking accuracy on TRAIN set
# Got 26 / 64 correct (40.62)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 2, Iteration 9, loss = 1.3157
# Checking accuracy on TRAIN set
# Got 23 / 64 correct (35.94)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 2, Iteration 10, loss = 1.2514
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 2, Iteration 11, loss = 1.1369
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 2, Iteration 12, loss = 1.2967
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 118 / 306 correct (38.56)
#
# Epoch 2, Iteration 13, loss = 1.2795
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 100 / 306 correct (32.68)
#
# Epoch 2, Iteration 14, loss = 1.2997
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 100 / 306 correct (32.68)
#
# Epoch 2, Iteration 15, loss = 1.2450
# Checking accuracy on TRAIN set
# Got 23 / 64 correct (35.94)
# Checking accuracy on VAL set
# Got 100 / 306 correct (32.68)
#
# Epoch 2, Iteration 16, loss = 1.1731
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 100 / 306 correct (32.68)
#
# Epoch 2, Iteration 17, loss = 1.2585
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 100 / 306 correct (32.68)
#
# Epoch 2, Iteration 18, loss = 1.3396
# Checking accuracy on TRAIN set
# Got 17 / 64 correct (26.56)
# Checking accuracy on VAL set
# Got 100 / 306 correct (32.68)
#
# Epoch 2, Iteration 19, loss = 1.3911
# Checking accuracy on TRAIN set
# Got 3 / 8 correct (37.50)
# Checking accuracy on VAL set
# Got 100 / 306 correct (32.68)
#
# Checking accuracy on VAL set
# Got 100 / 306 correct (32.68)
# Checking accuracy on TRAIN set
# Got 453 / 1224 correct (37.01)
# Epoch 3, Iteration 0, loss = 1.2335
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 105 / 306 correct (34.31)
#
# Epoch 3, Iteration 1, loss = 1.2533
# Checking accuracy on TRAIN set
# Got 25 / 64 correct (39.06)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 3, Iteration 2, loss = 1.2904
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 3, Iteration 3, loss = 1.2626
# Checking accuracy on TRAIN set
# Got 25 / 64 correct (39.06)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 3, Iteration 4, loss = 1.3011
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 3, Iteration 5, loss = 1.2359
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 3, Iteration 6, loss = 1.2368
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 3, Iteration 7, loss = 1.3073
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 3, Iteration 8, loss = 1.3642
# Checking accuracy on TRAIN set
# Got 16 / 64 correct (25.00)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 3, Iteration 9, loss = 1.2533
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 3, Iteration 10, loss = 1.2484
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 3, Iteration 11, loss = 1.3117
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 3, Iteration 12, loss = 1.3065
# Checking accuracy on TRAIN set
# Got 22 / 64 correct (34.38)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 3, Iteration 13, loss = 1.2195
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 3, Iteration 14, loss = 1.2703
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 3, Iteration 15, loss = 1.1980
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 3, Iteration 16, loss = 1.2155
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 3, Iteration 17, loss = 1.2321
# Checking accuracy on TRAIN set
# Got 25 / 64 correct (39.06)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 3, Iteration 18, loss = 1.2721
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 118 / 306 correct (38.56)
#
# Epoch 3, Iteration 19, loss = 1.7013
# Checking accuracy on TRAIN set
# Got 1 / 8 correct (12.50)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
# Checking accuracy on TRAIN set
# Got 488 / 1224 correct (39.87)
# Epoch 4, Iteration 0, loss = 1.2461
# Checking accuracy on TRAIN set
# Got 23 / 64 correct (35.94)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 4, Iteration 1, loss = 1.2534
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 4, Iteration 2, loss = 1.3435
# Checking accuracy on TRAIN set
# Got 25 / 64 correct (39.06)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 4, Iteration 3, loss = 1.3227
# Checking accuracy on TRAIN set
# Got 26 / 64 correct (40.62)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 4, Iteration 4, loss = 1.2346
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 4, Iteration 5, loss = 1.3317
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 4, Iteration 6, loss = 1.2646
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 4, Iteration 7, loss = 1.3424
# Checking accuracy on TRAIN set
# Got 22 / 64 correct (34.38)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 4, Iteration 8, loss = 1.2261
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 4, Iteration 9, loss = 1.2657
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 4, Iteration 10, loss = 1.2822
# Checking accuracy on TRAIN set
# Got 26 / 64 correct (40.62)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 4, Iteration 11, loss = 1.2906
# Checking accuracy on TRAIN set
# Got 22 / 64 correct (34.38)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 4, Iteration 12, loss = 1.2811
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 105 / 306 correct (34.31)
#
# Epoch 4, Iteration 13, loss = 1.2343
# Checking accuracy on TRAIN set
# Got 26 / 64 correct (40.62)
# Checking accuracy on VAL set
# Got 100 / 306 correct (32.68)
#
# Epoch 4, Iteration 14, loss = 1.3114
# Checking accuracy on TRAIN set
# Got 22 / 64 correct (34.38)
# Checking accuracy on VAL set
# Got 100 / 306 correct (32.68)
#
# Epoch 4, Iteration 15, loss = 1.2517
# Checking accuracy on TRAIN set
# Got 26 / 64 correct (40.62)
# Checking accuracy on VAL set
# Got 100 / 306 correct (32.68)
#
# Epoch 4, Iteration 16, loss = 1.2233
# Checking accuracy on TRAIN set
# Got 21 / 64 correct (32.81)
# Checking accuracy on VAL set
# Got 100 / 306 correct (32.68)
#
# Epoch 4, Iteration 17, loss = 1.2169
# Checking accuracy on TRAIN set
# Got 23 / 64 correct (35.94)
# Checking accuracy on VAL set
# Got 100 / 306 correct (32.68)
#
# Epoch 4, Iteration 18, loss = 1.2520
# Checking accuracy on TRAIN set
# Got 25 / 64 correct (39.06)
# Checking accuracy on VAL set
# Got 100 / 306 correct (32.68)
#
# Epoch 4, Iteration 19, loss = 1.3289
# Checking accuracy on TRAIN set
# Got 3 / 8 correct (37.50)
# Checking accuracy on VAL set
# Got 116 / 306 correct (37.91)
#
# Checking accuracy on VAL set
# Got 116 / 306 correct (37.91)
# Checking accuracy on TRAIN set
# Got 526 / 1224 correct (42.97)
# Epoch 5, Iteration 0, loss = 1.3358
# Checking accuracy on TRAIN set
# Got 23 / 64 correct (35.94)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 5, Iteration 1, loss = 1.1806
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 5, Iteration 2, loss = 1.2387
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 5, Iteration 3, loss = 1.3214
# Checking accuracy on TRAIN set
# Got 25 / 64 correct (39.06)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 5, Iteration 4, loss = 1.1840
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 5, Iteration 5, loss = 1.1792
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 5, Iteration 6, loss = 1.2347
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 5, Iteration 7, loss = 1.2243
# Checking accuracy on TRAIN set
# Got 25 / 64 correct (39.06)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 5, Iteration 8, loss = 1.3467
# Checking accuracy on TRAIN set
# Got 21 / 64 correct (32.81)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 5, Iteration 9, loss = 1.2492
# Checking accuracy on TRAIN set
# Got 23 / 64 correct (35.94)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 5, Iteration 10, loss = 1.4028
# Checking accuracy on TRAIN set
# Got 21 / 64 correct (32.81)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 5, Iteration 11, loss = 1.2617
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 5, Iteration 12, loss = 1.2308
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 5, Iteration 13, loss = 1.2454
# Checking accuracy on TRAIN set
# Got 23 / 64 correct (35.94)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 5, Iteration 14, loss = 1.2987
# Checking accuracy on TRAIN set
# Got 26 / 64 correct (40.62)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 5, Iteration 15, loss = 1.3358
# Checking accuracy on TRAIN set
# Got 21 / 64 correct (32.81)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 5, Iteration 16, loss = 1.3018
# Checking accuracy on TRAIN set
# Got 23 / 64 correct (35.94)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 5, Iteration 17, loss = 1.2207
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 5, Iteration 18, loss = 1.2681
# Checking accuracy on TRAIN set
# Got 23 / 64 correct (35.94)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 5, Iteration 19, loss = 1.1723
# Checking accuracy on TRAIN set
# Got 5 / 8 correct (62.50)
# Checking accuracy on VAL set
# Got 99 / 306 correct (32.35)
#
# Checking accuracy on VAL set
# Got 99 / 306 correct (32.35)
# Checking accuracy on TRAIN set
# Got 458 / 1224 correct (37.42)
# Epoch 6, Iteration 0, loss = 1.3469
# Checking accuracy on TRAIN set
# Got 17 / 64 correct (26.56)
# Checking accuracy on VAL set
# Got 100 / 306 correct (32.68)
#
# Epoch 6, Iteration 1, loss = 1.2852
# Checking accuracy on TRAIN set
# Got 21 / 64 correct (32.81)
# Checking accuracy on VAL set
# Got 100 / 306 correct (32.68)
#
# Epoch 6, Iteration 2, loss = 1.2904
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 100 / 306 correct (32.68)
#
# Epoch 6, Iteration 3, loss = 1.2172
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 100 / 306 correct (32.68)
#
# Epoch 6, Iteration 4, loss = 1.2230
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 100 / 306 correct (32.68)
#
# Epoch 6, Iteration 5, loss = 1.2269
# Checking accuracy on TRAIN set
# Got 25 / 64 correct (39.06)
# Checking accuracy on VAL set
# Got 100 / 306 correct (32.68)
#
# Epoch 6, Iteration 6, loss = 1.2638
# Checking accuracy on TRAIN set
# Got 25 / 64 correct (39.06)
# Checking accuracy on VAL set
# Got 100 / 306 correct (32.68)
#
# Epoch 6, Iteration 7, loss = 1.2737
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 100 / 306 correct (32.68)
#
# Epoch 6, Iteration 8, loss = 1.2805
# Checking accuracy on TRAIN set
# Got 23 / 64 correct (35.94)
# Checking accuracy on VAL set
# Got 100 / 306 correct (32.68)
#
# Epoch 6, Iteration 9, loss = 1.2124
# Checking accuracy on TRAIN set
# Got 25 / 64 correct (39.06)
# Checking accuracy on VAL set
# Got 100 / 306 correct (32.68)
#
# Epoch 6, Iteration 10, loss = 1.2506
# Checking accuracy on TRAIN set
# Got 17 / 64 correct (26.56)
# Checking accuracy on VAL set
# Got 113 / 306 correct (36.93)
#
# Epoch 6, Iteration 11, loss = 1.3411
# Checking accuracy on TRAIN set
# Got 26 / 64 correct (40.62)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 6, Iteration 12, loss = 1.2267
# Checking accuracy on TRAIN set
# Got 22 / 64 correct (34.38)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 6, Iteration 13, loss = 1.3150
# Checking accuracy on TRAIN set
# Got 23 / 64 correct (35.94)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 6, Iteration 14, loss = 1.2406
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 6, Iteration 15, loss = 1.3825
# Checking accuracy on TRAIN set
# Got 20 / 64 correct (31.25)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 6, Iteration 16, loss = 1.1558
# Checking accuracy on TRAIN set
# Got 36 / 64 correct (56.25)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 6, Iteration 17, loss = 1.1565
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 6, Iteration 18, loss = 1.2157
# Checking accuracy on TRAIN set
# Got 22 / 64 correct (34.38)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 6, Iteration 19, loss = 1.2469
# Checking accuracy on TRAIN set
# Got 3 / 8 correct (37.50)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
# Checking accuracy on TRAIN set
# Got 488 / 1224 correct (39.87)
# Epoch 7, Iteration 0, loss = 1.2616
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 7, Iteration 1, loss = 1.3126
# Checking accuracy on TRAIN set
# Got 16 / 64 correct (25.00)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 7, Iteration 2, loss = 1.2861
# Checking accuracy on TRAIN set
# Got 23 / 64 correct (35.94)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 7, Iteration 3, loss = 1.2223
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 115 / 306 correct (37.58)
#
# Epoch 7, Iteration 4, loss = 1.1962
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 128 / 306 correct (41.83)
#
# Epoch 7, Iteration 5, loss = 1.2137
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 120 / 306 correct (39.22)
#
# Epoch 7, Iteration 6, loss = 1.3139
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 114 / 306 correct (37.25)
#
# Epoch 7, Iteration 7, loss = 1.3416
# Checking accuracy on TRAIN set
# Got 23 / 64 correct (35.94)
# Checking accuracy on VAL set
# Got 125 / 306 correct (40.85)
#
# Epoch 7, Iteration 8, loss = 1.2399
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 119 / 306 correct (38.89)
#
# Epoch 7, Iteration 9, loss = 1.2244
# Checking accuracy on TRAIN set
# Got 26 / 64 correct (40.62)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 7, Iteration 10, loss = 1.3458
# Checking accuracy on TRAIN set
# Got 21 / 64 correct (32.81)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 7, Iteration 11, loss = 1.1349
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 7, Iteration 12, loss = 1.3575
# Checking accuracy on TRAIN set
# Got 16 / 64 correct (25.00)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 7, Iteration 13, loss = 1.2432
# Checking accuracy on TRAIN set
# Got 25 / 64 correct (39.06)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 7, Iteration 14, loss = 1.2336
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 7, Iteration 15, loss = 1.3161
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 7, Iteration 16, loss = 1.2084
# Checking accuracy on TRAIN set
# Got 23 / 64 correct (35.94)
# Checking accuracy on VAL set
# Got 118 / 306 correct (38.56)
#
# Epoch 7, Iteration 17, loss = 1.2119
# Checking accuracy on TRAIN set
# Got 25 / 64 correct (39.06)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 7, Iteration 18, loss = 1.2370
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 116 / 306 correct (37.91)
#
# Epoch 7, Iteration 19, loss = 1.2899
# Checking accuracy on TRAIN set
# Got 2 / 8 correct (25.00)
# Checking accuracy on VAL set
# Got 116 / 306 correct (37.91)
#
# Checking accuracy on VAL set
# Got 116 / 306 correct (37.91)
# Checking accuracy on TRAIN set
# Got 522 / 1224 correct (42.65)
# Epoch 8, Iteration 0, loss = 1.1443
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 118 / 306 correct (38.56)
#
# Epoch 8, Iteration 1, loss = 1.2499
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 116 / 306 correct (37.91)
#
# Epoch 8, Iteration 2, loss = 1.2135
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 8, Iteration 3, loss = 1.1672
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 119 / 306 correct (38.89)
#
# Epoch 8, Iteration 4, loss = 1.1842
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 8, Iteration 5, loss = 1.3525
# Checking accuracy on TRAIN set
# Got 20 / 64 correct (31.25)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 8, Iteration 6, loss = 1.2964
# Checking accuracy on TRAIN set
# Got 18 / 64 correct (28.12)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 8, Iteration 7, loss = 1.2691
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 8, Iteration 8, loss = 1.2014
# Checking accuracy on TRAIN set
# Got 26 / 64 correct (40.62)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 8, Iteration 9, loss = 1.1572
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 8, Iteration 10, loss = 1.2565
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 121 / 306 correct (39.54)
#
# Epoch 8, Iteration 11, loss = 1.2397
# Checking accuracy on TRAIN set
# Got 23 / 64 correct (35.94)
# Checking accuracy on VAL set
# Got 123 / 306 correct (40.20)
#
# Epoch 8, Iteration 12, loss = 1.2404
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 118 / 306 correct (38.56)
#
# Epoch 8, Iteration 13, loss = 1.2964
# Checking accuracy on TRAIN set
# Got 26 / 64 correct (40.62)
# Checking accuracy on VAL set
# Got 112 / 306 correct (36.60)
#
# Epoch 8, Iteration 14, loss = 1.3056
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 120 / 306 correct (39.22)
#
# Epoch 8, Iteration 15, loss = 1.3005
# Checking accuracy on TRAIN set
# Got 26 / 64 correct (40.62)
# Checking accuracy on VAL set
# Got 125 / 306 correct (40.85)
#
# Epoch 8, Iteration 16, loss = 1.3170
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 129 / 306 correct (42.16)
#
# Epoch 8, Iteration 17, loss = 1.2786
# Checking accuracy on TRAIN set
# Got 26 / 64 correct (40.62)
# Checking accuracy on VAL set
# Got 131 / 306 correct (42.81)
#
# Epoch 8, Iteration 18, loss = 1.2793
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 129 / 306 correct (42.16)
#
# Epoch 8, Iteration 19, loss = 1.2848
# Checking accuracy on TRAIN set
# Got 3 / 8 correct (37.50)
# Checking accuracy on VAL set
# Got 128 / 306 correct (41.83)
#
# Checking accuracy on VAL set
# Got 128 / 306 correct (41.83)
# Checking accuracy on TRAIN set
# Got 529 / 1224 correct (43.22)
# Epoch 9, Iteration 0, loss = 1.2327
# Checking accuracy on TRAIN set
# Got 25 / 64 correct (39.06)
# Checking accuracy on VAL set
# Got 128 / 306 correct (41.83)
#
# Epoch 9, Iteration 1, loss = 1.2213
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 123 / 306 correct (40.20)
#
# Epoch 9, Iteration 2, loss = 1.2859
# Checking accuracy on TRAIN set
# Got 22 / 64 correct (34.38)
# Checking accuracy on VAL set
# Got 118 / 306 correct (38.56)
#
# Epoch 9, Iteration 3, loss = 1.2915
# Checking accuracy on TRAIN set
# Got 22 / 64 correct (34.38)
# Checking accuracy on VAL set
# Got 118 / 306 correct (38.56)
#
# Epoch 9, Iteration 4, loss = 1.2479
# Checking accuracy on TRAIN set
# Got 23 / 64 correct (35.94)
# Checking accuracy on VAL set
# Got 118 / 306 correct (38.56)
#
# Epoch 9, Iteration 5, loss = 1.2268
# Checking accuracy on TRAIN set
# Got 25 / 64 correct (39.06)
# Checking accuracy on VAL set
# Got 124 / 306 correct (40.52)
#
# Epoch 9, Iteration 6, loss = 1.2838
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 125 / 306 correct (40.85)
#
# Epoch 9, Iteration 7, loss = 1.1488
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 123 / 306 correct (40.20)
#
# Epoch 9, Iteration 8, loss = 1.2814
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 119 / 306 correct (38.89)
#
# Epoch 9, Iteration 9, loss = 1.2378
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 119 / 306 correct (38.89)
#
# Epoch 9, Iteration 10, loss = 1.2245
# Checking accuracy on TRAIN set
# Got 25 / 64 correct (39.06)
# Checking accuracy on VAL set
# Got 120 / 306 correct (39.22)
#
# Epoch 9, Iteration 11, loss = 1.2554
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 127 / 306 correct (41.50)
#
# Epoch 9, Iteration 12, loss = 1.1337
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 124 / 306 correct (40.52)
#
# Epoch 9, Iteration 13, loss = 1.2810
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 122 / 306 correct (39.87)
#
# Epoch 9, Iteration 14, loss = 1.2727
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 119 / 306 correct (38.89)
#
# Epoch 9, Iteration 15, loss = 1.2147
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 121 / 306 correct (39.54)
#
# Epoch 9, Iteration 16, loss = 1.1968
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 120 / 306 correct (39.22)
#
# Epoch 9, Iteration 17, loss = 1.1695
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 115 / 306 correct (37.58)
#
# Epoch 9, Iteration 18, loss = 1.2865
# Checking accuracy on TRAIN set
# Got 26 / 64 correct (40.62)
# Checking accuracy on VAL set
# Got 118 / 306 correct (38.56)
#
# Epoch 9, Iteration 19, loss = 1.2891
# Checking accuracy on TRAIN set
# Got 2 / 8 correct (25.00)
# Checking accuracy on VAL set
# Got 126 / 306 correct (41.18)
#
# Checking accuracy on VAL set
# Got 126 / 306 correct (41.18)
# Checking accuracy on TRAIN set
# Got 525 / 1224 correct (42.89)
# Epoch 10, Iteration 0, loss = 1.1982
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 126 / 306 correct (41.18)
#
# Epoch 10, Iteration 1, loss = 1.1640
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 124 / 306 correct (40.52)
#
# Epoch 10, Iteration 2, loss = 1.1608
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 127 / 306 correct (41.50)
#
# Epoch 10, Iteration 3, loss = 1.1840
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 127 / 306 correct (41.50)
#
# Epoch 10, Iteration 4, loss = 1.3482
# Checking accuracy on TRAIN set
# Got 18 / 64 correct (28.12)
# Checking accuracy on VAL set
# Got 133 / 306 correct (43.46)
#
# Epoch 10, Iteration 5, loss = 1.2250
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 129 / 306 correct (42.16)
#
# Epoch 10, Iteration 6, loss = 1.2504
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 131 / 306 correct (42.81)
#
# Epoch 10, Iteration 7, loss = 1.2888
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 134 / 306 correct (43.79)
#
# Epoch 10, Iteration 8, loss = 1.2777
# Checking accuracy on TRAIN set
# Got 25 / 64 correct (39.06)
# Checking accuracy on VAL set
# Got 129 / 306 correct (42.16)
#
# Epoch 10, Iteration 9, loss = 1.2823
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 133 / 306 correct (43.46)
#
# Epoch 10, Iteration 10, loss = 1.2230
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 129 / 306 correct (42.16)
#
# Epoch 10, Iteration 11, loss = 1.2225
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 126 / 306 correct (41.18)
#
# Epoch 10, Iteration 12, loss = 1.2344
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 125 / 306 correct (40.85)
#
# Epoch 10, Iteration 13, loss = 1.1905
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 127 / 306 correct (41.50)
#
# Epoch 10, Iteration 14, loss = 1.1830
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 126 / 306 correct (41.18)
#
# Epoch 10, Iteration 15, loss = 1.1631
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 130 / 306 correct (42.48)
#
# Epoch 10, Iteration 16, loss = 1.2447
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 133 / 306 correct (43.46)
#
# Epoch 10, Iteration 17, loss = 1.2102
# Checking accuracy on TRAIN set
# Got 26 / 64 correct (40.62)
# Checking accuracy on VAL set
# Got 135 / 306 correct (44.12)
#
# Epoch 10, Iteration 18, loss = 1.1743
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 139 / 306 correct (45.42)
#
# Epoch 10, Iteration 19, loss = 1.2675
# Checking accuracy on TRAIN set
# Got 5 / 8 correct (62.50)
# Checking accuracy on VAL set
# Got 136 / 306 correct (44.44)
#
# Checking accuracy on VAL set
# Got 136 / 306 correct (44.44)
# Checking accuracy on TRAIN set
# Got 559 / 1224 correct (45.67)
# Epoch 11, Iteration 0, loss = 1.1987
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 133 / 306 correct (43.46)
#
# Epoch 11, Iteration 1, loss = 1.1191
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 132 / 306 correct (43.14)
#
# Epoch 11, Iteration 2, loss = 1.2215
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 131 / 306 correct (42.81)
#
# Epoch 11, Iteration 3, loss = 1.2940
# Checking accuracy on TRAIN set
# Got 26 / 64 correct (40.62)
# Checking accuracy on VAL set
# Got 133 / 306 correct (43.46)
#
# Epoch 11, Iteration 4, loss = 1.2204
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 136 / 306 correct (44.44)
#
# Epoch 11, Iteration 5, loss = 1.2604
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 139 / 306 correct (45.42)
#
# Epoch 11, Iteration 6, loss = 1.1443
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 137 / 306 correct (44.77)
#
# Epoch 11, Iteration 7, loss = 1.3332
# Checking accuracy on TRAIN set
# Got 20 / 64 correct (31.25)
# Checking accuracy on VAL set
# Got 137 / 306 correct (44.77)
#
# Epoch 11, Iteration 8, loss = 1.2696
# Checking accuracy on TRAIN set
# Got 23 / 64 correct (35.94)
# Checking accuracy on VAL set
# Got 138 / 306 correct (45.10)
#
# Epoch 11, Iteration 9, loss = 1.2708
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 131 / 306 correct (42.81)
#
# Epoch 11, Iteration 10, loss = 1.0347
# Checking accuracy on TRAIN set
# Got 44 / 64 correct (68.75)
# Checking accuracy on VAL set
# Got 122 / 306 correct (39.87)
#
# Epoch 11, Iteration 11, loss = 1.0441
# Checking accuracy on TRAIN set
# Got 36 / 64 correct (56.25)
# Checking accuracy on VAL set
# Got 121 / 306 correct (39.54)
#
# Epoch 11, Iteration 12, loss = 1.3307
# Checking accuracy on TRAIN set
# Got 18 / 64 correct (28.12)
# Checking accuracy on VAL set
# Got 132 / 306 correct (43.14)
#
# Epoch 11, Iteration 13, loss = 1.2187
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 134 / 306 correct (43.79)
#
# Epoch 11, Iteration 14, loss = 1.1315
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 132 / 306 correct (43.14)
#
# Epoch 11, Iteration 15, loss = 1.1284
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 131 / 306 correct (42.81)
#
# Epoch 11, Iteration 16, loss = 1.1967
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 133 / 306 correct (43.46)
#
# Epoch 11, Iteration 17, loss = 1.3097
# Checking accuracy on TRAIN set
# Got 20 / 64 correct (31.25)
# Checking accuracy on VAL set
# Got 134 / 306 correct (43.79)
#
# Epoch 11, Iteration 18, loss = 1.2389
# Checking accuracy on TRAIN set
# Got 25 / 64 correct (39.06)
# Checking accuracy on VAL set
# Got 133 / 306 correct (43.46)
#
# Epoch 11, Iteration 19, loss = 1.3233
# Checking accuracy on TRAIN set
# Got 4 / 8 correct (50.00)
# Checking accuracy on VAL set
# Got 131 / 306 correct (42.81)
#
# Checking accuracy on VAL set
# Got 131 / 306 correct (42.81)
# Checking accuracy on TRAIN set
# Got 485 / 1224 correct (39.62)
# Epoch 12, Iteration 0, loss = 1.2555
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 134 / 306 correct (43.79)
#
# Epoch 12, Iteration 1, loss = 1.2539
# Checking accuracy on TRAIN set
# Got 26 / 64 correct (40.62)
# Checking accuracy on VAL set
# Got 136 / 306 correct (44.44)
#
# Epoch 12, Iteration 2, loss = 1.0825
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 139 / 306 correct (45.42)
#
# Epoch 12, Iteration 3, loss = 1.1537
# Checking accuracy on TRAIN set
# Got 25 / 64 correct (39.06)
# Checking accuracy on VAL set
# Got 135 / 306 correct (44.12)
#
# Epoch 12, Iteration 4, loss = 1.2324
# Checking accuracy on TRAIN set
# Got 25 / 64 correct (39.06)
# Checking accuracy on VAL set
# Got 140 / 306 correct (45.75)
#
# Epoch 12, Iteration 5, loss = 1.0764
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 148 / 306 correct (48.37)
#
# Epoch 12, Iteration 6, loss = 1.2494
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 145 / 306 correct (47.39)
#
# Epoch 12, Iteration 7, loss = 1.1676
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 144 / 306 correct (47.06)
#
# Epoch 12, Iteration 8, loss = 1.1691
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 140 / 306 correct (45.75)
#
# Epoch 12, Iteration 9, loss = 1.2319
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 129 / 306 correct (42.16)
#
# Epoch 12, Iteration 10, loss = 1.2657
# Checking accuracy on TRAIN set
# Got 23 / 64 correct (35.94)
# Checking accuracy on VAL set
# Got 123 / 306 correct (40.20)
#
# Epoch 12, Iteration 11, loss = 1.2295
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 132 / 306 correct (43.14)
#
# Epoch 12, Iteration 12, loss = 1.1214
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 136 / 306 correct (44.44)
#
# Epoch 12, Iteration 13, loss = 1.1738
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 136 / 306 correct (44.44)
#
# Epoch 12, Iteration 14, loss = 1.2878
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 136 / 306 correct (44.44)
#
# Epoch 12, Iteration 15, loss = 1.2730
# Checking accuracy on TRAIN set
# Got 21 / 64 correct (32.81)
# Checking accuracy on VAL set
# Got 138 / 306 correct (45.10)
#
# Epoch 12, Iteration 16, loss = 1.1852
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 142 / 306 correct (46.41)
#
# Epoch 12, Iteration 17, loss = 1.2836
# Checking accuracy on TRAIN set
# Got 26 / 64 correct (40.62)
# Checking accuracy on VAL set
# Got 142 / 306 correct (46.41)
#
# Epoch 12, Iteration 18, loss = 1.1538
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 142 / 306 correct (46.41)
#
# Epoch 12, Iteration 19, loss = 1.6581
# Checking accuracy on TRAIN set
# Got 2 / 8 correct (25.00)
# Checking accuracy on VAL set
# Got 127 / 306 correct (41.50)
#
# Checking accuracy on VAL set
# Got 127 / 306 correct (41.50)
# Checking accuracy on TRAIN set
# Got 577 / 1224 correct (47.14)
# Epoch 13, Iteration 0, loss = 1.1342
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 123 / 306 correct (40.20)
#
# Epoch 13, Iteration 1, loss = 1.2524
# Checking accuracy on TRAIN set
# Got 21 / 64 correct (32.81)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 13, Iteration 2, loss = 1.2963
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 123 / 306 correct (40.20)
#
# Epoch 13, Iteration 3, loss = 1.2284
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 132 / 306 correct (43.14)
#
# Epoch 13, Iteration 4, loss = 1.2798
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 148 / 306 correct (48.37)
#
# Epoch 13, Iteration 5, loss = 1.2188
# Checking accuracy on TRAIN set
# Got 19 / 64 correct (29.69)
# Checking accuracy on VAL set
# Got 132 / 306 correct (43.14)
#
# Epoch 13, Iteration 6, loss = 1.2111
# Checking accuracy on TRAIN set
# Got 22 / 64 correct (34.38)
# Checking accuracy on VAL set
# Got 123 / 306 correct (40.20)
#
# Epoch 13, Iteration 7, loss = 1.2314
# Checking accuracy on TRAIN set
# Got 26 / 64 correct (40.62)
# Checking accuracy on VAL set
# Got 127 / 306 correct (41.50)
#
# Epoch 13, Iteration 8, loss = 1.3935
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 123 / 306 correct (40.20)
#
# Epoch 13, Iteration 9, loss = 1.2316
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 13, Iteration 10, loss = 1.2769
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 118 / 306 correct (38.56)
#
# Epoch 13, Iteration 11, loss = 1.2518
# Checking accuracy on TRAIN set
# Got 20 / 64 correct (31.25)
# Checking accuracy on VAL set
# Got 120 / 306 correct (39.22)
#
# Epoch 13, Iteration 12, loss = 1.1617
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 120 / 306 correct (39.22)
#
# Epoch 13, Iteration 13, loss = 1.2297
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 120 / 306 correct (39.22)
#
# Epoch 13, Iteration 14, loss = 1.1805
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 120 / 306 correct (39.22)
#
# Epoch 13, Iteration 15, loss = 1.2397
# Checking accuracy on TRAIN set
# Got 26 / 64 correct (40.62)
# Checking accuracy on VAL set
# Got 122 / 306 correct (39.87)
#
# Epoch 13, Iteration 16, loss = 1.2580
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 125 / 306 correct (40.85)
#
# Epoch 13, Iteration 17, loss = 1.1414
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 123 / 306 correct (40.20)
#
# Epoch 13, Iteration 18, loss = 1.2000
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 125 / 306 correct (40.85)
#
# Epoch 13, Iteration 19, loss = 1.2887
# Checking accuracy on TRAIN set
# Got 2 / 8 correct (25.00)
# Checking accuracy on VAL set
# Got 127 / 306 correct (41.50)
#
# Checking accuracy on VAL set
# Got 127 / 306 correct (41.50)
# Checking accuracy on TRAIN set
# Got 536 / 1224 correct (43.79)
# Epoch 14, Iteration 0, loss = 1.1870
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 128 / 306 correct (41.83)
#
# Epoch 14, Iteration 1, loss = 1.1682
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 129 / 306 correct (42.16)
#
# Epoch 14, Iteration 2, loss = 1.1649
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 133 / 306 correct (43.46)
#
# Epoch 14, Iteration 3, loss = 1.2575
# Checking accuracy on TRAIN set
# Got 26 / 64 correct (40.62)
# Checking accuracy on VAL set
# Got 140 / 306 correct (45.75)
#
# Epoch 14, Iteration 4, loss = 1.1217
# Checking accuracy on TRAIN set
# Got 36 / 64 correct (56.25)
# Checking accuracy on VAL set
# Got 139 / 306 correct (45.42)
#
# Epoch 14, Iteration 5, loss = 1.1752
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 136 / 306 correct (44.44)
#
# Epoch 14, Iteration 6, loss = 1.1064
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 125 / 306 correct (40.85)
#
# Epoch 14, Iteration 7, loss = 1.2378
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 126 / 306 correct (41.18)
#
# Epoch 14, Iteration 8, loss = 1.2258
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 133 / 306 correct (43.46)
#
# Epoch 14, Iteration 9, loss = 1.4892
# Checking accuracy on TRAIN set
# Got 19 / 64 correct (29.69)
# Checking accuracy on VAL set
# Got 139 / 306 correct (45.42)
#
# Epoch 14, Iteration 10, loss = 1.1768
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 140 / 306 correct (45.75)
#
# Epoch 14, Iteration 11, loss = 1.0653
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 142 / 306 correct (46.41)
#
# Epoch 14, Iteration 12, loss = 1.1916
# Checking accuracy on TRAIN set
# Got 25 / 64 correct (39.06)
# Checking accuracy on VAL set
# Got 142 / 306 correct (46.41)
#
# Epoch 14, Iteration 13, loss = 1.3255
# Checking accuracy on TRAIN set
# Got 20 / 64 correct (31.25)
# Checking accuracy on VAL set
# Got 146 / 306 correct (47.71)
#
# Epoch 14, Iteration 14, loss = 1.1367
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 142 / 306 correct (46.41)
#
# Epoch 14, Iteration 15, loss = 1.1482
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 136 / 306 correct (44.44)
#
# Epoch 14, Iteration 16, loss = 1.2287
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 135 / 306 correct (44.12)
#
# Epoch 14, Iteration 17, loss = 1.1684
# Checking accuracy on TRAIN set
# ...
# Got 161 / 306 correct (52.61)
#
# Epoch 75, Iteration 2, loss = 0.8901
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 156 / 306 correct (50.98)
#
# Epoch 75, Iteration 3, loss = 0.8979
# Checking accuracy on TRAIN set
# Got 46 / 64 correct (71.88)
# Checking accuracy on VAL set
# Got 160 / 306 correct (52.29)
#
# Epoch 75, Iteration 4, loss = 0.8824
# Checking accuracy on TRAIN set
# Got 38 / 64 correct (59.38)
# Checking accuracy on VAL set
# Got 155 / 306 correct (50.65)
#
# Epoch 75, Iteration 5, loss = 0.8008
# Checking accuracy on TRAIN set
# Got 42 / 64 correct (65.62)
# Checking accuracy on VAL set
# Got 155 / 306 correct (50.65)
#
# Epoch 75, Iteration 6, loss = 0.9394
# Checking accuracy on TRAIN set
# Got 40 / 64 correct (62.50)
# Checking accuracy on VAL set
# Got 154 / 306 correct (50.33)
#
# Epoch 75, Iteration 7, loss = 0.9231
# Checking accuracy on TRAIN set
# Got 41 / 64 correct (64.06)
# Checking accuracy on VAL set
# Got 153 / 306 correct (50.00)
#
# Epoch 75, Iteration 8, loss = 0.8725
# Checking accuracy on TRAIN set
# Got 44 / 64 correct (68.75)
# Checking accuracy on VAL set
# Got 151 / 306 correct (49.35)
#
# Epoch 75, Iteration 9, loss = 0.8355
# Checking accuracy on TRAIN set
# Got 43 / 64 correct (67.19)
# Checking accuracy on VAL set
# Got 151 / 306 correct (49.35)
#
# Epoch 75, Iteration 10, loss = 0.7059
# Checking accuracy on TRAIN set
# Got 50 / 64 correct (78.12)
# Checking accuracy on VAL set
# Got 149 / 306 correct (48.69)
#
# Epoch 75, Iteration 11, loss = 0.8417
# Checking accuracy on TRAIN set
# Got 45 / 64 correct (70.31)
# Checking accuracy on VAL set
# Got 150 / 306 correct (49.02)
#
# Epoch 75, Iteration 12, loss = 0.7724
# Checking accuracy on TRAIN set
# Got 46 / 64 correct (71.88)
# Checking accuracy on VAL set
# Got 151 / 306 correct (49.35)
#
# Epoch 75, Iteration 13, loss = 1.1091
# Checking accuracy on TRAIN set
# Got 40 / 64 correct (62.50)
# Checking accuracy on VAL set
# Got 153 / 306 correct (50.00)
#
# Epoch 75, Iteration 14, loss = 0.9006
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 153 / 306 correct (50.00)
#
# Epoch 75, Iteration 15, loss = 0.7238
# Checking accuracy on TRAIN set
# Got 48 / 64 correct (75.00)
# Checking accuracy on VAL set
# Got 156 / 306 correct (50.98)
#
# Epoch 75, Iteration 16, loss = 0.8320
# Checking accuracy on TRAIN set
# Got 43 / 64 correct (67.19)
# Checking accuracy on VAL set
# Got 156 / 306 correct (50.98)
#
# Epoch 75, Iteration 17, loss = 0.7735
# Checking accuracy on TRAIN set
# Got 44 / 64 correct (68.75)
# Checking accuracy on VAL set
# Got 156 / 306 correct (50.98)
#
# Epoch 75, Iteration 18, loss = 0.8776
# Checking accuracy on TRAIN set
# Got 39 / 64 correct (60.94)
# Checking accuracy on VAL set
# Got 150 / 306 correct (49.02)
#
# Epoch 75, Iteration 19, loss = 0.5541
# Checking accuracy on TRAIN set
# Got 6 / 8 correct (75.00)
# Checking accuracy on VAL set
# Got 153 / 306 correct (50.00)
#
# Checking accuracy on VAL set
# Got 153 / 306 correct (50.00)
# Checking accuracy on TRAIN set
# Got 839 / 1224 correct (68.55)
# Epoch 76, Iteration 0, loss = 0.7728
# Checking accuracy on TRAIN set
# Got 48 / 64 correct (75.00)
# Checking accuracy on VAL set
# Got 154 / 306 correct (50.33)
#
# Epoch 76, Iteration 1, loss = 0.7945
# Checking accuracy on TRAIN set
# Got 46 / 64 correct (71.88)
# Checking accuracy on VAL set
# Got 155 / 306 correct (50.65)
#
# Epoch 76, Iteration 2, loss = 0.8563
# Checking accuracy on TRAIN set
# Got 41 / 64 correct (64.06)
# Checking accuracy on VAL set
# Got 156 / 306 correct (50.98)
#
# Epoch 76, Iteration 3, loss = 0.9650
# Checking accuracy on TRAIN set
# Got 40 / 64 correct (62.50)
# Checking accuracy on VAL set
# Got 157 / 306 correct (51.31)
#
# Epoch 76, Iteration 4, loss = 0.8202
# Checking accuracy on TRAIN set
# Got 46 / 64 correct (71.88)
# Checking accuracy on VAL set
# Got 161 / 306 correct (52.61)
#
# Epoch 76, Iteration 5, loss = 0.8742
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 163 / 306 correct (53.27)
#
# Epoch 76, Iteration 6, loss = 0.9558
# Checking accuracy on TRAIN set
# Got 39 / 64 correct (60.94)
# Checking accuracy on VAL set
# Got 166 / 306 correct (54.25)
#
# Epoch 76, Iteration 7, loss = 0.8727
# Checking accuracy on TRAIN set
# Got 44 / 64 correct (68.75)
# Checking accuracy on VAL set
# Got 163 / 306 correct (53.27)
#
# Epoch 76, Iteration 8, loss = 0.6950
# Checking accuracy on TRAIN set
# Got 48 / 64 correct (75.00)
# Checking accuracy on VAL set
# Got 160 / 306 correct (52.29)
#
# Epoch 76, Iteration 9, loss = 0.8702
# Checking accuracy on TRAIN set
# Got 47 / 64 correct (73.44)
# Checking accuracy on VAL set
# Got 161 / 306 correct (52.61)
#
# Epoch 76, Iteration 10, loss = 0.8157
# Checking accuracy on TRAIN set
# Got 45 / 64 correct (70.31)
# Checking accuracy on VAL set
# Got 159 / 306 correct (51.96)
#
# Epoch 76, Iteration 11, loss = 0.9236
# Checking accuracy on TRAIN set
# Got 40 / 64 correct (62.50)
# Checking accuracy on VAL set
# Got 158 / 306 correct (51.63)
#
# Epoch 76, Iteration 12, loss = 0.7270
# Checking accuracy on TRAIN set
# Got 47 / 64 correct (73.44)
# Checking accuracy on VAL set
# Got 157 / 306 correct (51.31)
#
# Epoch 76, Iteration 13, loss = 0.8049
# Checking accuracy on TRAIN set
# Got 45 / 64 correct (70.31)
# Checking accuracy on VAL set
# Got 157 / 306 correct (51.31)
#
# Epoch 76, Iteration 14, loss = 0.8418
# Checking accuracy on TRAIN set
# Got 41 / 64 correct (64.06)
# Checking accuracy on VAL set
# Got 155 / 306 correct (50.65)
#
# Epoch 76, Iteration 15, loss = 0.8086
# Checking accuracy on TRAIN set
# Got 48 / 64 correct (75.00)
# Checking accuracy on VAL set
# Got 154 / 306 correct (50.33)
#
# Epoch 76, Iteration 16, loss = 0.8653
# Checking accuracy on TRAIN set
# Got 42 / 64 correct (65.62)
# Checking accuracy on VAL set
# Got 154 / 306 correct (50.33)
#
# Epoch 76, Iteration 17, loss = 0.8207
# Checking accuracy on TRAIN set
# Got 44 / 64 correct (68.75)
# Checking accuracy on VAL set
# Got 152 / 306 correct (49.67)
#
# Epoch 76, Iteration 18, loss = 0.7290
# Checking accuracy on TRAIN set
# Got 46 / 64 correct (71.88)
# Checking accuracy on VAL set
# Got 155 / 306 correct (50.65)
#
# Epoch 76, Iteration 19, loss = 0.6263
# Checking accuracy on TRAIN set
# Got 6 / 8 correct (75.00)
# Checking accuracy on VAL set
# Got 160 / 306 correct (52.29)
#
# Checking accuracy on VAL set
# Got 160 / 306 correct (52.29)
# Checking accuracy on TRAIN set
# Got 844 / 1224 correct (68.95)
# Epoch 77, Iteration 0, loss = 0.8562
# Checking accuracy on TRAIN set
# Got 40 / 64 correct (62.50)
# Checking accuracy on VAL set
# Got 155 / 306 correct (50.65)
#
# Epoch 77, Iteration 1, loss = 1.0002
# Checking accuracy on TRAIN set
# Got 41 / 64 correct (64.06)
# Checking accuracy on VAL set
# Got 152 / 306 correct (49.67)
#
# Epoch 77, Iteration 2, loss = 0.8455
# Checking accuracy on TRAIN set
# Got 39 / 64 correct (60.94)
# Checking accuracy on VAL set
# Got 150 / 306 correct (49.02)
#
# Epoch 77, Iteration 3, loss = 1.0297
# Checking accuracy on TRAIN set
# Got 35 / 64 correct (54.69)
# Checking accuracy on VAL set
# Got 155 / 306 correct (50.65)
#
# Epoch 77, Iteration 4, loss = 0.8625
# Checking accuracy on TRAIN set
# Got 41 / 64 correct (64.06)
# Checking accuracy on VAL set
# Got 157 / 306 correct (51.31)
#
# Epoch 77, Iteration 5, loss = 0.7706
# Checking accuracy on TRAIN set
# Got 48 / 64 correct (75.00)
# Checking accuracy on VAL set
# Got 157 / 306 correct (51.31)
#
# Epoch 77, Iteration 6, loss = 0.7621
# Checking accuracy on TRAIN set
# Got 43 / 64 correct (67.19)
# Checking accuracy on VAL set
# Got 155 / 306 correct (50.65)
#
# Epoch 77, Iteration 7, loss = 0.6881
# Checking accuracy on TRAIN set
# Got 47 / 64 correct (73.44)
# Checking accuracy on VAL set
# Got 149 / 306 correct (48.69)
#
# Epoch 77, Iteration 8, loss = 0.8530
# Checking accuracy on TRAIN set
# Got 42 / 64 correct (65.62)
# Checking accuracy on VAL set
# Got 149 / 306 correct (48.69)
#
# Epoch 77, Iteration 9, loss = 0.8480
# Checking accuracy on TRAIN set
# Got 42 / 64 correct (65.62)
# Checking accuracy on VAL set
# Got 148 / 306 correct (48.37)
#
# Epoch 77, Iteration 10, loss = 0.8240
# Checking accuracy on TRAIN set
# Got 47 / 64 correct (73.44)
# Checking accuracy on VAL set
# Got 147 / 306 correct (48.04)
#
# Epoch 77, Iteration 11, loss = 0.7176
# Checking accuracy on TRAIN set
# Got 44 / 64 correct (68.75)
# Checking accuracy on VAL set
# Got 147 / 306 correct (48.04)
#
# Epoch 77, Iteration 12, loss = 1.0255
# Checking accuracy on TRAIN set
# Got 40 / 64 correct (62.50)
# Checking accuracy on VAL set
# Got 143 / 306 correct (46.73)
#
# Epoch 77, Iteration 13, loss = 0.9281
# Checking accuracy on TRAIN set
# Got 42 / 64 correct (65.62)
# Checking accuracy on VAL set
# Got 149 / 306 correct (48.69)
#
# Epoch 77, Iteration 14, loss = 0.8119
# Checking accuracy on TRAIN set
# Got 50 / 64 correct (78.12)
# Checking accuracy on VAL set
# Got 153 / 306 correct (50.00)
#
# Epoch 77, Iteration 15, loss = 0.8117
# Checking accuracy on TRAIN set
# Got 45 / 64 correct (70.31)
# Checking accuracy on VAL set
# Got 158 / 306 correct (51.63)
#
# Epoch 77, Iteration 16, loss = 0.9131
# Checking accuracy on TRAIN set
# Got 41 / 64 correct (64.06)
# Checking accuracy on VAL set
# Got 161 / 306 correct (52.61)
#
# Epoch 77, Iteration 17, loss = 0.7943
# Checking accuracy on TRAIN set
# Got 39 / 64 correct (60.94)
# Checking accuracy on VAL set
# Got 159 / 306 correct (51.96)
#
# Epoch 77, Iteration 18, loss = 0.8490
# Checking accuracy on TRAIN set
# Got 44 / 64 correct (68.75)
# Checking accuracy on VAL set
# Got 159 / 306 correct (51.96)
#
# Epoch 77, Iteration 19, loss = 0.3417
# Checking accuracy on TRAIN set
# Got 8 / 8 correct (100.00)
# Checking accuracy on VAL set
# Got 162 / 306 correct (52.94)
#
# Checking accuracy on VAL set
# Got 162 / 306 correct (52.94)
# Checking accuracy on TRAIN set
# Got 812 / 1224 correct (66.34)
# Epoch 78, Iteration 0, loss = 0.7848
# Checking accuracy on TRAIN set
# Got 46 / 64 correct (71.88)
# Checking accuracy on VAL set
# Got 159 / 306 correct (51.96)
#
# Epoch 78, Iteration 1, loss = 0.9319
# Checking accuracy on TRAIN set
# Got 41 / 64 correct (64.06)
# Checking accuracy on VAL set
# Got 159 / 306 correct (51.96)
#
# Epoch 78, Iteration 2, loss = 0.8464
# Checking accuracy on TRAIN set
# Got 40 / 64 correct (62.50)
# Checking accuracy on VAL set
# Got 159 / 306 correct (51.96)
#
# Epoch 78, Iteration 3, loss = 1.0075
# Checking accuracy on TRAIN set
# Got 36 / 64 correct (56.25)
# Checking accuracy on VAL set
# Got 152 / 306 correct (49.67)
#
# Epoch 78, Iteration 4, loss = 0.7917
# Checking accuracy on TRAIN set
# Got 47 / 64 correct (73.44)
# Checking accuracy on VAL set
# Got 149 / 306 correct (48.69)
#
# Epoch 78, Iteration 5, loss = 0.8711
# Checking accuracy on TRAIN set
# Got 35 / 64 correct (54.69)
# Checking accuracy on VAL set
# Got 150 / 306 correct (49.02)
#
# Epoch 78, Iteration 6, loss = 1.0410
# Checking accuracy on TRAIN set
# Got 38 / 64 correct (59.38)
# Checking accuracy on VAL set
# Got 148 / 306 correct (48.37)
#
# Epoch 78, Iteration 7, loss = 0.7621
# Checking accuracy on TRAIN set
# Got 43 / 64 correct (67.19)
# Checking accuracy on VAL set
# Got 152 / 306 correct (49.67)
#
# Epoch 78, Iteration 8, loss = 0.7936
# Checking accuracy on TRAIN set
# Got 48 / 64 correct (75.00)
# Checking accuracy on VAL set
# Got 154 / 306 correct (50.33)
#
# Epoch 78, Iteration 9, loss = 0.6858
# Checking accuracy on TRAIN set
# Got 52 / 64 correct (81.25)
# Checking accuracy on VAL set
# Got 155 / 306 correct (50.65)
#
# Epoch 78, Iteration 10, loss = 0.8459
# Checking accuracy on TRAIN set
# Got 42 / 64 correct (65.62)
# Checking accuracy on VAL set
# Got 160 / 306 correct (52.29)
#
# Epoch 78, Iteration 11, loss = 1.0315
# Checking accuracy on TRAIN set
# Got 35 / 64 correct (54.69)
# Checking accuracy on VAL set
# Got 159 / 306 correct (51.96)
#
# Epoch 78, Iteration 12, loss = 0.7344
# Checking accuracy on TRAIN set
# Got 47 / 64 correct (73.44)
# Checking accuracy on VAL set
# Got 155 / 306 correct (50.65)
#
# Epoch 78, Iteration 13, loss = 0.7692
# Checking accuracy on TRAIN set
# Got 46 / 64 correct (71.88)
# Checking accuracy on VAL set
# Got 155 / 306 correct (50.65)
#
# Epoch 78, Iteration 14, loss = 0.7914
# Checking accuracy on TRAIN set
# Got 49 / 64 correct (76.56)
# Checking accuracy on VAL set
# Got 155 / 306 correct (50.65)
#
# Epoch 78, Iteration 15, loss = 0.7630
# Checking accuracy on TRAIN set
# Got 43 / 64 correct (67.19)
# Checking accuracy on VAL set
# Got 156 / 306 correct (50.98)
#
# Epoch 78, Iteration 16, loss = 0.7137
# Checking accuracy on TRAIN set
# Got 47 / 64 correct (73.44)
# Checking accuracy on VAL set
# Got 157 / 306 correct (51.31)
#
# Epoch 78, Iteration 17, loss = 0.7930
# Checking accuracy on TRAIN set
# Got 43 / 64 correct (67.19)
# Checking accuracy on VAL set
# Got 157 / 306 correct (51.31)
#
# Epoch 78, Iteration 18, loss = 0.7731
# Checking accuracy on TRAIN set
# Got 44 / 64 correct (68.75)
# Checking accuracy on VAL set
# Got 155 / 306 correct (50.65)
#
# Epoch 78, Iteration 19, loss = 0.9749
# Checking accuracy on TRAIN set
# Got 6 / 8 correct (75.00)
# Checking accuracy on VAL set
# Got 150 / 306 correct (49.02)
#
# Checking accuracy on VAL set
# Got 150 / 306 correct (49.02)
# Checking accuracy on TRAIN set
# Got 830 / 1224 correct (67.81)
# Epoch 79, Iteration 0, loss = 0.7155
# Checking accuracy on TRAIN set
# Got 48 / 64 correct (75.00)
# Checking accuracy on VAL set
# Got 156 / 306 correct (50.98)
#
# Epoch 79, Iteration 1, loss = 0.7884
# Checking accuracy on TRAIN set
# Got 39 / 64 correct (60.94)
# Checking accuracy on VAL set
# Got 156 / 306 correct (50.98)
#
# Epoch 79, Iteration 2, loss = 0.8280
# Checking accuracy on TRAIN set
# Got 44 / 64 correct (68.75)
# Checking accuracy on VAL set
# Got 157 / 306 correct (51.31)
#
# Epoch 79, Iteration 3, loss = 0.7913
# Checking accuracy on TRAIN set
# Got 47 / 64 correct (73.44)
# Checking accuracy on VAL set
# Got 157 / 306 correct (51.31)
#
# Epoch 79, Iteration 4, loss = 0.8460
# Checking accuracy on TRAIN set
# Got 44 / 64 correct (68.75)
# Checking accuracy on VAL set
# Got 162 / 306 correct (52.94)
#
# Epoch 79, Iteration 5, loss = 0.7682
# Checking accuracy on TRAIN set
# Got 44 / 64 correct (68.75)
# Checking accuracy on VAL set
# Got 168 / 306 correct (54.90)
#
# Epoch 79, Iteration 6, loss = 0.7035
# Checking accuracy on TRAIN set
# Got 51 / 64 correct (79.69)
# Checking accuracy on VAL set
# Got 159 / 306 correct (51.96)
#
# Epoch 79, Iteration 7, loss = 0.8982
# Checking accuracy on TRAIN set
# Got 43 / 64 correct (67.19)
# Checking accuracy on VAL set
# Got 158 / 306 correct (51.63)
#
# Epoch 79, Iteration 8, loss = 0.8688
# Checking accuracy on TRAIN set
# Got 41 / 64 correct (64.06)
# Checking accuracy on VAL set
# Got 161 / 306 correct (52.61)
#
# Epoch 79, Iteration 9, loss = 0.7952
# Checking accuracy on TRAIN set
# Got 44 / 64 correct (68.75)
# Checking accuracy on VAL set
# Got 161 / 306 correct (52.61)
#
# Epoch 79, Iteration 10, loss = 0.8523
# Checking accuracy on TRAIN set
# Got 40 / 64 correct (62.50)
# Checking accuracy on VAL set
# Got 158 / 306 correct (51.63)
#
# Epoch 79, Iteration 11, loss = 0.7829
# Checking accuracy on TRAIN set
# Got 46 / 64 correct (71.88)
# Checking accuracy on VAL set
# Got 163 / 306 correct (53.27)
#
# Epoch 79, Iteration 12, loss = 0.8513
# Checking accuracy on TRAIN set
# Got 42 / 64 correct (65.62)
# Checking accuracy on VAL set
# Got 157 / 306 correct (51.31)
#
# Epoch 79, Iteration 13, loss = 0.8042
# Checking accuracy on TRAIN set
# Got 44 / 64 correct (68.75)
# Checking accuracy on VAL set
# Got 157 / 306 correct (51.31)
#
# Epoch 79, Iteration 14, loss = 0.8805
# Checking accuracy on TRAIN set
# Got 43 / 64 correct (67.19)
# Checking accuracy on VAL set
# Got 160 / 306 correct (52.29)
#
# Epoch 79, Iteration 15, loss = 0.8619
# Checking accuracy on TRAIN set
# Got 40 / 64 correct (62.50)
# Checking accuracy on VAL set
# Got 162 / 306 correct (52.94)
#
# Epoch 79, Iteration 16, loss = 0.8975
# Checking accuracy on TRAIN set
# Got 42 / 64 correct (65.62)
# Checking accuracy on VAL set
# Got 160 / 306 correct (52.29)
#
# Epoch 79, Iteration 17, loss = 0.6800
# Checking accuracy on TRAIN set
# Got 51 / 64 correct (79.69)
# Checking accuracy on VAL set
# Got 159 / 306 correct (51.96)
#
# Epoch 79, Iteration 18, loss = 0.9255
# Checking accuracy on TRAIN set
# Got 42 / 64 correct (65.62)
# Checking accuracy on VAL set
# Got 157 / 306 correct (51.31)
#
# Epoch 79, Iteration 19, loss = 0.7239
# Checking accuracy on TRAIN set
# Got 8 / 8 correct (100.00)
# Checking accuracy on VAL set
# Got 157 / 306 correct (51.31)
#
# Checking accuracy on VAL set
# Got 157 / 306 correct (51.31)
# Checking accuracy on TRAIN set
# Got 845 / 1224 correct (69.04)
# DONE TRAINING

# %%
torch.save(best_model, "best_model_RNN_without_noise_cleanup_whole_time_scale_50_epochs")
torch.save(model, "model_RNN_without_noise_cleanup_whole_time_scale_50_epochs")

# %%
print("DONE")
per_epoch_train_accuracy_list
# Out:
# DONE
# [0.39869281045751637,
#  0.39869281045751637,
#  0.3700980392156863,
#  0.39869281045751637,
#  0.4297385620915033,
#  0.3741830065359477,
#  0.39869281045751637,
#  0.4264705882352941,
#  0.43218954248366015,
#  0.42892156862745096,
#  0.45669934640522875,
#  0.39624183006535946,
#  0.4714052287581699,
#  0.43790849673202614,
#  0.45588235294117646,
#  0.4616013071895425,
#  0.45016339869281047,
#  0.4681372549019608,
#  0.45751633986928103,
#  0.47794117647058826,
#  0.49264705882352944,
#  0.5008169934640523,
#  0.4730392156862745,
#  0.5016339869281046,
#  0.49836601307189543,
#  0.48856209150326796,
#  0.5130718954248366,
#  0.5294117647058824,
#  0.5253267973856209,
#  0.5343137254901961,
#  0.5302287581699346,
#  0.5138888888888888,
#  0.5351307189542484,
#  0.5555555555555556,
#  0.5383986928104575,
#  0.5433006535947712,
#  0.5555555555555556,
#  0.5637254901960784,
#  0.5588235294117647,
#  0.579248366013072,
#  0.5694444444444444,
#  0.5727124183006536,
#  0.5629084967320261,
#  0.5841503267973857,
#  0.5424836601307189,
#  0.5849673202614379,
#  0.5841503267973857,
#  0.5906862745098039,
#  0.5808823529411765,
#  0.5955882352941176,
#  0.5906862745098039,
#  0.6062091503267973,
#  0.5816993464052288,
#  0.5915032679738562,
#  0.5980392156862745,
#  0.5955882352941176,
#  0.5972222222222222,
#  0.6102941176470589,
#  0.6323529411764706,
#  0.6323529411764706,
#  0.6299019607843137,
#  0.6299019607843137,
#  0.6241830065359477,
#  0.6388888888888888,
#  0.6290849673202614,
#  0.6601307189542484,
#  0.6462418300653595,
#  0.6503267973856209,
#  0.6372549019607843,
#  0.6544117647058824,
#  0.6511437908496732,
#  0.6683006535947712,
#  0.6642156862745098,
#  0.6740196078431373,
#  0.6674836601307189,
#  0.6854575163398693,
#  0.6895424836601307,
#  0.6633986928104575,
#  0.6781045751633987,
#  0.690359477124183]

# %%
##PLOT LOSS, TRAIN ACCURACY, TEST ACCURACY
import matplotlib.pyplot as plt
max_train_accuracy = np.repeat(np.max(np.array([train_accuracy_list])),   len(train_accuracy_list))

max_test_accuracy = np.repeat(np.max(np.array([test_accuracy_list])),   len(test_accuracy_list))

max_p_e_train_accuracy = np.repeat(np.max(np.array([per_epoch_train_accuracy_list])),   len(per_epoch_train_accuracy_list))

max_p_e_test_accuracy = np.repeat(np.max(np.array([per_epoch_test_accuracy_list])),   len(per_epoch_test_accuracy_list))

# plot the loss history
plt.subplot()
plt.plot(loss_list)
plt.xlabel('iteration')
plt.ylabel('training loss')
plt.title('Training Loss history')
plt.legend()
plt.show()

plt.subplot()
plt.plot(train_accuracy_list, label='train')
plt.plot(test_accuracy_list, label='val')
plt.plot(max_train_accuracy, label='max train acc')
plt.plot(max_test_accuracy, label='max val acc')
plt.title('Classification accuracy history')
plt.xlabel('Iteration')
plt.ylabel('Classification accuracy')
plt.legend()
plt.show()

plt.subplot()
plt.plot(per_epoch_train_accuracy_list, label='train')
plt.plot(per_epoch_test_accuracy_list, label='val')
plt.plot(max_p_e_train_accuracy, label='max train acc')
plt.plot(max_p_e_test_accuracy, label='max val acc')
plt.title('Per Epoch Classification accuracy history')
plt.xlabel('Epoch')
plt.ylabel('Classification accuracy')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
from sklearn.metrics import confusion_matrix
#from resources.plotcm import plot_confusion_matrix
import itertools
import numpy as np
import matplotlib.pyplot as plt

def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion matrix', cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)
    #plt.figure(figsize=(10,10))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt), horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
def check_train_accuracy1(loader, model, for_confusion_matrix=0):
    #if loader.dataset.train:
    #    print('Checking accuracy on validation set')
    #else:
    #    print('Checking accuracy on test set')
    print('Checking accuracy on TRAIN set')
    num_correct = 0
    num_samples = 0
    model.eval()  # set model to evaluation mode
    true_label_list = []
    predicted_label_list = []
    with torch.no_grad():
        for x, y in loader:
            true_label_list.append(y.cpu().data.numpy())
            x = x.to(device=device, dtype=dtype)  # move to device, e.g. GPU
            y = y.to(device=device, dtype=torch.long)
            #pdb.set_trace()
            #y = torch.stack(y) #.to(device=device)
            #y = y.reshape((x.shape[0]))
            scores = model(x)
            _, preds = scores.max(1)
            predicted_label_list.append(preds.cpu().data.numpy())            
            num_correct += (preds == y).sum()
            num_samples += preds.size(0)
        acc = float(num_correct) / num_samples
        print('Got %d / %d correct (%.2f)' % (num_correct, num_samples, 100 * acc))
        if for_confusion_matrix == 1:
          return acc, true_label_list, predicted_label_list
        else:
          return acc

# %%
#best_model1 = torch.load("model2")
accuracy, true_label, predicted_label = check_train_accuracy1(loader_train, best_model, for_confusion_matrix=1)
true_label = np.concatenate(true_label, axis=None)
#print(true_label)

predicted_label = np.concatenate(predicted_label, axis=None)
#print(predicted_label)

emotion_dict = ('hap',
                'sad',
                'ang',
                'neu'
                )
cm = confusion_matrix(true_label, predicted_label)

#t_t = train_set_targets.cpu().data.numpy()
#predict = preds.cpu().data.numpy()
#t_t = 1 + t_t
#predict = 1 + predict

#for i in range(t_t.shape[0]):
#  print(t_t[i], predict[i])
#print(t_t)
#print(predict)
#print(cm)
plt.figure(figsize=(6,6))
plot_confusion_matrix(cm, emotion_dict)
# Out:
# Checking accuracy on TRAIN set
# Got 837 / 1224 correct (68.38)
# Confusion matrix, without normalization
# [[ 95  45  12  69]
#  [  5 265   6  62]
#  [ 28  15 168  44]
#  [  7  86   8 309]]

# %%
#best_model1 = torch.load("model1")
accuracy, true_label, predicted_label = check_train_accuracy1(loader_val, best_model, for_confusion_matrix=1)
true_label = np.concatenate(true_label, axis=None)
#print(true_label)

predicted_label = np.concatenate(predicted_label, axis=None)
#print(predicted_label)


cm = confusion_matrix(true_label, predicted_label)

#t_t = train_set_targets.cpu().data.numpy()
#predict = preds.cpu().data.numpy()
#t_t = 1 + t_t
#predict = 1 + predict

#for i in range(t_t.shape[0]):
#  print(t_t[i], predict[i])
#print(t_t)
#print(predict)
#print(cm)
plt.figure(figsize=(6,6))
plot_confusion_matrix(cm, emotion_dict)
# Out:
# Checking accuracy on TRAIN set
# Got 168 / 306 correct (54.90)
# Confusion matrix, without normalization
# [[12  9  8 13]
#  [ 5 48  2 13]
#  [14  2 58 25]
#  [23 13 11 50]]

# %%
accuracy, true_label, predicted_label = check_train_accuracy1(loader_train, model, for_confusion_matrix=1)
true_label = np.concatenate(true_label, axis=None)
#print(true_label)

predicted_label = np.concatenate(predicted_label, axis=None)
#print(predicted_label)

emotion_dict = ('hap',
                'sad',
                'ang',
                'neu'
                )
cm = confusion_matrix(true_label, predicted_label)

#t_t = train_set_targets.cpu().data.numpy()
#predict = preds.cpu().data.numpy()
#t_t = 1 + t_t
#predict = 1 + predict

#for i in range(t_t.shape[0]):
#  print(t_t[i], predict[i])
#print(t_t)
#print(predict)
#print(cm)
plt.figure(figsize=(10,6))
plot_confusion_matrix(cm, emotion_dict)
# Out:
# Checking accuracy on TRAIN set
# Got 845 / 1224 correct (69.04)
# Confusion matrix, without normalization
# [[ 84  51  32  54]
#  [  7 293   6  32]
#  [  7  17 203  28]
#  [ 15 112  18 265]]

# %%
#best_model1 = torch.load("model1")
accuracy, true_label, predicted_label = check_train_accuracy1(loader_val, model, for_confusion_matrix=1)
true_label = np.concatenate(true_label, axis=None)
#print(true_label)

predicted_label = np.concatenate(predicted_label, axis=None)
#print(predicted_label)


cm = confusion_matrix(true_label, predicted_label)

#t_t = train_set_targets.cpu().data.numpy()
#predict = preds.cpu().data.numpy()
#t_t = 1 + t_t
#predict = 1 + predict

#for i in range(t_t.shape[0]):
#  print(t_t[i], predict[i])
#print(t_t)
#print(predict)
#print(cm)
plt.figure(figsize=(6,10))
plot_confusion_matrix(cm, emotion_dict)
# Out:
# Checking accuracy on TRAIN set
# Got 157 / 306 correct (51.31)
# Confusion matrix, without normalization
# [[10 12 15  5]
#  [ 3 54  5  6]
#  [11  7 62 19]
#  [18 23 25 31]]
