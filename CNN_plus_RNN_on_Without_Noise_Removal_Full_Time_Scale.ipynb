# %%
'''
# this mounts your Google Drive to the Colab VM.
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# enter the foldername in your Drive where you have saved the unzipped
# assignment folder, e.g. 'cs231n/assignments/assignment3/'
FOLDERNAME = 'PROJECT/WITHOUT_NOISE_CLEANUP/'
assert FOLDERNAME is not None, "[!] Enter the foldername."

# now that we've mounted your Drive, this ensures that
# the Python interpreter of the Colab VM can load
# python files from within it.
import sys
sys.path.append('/content/drive/My Drive/{}'.format(FOLDERNAME))

# this downloads the CIFAR-10 dataset to your Drive
# if it doesn't already exist.
#%cd /content/drive/My\ Drive/$FOLDERNAME/
#!bash get_datasets.sh

'''
# Out:
# '\n# this mounts your Google Drive to the Colab VM.\nfrom google.colab import drive\ndrive.mount(\'/content/drive\', force_remount=True)\n\n# enter the foldername in your Drive where you have saved the unzipped\n# assignment folder, e.g. \'cs231n/assignments/assignment3/\'\nFOLDERNAME = \'PROJECT/WITHOUT_NOISE_CLEANUP/\'\nassert FOLDERNAME is not None, "[!] Enter the foldername."\n\n# now that we\'ve mounted your Drive, this ensures that\n# the Python interpreter of the Colab VM can load\n# python files from within it.\nimport sys\nsys.path.append(\'/content/drive/My Drive/{}\'.format(FOLDERNAME))\n\n# this downloads the CIFAR-10 dataset to your Drive\n# if it doesn\'t already exist.\n#%cd /content/drive/My\\ Drive/$FOLDERNAME/\n#!bash get_datasets.sh\n\n'

# %%
'''
import os 
os.chdir("/content/drive/My Drive/")
os.chdir(FOLDERNAME)
#!bash get_datasets.sh
'''
# Out:
# '\nimport os \nos.chdir("/content/drive/My Drive/")\nos.chdir(FOLDERNAME)\n#!bash get_datasets.sh\n'

# %%
#"neu_3.0_2.0_2.3333_Whole_Length.png".split('_')

# %%
#import sys
#!{sys.executable} -m pip install torchsummary


from torch.utils.data import Dataset,DataLoader
from torchvision import transforms
import os
import numpy as np
import time
from PIL import Image
#from PIL import ImageFile
#ImageFile.LOAD_TRUNCATED_IMAGES = True
from collections import defaultdict
import cv2
import pdb
IMG_SIZE = (200,300)

from torchvision import models
from torchsummary import summary
import copy
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#dataset_train.__len__
#dataset_test.shape
#dataset_val.shape

#'''test corrupted images'''
#data_path = "/home/mandeep_stanford/cs231n_project/code/pre-processed_data/images_denoised/session1/"
#dataset_train, dataset_test, dataset_val = get_imagenet_datasets(data_path, "cpc")
#
#print(f"Number of train samplest {dataset_train.__len__()}")
#print(f"Number of samples in test split {dataset_test.__len__()}")
#
#BATCH_SIZE = 200
#
#data_loader_train = DataLoader(dataset_train, BATCH_SIZE, shuffle = True)
#data_loader_test = DataLoader(dataset_test, BATCH_SIZE, shuffle = True)
#
#
#import matplotlib.pyplot as plt
#
#fig, axes = plt.subplots(BATCH_SIZE//20,20, figsize=(6,10))
#
#for batch in data_loader_train:
#
#    print(f"Shape of batch['image'] {batch['image'].shape}")
#    print(f"Shape of batch['cls'] {batch['cls'].shape}")
#
#    for i in range(BATCH_SIZE):
#
#        col = i % 20
#        row = i // 20
#
#        img = batch['image'][i].numpy()
#
#        axes[row,col].set_axis_off()
#        #axes[row,col].set_title(batch['class_name'][i])
#        axes[row,col].imshow(np.transpose(img,(1,2,0)))
#
#    plt.show()
#
#    break

# %%
#data_path = "/home/mandeep_stanford/cs231n_project/code/pre-processed_data/images/session1/"
#data_path = "/home/mandeep_stanford/cs231n_project/code/pre-processed_data/combined_session1_2/"
data_path1 = "/home/mandeep_stanford/cs231n_project/code/pre-processed_data/4_EMOTIONS/without_noise_cleanup/session1/"
data_path2 = "/home/mandeep_stanford/cs231n_project/code/pre-processed_data/4_EMOTIONS/without_noise_cleanup/session2/"
data_path3 = "/home/mandeep_stanford/cs231n_project/code/pre-processed_data/4_EMOTIONS/without_noise_cleanup/session3/"
data_path4 = "/home/mandeep_stanford/cs231n_project/code/pre-processed_data/4_EMOTIONS/without_noise_cleanup/session4/"

#img_files = os.listdir("/home/mandeep_stanford/cs231n_project/code/pre-processed_data/images/session1/")
#img_files = os.listdir("/home/mandeep_stanford/cs231n_project/code/pre-processed_data/combined_session1_2/")
#img_files = os.listdir("/home/mandeep_stanford/cs231n_project/code/pre-processed_data/4_EMOTIONS/cb_removed/with_noise_cleanup/session1/")

pkl_file = "/home/mandeep_stanford/cs231n_project/code/pre-processed_data/4_EMOTIONS/without_noise_cleanup/without_noise_cleanup_WHOLE.pkl"

# %%
import pickle
import pdb
X = []
Y = []
i = 0
#extract_emotion = ['hap','sad','ang','neu','fea', 'exc', 'fru']
extract_emotion = ['hap','sad','ang','neu']
if 1:
    path = [data_path1, data_path2, data_path3, data_path4]
    for p_files in path:
        for file_name in os.listdir(p_files):
                    
            print("Working on ", i)
            i = i+1
            #if i >= 7000:
            #    break
            if "Whole" in file_name.split('_'):
              print("")
            else:
              print("Skipping ", file_name)
              continue
            cat = file_name.split('_')[0]
            if cat in extract_emotion:
                #print("")
                if cat == "hap":
                    cat = 0
                if cat == "sad":
                    cat = 1
                if cat == "ang":
                    cat = 2
                if cat == "neu":
                    cat = 3
            else:
                continue
            
            Y.append(cat)
            img = Image.open(p_files+file_name)
            img = img.convert('RGB')
            tr = transforms.Resize((200,300))
            img=tr(img)
            
            trf = transforms.RandomHorizontalFlip(p=1)
            img2 = trf(img)
            #pdb.set_trace()
            tr = transforms.ToTensor()
            
            img1 = tr(img)
            img2 = tr(img2)
            
            img1 = np.array(img1)
            img2 = np.array(img2)
            if cat == "hap":
                Y.append(cat)
                X.append(img1)
                Y.append(cat)
                X.append(img1)
                Y.append(cat)
                X.append(img1)
                Y.append(cat)
                X.append(img1)
                Y.append(cat)
                X.append(img1)
                Y.append(cat)
                X.append(img2)
                
            if cat == "ang":
                Y.append(cat)
                X.append(img1)
                Y.append(cat)
                X.append(img1)
            #X=np.vstack((X,img1))
            X.append(img1)
            Y.append(cat)
            X.append(img2)
    
            del img1
            del img2
            del img
            del tr

    Y = np.asarray(Y)
    X = np.asarray(X)
    data = {}
    data["X"] = X
    data["Y"] = Y
    with open(pkl_file, 'wb') as f:
        pickle.dump(data, f)
        f.close()
# Out:
# Working on  0
#
# Working on  1
# Skipping  fru_2.5_3.5_3.50.png
# Working on  2
#
# Working on  3
#
# Working on  4
# Skipping  fru_1.5_3.5_4.02.png
# Working on  5
#
# Working on  6
# Skipping  ang_1.0_5.0_5.00.png
# Working on  7
# Skipping  exc_4.5_4.5_4.00.png
# Working on  8
# Skipping  hap_4.5_2.5_2.00.png
# Working on  9
#
# Working on  10
# Skipping  exc_5.0_4.5_4.00.png
# Working on  6504
# Skipping  sad_2.5_3.0_3.50.png
# Working on  6505
#
# Working on  6506
# Skipping  neu_3.5_3.5_4.00.png
# Working on  6507
#
# Working on  6508
#
# Working on  6509
# Skipping  ang_2.0_4.0_3.50.png
# Working on  6510
# Skipping  exc_4.0_3.5_3.50.png
# Working on  6511
# Skipping  hap_3.0_2.5_3.01.png
# Working on  6512
#
# Working on  6513
# Skipping  sad_2.0_3.5_4.52.png
# Working on  6514
# Skipping  sad_3.0_4.0_4.02.png
# Working on  6515
# Skipping  fru_2.5_3.5_3.02.png
# Working on  6516
#
# Working on  6517
#
# Working on  6518
#
# Working on  6519
#
# Working on  6520
# Skipping  fru_3.5_3.0_2.50.png
# Working on  6521
#
# Working on  6522
# Skipping  ang_2.0_4.5_4.50.png
# Working on  6523
# Skipping  hap_4.5_4.0_4.51.png
# Working on  6524
#
# Working on  6525
# Skipping  fru_2.5_4.0_3.00.png
# Working on  6526
#
# Working on  6527
# Skipping  sad_3.0_4.0_4.00.png
# Working on  6528
# Skipping  sad_4.0_3.5_4.01.png
# Working on  6529
# Skipping  neu_2.5_1.5_0.50.png
# Working on  6530
# Skipping  exc_3.5_3.0_3.01.png
# Working on  6531
# Skipping  sad_2.0_3.0_2.52.png
# Working on  6532
#
# Working on  6533
# Skipping  fru_2.0_2.5_2.51.png
# Working on  6534
#
# Working on  6535
# Skipping  neu_3.0_3.5_4.01.png
# Working on  6536
#
# Working on  6537
# Skipping  sad_4.0_3.0_3.01.png
# Working on  6538
# Skipping  sad_3.0_2.5_3.00.png
# Working on  6539
#
# Working on  6540
# Skipping  exc_4.0_4.0_4.02.png
# Working on  6541
# Skipping  ang_1.5_3.5_4.50.png
# Working on  6542
#
# Working on  6543
#
# Working on  6544
#
# Working on  6545
# Skipping  fru_2.0_3.5_4.01.png
# Working on  6546
# Skipping  fru_2.5_3.0_3.01.png
# Working on  6547
# Skipping  sad_2.5_2.5_2.50.png
# Working on  6548
#
# Working on  6549
# Skipping  fru_3.0_3.5_3.50.png
# Working on  6550
#
# Working on  6551
#
# Working on  6552
# Skipping  ang_1.5_3.5_4.51.png
# Working on  6553
#
# Working on  6554
# Skipping  fru_3.5_2.0_3.00.png
# Working on  6555
# Skipping  fru_3.0_3.5_4.01.png
# Working on  6556
# Skipping  sad_2.5_2.5_3.51.png
# Working on  6557
#
# Working on  6558
# Skipping  exc_3.5_3.5_3.52.png
# Working on  6559
#
# Working on  6560

# %%
import pickle
import torch
assert '.'.join(torch.__version__.split('.')[:2]) == '1.4'
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torch.utils.data import sampler
import torch.utils.data as data_utils
import torchvision.datasets as dset
import torchvision.transforms as T
import torch.nn.functional as F 
import numpy as np
#pkl_file = "/home/mandeep_stanford/cs231n_project/code/pre-processed_data/images_denoised/session1_pkl_tensor1.pkl"
data = pickle.load(open(pkl_file, 'rb'))
X = data["X"]
Y = data["Y"]

# %%
X.shape
# Out:
# (1530, 3, 200, 300)

# %%
np.unique(Y)
# Out:
# array([0, 1, 2, 3])

# %%
import numpy as np
total_images = X.shape[0]
test_data_images = np.int(total_images*0.2)
train_data_images = total_images - test_data_images
#X_train = X[0:train_data_images,-1]
#y_train = Y[0:train_data_images]
#X_test = X[train_data_images:train_data_images+test_data_images, -1]
#y_test= Y[train_data_images:train_data_images+test_data_images]

#X_train = np.asarray(X_train)
#X_test = np.asarray(X_test)
#y_train = np.asarray(y_train)
#y_test = np.asarray(y_test)

#y_train = y_train.reshape((y_train[0]))
#y_test = y_test.reshape((y_test[0]))
#print(X_train.shape)
#print(y_train.shape)
#print(X_test.shape)
#print(y_test.shape)

# %%
USE_GPU = True

dtype = torch.float32 # we will be using float throughout this tutorial

if USE_GPU and torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')

# Constant to control how frequently we print train loss
print_every = 100

print('using device:', device)
# Out:
# using device: cuda

# %%
train_data = []
keys_array = np.unique(Y)
for i in range(len(X)):
   ind = np.where(keys_array==Y[i]) 
   train_data.append([X[i], Y[i]])
print("DONE")
#dataset = data_utils.TensorDataset(train_data, batch_size=100)
print(train_data_images)
print(train_data_images+test_data_images)
loader_train = DataLoader(train_data, batch_size=64, 
                          sampler=sampler.SubsetRandomSampler(range(0,train_data_images)))

loader_val = DataLoader(train_data, batch_size=64, 
                        sampler=sampler.SubsetRandomSampler(range(train_data_images, train_data_images+test_data_images)))


#for t, (x,y) in enumerate(loader_train):
#  print(t, x, y)
# Out:
# DONE
# 1224
# 1530

# %%
print_every = 1

# %%
def check_train_accuracy(loader, model):
    #if loader.dataset.train:
    #    print('Checking accuracy on validation set')
    #else:
    #    print('Checking accuracy on test set')
    print('Checking accuracy on TRAIN set')
    num_correct = 0
    num_samples = 0
    model.eval()  # set model to evaluation mode
    with torch.no_grad():
        for x, y in loader:
            x = x.to(device=device, dtype=dtype)  # move to device, e.g. GPU
            y = y.to(device=device, dtype=torch.long)
            #pdb.set_trace()
            #y = torch.stack(y) #.to(device=device)
            #y = y.reshape((x.shape[0]))
            scores = model(x)
            _, preds = scores.max(1)
            
            num_correct += (preds == y).sum()
            num_samples += preds.size(0)
        acc = float(num_correct) / num_samples
        print('Got %d / %d correct (%.2f)' % (num_correct, num_samples, 100 * acc))
        return acc

# %%
def check_accuracy_part34(loader, model):
    #if loader.dataset.train:
    #    print('Checking accuracy on validation set')
    #else:
    #    print('Checking accuracy on test set')
    print('Checking accuracy on VAL set')
    num_correct = 0
    num_samples = 0
    model.eval()  # set model to evaluation mode
    with torch.no_grad():
        for x, y in loader:
            x = x.to(device=device, dtype=dtype)  # move to device, e.g. GPU
            y = y.to(device=device, dtype=torch.long)
            #pdb.set_trace()
            #y = torch.stack(y) #.to(device=device)
            #y = y.reshape((x.shape[0]))
            scores = model(x)
            _, preds = scores.max(1)
            
            num_correct += (preds == y).sum()
            num_samples += preds.size(0)
        acc = float(num_correct) / num_samples
        print('Got %d / %d correct (%.2f)' % (num_correct, num_samples, 100 * acc))
        return acc

# %%
def train_part34(model, optimizer, epochs=1):
    """
    Train a model on CIFAR-10 using the PyTorch Module API.
    
    Inputs:
    - model: A PyTorch Module giving the model to train.
    - optimizer: An Optimizer object we will use to train the model
    - epochs: (Optional) A Python integer giving the number of epochs to train for
    
    Returns: Nothing, but prints model accuracies during training.
    """
    acc = 0
    per_epoch_train_accuracy_list = []
    per_epoch_test_accuracy_list = []
    train_accuracy_list = []
    test_accuracy_list = []
    loss_list = []
    best_model = model = model.to(device=device)  # move the model parameters to CPU/GPU
    for e in range(epochs):
        for t, (x, y) in enumerate(loader_train):
            import pdb
            #pdb.set_trace()
            model.train()  # put model to training mode
            x = x.to(device=device, dtype=dtype)  # move to device, e.g. GPU
            y = y.to(device=device, dtype=torch.long)
            #y = torch.stack(y) #.to(device=device)
            #y = y.reshape((x.shape[0]))
            scores = model(x)
            
            loss = F.cross_entropy(scores, y)
            loss_list.append(loss.item())
            # Zero out all of the gradients for the variables which the optimizer
            # will update.
            optimizer.zero_grad()

            # This is the backwards pass: compute the gradient of the loss with
            # respect to each  parameter of the model.
            loss.backward()

            # Actually update the parameters of the model using the gradients
            # computed by the backwards pass.
            optimizer.step()
            #pdb.set_trace()
            #print("IN ITERATION", t)
            if t % print_every == 0:
                print('Epoch %d, Iteration %d, loss = %.4f' % (e, t, loss.item()))
                #pdb.set_trace()
                xx = x.cpu().data.numpy()
                yy = y.cpu().data.numpy()
                tt_data = []
                for i in range(len(xx)):
                  ind = np.where(keys_array==Y[i]) 
                  tt_data.append([xx[i], yy[i]])
                
                train_d = DataLoader(tt_data, batch_size = 1)
                
                train_acc = check_train_accuracy(train_d, model)
                train_accuracy_list.append(train_acc)
                test_acc = check_accuracy_part34(loader_val, model)
                test_accuracy_list.append(test_acc)
                if test_acc > acc:
                  acc = test_acc
                  best_model = copy.deepcopy(model)
                print()
        
        e_test_accuracy = check_accuracy_part34(loader_val, model)        
        per_epoch_test_accuracy_list.append(e_test_accuracy)     
        e_train_accuracy = check_train_accuracy(loader_train, model)        
        per_epoch_train_accuracy_list.append(e_train_accuracy)     
    return best_model, acc, train_accuracy_list, test_accuracy_list, per_epoch_train_accuracy_list, per_epoch_test_accuracy_list, loss_list

# %%
class Flatten(nn.Module):
    def flatten(x):
        N = x.shape[0] # read in N, C, H, W
        return x.view(N, -1)  # "flatten" the C * H * W values into a single vector per image

    def forward(self, x):
        N = x.shape[0]
        return x.view(N, -1)

class LSTM(nn.Module):
    def __init__(self):
        super().__init__()
        #self.model = nn.LSTM(input_size=(32*25*37),hidden_size=128,num_layers=2,batch_first=True,bidirectional =True, dropout=0.1)
        self.model = nn.RNN(input_size=(32*25*37),hidden_size=128,num_layers=2,batch_first=True,bidirectional =True, dropout=0.1)
    def forward(self, x):

        # From [batches, seqs, seq len, features]
        # to [seq len, batch data, features]
        x = x.unsqueeze(1)
       
        # Data is fed to the LSTM
        out, _ = self.model(x)

        # From [seq len, batch, num_directions * hidden_size]
        # to [batches, seqs, seq_len,prediction]
        out = out.squeeze(1)


        return out

#hidden_layer_size = 500
#learning_rate = 1e-2

#model = nn.Sequential(
#    Flatten(),
#    nn.Linear(3 * 200 * 300, hidden_layer_size),
#    nn.ReLU(),
#    nn.Linear(hidden_layer_size, keys_array.shape[0]),
#)


l1 = nn.Sequential(
            nn.Conv2d(3, 16, kernel_size=(12,16), padding=(6,8), stride=1),
            nn.ReLU(),
            #nn.Conv2d(channel_1, channel_1, kernel_size=5, padding=2, stride=1),
            nn.MaxPool2d(2, 2)
)

#for t, (x, y) in enumerate(loader_train):
#            # put model to training mode
#            x = x.to(device=device, dtype=dtype)
#            import pdb
#            pdb.set_trace()
#            break
    
#pdb.set_trace()
#h = l1(x)
#h.shape

l2 = nn.Sequential(
            nn.Conv2d(16, 24, kernel_size=(8,12), padding=(4,6), stride=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2)
)
#h = l2(h)

l3 = nn.Sequential(
            nn.Conv2d(24, 32, kernel_size=(5,7), padding=(2,3), stride=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            Flatten(),
            LSTM()
            
)

#l4 = nn.Sequential(
#            nn.Conv2d(channel_3, channel_4, kernel_size=3, padding=1, stride=1),
#            nn.MaxPool2d(2, 1)
#)

#import pdb
#pdb.set_trace()
hidden_layer_size = keys_array.shape[0]
learning_rate = 1e-4 #1e-4   1e-3 looks gud
model = nn.Sequential(
            l1,
            l2,
            l3,
            nn.Linear(256, 64),
            nn.ReLU(),
            nn.Dropout(p=0.2),
            nn.Linear(64, keys_array.shape[0])
)




# you can use Nesterov momentum in optim.SGD
#optimizer = optim.Adam(model.parameters(), lr=learning_rate,momentum=0.9, nesterov=True)
optimizer = optim.Adam(model.parameters(), lr=learning_rate, 
                     betas=(0.9, 0.999), eps=1e-08, weight_decay=0, amsgrad=False) #weight_decay = 0 luks gud. Trying with 0.1


#best_model, best_test_acc, train_accuracy_list, test_accuracy_list, loss_list = train_part34(model, optimizer, 2)
best_model, best_test_acc, train_accuracy_list, test_accuracy_list, per_epoch_train_accuracy_list, per_epoch_test_accuracy_list, loss_list = train_part34(model, optimizer, 50)
print("DONE TRAINING")
# Out:
# Epoch 0, Iteration 0, loss = 1.3970
# Checking accuracy on TRAIN set
# Got 23 / 64 correct (35.94)
# Checking accuracy on VAL set
# Got 96 / 306 correct (31.37)
#
# Epoch 0, Iteration 1, loss = 1.3990
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 119 / 306 correct (38.89)
#
# Epoch 0, Iteration 2, loss = 1.3805
# Checking accuracy on TRAIN set
# Got 20 / 64 correct (31.25)
# Checking accuracy on VAL set
# Got 98 / 306 correct (32.03)
#
# Epoch 0, Iteration 3, loss = 1.3599
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 97 / 306 correct (31.70)
#
# Epoch 0, Iteration 4, loss = 1.3484
# Checking accuracy on TRAIN set
# Got 23 / 64 correct (35.94)
# Checking accuracy on VAL set
# Got 97 / 306 correct (31.70)
#
# Epoch 0, Iteration 5, loss = 1.3510
# Checking accuracy on TRAIN set
# Got 21 / 64 correct (32.81)
# Checking accuracy on VAL set
# Got 97 / 306 correct (31.70)
#
# Epoch 0, Iteration 6, loss = 1.3753
# Checking accuracy on TRAIN set
# Got 16 / 64 correct (25.00)
# Checking accuracy on VAL set
# Got 97 / 306 correct (31.70)
#
# Epoch 0, Iteration 7, loss = 1.3519
# Checking accuracy on TRAIN set
# Got 19 / 64 correct (29.69)
# Checking accuracy on VAL set
# Got 97 / 306 correct (31.70)
#
# Epoch 0, Iteration 8, loss = 1.3339
# Checking accuracy on TRAIN set
# Got 19 / 64 correct (29.69)
# Checking accuracy on VAL set
# Got 97 / 306 correct (31.70)
#
# Epoch 0, Iteration 9, loss = 1.3546
# Checking accuracy on TRAIN set
# Got 20 / 64 correct (31.25)
# Checking accuracy on VAL set
# Got 97 / 306 correct (31.70)
#
# Epoch 0, Iteration 10, loss = 1.3273
# Checking accuracy on TRAIN set
# Got 21 / 64 correct (32.81)
# Checking accuracy on VAL set
# Got 97 / 306 correct (31.70)
#
# Epoch 0, Iteration 11, loss = 1.3479
# Checking accuracy on TRAIN set
# Got 25 / 64 correct (39.06)
# Checking accuracy on VAL set
# Got 97 / 306 correct (31.70)
#
# Epoch 0, Iteration 12, loss = 1.3308
# Checking accuracy on TRAIN set
# Got 20 / 64 correct (31.25)
# Checking accuracy on VAL set
# Got 97 / 306 correct (31.70)
#
# Epoch 0, Iteration 13, loss = 1.3529
# Checking accuracy on TRAIN set
# Got 25 / 64 correct (39.06)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 0, Iteration 14, loss = 1.3381
# Checking accuracy on TRAIN set
# Got 25 / 64 correct (39.06)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 0, Iteration 15, loss = 1.3416
# Checking accuracy on TRAIN set
# Got 21 / 64 correct (32.81)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 0, Iteration 16, loss = 1.3568
# Checking accuracy on TRAIN set
# Got 26 / 64 correct (40.62)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 0, Iteration 17, loss = 1.3202
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 0, Iteration 18, loss = 1.3131
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 0, Iteration 19, loss = 1.2289
# Checking accuracy on TRAIN set
# Got 3 / 8 correct (37.50)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
# Checking accuracy on TRAIN set
# Got 488 / 1224 correct (39.87)
# Epoch 1, Iteration 0, loss = 1.2712
# Checking accuracy on TRAIN set
# Got 26 / 64 correct (40.62)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 1, Iteration 1, loss = 1.3911
# Checking accuracy on TRAIN set
# Got 22 / 64 correct (34.38)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 1, Iteration 2, loss = 1.2866
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 1, Iteration 3, loss = 1.4269
# Checking accuracy on TRAIN set
# Got 22 / 64 correct (34.38)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 1, Iteration 4, loss = 1.2382
# Checking accuracy on TRAIN set
# Got 26 / 64 correct (40.62)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 1, Iteration 5, loss = 1.2805
# Checking accuracy on TRAIN set
# Got 25 / 64 correct (39.06)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 1, Iteration 6, loss = 1.3575
# Checking accuracy on TRAIN set
# Got 20 / 64 correct (31.25)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 1, Iteration 7, loss = 1.2041
# Checking accuracy on TRAIN set
# Got 35 / 64 correct (54.69)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 1, Iteration 8, loss = 1.2637
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 1, Iteration 9, loss = 1.2492
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 1, Iteration 10, loss = 1.2817
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 1, Iteration 11, loss = 1.2342
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 1, Iteration 12, loss = 1.3028
# Checking accuracy on TRAIN set
# Got 26 / 64 correct (40.62)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 1, Iteration 13, loss = 1.3427
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 1, Iteration 14, loss = 1.3469
# Checking accuracy on TRAIN set
# Got 19 / 64 correct (29.69)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 1, Iteration 15, loss = 1.3323
# Checking accuracy on TRAIN set
# Got 22 / 64 correct (34.38)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 1, Iteration 16, loss = 1.2607
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 1, Iteration 17, loss = 1.2363
# Checking accuracy on TRAIN set
# Got 25 / 64 correct (39.06)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 1, Iteration 18, loss = 1.2607
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 1, Iteration 19, loss = 1.0734
# Checking accuracy on TRAIN set
# Got 5 / 8 correct (62.50)
# Checking accuracy on VAL set
# Got 119 / 306 correct (38.89)
#
# Checking accuracy on VAL set
# Got 119 / 306 correct (38.89)
# Checking accuracy on TRAIN set
# Got 498 / 1224 correct (40.69)
# Epoch 2, Iteration 0, loss = 1.1714
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 102 / 306 correct (33.33)
#
# Epoch 2, Iteration 1, loss = 1.2719
# Checking accuracy on TRAIN set
# Got 25 / 64 correct (39.06)
# Checking accuracy on VAL set
# Got 100 / 306 correct (32.68)
#
# Epoch 2, Iteration 2, loss = 1.3483
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 100 / 306 correct (32.68)
#
# Epoch 2, Iteration 3, loss = 1.3175
# Checking accuracy on TRAIN set
# Got 23 / 64 correct (35.94)
# Checking accuracy on VAL set
# Got 100 / 306 correct (32.68)
#
# Epoch 2, Iteration 4, loss = 1.3129
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 100 / 306 correct (32.68)
#
# Epoch 2, Iteration 5, loss = 1.3256
# Checking accuracy on TRAIN set
# Got 17 / 64 correct (26.56)
# Checking accuracy on VAL set
# Got 100 / 306 correct (32.68)
#
# Epoch 2, Iteration 6, loss = 1.2464
# Checking accuracy on TRAIN set
# Got 23 / 64 correct (35.94)
# Checking accuracy on VAL set
# Got 100 / 306 correct (32.68)
#
# Epoch 2, Iteration 7, loss = 1.1720
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 100 / 306 correct (32.68)
#
# Epoch 2, Iteration 8, loss = 1.2442
# Checking accuracy on TRAIN set
# Got 25 / 64 correct (39.06)
# Checking accuracy on VAL set
# Got 109 / 306 correct (35.62)
#
# Epoch 2, Iteration 9, loss = 1.2206
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 118 / 306 correct (38.56)
#
# Epoch 2, Iteration 10, loss = 1.2522
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 2, Iteration 11, loss = 1.3174
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 2, Iteration 12, loss = 1.2263
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 2, Iteration 13, loss = 1.3494
# Checking accuracy on TRAIN set
# Got 21 / 64 correct (32.81)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 2, Iteration 14, loss = 1.2476
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 2, Iteration 15, loss = 1.3128
# Checking accuracy on TRAIN set
# Got 25 / 64 correct (39.06)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 2, Iteration 16, loss = 1.2573
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 2, Iteration 17, loss = 1.4084
# Checking accuracy on TRAIN set
# Got 15 / 64 correct (23.44)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 2, Iteration 18, loss = 1.2587
# Checking accuracy on TRAIN set
# Got 25 / 64 correct (39.06)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 2, Iteration 19, loss = 1.2792
# Checking accuracy on TRAIN set
# Got 4 / 8 correct (50.00)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
# Checking accuracy on TRAIN set
# Got 488 / 1224 correct (39.87)
# Epoch 3, Iteration 0, loss = 1.2751
# Checking accuracy on TRAIN set
# Got 25 / 64 correct (39.06)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 3, Iteration 1, loss = 1.2603
# Checking accuracy on TRAIN set
# Got 25 / 64 correct (39.06)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 3, Iteration 2, loss = 1.2504
# Checking accuracy on TRAIN set
# Got 26 / 64 correct (40.62)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 3, Iteration 3, loss = 1.2257
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 3, Iteration 4, loss = 1.3466
# Checking accuracy on TRAIN set
# Got 21 / 64 correct (32.81)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 3, Iteration 5, loss = 1.2931
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 3, Iteration 6, loss = 1.2021
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 3, Iteration 7, loss = 1.2646
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 3, Iteration 8, loss = 1.2184
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 3, Iteration 9, loss = 1.2050
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 3, Iteration 10, loss = 1.3426
# Checking accuracy on TRAIN set
# Got 20 / 64 correct (31.25)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 3, Iteration 11, loss = 1.3676
# Checking accuracy on TRAIN set
# Got 17 / 64 correct (26.56)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 3, Iteration 12, loss = 1.3499
# Checking accuracy on TRAIN set
# Got 25 / 64 correct (39.06)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 3, Iteration 13, loss = 1.2809
# Checking accuracy on TRAIN set
# Got 26 / 64 correct (40.62)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 3, Iteration 14, loss = 1.2722
# Checking accuracy on TRAIN set
# Got 23 / 64 correct (35.94)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 3, Iteration 15, loss = 1.2458
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 3, Iteration 16, loss = 1.3010
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 3, Iteration 17, loss = 1.2391
# Checking accuracy on TRAIN set
# Got 26 / 64 correct (40.62)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 3, Iteration 18, loss = 1.2431
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 3, Iteration 19, loss = 1.2303
# Checking accuracy on TRAIN set
# Got 4 / 8 correct (50.00)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
# Checking accuracy on TRAIN set
# Got 488 / 1224 correct (39.87)
# Epoch 4, Iteration 0, loss = 1.2760
# Checking accuracy on TRAIN set
# Got 25 / 64 correct (39.06)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 4, Iteration 1, loss = 1.2580
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 4, Iteration 2, loss = 1.2312
# Checking accuracy on TRAIN set
# Got 26 / 64 correct (40.62)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 4, Iteration 3, loss = 1.3161
# Checking accuracy on TRAIN set
# Got 25 / 64 correct (39.06)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 4, Iteration 4, loss = 1.2063
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 106 / 306 correct (34.64)
#
# Epoch 4, Iteration 5, loss = 1.1848
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 101 / 306 correct (33.01)
#
# Epoch 4, Iteration 6, loss = 1.2640
# Checking accuracy on TRAIN set
# Got 22 / 64 correct (34.38)
# Checking accuracy on VAL set
# Got 119 / 306 correct (38.89)
#
# Epoch 4, Iteration 7, loss = 1.3409
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 4, Iteration 8, loss = 1.3641
# Checking accuracy on TRAIN set
# Got 21 / 64 correct (32.81)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 4, Iteration 9, loss = 1.2638
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 4, Iteration 10, loss = 1.2736
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 4, Iteration 11, loss = 1.2976
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 4, Iteration 12, loss = 1.3351
# Checking accuracy on TRAIN set
# Got 20 / 64 correct (31.25)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 4, Iteration 13, loss = 1.2701
# Checking accuracy on TRAIN set
# Got 25 / 64 correct (39.06)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 4, Iteration 14, loss = 1.2813
# Checking accuracy on TRAIN set
# Got 23 / 64 correct (35.94)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 4, Iteration 15, loss = 1.2139
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 4, Iteration 16, loss = 1.2562
# Checking accuracy on TRAIN set
# Got 20 / 64 correct (31.25)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 4, Iteration 17, loss = 1.2333
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 4, Iteration 18, loss = 1.1890
# Checking accuracy on TRAIN set
# Got 26 / 64 correct (40.62)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 4, Iteration 19, loss = 1.2605
# Checking accuracy on TRAIN set
# Got 2 / 8 correct (25.00)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
# Checking accuracy on TRAIN set
# Got 488 / 1224 correct (39.87)
# Epoch 5, Iteration 0, loss = 1.2706
# Checking accuracy on TRAIN set
# Got 25 / 64 correct (39.06)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 5, Iteration 1, loss = 1.1754
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 5, Iteration 2, loss = 1.2351
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 5, Iteration 3, loss = 1.3365
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 5, Iteration 4, loss = 1.2016
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 5, Iteration 5, loss = 1.2783
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 5, Iteration 6, loss = 1.2156
# Checking accuracy on TRAIN set
# Got 23 / 64 correct (35.94)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 5, Iteration 7, loss = 1.2968
# Checking accuracy on TRAIN set
# Got 21 / 64 correct (32.81)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 5, Iteration 8, loss = 1.2369
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 5, Iteration 9, loss = 1.2625
# Checking accuracy on TRAIN set
# Got 26 / 64 correct (40.62)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 5, Iteration 10, loss = 1.2047
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 5, Iteration 11, loss = 1.2517
# Checking accuracy on TRAIN set
# Got 21 / 64 correct (32.81)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 5, Iteration 12, loss = 1.3914
# Checking accuracy on TRAIN set
# Got 18 / 64 correct (28.12)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 5, Iteration 13, loss = 1.2204
# Checking accuracy on TRAIN set
# Got 23 / 64 correct (35.94)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 5, Iteration 14, loss = 1.2020
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 5, Iteration 15, loss = 1.2372
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 5, Iteration 16, loss = 1.2902
# Checking accuracy on TRAIN set
# Got 26 / 64 correct (40.62)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 5, Iteration 17, loss = 1.3020
# Checking accuracy on TRAIN set
# Got 22 / 64 correct (34.38)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 5, Iteration 18, loss = 1.2509
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 5, Iteration 19, loss = 1.3892
# Checking accuracy on TRAIN set
# Got 2 / 8 correct (25.00)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
# Checking accuracy on TRAIN set
# Got 488 / 1224 correct (39.87)
# Epoch 6, Iteration 0, loss = 1.2191
# Checking accuracy on TRAIN set
# Got 23 / 64 correct (35.94)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 6, Iteration 1, loss = 1.2415
# Checking accuracy on TRAIN set
# Got 25 / 64 correct (39.06)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 6, Iteration 2, loss = 1.2660
# Checking accuracy on TRAIN set
# Got 26 / 64 correct (40.62)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 6, Iteration 3, loss = 1.2601
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 6, Iteration 4, loss = 1.1716
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 6, Iteration 5, loss = 1.2625
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 116 / 306 correct (37.91)
#
# Epoch 6, Iteration 6, loss = 1.3028
# Checking accuracy on TRAIN set
# Got 22 / 64 correct (34.38)
# Checking accuracy on VAL set
# Got 116 / 306 correct (37.91)
#
# Epoch 6, Iteration 7, loss = 1.3072
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 116 / 306 correct (37.91)
#
# Epoch 6, Iteration 8, loss = 1.2247
# Checking accuracy on TRAIN set
# Got 25 / 64 correct (39.06)
# Checking accuracy on VAL set
# Got 115 / 306 correct (37.58)
#
# Epoch 6, Iteration 9, loss = 1.2570
# Checking accuracy on TRAIN set
# Got 26 / 64 correct (40.62)
# Checking accuracy on VAL set
# Got 112 / 306 correct (36.60)
#
# Epoch 6, Iteration 10, loss = 1.2452
# Checking accuracy on TRAIN set
# Got 25 / 64 correct (39.06)
# Checking accuracy on VAL set
# Got 116 / 306 correct (37.91)
#
# Epoch 6, Iteration 11, loss = 1.2548
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 116 / 306 correct (37.91)
#
# Epoch 6, Iteration 12, loss = 1.3076
# Checking accuracy on TRAIN set
# Got 26 / 64 correct (40.62)
# Checking accuracy on VAL set
# Got 116 / 306 correct (37.91)
#
# Epoch 6, Iteration 13, loss = 1.2760
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 116 / 306 correct (37.91)
#
# Epoch 6, Iteration 14, loss = 1.2152
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 119 / 306 correct (38.89)
#
# Epoch 6, Iteration 15, loss = 1.2246
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 6, Iteration 16, loss = 1.2840
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 6, Iteration 17, loss = 1.2738
# Checking accuracy on TRAIN set
# Got 22 / 64 correct (34.38)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 6, Iteration 18, loss = 1.3085
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 6, Iteration 19, loss = 1.3380
# Checking accuracy on TRAIN set
# Got 1 / 8 correct (12.50)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
# Checking accuracy on TRAIN set
# Got 488 / 1224 correct (39.87)
# Epoch 7, Iteration 0, loss = 1.1924
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 7, Iteration 1, loss = 1.2281
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 7, Iteration 2, loss = 1.2275
# Checking accuracy on TRAIN set
# Got 23 / 64 correct (35.94)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 7, Iteration 3, loss = 1.4071
# Checking accuracy on TRAIN set
# Got 18 / 64 correct (28.12)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 7, Iteration 4, loss = 1.2631
# Checking accuracy on TRAIN set
# Got 25 / 64 correct (39.06)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 7, Iteration 5, loss = 1.2403
# Checking accuracy on TRAIN set
# Got 26 / 64 correct (40.62)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 7, Iteration 6, loss = 1.2246
# Checking accuracy on TRAIN set
# Got 26 / 64 correct (40.62)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 7, Iteration 7, loss = 1.2935
# Checking accuracy on TRAIN set
# Got 21 / 64 correct (32.81)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 7, Iteration 8, loss = 1.1965
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 7, Iteration 9, loss = 1.3013
# Checking accuracy on TRAIN set
# Got 22 / 64 correct (34.38)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 7, Iteration 10, loss = 1.3313
# Checking accuracy on TRAIN set
# Got 19 / 64 correct (29.69)
# Checking accuracy on VAL set
# Got 118 / 306 correct (38.56)
#
# Epoch 7, Iteration 11, loss = 1.1962
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 120 / 306 correct (39.22)
#
# Epoch 7, Iteration 12, loss = 1.2728
# Checking accuracy on TRAIN set
# Got 21 / 64 correct (32.81)
# Checking accuracy on VAL set
# Got 120 / 306 correct (39.22)
#
# Epoch 7, Iteration 13, loss = 1.2411
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 118 / 306 correct (38.56)
#
# Epoch 7, Iteration 14, loss = 1.2132
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 7, Iteration 15, loss = 1.2787
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 7, Iteration 16, loss = 1.2520
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 118 / 306 correct (38.56)
#
# Epoch 7, Iteration 17, loss = 1.2322
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 7, Iteration 18, loss = 1.2028
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Epoch 7, Iteration 19, loss = 1.2538
# Checking accuracy on TRAIN set
# Got 3 / 8 correct (37.50)
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
#
# Checking accuracy on VAL set
# Got 117 / 306 correct (38.24)
# Checking accuracy on TRAIN set
# Got 532 / 1224 correct (43.46)
# Epoch 8, Iteration 0, loss = 1.2125
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 118 / 306 correct (38.56)
#
# Epoch 8, Iteration 1, loss = 1.1496
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 116 / 306 correct (37.91)
#
# Epoch 8, Iteration 2, loss = 1.1890
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 116 / 306 correct (37.91)
#
# Epoch 8, Iteration 3, loss = 1.2898
# Checking accuracy on TRAIN set
# Got 26 / 64 correct (40.62)
# Checking accuracy on VAL set
# Got 124 / 306 correct (40.52)
#
# Epoch 8, Iteration 4, loss = 1.1999
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 122 / 306 correct (39.87)
#
# Epoch 8, Iteration 5, loss = 1.1827
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 124 / 306 correct (40.52)
#
# Epoch 8, Iteration 6, loss = 1.1771
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 124 / 306 correct (40.52)
#
# Epoch 8, Iteration 7, loss = 1.3327
# Checking accuracy on TRAIN set
# Got 21 / 64 correct (32.81)
# Checking accuracy on VAL set
# Got 122 / 306 correct (39.87)
#
# Epoch 8, Iteration 8, loss = 1.1749
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 122 / 306 correct (39.87)
#
# Epoch 8, Iteration 9, loss = 1.1488
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 122 / 306 correct (39.87)
#
# Epoch 8, Iteration 10, loss = 1.2545
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 123 / 306 correct (40.20)
#
# Epoch 8, Iteration 11, loss = 1.2598
# Checking accuracy on TRAIN set
# Got 25 / 64 correct (39.06)
# Checking accuracy on VAL set
# Got 127 / 306 correct (41.50)
#
# Epoch 8, Iteration 12, loss = 1.1410
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 133 / 306 correct (43.46)
#
# Epoch 8, Iteration 13, loss = 1.1996
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 135 / 306 correct (44.12)
#
# Epoch 8, Iteration 14, loss = 1.2500
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 134 / 306 correct (43.79)
#
# Epoch 8, Iteration 15, loss = 1.2197
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 135 / 306 correct (44.12)
#
# Epoch 8, Iteration 16, loss = 1.1935
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 132 / 306 correct (43.14)
#
# Epoch 8, Iteration 17, loss = 1.3085
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 139 / 306 correct (45.42)
#
# Epoch 8, Iteration 18, loss = 1.3830
# Checking accuracy on TRAIN set
# Got 20 / 64 correct (31.25)
# Checking accuracy on VAL set
# Got 139 / 306 correct (45.42)
#
# Epoch 8, Iteration 19, loss = 1.0663
# Checking accuracy on TRAIN set
# Got 5 / 8 correct (62.50)
# Checking accuracy on VAL set
# Got 132 / 306 correct (43.14)
#
# Checking accuracy on VAL set
# Got 132 / 306 correct (43.14)
# Checking accuracy on TRAIN set
# Got 492 / 1224 correct (40.20)
# Epoch 9, Iteration 0, loss = 1.1216
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 122 / 306 correct (39.87)
#
# Epoch 9, Iteration 1, loss = 1.2204
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 114 / 306 correct (37.25)
#
# Epoch 9, Iteration 2, loss = 1.3064
# Checking accuracy on TRAIN set
# Got 21 / 64 correct (32.81)
# Checking accuracy on VAL set
# Got 115 / 306 correct (37.58)
#
# Epoch 9, Iteration 3, loss = 1.3264
# Checking accuracy on TRAIN set
# Got 21 / 64 correct (32.81)
# Checking accuracy on VAL set
# Got 130 / 306 correct (42.48)
#
# Epoch 9, Iteration 4, loss = 1.1717
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 141 / 306 correct (46.08)
#
# Epoch 9, Iteration 5, loss = 1.2128
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 131 / 306 correct (42.81)
#
# Epoch 9, Iteration 6, loss = 1.1167
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 124 / 306 correct (40.52)
#
# Epoch 9, Iteration 7, loss = 1.2211
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 124 / 306 correct (40.52)
#
# Epoch 9, Iteration 8, loss = 1.2372
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 129 / 306 correct (42.16)
#
# Epoch 9, Iteration 9, loss = 1.1636
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 138 / 306 correct (45.10)
#
# Epoch 9, Iteration 10, loss = 1.2402
# Checking accuracy on TRAIN set
# Got 23 / 64 correct (35.94)
# Checking accuracy on VAL set
# Got 128 / 306 correct (41.83)
#
# Epoch 9, Iteration 11, loss = 1.2183
# Checking accuracy on TRAIN set
# Got 25 / 64 correct (39.06)
# Checking accuracy on VAL set
# Got 125 / 306 correct (40.85)
#
# Epoch 9, Iteration 12, loss = 1.2784
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 125 / 306 correct (40.85)
#
# Epoch 9, Iteration 13, loss = 1.1847
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 125 / 306 correct (40.85)
#
# Epoch 9, Iteration 14, loss = 1.2746
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 128 / 306 correct (41.83)
#
# Epoch 9, Iteration 15, loss = 1.1620
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 129 / 306 correct (42.16)
#
# Epoch 9, Iteration 16, loss = 1.3507
# Checking accuracy on TRAIN set
# Got 22 / 64 correct (34.38)
# Checking accuracy on VAL set
# Got 137 / 306 correct (44.77)
#
# Epoch 9, Iteration 17, loss = 1.1779
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 134 / 306 correct (43.79)
#
# Epoch 9, Iteration 18, loss = 1.1977
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 132 / 306 correct (43.14)
#
# Epoch 9, Iteration 19, loss = 1.4299
# Checking accuracy on TRAIN set
# Got 2 / 8 correct (25.00)
# Checking accuracy on VAL set
# Got 132 / 306 correct (43.14)
#
# Checking accuracy on VAL set
# Got 132 / 306 correct (43.14)
# Checking accuracy on TRAIN set
# Got 536 / 1224 correct (43.79)
# Epoch 10, Iteration 0, loss = 1.2742
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 133 / 306 correct (43.46)
#
# Epoch 10, Iteration 1, loss = 1.1200
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 134 / 306 correct (43.79)
#
# Epoch 10, Iteration 2, loss = 1.2325
# Checking accuracy on TRAIN set
# Got 26 / 64 correct (40.62)
# Checking accuracy on VAL set
# Got 137 / 306 correct (44.77)
#
# Epoch 10, Iteration 3, loss = 1.0942
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 137 / 306 correct (44.77)
#
# Epoch 10, Iteration 4, loss = 1.2023
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 137 / 306 correct (44.77)
#
# Epoch 10, Iteration 5, loss = 1.2169
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 137 / 306 correct (44.77)
#
# Epoch 10, Iteration 6, loss = 1.2522
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 139 / 306 correct (45.42)
#
# Epoch 10, Iteration 7, loss = 1.1379
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 139 / 306 correct (45.42)
#
# Epoch 10, Iteration 8, loss = 1.1876
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 143 / 306 correct (46.73)
#
# Epoch 10, Iteration 9, loss = 1.1665
# Checking accuracy on TRAIN set
# Got 22 / 64 correct (34.38)
# Checking accuracy on VAL set
# Got 143 / 306 correct (46.73)
#
# Epoch 10, Iteration 10, loss = 1.1869
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 144 / 306 correct (47.06)
#
# Epoch 10, Iteration 11, loss = 1.3587
# Checking accuracy on TRAIN set
# Got 23 / 64 correct (35.94)
# Checking accuracy on VAL set
# Got 133 / 306 correct (43.46)
#
# Epoch 10, Iteration 12, loss = 1.1312
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 131 / 306 correct (42.81)
#
# Epoch 10, Iteration 13, loss = 1.2022
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 135 / 306 correct (44.12)
#
# Epoch 10, Iteration 14, loss = 1.2822
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 133 / 306 correct (43.46)
#
# Epoch 10, Iteration 15, loss = 1.3414
# Checking accuracy on TRAIN set
# Got 21 / 64 correct (32.81)
# Checking accuracy on VAL set
# Got 131 / 306 correct (42.81)
#
# Epoch 10, Iteration 16, loss = 1.1047
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 130 / 306 correct (42.48)
#
# Epoch 10, Iteration 17, loss = 1.2282
# Checking accuracy on TRAIN set
# Got 25 / 64 correct (39.06)
# Checking accuracy on VAL set
# Got 135 / 306 correct (44.12)
#
# Epoch 10, Iteration 18, loss = 1.2150
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 131 / 306 correct (42.81)
#
# Epoch 10, Iteration 19, loss = 1.3312
# Checking accuracy on TRAIN set
# Got 4 / 8 correct (50.00)
# Checking accuracy on VAL set
# Got 129 / 306 correct (42.16)
#
# Checking accuracy on VAL set
# Got 129 / 306 correct (42.16)
# Checking accuracy on TRAIN set
# Got 560 / 1224 correct (45.75)
# Epoch 11, Iteration 0, loss = 1.1327
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 125 / 306 correct (40.85)
#
# Epoch 11, Iteration 1, loss = 1.1953
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 127 / 306 correct (41.50)
#
# Epoch 11, Iteration 2, loss = 1.1757
# Checking accuracy on TRAIN set
# Got 35 / 64 correct (54.69)
# Checking accuracy on VAL set
# Got 128 / 306 correct (41.83)
#
# Epoch 11, Iteration 3, loss = 1.2802
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 135 / 306 correct (44.12)
#
# Epoch 11, Iteration 4, loss = 1.1234
# Checking accuracy on TRAIN set
# Got 35 / 64 correct (54.69)
# Checking accuracy on VAL set
# Got 136 / 306 correct (44.44)
#
# Epoch 11, Iteration 5, loss = 1.2287
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 135 / 306 correct (44.12)
#
# Epoch 11, Iteration 6, loss = 1.2619
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 136 / 306 correct (44.44)
#
# Epoch 11, Iteration 7, loss = 1.1447
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 133 / 306 correct (43.46)
#
# Epoch 11, Iteration 8, loss = 1.2742
# Checking accuracy on TRAIN set
# Got 22 / 64 correct (34.38)
# Checking accuracy on VAL set
# Got 133 / 306 correct (43.46)
#
# Epoch 11, Iteration 9, loss = 1.2598
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 130 / 306 correct (42.48)
#
# Epoch 11, Iteration 10, loss = 1.2295
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 129 / 306 correct (42.16)
#
# Epoch 11, Iteration 11, loss = 1.2205
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 122 / 306 correct (39.87)
#
# Epoch 11, Iteration 12, loss = 1.1675
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 123 / 306 correct (40.20)
#
# Epoch 11, Iteration 13, loss = 1.1321
# Checking accuracy on TRAIN set
# Got 36 / 64 correct (56.25)
# Checking accuracy on VAL set
# Got 129 / 306 correct (42.16)
#
# Epoch 11, Iteration 14, loss = 1.2004
# Checking accuracy on TRAIN set
# Got 25 / 64 correct (39.06)
# Checking accuracy on VAL set
# Got 134 / 306 correct (43.79)
#
# Epoch 11, Iteration 15, loss = 1.1388
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 140 / 306 correct (45.75)
#
# Epoch 11, Iteration 16, loss = 1.3299
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 139 / 306 correct (45.42)
#
# Epoch 11, Iteration 17, loss = 1.2622
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 142 / 306 correct (46.41)
#
# Epoch 11, Iteration 18, loss = 1.1453
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 145 / 306 correct (47.39)
#
# Epoch 11, Iteration 19, loss = 1.1412
# Checking accuracy on TRAIN set
# Got 3 / 8 correct (37.50)
# Checking accuracy on VAL set
# Got 143 / 306 correct (46.73)
#
# Checking accuracy on VAL set
# Got 143 / 306 correct (46.73)
# Checking accuracy on TRAIN set
# Got 537 / 1224 correct (43.87)
# Epoch 12, Iteration 0, loss = 1.2742
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 135 / 306 correct (44.12)
#
# Epoch 12, Iteration 1, loss = 1.1768
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 130 / 306 correct (42.48)
#
# Epoch 12, Iteration 2, loss = 1.2005
# Checking accuracy on TRAIN set
# Got 26 / 64 correct (40.62)
# Checking accuracy on VAL set
# Got 123 / 306 correct (40.20)
#
# Epoch 12, Iteration 3, loss = 1.2222
# Checking accuracy on TRAIN set
# Got 26 / 64 correct (40.62)
# Checking accuracy on VAL set
# Got 124 / 306 correct (40.52)
#
# Epoch 12, Iteration 4, loss = 1.1971
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 125 / 306 correct (40.85)
#
# Epoch 12, Iteration 5, loss = 1.2374
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 133 / 306 correct (43.46)
#
# Epoch 12, Iteration 6, loss = 1.2326
# Checking accuracy on TRAIN set
# Got 25 / 64 correct (39.06)
# Checking accuracy on VAL set
# Got 131 / 306 correct (42.81)
#
# Epoch 12, Iteration 7, loss = 1.2784
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 133 / 306 correct (43.46)
#
# Epoch 12, Iteration 8, loss = 1.1632
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 132 / 306 correct (43.14)
#
# Epoch 12, Iteration 9, loss = 1.2081
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 138 / 306 correct (45.10)
#
# Epoch 12, Iteration 10, loss = 1.1117
# Checking accuracy on TRAIN set
# Got 36 / 64 correct (56.25)
# Checking accuracy on VAL set
# Got 144 / 306 correct (47.06)
#
# Epoch 12, Iteration 11, loss = 1.1432
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 146 / 306 correct (47.71)
#
# Epoch 12, Iteration 12, loss = 1.2195
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 147 / 306 correct (48.04)
#
# Epoch 12, Iteration 13, loss = 1.2447
# Checking accuracy on TRAIN set
# Got 21 / 64 correct (32.81)
# Checking accuracy on VAL set
# Got 142 / 306 correct (46.41)
#
# Epoch 12, Iteration 14, loss = 1.1611
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 138 / 306 correct (45.10)
#
# Epoch 12, Iteration 15, loss = 1.1907
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 137 / 306 correct (44.77)
#
# Epoch 12, Iteration 16, loss = 1.1546
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 129 / 306 correct (42.16)
#
# Epoch 12, Iteration 17, loss = 1.2779
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 130 / 306 correct (42.48)
#
# Epoch 12, Iteration 18, loss = 1.1672
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 139 / 306 correct (45.42)
#
# Epoch 12, Iteration 19, loss = 1.2146
# Checking accuracy on TRAIN set
# Got 4 / 8 correct (50.00)
# Checking accuracy on VAL set
# Got 139 / 306 correct (45.42)
#
# Checking accuracy on VAL set
# Got 139 / 306 correct (45.42)
# Checking accuracy on TRAIN set
# Got 562 / 1224 correct (45.92)
# Epoch 13, Iteration 0, loss = 1.1323
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 137 / 306 correct (44.77)
#
# Epoch 13, Iteration 1, loss = 1.0909
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 136 / 306 correct (44.44)
#
# Epoch 13, Iteration 2, loss = 1.2295
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 133 / 306 correct (43.46)
#
# Epoch 13, Iteration 3, loss = 1.2406
# Checking accuracy on TRAIN set
# Got 22 / 64 correct (34.38)
# Checking accuracy on VAL set
# Got 134 / 306 correct (43.79)
#
# Epoch 13, Iteration 4, loss = 1.1245
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 139 / 306 correct (45.42)
#
# Epoch 13, Iteration 5, loss = 1.2310
# Checking accuracy on TRAIN set
# Got 26 / 64 correct (40.62)
# Checking accuracy on VAL set
# Got 142 / 306 correct (46.41)
#
# Epoch 13, Iteration 6, loss = 1.1851
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 144 / 306 correct (47.06)
#
# Epoch 13, Iteration 7, loss = 1.0954
# Checking accuracy on TRAIN set
# Got 36 / 64 correct (56.25)
# Checking accuracy on VAL set
# Got 143 / 306 correct (46.73)
#
# Epoch 13, Iteration 8, loss = 1.2849
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 134 / 306 correct (43.79)
#
# Epoch 13, Iteration 9, loss = 1.2125
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 133 / 306 correct (43.46)
#
# Epoch 13, Iteration 10, loss = 1.1349
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 125 / 306 correct (40.85)
#
# Epoch 13, Iteration 11, loss = 1.2587
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 126 / 306 correct (41.18)
#
# Epoch 13, Iteration 12, loss = 1.1313
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 125 / 306 correct (40.85)
#
# Epoch 13, Iteration 13, loss = 1.2316
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 131 / 306 correct (42.81)
#
# Epoch 13, Iteration 14, loss = 1.1660
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 136 / 306 correct (44.44)
#
# Epoch 13, Iteration 15, loss = 1.2195
# Checking accuracy on TRAIN set
# Got 25 / 64 correct (39.06)
# Checking accuracy on VAL set
# Got 132 / 306 correct (43.14)
#
# Epoch 13, Iteration 16, loss = 1.1994
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 137 / 306 correct (44.77)
#
# Epoch 13, Iteration 17, loss = 1.3116
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 134 / 306 correct (43.79)
#
# Epoch 13, Iteration 18, loss = 1.2084
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 136 / 306 correct (44.44)
#
# Epoch 13, Iteration 19, loss = 1.3101
# Checking accuracy on TRAIN set
# Got 4 / 8 correct (50.00)
# Checking accuracy on VAL set
# Got 129 / 306 correct (42.16)
#
# Checking accuracy on VAL set
# Got 129 / 306 correct (42.16)
# Checking accuracy on TRAIN set
# Got 581 / 1224 correct (47.47)
# Epoch 14, Iteration 0, loss = 1.1934
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 131 / 306 correct (42.81)
#
# Epoch 14, Iteration 1, loss = 1.2518
# Checking accuracy on TRAIN set
# Got 21 / 64 correct (32.81)
# Checking accuracy on VAL set
# Got 127 / 306 correct (41.50)
#
# Epoch 14, Iteration 2, loss = 1.1751
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 131 / 306 correct (42.81)
#
# Epoch 14, Iteration 3, loss = 1.1990
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 134 / 306 correct (43.79)
#
# Epoch 14, Iteration 4, loss = 1.1885
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 137 / 306 correct (44.77)
#
# Epoch 14, Iteration 5, loss = 1.2832
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 140 / 306 correct (45.75)
#
# Epoch 14, Iteration 6, loss = 1.2405
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 141 / 306 correct (46.08)
#
# Epoch 14, Iteration 7, loss = 1.2193
# Checking accuracy on TRAIN set
# Got 22 / 64 correct (34.38)
# Checking accuracy on VAL set
# Got 135 / 306 correct (44.12)
#
# Epoch 14, Iteration 8, loss = 1.1502
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 135 / 306 correct (44.12)
#
# Epoch 14, Iteration 9, loss = 1.1076
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 136 / 306 correct (44.44)
#
# Epoch 14, Iteration 10, loss = 1.0920
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 139 / 306 correct (45.42)
#
# Epoch 14, Iteration 11, loss = 1.0822
# Checking accuracy on TRAIN set
# Got 36 / 64 correct (56.25)
# Checking accuracy on VAL set
# Got 142 / 306 correct (46.41)
#
# Epoch 14, Iteration 12, loss = 1.2357
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 139 / 306 correct (45.42)
#
# Epoch 14, Iteration 13, loss = 1.2122
# Checking accuracy on TRAIN set
# Got 27 / 64 correct (42.19)
# Checking accuracy on VAL set
# Got 132 / 306 correct (43.14)
#
# Epoch 14, Iteration 14, loss = 1.1678
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 129 / 306 correct (42.16)
#
# Epoch 14, Iteration 15, loss = 1.2065
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 130 / 306 correct (42.48)
#
# Epoch 14, Iteration 16, loss = 1.2522
# Checking accuracy on TRAIN set
# Got 29 / 64 correct (45.31)
# Checking accuracy on VAL set
# Got 131 / 306 correct (42.81)
#
# Epoch 14, Iteration 17, loss = 1.2120
# ...
# Got 134 / 306 correct (43.79)
#
# Epoch 45, Iteration 2, loss = 0.9336
# Checking accuracy on TRAIN set
# Got 44 / 64 correct (68.75)
# Checking accuracy on VAL set
# Got 134 / 306 correct (43.79)
#
# Epoch 45, Iteration 3, loss = 0.9521
# Checking accuracy on TRAIN set
# Got 38 / 64 correct (59.38)
# Checking accuracy on VAL set
# Got 139 / 306 correct (45.42)
#
# Epoch 45, Iteration 4, loss = 0.9351
# Checking accuracy on TRAIN set
# Got 38 / 64 correct (59.38)
# Checking accuracy on VAL set
# Got 144 / 306 correct (47.06)
#
# Epoch 45, Iteration 5, loss = 0.8924
# Checking accuracy on TRAIN set
# Got 46 / 64 correct (71.88)
# Checking accuracy on VAL set
# Got 148 / 306 correct (48.37)
#
# Epoch 45, Iteration 6, loss = 0.8792
# Checking accuracy on TRAIN set
# Got 43 / 64 correct (67.19)
# Checking accuracy on VAL set
# Got 146 / 306 correct (47.71)
#
# Epoch 45, Iteration 7, loss = 1.0425
# Checking accuracy on TRAIN set
# Got 38 / 64 correct (59.38)
# Checking accuracy on VAL set
# Got 147 / 306 correct (48.04)
#
# Epoch 45, Iteration 8, loss = 1.1117
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 150 / 306 correct (49.02)
#
# Epoch 45, Iteration 9, loss = 0.9986
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 148 / 306 correct (48.37)
#
# Epoch 45, Iteration 10, loss = 0.9157
# Checking accuracy on TRAIN set
# Got 39 / 64 correct (60.94)
# Checking accuracy on VAL set
# Got 153 / 306 correct (50.00)
#
# Epoch 45, Iteration 11, loss = 1.0632
# Checking accuracy on TRAIN set
# Got 38 / 64 correct (59.38)
# Checking accuracy on VAL set
# Got 151 / 306 correct (49.35)
#
# Epoch 45, Iteration 12, loss = 0.9978
# Checking accuracy on TRAIN set
# Got 36 / 64 correct (56.25)
# Checking accuracy on VAL set
# Got 145 / 306 correct (47.39)
#
# Epoch 45, Iteration 13, loss = 0.8863
# Checking accuracy on TRAIN set
# Got 42 / 64 correct (65.62)
# Checking accuracy on VAL set
# Got 143 / 306 correct (46.73)
#
# Epoch 45, Iteration 14, loss = 0.7968
# Checking accuracy on TRAIN set
# Got 47 / 64 correct (73.44)
# Checking accuracy on VAL set
# Got 142 / 306 correct (46.41)
#
# Epoch 45, Iteration 15, loss = 0.9739
# Checking accuracy on TRAIN set
# Got 40 / 64 correct (62.50)
# Checking accuracy on VAL set
# Got 141 / 306 correct (46.08)
#
# Epoch 45, Iteration 16, loss = 1.0188
# Checking accuracy on TRAIN set
# Got 36 / 64 correct (56.25)
# Checking accuracy on VAL set
# Got 138 / 306 correct (45.10)
#
# Epoch 45, Iteration 17, loss = 1.1200
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 129 / 306 correct (42.16)
#
# Epoch 45, Iteration 18, loss = 1.0739
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 132 / 306 correct (43.14)
#
# Epoch 45, Iteration 19, loss = 0.7225
# Checking accuracy on TRAIN set
# Got 8 / 8 correct (100.00)
# Checking accuracy on VAL set
# Got 146 / 306 correct (47.71)
#
# Checking accuracy on VAL set
# Got 146 / 306 correct (47.71)
# Checking accuracy on TRAIN set
# Got 713 / 1224 correct (58.25)
# Epoch 46, Iteration 0, loss = 0.9486
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 151 / 306 correct (49.35)
#
# Epoch 46, Iteration 1, loss = 0.9710
# Checking accuracy on TRAIN set
# Got 36 / 64 correct (56.25)
# Checking accuracy on VAL set
# Got 149 / 306 correct (48.69)
#
# Epoch 46, Iteration 2, loss = 1.0475
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 146 / 306 correct (47.71)
#
# Epoch 46, Iteration 3, loss = 0.9580
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 151 / 306 correct (49.35)
#
# Epoch 46, Iteration 4, loss = 0.8884
# Checking accuracy on TRAIN set
# Got 38 / 64 correct (59.38)
# Checking accuracy on VAL set
# Got 141 / 306 correct (46.08)
#
# Epoch 46, Iteration 5, loss = 0.8040
# Checking accuracy on TRAIN set
# Got 42 / 64 correct (65.62)
# Checking accuracy on VAL set
# Got 139 / 306 correct (45.42)
#
# Epoch 46, Iteration 6, loss = 1.0055
# Checking accuracy on TRAIN set
# Got 40 / 64 correct (62.50)
# Checking accuracy on VAL set
# Got 137 / 306 correct (44.77)
#
# Epoch 46, Iteration 7, loss = 1.0807
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 137 / 306 correct (44.77)
#
# Epoch 46, Iteration 8, loss = 0.8295
# Checking accuracy on TRAIN set
# Got 47 / 64 correct (73.44)
# Checking accuracy on VAL set
# Got 141 / 306 correct (46.08)
#
# Epoch 46, Iteration 9, loss = 1.0967
# Checking accuracy on TRAIN set
# Got 35 / 64 correct (54.69)
# Checking accuracy on VAL set
# Got 150 / 306 correct (49.02)
#
# Epoch 46, Iteration 10, loss = 0.8660
# Checking accuracy on TRAIN set
# Got 42 / 64 correct (65.62)
# Checking accuracy on VAL set
# Got 153 / 306 correct (50.00)
#
# Epoch 46, Iteration 11, loss = 1.1878
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 154 / 306 correct (50.33)
#
# Epoch 46, Iteration 12, loss = 1.0446
# Checking accuracy on TRAIN set
# Got 39 / 64 correct (60.94)
# Checking accuracy on VAL set
# Got 149 / 306 correct (48.69)
#
# Epoch 46, Iteration 13, loss = 1.0433
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 140 / 306 correct (45.75)
#
# Epoch 46, Iteration 14, loss = 1.0987
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 144 / 306 correct (47.06)
#
# Epoch 46, Iteration 15, loss = 0.9667
# Checking accuracy on TRAIN set
# Got 33 / 64 correct (51.56)
# Checking accuracy on VAL set
# Got 140 / 306 correct (45.75)
#
# Epoch 46, Iteration 16, loss = 0.8818
# Checking accuracy on TRAIN set
# Got 40 / 64 correct (62.50)
# Checking accuracy on VAL set
# Got 134 / 306 correct (43.79)
#
# Epoch 46, Iteration 17, loss = 1.0712
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 136 / 306 correct (44.44)
#
# Epoch 46, Iteration 18, loss = 0.9861
# Checking accuracy on TRAIN set
# Got 42 / 64 correct (65.62)
# Checking accuracy on VAL set
# Got 131 / 306 correct (42.81)
#
# Epoch 46, Iteration 19, loss = 0.9992
# Checking accuracy on TRAIN set
# Got 4 / 8 correct (50.00)
# Checking accuracy on VAL set
# Got 150 / 306 correct (49.02)
#
# Checking accuracy on VAL set
# Got 150 / 306 correct (49.02)
# Checking accuracy on TRAIN set
# Got 758 / 1224 correct (61.93)
# Epoch 47, Iteration 0, loss = 0.8761
# Checking accuracy on TRAIN set
# Got 44 / 64 correct (68.75)
# Checking accuracy on VAL set
# Got 144 / 306 correct (47.06)
#
# Epoch 47, Iteration 1, loss = 1.0250
# Checking accuracy on TRAIN set
# Got 38 / 64 correct (59.38)
# Checking accuracy on VAL set
# Got 151 / 306 correct (49.35)
#
# Epoch 47, Iteration 2, loss = 0.9482
# Checking accuracy on TRAIN set
# Got 44 / 64 correct (68.75)
# Checking accuracy on VAL set
# Got 156 / 306 correct (50.98)
#
# Epoch 47, Iteration 3, loss = 1.0831
# Checking accuracy on TRAIN set
# Got 40 / 64 correct (62.50)
# Checking accuracy on VAL set
# Got 151 / 306 correct (49.35)
#
# Epoch 47, Iteration 4, loss = 0.9524
# Checking accuracy on TRAIN set
# Got 41 / 64 correct (64.06)
# Checking accuracy on VAL set
# Got 154 / 306 correct (50.33)
#
# Epoch 47, Iteration 5, loss = 0.9272
# Checking accuracy on TRAIN set
# Got 39 / 64 correct (60.94)
# Checking accuracy on VAL set
# Got 142 / 306 correct (46.41)
#
# Epoch 47, Iteration 6, loss = 0.9202
# Checking accuracy on TRAIN set
# Got 36 / 64 correct (56.25)
# Checking accuracy on VAL set
# Got 141 / 306 correct (46.08)
#
# Epoch 47, Iteration 7, loss = 0.9900
# Checking accuracy on TRAIN set
# Got 39 / 64 correct (60.94)
# Checking accuracy on VAL set
# Got 140 / 306 correct (45.75)
#
# Epoch 47, Iteration 8, loss = 0.8882
# Checking accuracy on TRAIN set
# Got 41 / 64 correct (64.06)
# Checking accuracy on VAL set
# Got 140 / 306 correct (45.75)
#
# Epoch 47, Iteration 9, loss = 0.9089
# Checking accuracy on TRAIN set
# Got 41 / 64 correct (64.06)
# Checking accuracy on VAL set
# Got 152 / 306 correct (49.67)
#
# Epoch 47, Iteration 10, loss = 0.7792
# Checking accuracy on TRAIN set
# Got 42 / 64 correct (65.62)
# Checking accuracy on VAL set
# Got 154 / 306 correct (50.33)
#
# Epoch 47, Iteration 11, loss = 1.2141
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 151 / 306 correct (49.35)
#
# Epoch 47, Iteration 12, loss = 0.8948
# Checking accuracy on TRAIN set
# Got 42 / 64 correct (65.62)
# Checking accuracy on VAL set
# Got 141 / 306 correct (46.08)
#
# Epoch 47, Iteration 13, loss = 0.9976
# Checking accuracy on TRAIN set
# Got 38 / 64 correct (59.38)
# Checking accuracy on VAL set
# Got 138 / 306 correct (45.10)
#
# Epoch 47, Iteration 14, loss = 0.9652
# Checking accuracy on TRAIN set
# Got 38 / 64 correct (59.38)
# Checking accuracy on VAL set
# Got 133 / 306 correct (43.46)
#
# Epoch 47, Iteration 15, loss = 1.0707
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 133 / 306 correct (43.46)
#
# Epoch 47, Iteration 16, loss = 0.8721
# Checking accuracy on TRAIN set
# Got 46 / 64 correct (71.88)
# Checking accuracy on VAL set
# Got 134 / 306 correct (43.79)
#
# Epoch 47, Iteration 17, loss = 1.0740
# Checking accuracy on TRAIN set
# Got 36 / 64 correct (56.25)
# Checking accuracy on VAL set
# Got 140 / 306 correct (45.75)
#
# Epoch 47, Iteration 18, loss = 0.8793
# Checking accuracy on TRAIN set
# Got 45 / 64 correct (70.31)
# Checking accuracy on VAL set
# Got 142 / 306 correct (46.41)
#
# Epoch 47, Iteration 19, loss = 0.7446
# Checking accuracy on TRAIN set
# Got 8 / 8 correct (100.00)
# Checking accuracy on VAL set
# Got 152 / 306 correct (49.67)
#
# Checking accuracy on VAL set
# Got 152 / 306 correct (49.67)
# Checking accuracy on TRAIN set
# Got 701 / 1224 correct (57.27)
# Epoch 48, Iteration 0, loss = 0.9715
# Checking accuracy on TRAIN set
# Got 31 / 64 correct (48.44)
# Checking accuracy on VAL set
# Got 147 / 306 correct (48.04)
#
# Epoch 48, Iteration 1, loss = 0.9929
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 148 / 306 correct (48.37)
#
# Epoch 48, Iteration 2, loss = 0.9816
# Checking accuracy on TRAIN set
# Got 35 / 64 correct (54.69)
# Checking accuracy on VAL set
# Got 156 / 306 correct (50.98)
#
# Epoch 48, Iteration 3, loss = 1.2399
# Checking accuracy on TRAIN set
# Got 30 / 64 correct (46.88)
# Checking accuracy on VAL set
# Got 154 / 306 correct (50.33)
#
# Epoch 48, Iteration 4, loss = 1.0796
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 163 / 306 correct (53.27)
#
# Epoch 48, Iteration 5, loss = 1.0517
# Checking accuracy on TRAIN set
# Got 41 / 64 correct (64.06)
# Checking accuracy on VAL set
# Got 150 / 306 correct (49.02)
#
# Epoch 48, Iteration 6, loss = 0.9914
# Checking accuracy on TRAIN set
# Got 34 / 64 correct (53.12)
# Checking accuracy on VAL set
# Got 135 / 306 correct (44.12)
#
# Epoch 48, Iteration 7, loss = 0.9047
# Checking accuracy on TRAIN set
# Got 43 / 64 correct (67.19)
# Checking accuracy on VAL set
# Got 136 / 306 correct (44.44)
#
# Epoch 48, Iteration 8, loss = 1.2813
# Checking accuracy on TRAIN set
# Got 24 / 64 correct (37.50)
# Checking accuracy on VAL set
# Got 136 / 306 correct (44.44)
#
# Epoch 48, Iteration 9, loss = 0.9605
# Checking accuracy on TRAIN set
# Got 40 / 64 correct (62.50)
# Checking accuracy on VAL set
# Got 138 / 306 correct (45.10)
#
# Epoch 48, Iteration 10, loss = 0.9826
# Checking accuracy on TRAIN set
# Got 37 / 64 correct (57.81)
# Checking accuracy on VAL set
# Got 144 / 306 correct (47.06)
#
# Epoch 48, Iteration 11, loss = 0.9738
# Checking accuracy on TRAIN set
# Got 40 / 64 correct (62.50)
# Checking accuracy on VAL set
# Got 145 / 306 correct (47.39)
#
# Epoch 48, Iteration 12, loss = 0.9495
# Checking accuracy on TRAIN set
# Got 45 / 64 correct (70.31)
# Checking accuracy on VAL set
# Got 150 / 306 correct (49.02)
#
# Epoch 48, Iteration 13, loss = 1.0782
# Checking accuracy on TRAIN set
# Got 36 / 64 correct (56.25)
# Checking accuracy on VAL set
# Got 158 / 306 correct (51.63)
#
# Epoch 48, Iteration 14, loss = 1.0586
# Checking accuracy on TRAIN set
# Got 36 / 64 correct (56.25)
# Checking accuracy on VAL set
# Got 162 / 306 correct (52.94)
#
# Epoch 48, Iteration 15, loss = 0.8057
# Checking accuracy on TRAIN set
# Got 44 / 64 correct (68.75)
# Checking accuracy on VAL set
# Got 164 / 306 correct (53.59)
#
# Epoch 48, Iteration 16, loss = 0.9039
# Checking accuracy on TRAIN set
# Got 41 / 64 correct (64.06)
# Checking accuracy on VAL set
# Got 156 / 306 correct (50.98)
#
# Epoch 48, Iteration 17, loss = 0.9232
# Checking accuracy on TRAIN set
# Got 40 / 64 correct (62.50)
# Checking accuracy on VAL set
# Got 143 / 306 correct (46.73)
#
# Epoch 48, Iteration 18, loss = 0.9820
# Checking accuracy on TRAIN set
# Got 32 / 64 correct (50.00)
# Checking accuracy on VAL set
# Got 132 / 306 correct (43.14)
#
# Epoch 48, Iteration 19, loss = 1.2666
# Checking accuracy on TRAIN set
# Got 4 / 8 correct (50.00)
# Checking accuracy on VAL set
# Got 139 / 306 correct (45.42)
#
# Checking accuracy on VAL set
# Got 139 / 306 correct (45.42)
# Checking accuracy on TRAIN set
# Got 753 / 1224 correct (61.52)
# Epoch 49, Iteration 0, loss = 0.9262
# Checking accuracy on TRAIN set
# Got 38 / 64 correct (59.38)
# Checking accuracy on VAL set
# Got 135 / 306 correct (44.12)
#
# Epoch 49, Iteration 1, loss = 0.9158
# Checking accuracy on TRAIN set
# Got 39 / 64 correct (60.94)
# Checking accuracy on VAL set
# Got 136 / 306 correct (44.44)
#
# Epoch 49, Iteration 2, loss = 0.9428
# Checking accuracy on TRAIN set
# Got 40 / 64 correct (62.50)
# Checking accuracy on VAL set
# Got 136 / 306 correct (44.44)
#
# Epoch 49, Iteration 3, loss = 1.0260
# Checking accuracy on TRAIN set
# Got 35 / 64 correct (54.69)
# Checking accuracy on VAL set
# Got 136 / 306 correct (44.44)
#
# Epoch 49, Iteration 4, loss = 1.1471
# Checking accuracy on TRAIN set
# Got 28 / 64 correct (43.75)
# Checking accuracy on VAL set
# Got 138 / 306 correct (45.10)
#
# Epoch 49, Iteration 5, loss = 0.9080
# Checking accuracy on TRAIN set
# Got 42 / 64 correct (65.62)
# Checking accuracy on VAL set
# Got 139 / 306 correct (45.42)
#
# Epoch 49, Iteration 6, loss = 0.8346
# Checking accuracy on TRAIN set
# Got 44 / 64 correct (68.75)
# Checking accuracy on VAL set
# Got 137 / 306 correct (44.77)
#
# Epoch 49, Iteration 7, loss = 0.8659
# Checking accuracy on TRAIN set
# Got 45 / 64 correct (70.31)
# Checking accuracy on VAL set
# Got 134 / 306 correct (43.79)
#
# Epoch 49, Iteration 8, loss = 0.9646
# Checking accuracy on TRAIN set
# Got 38 / 64 correct (59.38)
# Checking accuracy on VAL set
# Got 129 / 306 correct (42.16)
#
# Epoch 49, Iteration 9, loss = 0.9598
# Checking accuracy on TRAIN set
# Got 38 / 64 correct (59.38)
# Checking accuracy on VAL set
# Got 133 / 306 correct (43.46)
#
# Epoch 49, Iteration 10, loss = 0.9421
# Checking accuracy on TRAIN set
# Got 38 / 64 correct (59.38)
# Checking accuracy on VAL set
# Got 136 / 306 correct (44.44)
#
# Epoch 49, Iteration 11, loss = 0.9550
# Checking accuracy on TRAIN set
# Got 38 / 64 correct (59.38)
# Checking accuracy on VAL set
# Got 139 / 306 correct (45.42)
#
# Epoch 49, Iteration 12, loss = 1.0011
# Checking accuracy on TRAIN set
# Got 38 / 64 correct (59.38)
# Checking accuracy on VAL set
# Got 145 / 306 correct (47.39)
#
# Epoch 49, Iteration 13, loss = 0.9067
# Checking accuracy on TRAIN set
# Got 44 / 64 correct (68.75)
# Checking accuracy on VAL set
# Got 152 / 306 correct (49.67)
#
# Epoch 49, Iteration 14, loss = 1.0810
# Checking accuracy on TRAIN set
# Got 35 / 64 correct (54.69)
# Checking accuracy on VAL set
# Got 158 / 306 correct (51.63)
#
# Epoch 49, Iteration 15, loss = 0.9394
# Checking accuracy on TRAIN set
# Got 35 / 64 correct (54.69)
# Checking accuracy on VAL set
# Got 161 / 306 correct (52.61)
#
# Epoch 49, Iteration 16, loss = 0.9642
# Checking accuracy on TRAIN set
# Got 36 / 64 correct (56.25)
# Checking accuracy on VAL set
# Got 163 / 306 correct (53.27)
#
# Epoch 49, Iteration 17, loss = 0.9620
# Checking accuracy on TRAIN set
# Got 38 / 64 correct (59.38)
# Checking accuracy on VAL set
# Got 162 / 306 correct (52.94)
#
# Epoch 49, Iteration 18, loss = 0.9572
# Checking accuracy on TRAIN set
# Got 41 / 64 correct (64.06)
# Checking accuracy on VAL set
# Got 158 / 306 correct (51.63)
#
# Epoch 49, Iteration 19, loss = 0.5713
# Checking accuracy on TRAIN set
# Got 7 / 8 correct (87.50)
# Checking accuracy on VAL set
# Got 142 / 306 correct (46.41)
#
# Checking accuracy on VAL set
# Got 142 / 306 correct (46.41)
# Checking accuracy on TRAIN set
# Got 752 / 1224 correct (61.44)
# DONE TRAINING

# %%
torch.save(best_model, "best_model_RNN_without_noise_cleanup_whole_time_scale_50_epochs")
torch.save(model, "model_RNN_without_noise_cleanup_whole_time_scale_50_epochs")

# %%
print("DONE")
per_epoch_train_accuracy_list
# Out:
# DONE
# [0.39869281045751637,
#  0.4068627450980392,
#  0.39869281045751637,
#  0.39869281045751637,
#  0.39869281045751637,
#  0.39869281045751637,
#  0.39869281045751637,
#  0.434640522875817,
#  0.4019607843137255,
#  0.43790849673202614,
#  0.45751633986928103,
#  0.4387254901960784,
#  0.4591503267973856,
#  0.47467320261437906,
#  0.44689542483660133,
#  0.45751633986928103,
#  0.4673202614379085,
#  0.47467320261437906,
#  0.47875816993464054,
#  0.4681372549019608,
#  0.49019607843137253,
#  0.4673202614379085,
#  0.4395424836601307,
#  0.4714052287581699,
#  0.477124183006536,
#  0.4877450980392157,
#  0.5073529411764706,
#  0.5106209150326797,
#  0.5016339869281046,
#  0.5130718954248366,
#  0.5171568627450981,
#  0.47467320261437906,
#  0.4852941176470588,
#  0.5098039215686274,
#  0.5236928104575164,
#  0.5433006535947712,
#  0.5318627450980392,
#  0.5400326797385621,
#  0.5179738562091504,
#  0.5588235294117647,
#  0.5776143790849673,
#  0.5743464052287581,
#  0.5784313725490197,
#  0.579248366013072,
#  0.6053921568627451,
#  0.5825163398692811,
#  0.619281045751634,
#  0.5727124183006536,
#  0.6151960784313726,
#  0.6143790849673203]

# %%
##PLOT LOSS, TRAIN ACCURACY, TEST ACCURACY
import matplotlib.pyplot as plt
max_train_accuracy = np.repeat(np.max(np.array([train_accuracy_list])),   len(train_accuracy_list))

max_test_accuracy = np.repeat(np.max(np.array([test_accuracy_list])),   len(test_accuracy_list))

max_p_e_train_accuracy = np.repeat(np.max(np.array([per_epoch_train_accuracy_list])),   len(per_epoch_train_accuracy_list))

max_p_e_test_accuracy = np.repeat(np.max(np.array([per_epoch_test_accuracy_list])),   len(per_epoch_test_accuracy_list))

# plot the loss history
plt.subplot()
plt.plot(loss_list)
plt.xlabel('iteration')
plt.ylabel('training loss')
plt.title('Training Loss history')
plt.legend()
plt.show()

plt.subplot()
plt.plot(train_accuracy_list, label='train')
plt.plot(test_accuracy_list, label='val')
plt.plot(max_train_accuracy, label='max train acc')
plt.plot(max_test_accuracy, label='max val acc')
plt.title('Classification accuracy history')
plt.xlabel('Iteration')
plt.ylabel('Classification accuracy')
plt.legend()
plt.show()

plt.subplot()
plt.plot(per_epoch_train_accuracy_list, label='train')
plt.plot(per_epoch_test_accuracy_list, label='val')
plt.plot(max_p_e_train_accuracy, label='max train acc')
plt.plot(max_p_e_test_accuracy, label='max val acc')
plt.title('Per Epoch Classification accuracy history')
plt.xlabel('Epoch')
plt.ylabel('Classification accuracy')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
from sklearn.metrics import confusion_matrix
#from resources.plotcm import plot_confusion_matrix
import itertools
import numpy as np
import matplotlib.pyplot as plt

def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion matrix', cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)
    #plt.figure(figsize=(10,10))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt), horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
def check_train_accuracy1(loader, model, for_confusion_matrix=0):
    #if loader.dataset.train:
    #    print('Checking accuracy on validation set')
    #else:
    #    print('Checking accuracy on test set')
    print('Checking accuracy on TRAIN set')
    num_correct = 0
    num_samples = 0
    model.eval()  # set model to evaluation mode
    true_label_list = []
    predicted_label_list = []
    with torch.no_grad():
        for x, y in loader:
            true_label_list.append(y.cpu().data.numpy())
            x = x.to(device=device, dtype=dtype)  # move to device, e.g. GPU
            y = y.to(device=device, dtype=torch.long)
            #pdb.set_trace()
            #y = torch.stack(y) #.to(device=device)
            #y = y.reshape((x.shape[0]))
            scores = model(x)
            _, preds = scores.max(1)
            predicted_label_list.append(preds.cpu().data.numpy())            
            num_correct += (preds == y).sum()
            num_samples += preds.size(0)
        acc = float(num_correct) / num_samples
        print('Got %d / %d correct (%.2f)' % (num_correct, num_samples, 100 * acc))
        if for_confusion_matrix == 1:
          return acc, true_label_list, predicted_label_list
        else:
          return acc

# %%
#best_model1 = torch.load("model2")
accuracy, true_label, predicted_label = check_train_accuracy1(loader_train, best_model, for_confusion_matrix=1)
true_label = np.concatenate(true_label, axis=None)
#print(true_label)

predicted_label = np.concatenate(predicted_label, axis=None)
#print(predicted_label)

emotion_dict = ('hap',
                'sad',
                'ang',
                'neu'
                )
cm = confusion_matrix(true_label, predicted_label)

#t_t = train_set_targets.cpu().data.numpy()
#predict = preds.cpu().data.numpy()
#t_t = 1 + t_t
#predict = 1 + predict

#for i in range(t_t.shape[0]):
#  print(t_t[i], predict[i])
#print(t_t)
#print(predict)
#print(cm)
plt.figure(figsize=(6,6))
plot_confusion_matrix(cm, emotion_dict)
# Out:
# Checking accuracy on TRAIN set
# /opt/conda/conda-bld/pytorch_1579022060824/work/aten/src/ATen/native/cudnn/RNN.cpp:1266: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /opt/conda/conda-bld/pytorch_1579022060824/work/aten/src/ATen/native/cudnn/RNN.cpp:1266: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /opt/conda/conda-bld/pytorch_1579022060824/work/aten/src/ATen/native/cudnn/RNN.cpp:1266: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /opt/conda/conda-bld/pytorch_1579022060824/work/aten/src/ATen/native/cudnn/RNN.cpp:1266: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /opt/conda/conda-bld/pytorch_1579022060824/work/aten/src/ATen/native/cudnn/RNN.cpp:1266: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /opt/conda/conda-bld/pytorch_1579022060824/work/aten/src/ATen/native/cudnn/RNN.cpp:1266: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /opt/conda/conda-bld/pytorch_1579022060824/work/aten/src/ATen/native/cudnn/RNN.cpp:1266: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /opt/conda/conda-bld/pytorch_1579022060824/work/aten/src/ATen/native/cudnn/RNN.cpp:1266: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /opt/conda/conda-bld/pytorch_1579022060824/work/aten/src/ATen/native/cudnn/RNN.cpp:1266: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /opt/conda/conda-bld/pytorch_1579022060824/work/aten/src/ATen/native/cudnn/RNN.cpp:1266: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /opt/conda/conda-bld/pytorch_1579022060824/work/aten/src/ATen/native/cudnn/RNN.cpp:1266: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /opt/conda/conda-bld/pytorch_1579022060824/work/aten/src/ATen/native/cudnn/RNN.cpp:1266: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /opt/conda/conda-bld/pytorch_1579022060824/work/aten/src/ATen/native/cudnn/RNN.cpp:1266: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /opt/conda/conda-bld/pytorch_1579022060824/work/aten/src/ATen/native/cudnn/RNN.cpp:1266: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /opt/conda/conda-bld/pytorch_1579022060824/work/aten/src/ATen/native/cudnn/RNN.cpp:1266: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /opt/conda/conda-bld/pytorch_1579022060824/work/aten/src/ATen/native/cudnn/RNN.cpp:1266: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /opt/conda/conda-bld/pytorch_1579022060824/work/aten/src/ATen/native/cudnn/RNN.cpp:1266: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /opt/conda/conda-bld/pytorch_1579022060824/work/aten/src/ATen/native/cudnn/RNN.cpp:1266: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /opt/conda/conda-bld/pytorch_1579022060824/work/aten/src/ATen/native/cudnn/RNN.cpp:1266: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /opt/conda/conda-bld/pytorch_1579022060824/work/aten/src/ATen/native/cudnn/RNN.cpp:1266: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# Got 739 / 1224 correct (60.38)
# Confusion matrix, without normalization
# [[ 40  67  43  71]
#  [  0 284   2  52]
#  [  6  27 176  46]
#  [ 16 137  18 239]]

# %%
#best_model1 = torch.load("model1")
accuracy, true_label, predicted_label = check_train_accuracy1(loader_val, best_model, for_confusion_matrix=1)
true_label = np.concatenate(true_label, axis=None)
#print(true_label)

predicted_label = np.concatenate(predicted_label, axis=None)
#print(predicted_label)


cm = confusion_matrix(true_label, predicted_label)

#t_t = train_set_targets.cpu().data.numpy()
#predict = preds.cpu().data.numpy()
#t_t = 1 + t_t
#predict = 1 + predict

#for i in range(t_t.shape[0]):
#  print(t_t[i], predict[i])
#print(t_t)
#print(predict)
#print(cm)
plt.figure(figsize=(6,6))
plot_confusion_matrix(cm, emotion_dict)
# Out:
# Checking accuracy on TRAIN set
# /opt/conda/conda-bld/pytorch_1579022060824/work/aten/src/ATen/native/cudnn/RNN.cpp:1266: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /opt/conda/conda-bld/pytorch_1579022060824/work/aten/src/ATen/native/cudnn/RNN.cpp:1266: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /opt/conda/conda-bld/pytorch_1579022060824/work/aten/src/ATen/native/cudnn/RNN.cpp:1266: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /opt/conda/conda-bld/pytorch_1579022060824/work/aten/src/ATen/native/cudnn/RNN.cpp:1266: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# /opt/conda/conda-bld/pytorch_1579022060824/work/aten/src/ATen/native/cudnn/RNN.cpp:1266: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
# Got 164 / 306 correct (53.59)
# Confusion matrix, without normalization
# [[ 5 11 13 13]
#  [ 1 44  4 19]
#  [ 4  8 65 22]
#  [ 6 20 21 50]]

# %%
accuracy, true_label, predicted_label = check_train_accuracy1(loader_train, model, for_confusion_matrix=1)
true_label = np.concatenate(true_label, axis=None)
#print(true_label)

predicted_label = np.concatenate(predicted_label, axis=None)
#print(predicted_label)

emotion_dict = ('hap',
                'sad',
                'ang',
                'neu'
                )
cm = confusion_matrix(true_label, predicted_label)

#t_t = train_set_targets.cpu().data.numpy()
#predict = preds.cpu().data.numpy()
#t_t = 1 + t_t
#predict = 1 + predict

#for i in range(t_t.shape[0]):
#  print(t_t[i], predict[i])
#print(t_t)
#print(predict)
#print(cm)
plt.figure(figsize=(10,6))
plot_confusion_matrix(cm, emotion_dict)
# Out:
# Checking accuracy on TRAIN set
# Got 752 / 1224 correct (61.44)
# Confusion matrix, without normalization
# [[ 50  59  52  60]
#  [  1 283   8  46]
#  [  8  16 199  32]
#  [ 27 133  30 220]]

# %%
#best_model1 = torch.load("model1")
accuracy, true_label, predicted_label = check_train_accuracy1(loader_val, model, for_confusion_matrix=1)
true_label = np.concatenate(true_label, axis=None)
#print(true_label)

predicted_label = np.concatenate(predicted_label, axis=None)
#print(predicted_label)


cm = confusion_matrix(true_label, predicted_label)

#t_t = train_set_targets.cpu().data.numpy()
#predict = preds.cpu().data.numpy()
#t_t = 1 + t_t
#predict = 1 + predict

#for i in range(t_t.shape[0]):
#  print(t_t[i], predict[i])
#print(t_t)
#print(predict)
#print(cm)
plt.figure(figsize=(6,10))
plot_confusion_matrix(cm, emotion_dict)
# Out:
# Checking accuracy on TRAIN set
# Got 142 / 306 correct (46.41)
# Confusion matrix, without normalization
# [[ 4  7 23  8]
#  [ 3 36 11 18]
#  [ 6  8 75 10]
#  [ 9 25 36 27]]
